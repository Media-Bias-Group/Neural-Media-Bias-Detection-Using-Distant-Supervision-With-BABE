# %% [markdown]
# # Features engineering

# %% [markdown]
# This script implements the features proposed in
#
# Spinde, T.; Rudnitckaia, L.; Mitrović, J.; Hamborg, F.; Granitzer, M.; Gipp, B. & Donnay, K.
# Automated identification of bias inducing words in news articles using linguistic and context-oriented features
# Information Processing & Management, Elsevier, 2021, 58, 102505

# %% [markdown]
# In this script, we:
# - pre-process the sentences,
# - create features,
# - prepare data for further ML training (e.g., one-hot encoding, etc.)
#
# Dictionaries needed to run the code (only biased lexicon is attached):
# - LIWC2015 dictionary (J. W. Pennebaker, R. L. Boyd, K. Jordan and K. Blackburn, "The Development and Psychometric Properties of LIWC2015," 2015.)
# - sentiment and subjectivity lexicon (T. Wilson, J. Wiebe and P. Hoffmann, "Recognizing Contextual Polarity in Phrase-Level Sentiment Analysis," in HLT/EMNLP, 2005. https://mpqa.cs.pitt.edu/lexicons/subj_lexicon/)
# - sentiment lexicon (M. Hu and B. Liu, "Mining and Summarizing Customer Reviews," in Proceedings of the ACM SIGKDD International Conference on Knowledge Discovery and Data Mining (KDD-2004), Seattle, Washington, 2004. https://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html)
# - assertive_verbs (Hooper, J. B. (1974). On assertive predicates. Bloomington: Indiana University Linguistics Club.)
# - factive_verbs (Hooper, J. B. (1974). On assertive predicates. Bloomington: Indiana University Linguistics Club.)
# - implicative_verbs (Karttunen, L. (1971). Implicative Verbs. Language, 47(2), 340-358. doi:10.2307/412084)
# - report_verbs (https://en.wiktionary.org/wiki/Category:English_reporting_verbs, https://www.ef.com/in/english-resources/english-grammar/reporting-verbs/, https://www.adelaide.edu.au/writingcentre/sites/default/files/docs/learningguide-verbsforreporting.pdf)
# - hyperbolic terms (A. Chakraborty, B. Paranjape, S. Kakar and N. Ganguly, "Stop Clickbait: Detecting and preventing clickbaits in online news media," 2016 IEEE/ACM International Conference on Advances in Social Networks Analysis and Mining (ASONAM), pp. 9-16, 2016.)
# - attitude markers (Hyland, K. (2005). Metadiscourse: Exploring Interaction in Writing.)
# - boosters (Hyland, K. (2005). Metadiscourse: Exploring Interaction in Writing.)
# - hedges (Hyland, K. (2005). Metadiscourse: Exploring Interaction in Writing.)
# - kill verbs (Greene, S., & Resnik, P. (2009). More than Words: Syntactic Packaging and Implicit Sentiment. HLT-NAACL.)
# - MRCP_concretness_ratings (MRC database: https://websites.psychology.uwa.edu.au/school/MRCDatabase/uwa_mrc.htm)
# - MRCP_Imagability_ratings (MRC database: https://websites.psychology.uwa.edu.au/school/MRCDatabase/uwa_mrc.htm)
# - bised_words_lexicon.xlsx

# %%
# data
import pandas as pd
import numpy as np
import csv

# misc
import os
import re
import time
import ast
import warnings
import math
import copy

# nlp
import spacy
import en_core_web_sm
nlp_spacy_core_web_lg = en_core_web_sm.load()
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('drive/MyDrive/media-bias-detection')

#dt = pd.read_excel('data/final_labels_SG1.xlsx')
dt = pd.read_excel('data/final_labels_SG2.xlsx')
dt.rename(columns={'text': 'sentence', 'biased_words': 'biased_words2'}, inplace=True)
dt = dt[dt['biased_words2'].isna()==False]
dt.reset_index(inplace=True)
dt = dt[['sentence',
         'outlet',
         'topic',
         'type',
         'biased_words2']]
dt["biased_words2"] = dt.biased_words2.apply(lambda s: list(ast.literal_eval(s)))

dt.head(3)
# Out:
# Mounted at /content/drive
#                                             sentence  ...                  biased_words2
# 0  "Orange Is the New Black" star Yael Stone is r...  ...                             []
# 1  "We have one beautiful law," Trump recently sa...  ...  [bizarre, characteristically]
# 2  ...immigrants as criminals and eugenics, all o...  ...   [criminals, fringe, extreme]
#
# [3 rows x 5 columns]

# %% [markdown]
# ## 1 Tokenization, POS tagging, lemmatization, syntactic dependencies, NER

# %% [markdown]
# Info on SpaCy objects:
# - Text: The original word text.
# - Lemma: The base form of the word.
# - POS: The simple UPOS part-of-speech tag.
# - Tag: The detailed part-of-speech tag.
# - Dep: Syntactic dependency, i.e. the relation between tokens.
# - Shape: The word shape – capitalization, punctuation, digits.
# - is alpha: Is the token an alpha character?
# - is stop: Is the token part of a stop list, i.e. the most common words of the language?

# %%
# run just once - adjust pipeline
# deactivate splitting to sentences. We have 1 sentence always, no need to introduce extra errors
def custom_sentencizer(doc):
    for i, token in enumerate(doc[:-2]):
        doc[i+1].is_sent_start = False
    return doc

nlp_spacy_core_web_lg.add_pipe(custom_sentencizer, before="tagger")

# %%
# tokenization 
dt["spacy_lg"] = dt["sentence"].apply(lambda x: nlp_spacy_core_web_lg(x))
dt["spacy_lg_dict"] = None # to be filled in the next section

# %% [markdown]
# ## 2 TF-IDF, dictionaries, bias lexicon

# %% [markdown]
# ### 2.1 Create TF-IDF matrix, upload dictionaries, assign TF-IDF and dictionaries labels to each word (except those dictionaries that include more than 1 token)

# %%
# calculate tf-idf matrix for corpus of articles
dt = dt.replace({np.nan: None})
# len(data_1sent[data_1sent['article'].isna()]) # mostly articles from usa today are lost
# for the articles that couldn't be scraped, use sentence 
dt['article'] = dt['sentence']
corpus_art = dt[['sentence','article']]
corpus_art.drop_duplicates(subset = ["article"], keep = 'first', inplace = True)
corpus_art = corpus_art.reset_index()
corpus_art = corpus_art.rename(columns={"sentence": "sentence_", "article": "article_", "index": "index_"})

corpus_art_list = list(corpus_art['article_'])


tfidf = TfidfVectorizer(token_pattern = r"(?u)\b\w+\b")
x_art = tfidf.fit_transform(corpus_art_list)

df_tfidf_art = pd.DataFrame(x_art.toarray(), columns=tfidf.get_feature_names())

corpus_art = pd.merge(corpus_art, df_tfidf_art, left_index=True, right_index=True, how='left')
df_tfidf_art_updated = pd.merge(dt['article'], corpus_art, left_on='article',
                                right_on='article_', how='left')

df_tfidf_art_updated.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                            article_x  index_  ... zuckerberg über
# 0  "Orange Is the New Black" star Yael Stone is r...       0  ...        0.0  0.0
# 1  "We have one beautiful law," Trump recently sa...       1  ...        0.0  0.0
# 2  ...immigrants as criminals and eugenics, all o...       2  ...        0.0  0.0
#
# [3 rows x 12681 columns]

# %%
# upload liwc2015 dictionary and codes
liwc2015 = pd.read_excel("data/bias_related_lexicons/LIWC2015.xlsx", sheet_name='lexica')
#                        converters={'codes':ast.literal_eval})
liwc2015_codes = pd.read_excel("data/bias_related_lexicons/LIWC2015.xlsx", sheet_name='psychological_codes')
liwc2015['codes_list'] = liwc2015[['c1', 'c2', 'c3', 'c4', 'c5',
                                   'c6', 'c7', 'c8', 'c9', 'c10']].values.tolist()
liwc2015['codes_list_clean'] = liwc2015.apply(lambda row: [int(x) for x in row['codes_list'] if math.isnan(x) == False],
                                              axis=1)
liwc2015 = liwc2015[['word','codes_list_clean']]
liwc2015 = liwc2015.rename(columns={"codes_list_clean": "codes"})

# %%
# sentiment and subjectivity lexicons
subjectivity_lexicon = pd.read_excel("data/bias_related_lexicons/subjectivity_lexicon.xlsx")
weak_subj = list(set(subjectivity_lexicon[subjectivity_lexicon['type']=='weaksubj']['word']))
strong_subj = list(set(subjectivity_lexicon[subjectivity_lexicon['type']=='strongsubj']['word']))
negative_wilson = list(set(subjectivity_lexicon[subjectivity_lexicon['priorpolarity']=='negative']['word']))
positive_wilson = list(set(subjectivity_lexicon[subjectivity_lexicon['priorpolarity']=='positive']['word']))

negative_bing = list(pd.read_excel("data/bias_related_lexicons/opinion_lexicon_english/negative-words.xlsx", header=None)[0])
positive_bing = list(pd.read_excel("data/bias_related_lexicons/opinion_lexicon_english/positive-words.xlsx", header=None)[0])

# concatenation of sentiment lexicons
positive_conc = list(set(positive_wilson + positive_bing))
negative_conc = list(set(negative_wilson + negative_bing))

print('positive: bing:',len(positive_bing),'wilson:',len(positive_wilson),'concatenated:',len(positive_conc))
print('negative: bing:',len(negative_bing),'wilson:',len(negative_wilson),'concatenated:',len(negative_conc))

both_conc = [value for value in negative_conc if value in positive_conc]
both_bing = [value for value in positive_bing if value in negative_bing]
both_wilson = [value for value in positive_wilson if value in negative_wilson]
print('overlap between concatenated positive and negative lists:', len(both_conc))
print("overlap between bing's positive and negative lists:", len(both_bing))
print("overlap between wilson's positive and negative lists:", len(both_wilson))
# what to do with overlap? maybe annotate them manually? or according to sentiwordnet (code in old.ipynb)
# Out:
# positive: bing: 2005 wilson: 2304 concatenated: 2757
# negative: bing: 4783 wilson: 4154 concatenated: 5112
# overlap between concatenated positive and negative lists: 36
# overlap between bing's positive and negative lists: 3
# overlap between wilson's positive and negative lists: 6

# %%
# other lexical features
assertive_verbs = list(pd.read_excel("data/bias_related_lexicons/assertive_verbs.xlsx", header=None)[0])
factive_verbs = list(pd.read_excel("data/bias_related_lexicons/factive_verbs.xlsx", header=None)[0])
implicative_verbs = list(pd.read_csv("data/bias_related_lexicons/implicative_verbs.csv", header=None)[1])
report_verbs1 = list(pd.read_excel("data/bias_related_lexicons/report_verbs.xlsx", header=None, sheet_name = 'wiki')[0])
report_verbs2 = list(pd.read_excel("data/bias_related_lexicons/report_verbs.xlsx", header=None, sheet_name = 'ef')[0])
report_verbs3 = list(pd.read_excel("data/bias_related_lexicons/report_verbs.xlsx", header=None, sheet_name = 'adelaide')[0])
report_verbs = list(set(report_verbs1+report_verbs2+report_verbs3))
hyperbolic_terms = list(pd.read_csv("data/bias_related_lexicons/hyperbolic_terms.csv", header=None)[0])
attitude_markers = list(pd.read_excel("data/bias_related_lexicons/attitude_markers.xlsx", header=None)[0])
boosters = list(pd.read_excel("data/bias_related_lexicons/boosters.xlsx", header=None)[0])
hedges = list(pd.read_excel("data/bias_related_lexicons/hedges.xlsx", header=None)[0])
kill_verbs = list(pd.read_excel("data/bias_related_lexicons/kill_verbs_nominalizations.xlsx", header=None)[0])

# MRCP ratings
MRCP_concretness_ratings = pd.read_excel("data/bias_related_lexicons/MRCP_concretness_ratings.xlsx")
MRCP_concretness_ratings = MRCP_concretness_ratings.drop_duplicates(subset=['WORD'])
MRCP_concretness_ratings["WORD"] = MRCP_concretness_ratings["WORD"].apply(lambda x: x.lower())
MRCP_concretness_ratings = MRCP_concretness_ratings.reset_index()
MRCP_concretness_ratings = MRCP_concretness_ratings[["WORD", "CNC"]]

MRCP_Imagability_ratings = pd.read_excel("data/bias_related_lexicons/MRCP_Imagability_ratings.xlsx")
MRCP_Imagability_ratings = MRCP_Imagability_ratings.drop_duplicates(subset=['WORD'])
MRCP_Imagability_ratings["WORD"] = MRCP_Imagability_ratings["WORD"].apply(lambda x: x.lower())
MRCP_Imagability_ratings = MRCP_Imagability_ratings.reset_index()
MRCP_Imagability_ratings = MRCP_Imagability_ratings[["WORD", "IMG"]]


#bias_lexicon = list(pd.read_excel("bias_word_lexicon_top100_10times.xlsx", header=None, 
#                                  sheet_name='top100_10times')[0])
bias_lexicon = list(pd.read_excel("data/bias_related_lexicons/bias_word_lexicon.xlsx", header=None)[0])

# %%
dt = dt.loc[dt['spacy_lg'].map(len) > 1,]

# %%
# features names
feats = ['text', 'text_low', 'pos', 'lemma', 'lemma_low', 'tag', 'dep', 'shape', 'is_alpha', 'is_stop',
         'has_vec', 'glove_vec300', 'glove_vec300_norm', 'is_oov', 'order', 'is_ne', 'ne_label',
         'tfidf_art', 'liwc2015', 
         'negative_conc', 'positive_conc',
         'weak_subj', 'strong_subj',
         'MRCP_concretness_ratings', 'MRCP_Imagability_ratings',
         'hyperbolic_terms', 'attitude_markers', 'kill_verbs', 'bias_lexicon']

# 'assertive_verbs', 'factive_verbs', 'implicative_verbs', 'report_verbs', 'boosters', 'hedges',
feats_C1 = [a + b for a, b in zip(feats, len(feats)*['_C1'])]
feats_C2 = [a + b for a, b in zip(feats, len(feats)*['_C2'])]
feats_C3 = [a + b for a, b in zip(feats, len(feats)*['_C3'])]
feats_C4 = [a + b for a, b in zip(feats, len(feats)*['_C4'])]

start_time = time.time()
# iterate over each sentence
for index, row in dt.iterrows():
    #biased = row.biased_words

    sent_tokens = []
    
    # create a list of NEs in a sentence
    entities = []
    for ent in dt['spacy_lg'][index].ents:
        ent_dict = {'text': ent.text,
                    'label': ent.label_}
        #print((ent.text, ent.start_char, ent.end_char, ent.label_))
        entities.append(ent_dict)

    # add linguistic features for each token
    order = 0
    for token in dt['spacy_lg'][index]:
        if token.pos_ not in ['PUNCT', 'SPACE', 'SYM', 'CCONJ', 'PART', 'NUM']:
        #if token.pos_ != 'PUNCT' and token.pos_ != 'SPACE' and token.pos_ != 'SYM' and token.pos_ != 'CCONJ' and token.pos_ != 'PART':
            order += 1
            if token.text.lower() in list(df_tfidf_art_updated):
                tfidf_art = df_tfidf_art_updated[token.text.lower()][index]
            else:
                tfidf_art = None 
                
            if token.text in row.biased_words2:
                label2 = 1
            else:
                label2 = 0
            # if token.text in row.biased_words4:
            #     label4 = 1
            # else:
            #     label4 = 0                
            # if token.text in row.biased_words5:
            #     label5 = 1
            # else:
            #     label5 = 0
            
            token_dict={'text':token.text,
                    'text_low': token.text.lower(),
                    'pos': token.pos_,
                    'lemma': token.lemma_,
                    'lemma_low': token.lemma_.lower(),
                    'tag': token.tag_,
                    'dep': token.dep_,
                    'shape': token.shape_,
                    'is_alpha': token.is_alpha,
                    'is_stop': token.is_stop,
                    'has_vec':token.has_vector,
                    'glove_vec300':token.vector,
                    'glove_vec300_norm':token.vector_norm,
                    'is_oov':token.is_oov,
                    'order': (order - 1),
                    'tfidf_art': tfidf_art,
                    'label3': label2,
                    'label4': label2,
                    'label5': label2}
    
            # check if a token is NE, if yes: add is_ne=True and type of NE
            for ent in entities:
                if token.text in ent['text']:
                    token_dict['is_ne']=True
                    token_dict['ne_label']=ent['label']
            if 'is_ne' not in token_dict:
                token_dict['is_ne']=False
                token_dict['ne_label']=None

    # dictionaries with 1 token
            # LIWC2015 FEATURES
            if token.text.lower() in list(liwc2015.word):
                token_dict['liwc2015'] = list(liwc2015[liwc2015['word']==token.text.lower()]['codes'])[0]
            elif token.lemma_ in list(liwc2015.word):
                token_dict['liwc2015'] = list(liwc2015[liwc2015['word']==token.lemma_]['codes'])[0]
            else:
                token_dict['liwc2015'] = []
                
            # concatenated negative list
            if token.text.lower() in negative_conc:
                token_dict['negative_conc'] = 1
            elif token.lemma_.lower() in negative_conc:
                token_dict['negative_conc'] = 1
            else:
                token_dict['negative_conc'] = 0
                
            # concatenated positive list
            if token.text.lower() in positive_conc:
                token_dict['positive_conc'] = 1
            elif token.lemma_.lower() in positive_conc:
                token_dict['positive_conc'] = 1
            else:
                token_dict['positive_conc'] = 0
                
            # weak subjectivity list
            if token.text.lower() in weak_subj:
                token_dict['weak_subj'] = 1
            elif token.lemma_.lower() in weak_subj:
                token_dict['weak_subj'] = 1
            else:
                token_dict['weak_subj'] = 0
                
            # strong subjectivity list
            if token.text.lower() in strong_subj:
                token_dict['strong_subj'] = 1
            elif token.lemma_.lower() in strong_subj:
                token_dict['strong_subj'] = 1
            else:
                token_dict['strong_subj'] = 0

            # MRCP concretness ratings
            if token.text.lower() in list(MRCP_concretness_ratings['WORD']):
                rating = list(MRCP_concretness_ratings[MRCP_concretness_ratings['WORD']==token.text.lower()]['CNC'])[0]
                token_dict['MRCP_concretness_ratings'] = rating
            elif token.lemma_.lower() in list(MRCP_concretness_ratings['WORD']):
                rating = list(MRCP_concretness_ratings[MRCP_concretness_ratings['WORD']==token.lemma_.lower()]['CNC'])[0]
                token_dict['MRCP_concretness_ratings'] = rating
            else:
                token_dict['MRCP_concretness_ratings'] = None
                
            # MRCP Imagability ratings
            if token.text.lower() in list(MRCP_Imagability_ratings['WORD']):
                rating = list(MRCP_Imagability_ratings[MRCP_Imagability_ratings['WORD']==token.text.lower()]['IMG'])[0]
                token_dict['MRCP_Imagability_ratings'] = rating
            elif token.lemma_.lower() in list(MRCP_Imagability_ratings['WORD']):
                rating = list(MRCP_Imagability_ratings[MRCP_Imagability_ratings['WORD']==token.lemma_.lower()]['IMG'])[0]
                token_dict['MRCP_Imagability_ratings'] = rating
            else:
                token_dict['MRCP_Imagability_ratings'] = None

            # hyperbolic terms
            if token.text.lower() in hyperbolic_terms:
                token_dict['hyperbolic_terms'] = 1
            elif token.lemma_.lower() in hyperbolic_terms:
                token_dict['hyperbolic_terms'] = 1
            else:
                token_dict['hyperbolic_terms'] = 0

            # attitude markers
            if token.text.lower() in attitude_markers:
                token_dict['attitude_markers'] = 1
            elif token.lemma_.lower() in attitude_markers:
                token_dict['attitude_markers'] = 1
            else:
                token_dict['attitude_markers'] = 0
            
            # kill verbs + nouns
            if token.text.lower() in kill_verbs:
                token_dict['kill_verbs'] = 1
            elif token.lemma_.lower() in kill_verbs:
                token_dict['kill_verbs'] = 1
            else:
                token_dict['kill_verbs'] = 0
                
            # bias lexicon
            if token.text.lower() in bias_lexicon:
                token_dict['bias_lexicon'] = 1
            elif token.lemma_.lower() in bias_lexicon:
                token_dict['bias_lexicon'] = 1
            else:
                token_dict['bias_lexicon'] = 0
                
                
            # merge everyting in list of tokens and their properties
            sent_tokens.append(token_dict)
    
    
    # context
    for token in sent_tokens:
        # the 1st word in the sentence
        if token['order'] == 0:
            for feat in feats_C1: # context word -2
                token[feat]=None
            for feat in feats_C2: # context word -1
                token[feat]=None
            for i, feat in enumerate(feats_C3): # context word +1
                token[feat]=sent_tokens[token['order']+1][feats[i]]
            for i, feat in enumerate(feats_C4): # context word +2
                token[feat]=sent_tokens[token['order']+2][feats[i]]
        # the 2nd word in the sentence
        elif token['order'] == 1:
            for feat in feats_C1: # context word -2
                token[feat]=None
            for i, feat in enumerate(feats_C2): # context word -1
                token[feat]=sent_tokens[token['order']-1][feats[i]]
            for i, feat in enumerate(feats_C3): # context word +1
                token[feat]=sent_tokens[token['order']+1][feats[i]]
            for i, feat in enumerate(feats_C4): # context word +2
                token[feat]=sent_tokens[token['order']+2][feats[i]]
        # the pre-last word in the sentence
        elif token['order'] == (len(sent_tokens)-2):
            for i, feat in enumerate(feats_C1): # context word -2
                token[feat]=sent_tokens[token['order']-2][feats[i]]
            for i, feat in enumerate(feats_C2): # context word -1
                token[feat]=sent_tokens[token['order']-1][feats[i]]
            for i, feat in enumerate(feats_C3): # context word +1
                token[feat]=sent_tokens[token['order']+1][feats[i]]
            for i, feat in enumerate(feats_C4): # context word +2
                token[feat]=None
        # the last word in the sentence
        elif token['order'] == (len(sent_tokens)-1):
            for i, feat in enumerate(feats_C1): # context word -2
                token[feat]=sent_tokens[token['order']-2][feats[i]]
            for i, feat in enumerate(feats_C2): # context word -1
                token[feat]=sent_tokens[token['order']-1][feats[i]]
            for i, feat in enumerate(feats_C3): # context word +1
                token[feat]=None
            for i, feat in enumerate(feats_C4): # context word +2
                token[feat]=None
        # in other cases:
        else:
            for i, feat in enumerate(feats_C1): # context word -2
                token[feat]=sent_tokens[token['order']-2][feats[i]]
            for i, feat in enumerate(feats_C2): # context word -1
                token[feat]=sent_tokens[token['order']-1][feats[i]]
            for i, feat in enumerate(feats_C3): # context word +1
                token[feat]=sent_tokens[token['order']+1][feats[i]]
            for i, feat in enumerate(feats_C4): # context word +2
                token[feat]=sent_tokens[token['order']+2][feats[i]]            
        
    
    # update column spacy_lg_dict
    dt.at[index,'spacy_lg_dict'] = sent_tokens
    
end_time = time.time()
print('Time to create features for each word:', round((end_time-start_time),2), 'seconds')
# Out:
# Time to create features for each word: 1061.91 seconds

# %% [markdown]
# ### 2.2 Handle dictionaries that include more than 1 token

# %%
# add windows of -4 and +4 words and lemmas
for index, row in dt.iterrows():
    print(index)
    print(len(row.spacy_lg_dict))
    if len(row.spacy_lg_dict) >= 8:
        for i, token in enumerate(row.spacy_lg_dict):
            print(i, token['text'])
            if i == 0:
                print('it chooes 0')
                token['window_text'] = [None, None, None, None, token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        row.spacy_lg_dict[i+3]['text_low'],row.spacy_lg_dict[i+4]['text_low']]
                token['window_lemma'] = [None, None, None, None, token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                        row.spacy_lg_dict[i+3]['lemma_low'],row.spacy_lg_dict[i+4]['lemma_low']]
            elif i == 1:
                print('it chooes 1')
                token['window_text'] = [None, None, None, row.spacy_lg_dict[i-1]['text_low'], token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        row.spacy_lg_dict[i+3]['text_low'],row.spacy_lg_dict[i+4]['text_low']]
                token['window_lemma'] = [None, None, None, row.spacy_lg_dict[i-1]['lemma_low'], token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                        row.spacy_lg_dict[i+3]['lemma_low'],row.spacy_lg_dict[i+4]['lemma_low']]
            elif i == 2:
                print('it chooes 2')
                token['window_text'] = [None, None, row.spacy_lg_dict[i-2]['text_low'],
                                        row.spacy_lg_dict[i-1]['text_low'],token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        row.spacy_lg_dict[i+3]['text_low'],row.spacy_lg_dict[i+4]['text_low']]
                token['window_lemma'] = [None, None, row.spacy_lg_dict[i-2]['lemma_low'],
                                         row.spacy_lg_dict[i-1]['lemma_low'],token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                        row.spacy_lg_dict[i+3]['lemma_low'],row.spacy_lg_dict[i+4]['lemma_low']]
            elif i == 3:
                print('it chooes 3')
                token['window_text'] = [None, row.spacy_lg_dict[i-3]['text_low'], row.spacy_lg_dict[i-2]['text_low'],
                                        row.spacy_lg_dict[i-1]['text_low'],token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        row.spacy_lg_dict[i+3]['text_low'],row.spacy_lg_dict[i+4]['text_low']]
                token['window_lemma'] = [None, row.spacy_lg_dict[i-3]['lemma_low'], row.spacy_lg_dict[i-2]['lemma_low'],
                                         row.spacy_lg_dict[i-1]['lemma_low'],token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                        row.spacy_lg_dict[i+3]['lemma_low'],row.spacy_lg_dict[i+4]['lemma_low']]
            elif i == (len(row.spacy_lg_dict)-4):
                print('it chooes -4')
                token['window_text'] = [row.spacy_lg_dict[i-4]['text_low'], row.spacy_lg_dict[i-3]['text_low'],
                                        row.spacy_lg_dict[i-2]['text_low'], row.spacy_lg_dict[i-1]['text_low'],
                                        token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        row.spacy_lg_dict[i+3]['text_low'],None]
                token['window_lemma'] = [row.spacy_lg_dict[i-4]['lemma_low'], row.spacy_lg_dict[i-3]['lemma_low'],
                                         row.spacy_lg_dict[i-2]['lemma_low'], row.spacy_lg_dict[i-1]['lemma_low'],
                                         token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                        row.spacy_lg_dict[i+3]['lemma_low'],None]
            elif i == (len(row.spacy_lg_dict)-3):
                print('it chooes -3')
                token['window_text'] = [row.spacy_lg_dict[i-4]['text_low'], row.spacy_lg_dict[i-3]['text_low'],
                                        row.spacy_lg_dict[i-2]['text_low'], row.spacy_lg_dict[i-1]['text_low'],
                                        token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        None,None]
                token['window_lemma'] = [row.spacy_lg_dict[i-4]['lemma_low'], row.spacy_lg_dict[i-3]['lemma_low'],
                                         row.spacy_lg_dict[i-2]['lemma_low'], row.spacy_lg_dict[i-1]['lemma_low'],
                                         token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                         None,None]
            elif i == (len(row.spacy_lg_dict)-2):
                print('it chooes -2')
                token['window_text'] = [row.spacy_lg_dict[i-4]['text_low'], row.spacy_lg_dict[i-3]['text_low'],
                                        row.spacy_lg_dict[i-2]['text_low'], row.spacy_lg_dict[i-1]['text_low'],
                                        token['text_low'],row.spacy_lg_dict[i+1]['text_low'],None,None,None]
                token['window_lemma'] = [row.spacy_lg_dict[i-4]['lemma_low'], row.spacy_lg_dict[i-3]['lemma_low'],
                                         row.spacy_lg_dict[i-2]['lemma_low'], row.spacy_lg_dict[i-1]['lemma_low'],
                                         token['lemma_low'],row.spacy_lg_dict[i+1]['lemma_low'],None,None,None]
            elif i == (len(row.spacy_lg_dict)-1):
                print('it chooes -1')
                token['window_text'] = [row.spacy_lg_dict[i-4]['text_low'], row.spacy_lg_dict[i-3]['text_low'],
                                        row.spacy_lg_dict[i-2]['text_low'], row.spacy_lg_dict[i-1]['text_low'],
                                        token['text_low'],None,None,None,None]
                token['window_lemma'] = [row.spacy_lg_dict[i-4]['lemma_low'], row.spacy_lg_dict[i-3]['lemma_low'],
                                         row.spacy_lg_dict[i-2]['lemma_low'], row.spacy_lg_dict[i-1]['lemma_low'],
                                         token['lemma_low'],None,None,None,None]
            else:
                print('it chooes else')
                token['window_text'] = [row.spacy_lg_dict[i-4]['text_low'], row.spacy_lg_dict[i-3]['text_low'],
                                        row.spacy_lg_dict[i-2]['text_low'], row.spacy_lg_dict[i-1]['text_low'],
                                        token['text_low'],
                                        row.spacy_lg_dict[i+1]['text_low'],row.spacy_lg_dict[i+2]['text_low'],
                                        row.spacy_lg_dict[i+3]['text_low'],row.spacy_lg_dict[i+4]['text_low']]
                token['window_lemma'] = [row.spacy_lg_dict[i-4]['lemma_low'], row.spacy_lg_dict[i-3]['lemma_low'],
                                         row.spacy_lg_dict[i-2]['lemma_low'], row.spacy_lg_dict[i-1]['lemma_low'],
                                         token['lemma_low'],
                                        row.spacy_lg_dict[i+1]['lemma_low'],row.spacy_lg_dict[i+2]['lemma_low'],
                                        row.spacy_lg_dict[i+3]['lemma_low'],row.spacy_lg_dict[i+4]['lemma_low']]

            print(token['window_text'])
        
    else:
        for i, token in enumerate(row.spacy_lg_dict):
            token['window_text'] = None
            token['window_lemma'] = None
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# it chooes else
# ['majority', 'of', 'the', 'federal', 'government', 'public', 'lands', 'deleted', 'sexual']
# 31 public
# it chooes else
# ['of', 'the', 'federal', 'government', 'public', 'lands', 'deleted', 'sexual', 'orientation']
# 32 lands
# it chooes else
# ['the', 'federal', 'government', 'public', 'lands', 'deleted', 'sexual', 'orientation', 'from']
# 33 deleted
# it chooes else
# ['federal', 'government', 'public', 'lands', 'deleted', 'sexual', 'orientation', 'from', 'its']
# 34 sexual
# it chooes else
# ['government', 'public', 'lands', 'deleted', 'sexual', 'orientation', 'from', 'its', 'anti']
# 35 orientation
# it chooes else
# ['public', 'lands', 'deleted', 'sexual', 'orientation', 'from', 'its', 'anti', '-']
# 36 from
# it chooes else
# ['lands', 'deleted', 'sexual', 'orientation', 'from', 'its', 'anti', '-', 'discrimination']
# 37 its
# it chooes else
# ['deleted', 'sexual', 'orientation', 'from', 'its', 'anti', '-', 'discrimination', 'guidelines']
# 38 anti
# it chooes -4
# ['sexual', 'orientation', 'from', 'its', 'anti', '-', 'discrimination', 'guidelines', None]
# 39 -
# it chooes -3
# ['orientation', 'from', 'its', 'anti', '-', 'discrimination', 'guidelines', None, None]
# 40 discrimination
# it chooes -2
# ['from', 'its', 'anti', '-', 'discrimination', 'guidelines', None, None, None]
# 41 guidelines
# it chooes -1
# ['its', 'anti', '-', 'discrimination', 'guidelines', None, None, None, None]
# 3623
# 30
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'many', 'formal', 'juneteenth', 'events']
# 1 many
# it chooes 1
# [None, None, None, 'with', 'many', 'formal', 'juneteenth', 'events', 'canceled']
# 2 formal
# it chooes 2
# [None, None, 'with', 'many', 'formal', 'juneteenth', 'events', 'canceled', 'due']
# 3 Juneteenth
# it chooes 3
# [None, 'with', 'many', 'formal', 'juneteenth', 'events', 'canceled', 'due', 'to']
# 4 events
# it chooes else
# ['with', 'many', 'formal', 'juneteenth', 'events', 'canceled', 'due', 'to', 'coronavirus']
# 5 canceled
# it chooes else
# ['many', 'formal', 'juneteenth', 'events', 'canceled', 'due', 'to', 'coronavirus', 'concerns']
# 6 due
# it chooes else
# ['formal', 'juneteenth', 'events', 'canceled', 'due', 'to', 'coronavirus', 'concerns', 'activists']
# 7 to
# it chooes else
# ['juneteenth', 'events', 'canceled', 'due', 'to', 'coronavirus', 'concerns', 'activists', 'instead']
# 8 coronavirus
# it chooes else
# ['events', 'canceled', 'due', 'to', 'coronavirus', 'concerns', 'activists', 'instead', 'organized']
# 9 concerns
# it chooes else
# ['canceled', 'due', 'to', 'coronavirus', 'concerns', 'activists', 'instead', 'organized', 'a']
# 10 activists
# it chooes else
# ['due', 'to', 'coronavirus', 'concerns', 'activists', 'instead', 'organized', 'a', 'host']
# 11 instead
# it chooes else
# ['to', 'coronavirus', 'concerns', 'activists', 'instead', 'organized', 'a', 'host', 'of']
# 12 organized
# it chooes else
# ['coronavirus', 'concerns', 'activists', 'instead', 'organized', 'a', 'host', 'of', 'virtual']
# 13 a
# it chooes else
# ['concerns', 'activists', 'instead', 'organized', 'a', 'host', 'of', 'virtual', 'observances']
# 14 host
# it chooes else
# ['activists', 'instead', 'organized', 'a', 'host', 'of', 'virtual', 'observances', 'online']
# 15 of
# it chooes else
# ['instead', 'organized', 'a', 'host', 'of', 'virtual', 'observances', 'online', 'as']
# 16 virtual
# it chooes else
# ['organized', 'a', 'host', 'of', 'virtual', 'observances', 'online', 'as', 'well']
# 17 observances
# it chooes else
# ['a', 'host', 'of', 'virtual', 'observances', 'online', 'as', 'well', 'as']
# 18 online
# it chooes else
# ['host', 'of', 'virtual', 'observances', 'online', 'as', 'well', 'as', 'street']
# 19 as
# it chooes else
# ['of', 'virtual', 'observances', 'online', 'as', 'well', 'as', 'street', 'marches']
# 20 well
# it chooes else
# ['virtual', 'observances', 'online', 'as', 'well', 'as', 'street', 'marches', 'car']
# 21 as
# it chooes else
# ['observances', 'online', 'as', 'well', 'as', 'street', 'marches', 'car', 'caravans']
# 22 street
# it chooes else
# ['online', 'as', 'well', 'as', 'street', 'marches', 'car', 'caravans', 'through']
# 23 marches
# it chooes else
# ['as', 'well', 'as', 'street', 'marches', 'car', 'caravans', 'through', 'several']
# 24 car
# it chooes else
# ['well', 'as', 'street', 'marches', 'car', 'caravans', 'through', 'several', 'major']
# 25 caravans
# it chooes else
# ['as', 'street', 'marches', 'car', 'caravans', 'through', 'several', 'major', 'cities']
# 26 through
# it chooes -4
# ['street', 'marches', 'car', 'caravans', 'through', 'several', 'major', 'cities', None]
# 27 several
# it chooes -3
# ['marches', 'car', 'caravans', 'through', 'several', 'major', 'cities', None, None]
# 28 major
# it chooes -2
# ['car', 'caravans', 'through', 'several', 'major', 'cities', None, None, None]
# 29 cities
# it chooes -1
# ['caravans', 'through', 'several', 'major', 'cities', None, None, None, None]
# 3624
# 41
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'more', 'than', 'people', 'killed']
# 1 more
# it chooes 1
# [None, None, None, 'with', 'more', 'than', 'people', 'killed', 'by']
# 2 than
# it chooes 2
# [None, None, 'with', 'more', 'than', 'people', 'killed', 'by', 'gun']
# 3 people
# it chooes 3
# [None, 'with', 'more', 'than', 'people', 'killed', 'by', 'gun', 'violence']
# 4 killed
# it chooes else
# ['with', 'more', 'than', 'people', 'killed', 'by', 'gun', 'violence', 'in']
# 5 by
# it chooes else
# ['more', 'than', 'people', 'killed', 'by', 'gun', 'violence', 'in', 'the']
# 6 gun
# it chooes else
# ['than', 'people', 'killed', 'by', 'gun', 'violence', 'in', 'the', 'united']
# 7 violence
# it chooes else
# ['people', 'killed', 'by', 'gun', 'violence', 'in', 'the', 'united', 'states']
# 8 in
# it chooes else
# ['killed', 'by', 'gun', 'violence', 'in', 'the', 'united', 'states', 'last']
# 9 the
# it chooes else
# ['by', 'gun', 'violence', 'in', 'the', 'united', 'states', 'last', 'year']
# 10 United
# it chooes else
# ['gun', 'violence', 'in', 'the', 'united', 'states', 'last', 'year', 'counting']
# 11 States
# it chooes else
# ['violence', 'in', 'the', 'united', 'states', 'last', 'year', 'counting', 'suicides']
# 12 last
# it chooes else
# ['in', 'the', 'united', 'states', 'last', 'year', 'counting', 'suicides', 'democrats']
# 13 year
# it chooes else
# ['the', 'united', 'states', 'last', 'year', 'counting', 'suicides', 'democrats', 'running']
# 14 counting
# it chooes else
# ['united', 'states', 'last', 'year', 'counting', 'suicides', 'democrats', 'running', 'for']
# 15 suicides
# it chooes else
# ['states', 'last', 'year', 'counting', 'suicides', 'democrats', 'running', 'for', 'their']
# 16 Democrats
# it chooes else
# ['last', 'year', 'counting', 'suicides', 'democrats', 'running', 'for', 'their', 'party']
# 17 running
# it chooes else
# ['year', 'counting', 'suicides', 'democrats', 'running', 'for', 'their', 'party', 'presidential']
# 18 for
# it chooes else
# ['counting', 'suicides', 'democrats', 'running', 'for', 'their', 'party', 'presidential', 'nomination']
# 19 their
# it chooes else
# ['suicides', 'democrats', 'running', 'for', 'their', 'party', 'presidential', 'nomination', 'are']
# 20 party
# it chooes else
# ['democrats', 'running', 'for', 'their', 'party', 'presidential', 'nomination', 'are', 'pointing']
# 21 presidential
# it chooes else
# ['running', 'for', 'their', 'party', 'presidential', 'nomination', 'are', 'pointing', 'to']
# 22 nomination
# it chooes else
# ['for', 'their', 'party', 'presidential', 'nomination', 'are', 'pointing', 'to', 'inaction']
# 23 are
# it chooes else
# ['their', 'party', 'presidential', 'nomination', 'are', 'pointing', 'to', 'inaction', 'in']
# 24 pointing
# it chooes else
# ['party', 'presidential', 'nomination', 'are', 'pointing', 'to', 'inaction', 'in', 'washington']
# 25 to
# it chooes else
# ['presidential', 'nomination', 'are', 'pointing', 'to', 'inaction', 'in', 'washington', 'as']
# 26 inaction
# it chooes else
# ['nomination', 'are', 'pointing', 'to', 'inaction', 'in', 'washington', 'as', 'evidence']
# 27 in
# it chooes else
# ['are', 'pointing', 'to', 'inaction', 'in', 'washington', 'as', 'evidence', 'they']
# 28 Washington
# it chooes else
# ['pointing', 'to', 'inaction', 'in', 'washington', 'as', 'evidence', 'they', 'should']
# 29 as
# it chooes else
# ['to', 'inaction', 'in', 'washington', 'as', 'evidence', 'they', 'should', 'be']
# 30 evidence
# it chooes else
# ['inaction', 'in', 'washington', 'as', 'evidence', 'they', 'should', 'be', 'chosen']
# 31 they
# it chooes else
# ['in', 'washington', 'as', 'evidence', 'they', 'should', 'be', 'chosen', 'run']
# 32 should
# it chooes else
# ['washington', 'as', 'evidence', 'they', 'should', 'be', 'chosen', 'run', 'against']
# 33 be
# it chooes else
# ['as', 'evidence', 'they', 'should', 'be', 'chosen', 'run', 'against', 'republican']
# 34 chosen
# it chooes else
# ['evidence', 'they', 'should', 'be', 'chosen', 'run', 'against', 'republican', 'president']
# 35 run
# it chooes else
# ['they', 'should', 'be', 'chosen', 'run', 'against', 'republican', 'president', 'donald']
# 36 against
# it chooes else
# ['should', 'be', 'chosen', 'run', 'against', 'republican', 'president', 'donald', 'trump']
# 37 Republican
# it chooes -4
# ['be', 'chosen', 'run', 'against', 'republican', 'president', 'donald', 'trump', None]
# 38 President
# it chooes -3
# ['chosen', 'run', 'against', 'republican', 'president', 'donald', 'trump', None, None]
# 39 Donald
# it chooes -2
# ['run', 'against', 'republican', 'president', 'donald', 'trump', None, None, None]
# 40 Trump
# it chooes -1
# ['against', 'republican', 'president', 'donald', 'trump', None, None, None, None]
# 3625
# 29
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'more', 'than', 'reported', 'cases']
# 1 more
# it chooes 1
# [None, None, None, 'with', 'more', 'than', 'reported', 'cases', 'of']
# 2 than
# it chooes 2
# [None, None, 'with', 'more', 'than', 'reported', 'cases', 'of', 'the']
# 3 reported
# it chooes 3
# [None, 'with', 'more', 'than', 'reported', 'cases', 'of', 'the', 'disease']
# 4 cases
# it chooes else
# ['with', 'more', 'than', 'reported', 'cases', 'of', 'the', 'disease', 'the']
# 5 of
# it chooes else
# ['more', 'than', 'reported', 'cases', 'of', 'the', 'disease', 'the', 'viral']
# 6 the
# it chooes else
# ['than', 'reported', 'cases', 'of', 'the', 'disease', 'the', 'viral', 'outbreak']
# 7 disease
# it chooes else
# ['reported', 'cases', 'of', 'the', 'disease', 'the', 'viral', 'outbreak', 'continues']
# 8 the
# it chooes else
# ['cases', 'of', 'the', 'disease', 'the', 'viral', 'outbreak', 'continues', 'create']
# 9 viral
# it chooes else
# ['of', 'the', 'disease', 'the', 'viral', 'outbreak', 'continues', 'create', 'uncertainty']
# 10 outbreak
# it chooes else
# ['the', 'disease', 'the', 'viral', 'outbreak', 'continues', 'create', 'uncertainty', 'about']
# 11 continues
# it chooes else
# ['disease', 'the', 'viral', 'outbreak', 'continues', 'create', 'uncertainty', 'about', 'future']
# 12 create
# it chooes else
# ['the', 'viral', 'outbreak', 'continues', 'create', 'uncertainty', 'about', 'future', 'competitions']
# 13 uncertainty
# it chooes else
# ['viral', 'outbreak', 'continues', 'create', 'uncertainty', 'about', 'future', 'competitions', 'from']
# 14 about
# it chooes else
# ['outbreak', 'continues', 'create', 'uncertainty', 'about', 'future', 'competitions', 'from', 'track']
# 15 future
# it chooes else
# ['continues', 'create', 'uncertainty', 'about', 'future', 'competitions', 'from', 'track', 'field']
# 16 competitions
# it chooes else
# ['create', 'uncertainty', 'about', 'future', 'competitions', 'from', 'track', 'field', 'formula']
# 17 from
# it chooes else
# ['uncertainty', 'about', 'future', 'competitions', 'from', 'track', 'field', 'formula', 'to']
# 18 track
# it chooes else
# ['about', 'future', 'competitions', 'from', 'track', 'field', 'formula', 'to', 'the']
# 19 field
# it chooes else
# ['future', 'competitions', 'from', 'track', 'field', 'formula', 'to', 'the', 'ultimate']
# 20 Formula
# it chooes else
# ['competitions', 'from', 'track', 'field', 'formula', 'to', 'the', 'ultimate', 'global']
# 21 to
# it chooes else
# ['from', 'track', 'field', 'formula', 'to', 'the', 'ultimate', 'global', 'event']
# 22 the
# it chooes else
# ['track', 'field', 'formula', 'to', 'the', 'ultimate', 'global', 'event', 'the']
# 23 ultimate
# it chooes else
# ['field', 'formula', 'to', 'the', 'ultimate', 'global', 'event', 'the', 'tokyo']
# 24 global
# it chooes else
# ['formula', 'to', 'the', 'ultimate', 'global', 'event', 'the', 'tokyo', 'olympics']
# 25 event
# it chooes -4
# ['to', 'the', 'ultimate', 'global', 'event', 'the', 'tokyo', 'olympics', None]
# 26 the
# it chooes -3
# ['the', 'ultimate', 'global', 'event', 'the', 'tokyo', 'olympics', None, None]
# 27 Tokyo
# it chooes -2
# ['ultimate', 'global', 'event', 'the', 'tokyo', 'olympics', None, None, None]
# 28 Olympics
# it chooes -1
# ['global', 'event', 'the', 'tokyo', 'olympics', None, None, None, None]
# 3626
# 37
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'our', 'climate', 'impacted', 'world']
# 1 our
# it chooes 1
# [None, None, None, 'with', 'our', 'climate', 'impacted', 'world', 'now']
# 2 climate
# it chooes 2
# [None, None, 'with', 'our', 'climate', 'impacted', 'world', 'now', 'highly']
# 3 impacted
# it chooes 3
# [None, 'with', 'our', 'climate', 'impacted', 'world', 'now', 'highly', 'prone']
# 4 world
# it chooes else
# ['with', 'our', 'climate', 'impacted', 'world', 'now', 'highly', 'prone', 'to']
# 5 now
# it chooes else
# ['our', 'climate', 'impacted', 'world', 'now', 'highly', 'prone', 'to', 'fires']
# 6 highly
# it chooes else
# ['climate', 'impacted', 'world', 'now', 'highly', 'prone', 'to', 'fires', 'extreme']
# 7 prone
# it chooes else
# ['impacted', 'world', 'now', 'highly', 'prone', 'to', 'fires', 'extreme', 'storms']
# 8 to
# it chooes else
# ['world', 'now', 'highly', 'prone', 'to', 'fires', 'extreme', 'storms', 'sea']
# 9 fires
# it chooes else
# ['now', 'highly', 'prone', 'to', 'fires', 'extreme', 'storms', 'sea', 'level']
# 10 extreme
# it chooes else
# ['highly', 'prone', 'to', 'fires', 'extreme', 'storms', 'sea', 'level', 'rise']
# 11 storms
# it chooes else
# ['prone', 'to', 'fires', 'extreme', 'storms', 'sea', 'level', 'rise', 'nuclear']
# 12 sea
# it chooes else
# ['to', 'fires', 'extreme', 'storms', 'sea', 'level', 'rise', 'nuclear', 'energy']
# 13 level
# it chooes else
# ['fires', 'extreme', 'storms', 'sea', 'level', 'rise', 'nuclear', 'energy', 'is']
# 14 rise
# it chooes else
# ['extreme', 'storms', 'sea', 'level', 'rise', 'nuclear', 'energy', 'is', 'touted']
# 15 nuclear
# it chooes else
# ['storms', 'sea', 'level', 'rise', 'nuclear', 'energy', 'is', 'touted', 'as']
# 16 energy
# it chooes else
# ['sea', 'level', 'rise', 'nuclear', 'energy', 'is', 'touted', 'as', 'a']
# 17 is
# it chooes else
# ['level', 'rise', 'nuclear', 'energy', 'is', 'touted', 'as', 'a', 'possible']
# 18 touted
# it chooes else
# ['rise', 'nuclear', 'energy', 'is', 'touted', 'as', 'a', 'possible', 'replacement']
# 19 as
# it chooes else
# ['nuclear', 'energy', 'is', 'touted', 'as', 'a', 'possible', 'replacement', 'for']
# 20 a
# it chooes else
# ['energy', 'is', 'touted', 'as', 'a', 'possible', 'replacement', 'for', 'the']
# 21 possible
# it chooes else
# ['is', 'touted', 'as', 'a', 'possible', 'replacement', 'for', 'the', 'burning']
# 22 replacement
# it chooes else
# ['touted', 'as', 'a', 'possible', 'replacement', 'for', 'the', 'burning', 'of']
# 23 for
# it chooes else
# ['as', 'a', 'possible', 'replacement', 'for', 'the', 'burning', 'of', 'fossil']
# 24 the
# it chooes else
# ['a', 'possible', 'replacement', 'for', 'the', 'burning', 'of', 'fossil', 'fuels']
# 25 burning
# it chooes else
# ['possible', 'replacement', 'for', 'the', 'burning', 'of', 'fossil', 'fuels', 'for']
# 26 of
# it chooes else
# ['replacement', 'for', 'the', 'burning', 'of', 'fossil', 'fuels', 'for', 'energy']
# 27 fossil
# it chooes else
# ['for', 'the', 'burning', 'of', 'fossil', 'fuels', 'for', 'energy', 'the']
# 28 fuels
# it chooes else
# ['the', 'burning', 'of', 'fossil', 'fuels', 'for', 'energy', 'the', 'leading']
# 29 for
# it chooes else
# ['burning', 'of', 'fossil', 'fuels', 'for', 'energy', 'the', 'leading', 'cause']
# 30 energy
# it chooes else
# ['of', 'fossil', 'fuels', 'for', 'energy', 'the', 'leading', 'cause', 'of']
# 31 the
# it chooes else
# ['fossil', 'fuels', 'for', 'energy', 'the', 'leading', 'cause', 'of', 'climate']
# 32 leading
# it chooes else
# ['fuels', 'for', 'energy', 'the', 'leading', 'cause', 'of', 'climate', 'change']
# 33 cause
# it chooes -4
# ['for', 'energy', 'the', 'leading', 'cause', 'of', 'climate', 'change', None]
# 34 of
# it chooes -3
# ['energy', 'the', 'leading', 'cause', 'of', 'climate', 'change', None, None]
# 35 climate
# it chooes -2
# ['the', 'leading', 'cause', 'of', 'climate', 'change', None, None, None]
# 36 change
# it chooes -1
# ['leading', 'cause', 'of', 'climate', 'change', None, None, None, None]
# 3627
# 36
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'protests', 'over', 'racial', 'injustice']
# 1 protests
# it chooes 1
# [None, None, None, 'with', 'protests', 'over', 'racial', 'injustice', 'continuing']
# 2 over
# it chooes 2
# [None, None, 'with', 'protests', 'over', 'racial', 'injustice', 'continuing', 'roil']
# 3 racial
# it chooes 3
# [None, 'with', 'protests', 'over', 'racial', 'injustice', 'continuing', 'roil', 'the']
# 4 injustice
# it chooes else
# ['with', 'protests', 'over', 'racial', 'injustice', 'continuing', 'roil', 'the', 'united']
# 5 continuing
# it chooes else
# ['protests', 'over', 'racial', 'injustice', 'continuing', 'roil', 'the', 'united', 'states']
# 6 roil
# it chooes else
# ['over', 'racial', 'injustice', 'continuing', 'roil', 'the', 'united', 'states', 'queer']
# 7 the
# it chooes else
# ['racial', 'injustice', 'continuing', 'roil', 'the', 'united', 'states', 'queer', 'eye']
# 8 United
# it chooes else
# ['injustice', 'continuing', 'roil', 'the', 'united', 'states', 'queer', 'eye', 'star']
# 9 States
# it chooes else
# ['continuing', 'roil', 'the', 'united', 'states', 'queer', 'eye', 'star', 'karamo']
# 10 Queer
# it chooes else
# ['roil', 'the', 'united', 'states', 'queer', 'eye', 'star', 'karamo', 'brown']
# 11 Eye
# it chooes else
# ['the', 'united', 'states', 'queer', 'eye', 'star', 'karamo', 'brown', 'has']
# 12 star
# it chooes else
# ['united', 'states', 'queer', 'eye', 'star', 'karamo', 'brown', 'has', 'called']
# 13 Karamo
# it chooes else
# ['states', 'queer', 'eye', 'star', 'karamo', 'brown', 'has', 'called', 'on']
# 14 Brown
# it chooes else
# ['queer', 'eye', 'star', 'karamo', 'brown', 'has', 'called', 'on', 'lgbt+']
# 15 has
# it chooes else
# ['eye', 'star', 'karamo', 'brown', 'has', 'called', 'on', 'lgbt+', 'people']
# 16 called
# it chooes else
# ['star', 'karamo', 'brown', 'has', 'called', 'on', 'lgbt+', 'people', 'recognize']
# 17 on
# it chooes else
# ['karamo', 'brown', 'has', 'called', 'on', 'lgbt+', 'people', 'recognize', 'the']
# 18 LGBT+
# it chooes else
# ['brown', 'has', 'called', 'on', 'lgbt+', 'people', 'recognize', 'the', 'racism']
# 19 people
# it chooes else
# ['has', 'called', 'on', 'lgbt+', 'people', 'recognize', 'the', 'racism', 'transphobia']
# 20 recognize
# it chooes else
# ['called', 'on', 'lgbt+', 'people', 'recognize', 'the', 'racism', 'transphobia', 'in']
# 21 the
# it chooes else
# ['on', 'lgbt+', 'people', 'recognize', 'the', 'racism', 'transphobia', 'in', 'the']
# 22 racism
# it chooes else
# ['lgbt+', 'people', 'recognize', 'the', 'racism', 'transphobia', 'in', 'the', 'community']
# 23 transphobia
# it chooes else
# ['people', 'recognize', 'the', 'racism', 'transphobia', 'in', 'the', 'community', 'remember']
# 24 in
# it chooes else
# ['recognize', 'the', 'racism', 'transphobia', 'in', 'the', 'community', 'remember', 'the']
# 25 the
# it chooes else
# ['the', 'racism', 'transphobia', 'in', 'the', 'community', 'remember', 'the', 'radical']
# 26 community
# it chooes else
# ['racism', 'transphobia', 'in', 'the', 'community', 'remember', 'the', 'radical', 'roots']
# 27 remember
# it chooes else
# ['transphobia', 'in', 'the', 'community', 'remember', 'the', 'radical', 'roots', 'of']
# 28 the
# it chooes else
# ['in', 'the', 'community', 'remember', 'the', 'radical', 'roots', 'of', 'the']
# 29 radical
# it chooes else
# ['the', 'community', 'remember', 'the', 'radical', 'roots', 'of', 'the', 'gay']
# 30 roots
# it chooes else
# ['community', 'remember', 'the', 'radical', 'roots', 'of', 'the', 'gay', 'rights']
# 31 of
# it chooes else
# ['remember', 'the', 'radical', 'roots', 'of', 'the', 'gay', 'rights', 'movement']
# 32 the
# it chooes -4
# ['the', 'radical', 'roots', 'of', 'the', 'gay', 'rights', 'movement', None]
# 33 gay
# it chooes -3
# ['radical', 'roots', 'of', 'the', 'gay', 'rights', 'movement', None, None]
# 34 rights
# it chooes -2
# ['roots', 'of', 'the', 'gay', 'rights', 'movement', None, None, None]
# 35 movement
# it chooes -1
# ['of', 'the', 'gay', 'rights', 'movement', None, None, None, None]
# 3628
# 36
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'radical', 'feminists', 'extremist', 'trans']
# 1 radical
# it chooes 1
# [None, None, None, 'with', 'radical', 'feminists', 'extremist', 'trans', 'activists']
# 2 feminists
# it chooes 2
# [None, None, 'with', 'radical', 'feminists', 'extremist', 'trans', 'activists', 'seeking']
# 3 extremist
# it chooes 3
# [None, 'with', 'radical', 'feminists', 'extremist', 'trans', 'activists', 'seeking', 'have']
# 4 trans
# it chooes else
# ['with', 'radical', 'feminists', 'extremist', 'trans', 'activists', 'seeking', 'have', 'her']
# 5 activists
# it chooes else
# ['radical', 'feminists', 'extremist', 'trans', 'activists', 'seeking', 'have', 'her', 'publishers']
# 6 seeking
# it chooes else
# ['feminists', 'extremist', 'trans', 'activists', 'seeking', 'have', 'her', 'publishers', 'film']
# 7 have
# it chooes else
# ['extremist', 'trans', 'activists', 'seeking', 'have', 'her', 'publishers', 'film', 'associates']
# 8 her
# it chooes else
# ['trans', 'activists', 'seeking', 'have', 'her', 'publishers', 'film', 'associates', 'ban']
# 9 publishers
# it chooes else
# ['activists', 'seeking', 'have', 'her', 'publishers', 'film', 'associates', 'ban', 'her']
# 10 film
# it chooes else
# ['seeking', 'have', 'her', 'publishers', 'film', 'associates', 'ban', 'her', 'from']
# 11 associates
# it chooes else
# ['have', 'her', 'publishers', 'film', 'associates', 'ban', 'her', 'from', 'earning']
# 12 ban
# it chooes else
# ['her', 'publishers', 'film', 'associates', 'ban', 'her', 'from', 'earning', 'a']
# 13 her
# it chooes else
# ['publishers', 'film', 'associates', 'ban', 'her', 'from', 'earning', 'a', 'living']
# 14 from
# it chooes else
# ['film', 'associates', 'ban', 'her', 'from', 'earning', 'a', 'living', 'she']
# 15 earning
# it chooes else
# ['associates', 'ban', 'her', 'from', 'earning', 'a', 'living', 'she', 'understands']
# 16 a
# it chooes else
# ['ban', 'her', 'from', 'earning', 'a', 'living', 'she', 'understands', 'how']
# 17 living
# it chooes else
# ['her', 'from', 'earning', 'a', 'living', 'she', 'understands', 'how', 'the']
# 18 she
# it chooes else
# ['from', 'earning', 'a', 'living', 'she', 'understands', 'how', 'the', 'radical']
# 19 understands
# it chooes else
# ['earning', 'a', 'living', 'she', 'understands', 'how', 'the', 'radical', 'left']
# 20 how
# it chooes else
# ['a', 'living', 'she', 'understands', 'how', 'the', 'radical', 'left', 'seeks']
# 21 the
# it chooes else
# ['living', 'she', 'understands', 'how', 'the', 'radical', 'left', 'seeks', 'merely']
# 22 radical
# it chooes else
# ['she', 'understands', 'how', 'the', 'radical', 'left', 'seeks', 'merely', 'disagree']
# 23 left
# it chooes else
# ['understands', 'how', 'the', 'radical', 'left', 'seeks', 'merely', 'disagree', 'with']
# 24 seeks
# it chooes else
# ['how', 'the', 'radical', 'left', 'seeks', 'merely', 'disagree', 'with', 'their']
# 25 merely
# it chooes else
# ['the', 'radical', 'left', 'seeks', 'merely', 'disagree', 'with', 'their', 'opponents']
# 26 disagree
# it chooes else
# ['radical', 'left', 'seeks', 'merely', 'disagree', 'with', 'their', 'opponents', 'destroy']
# 27 with
# it chooes else
# ['left', 'seeks', 'merely', 'disagree', 'with', 'their', 'opponents', 'destroy', 'them']
# 28 their
# it chooes else
# ['seeks', 'merely', 'disagree', 'with', 'their', 'opponents', 'destroy', 'them', 'utterly']
# 29 opponents
# it chooes else
# ['merely', 'disagree', 'with', 'their', 'opponents', 'destroy', 'them', 'utterly', 'as']
# 30 destroy
# it chooes else
# ['disagree', 'with', 'their', 'opponents', 'destroy', 'them', 'utterly', 'as', 'human']
# 31 them
# it chooes else
# ['with', 'their', 'opponents', 'destroy', 'them', 'utterly', 'as', 'human', 'beings']
# 32 utterly
# it chooes -4
# ['their', 'opponents', 'destroy', 'them', 'utterly', 'as', 'human', 'beings', None]
# 33 as
# it chooes -3
# ['opponents', 'destroy', 'them', 'utterly', 'as', 'human', 'beings', None, None]
# 34 human
# it chooes -2
# ['destroy', 'them', 'utterly', 'as', 'human', 'beings', None, None, None]
# 35 beings
# it chooes -1
# ['them', 'utterly', 'as', 'human', 'beings', None, None, None, None]
# 3629
# 27
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'the', 'arrival', 'of', 'virus']
# 1 the
# it chooes 1
# [None, None, None, 'with', 'the', 'arrival', 'of', 'virus', 'our']
# 2 arrival
# it chooes 2
# [None, None, 'with', 'the', 'arrival', 'of', 'virus', 'our', 'legal']
# 3 of
# it chooes 3
# [None, 'with', 'the', 'arrival', 'of', 'virus', 'our', 'legal', 'rights']
# 4 virus
# it chooes else
# ['with', 'the', 'arrival', 'of', 'virus', 'our', 'legal', 'rights', 'seem']
# 5 our
# it chooes else
# ['the', 'arrival', 'of', 'virus', 'our', 'legal', 'rights', 'seem', 'have']
# 6 legal
# it chooes else
# ['arrival', 'of', 'virus', 'our', 'legal', 'rights', 'seem', 'have', 'been']
# 7 rights
# it chooes else
# ['of', 'virus', 'our', 'legal', 'rights', 'seem', 'have', 'been', 'deemed']
# 8 seem
# it chooes else
# ['virus', 'our', 'legal', 'rights', 'seem', 'have', 'been', 'deemed', 'irrelevant']
# 9 have
# it chooes else
# ['our', 'legal', 'rights', 'seem', 'have', 'been', 'deemed', 'irrelevant', 'completely']
# 10 been
# it chooes else
# ['legal', 'rights', 'seem', 'have', 'been', 'deemed', 'irrelevant', 'completely', 'subordinated']
# 11 deemed
# it chooes else
# ['rights', 'seem', 'have', 'been', 'deemed', 'irrelevant', 'completely', 'subordinated', 'to']
# 12 irrelevant
# it chooes else
# ['seem', 'have', 'been', 'deemed', 'irrelevant', 'completely', 'subordinated', 'to', 'the']
# 13 completely
# it chooes else
# ['have', 'been', 'deemed', 'irrelevant', 'completely', 'subordinated', 'to', 'the', 'arbitrary']
# 14 subordinated
# it chooes else
# ['been', 'deemed', 'irrelevant', 'completely', 'subordinated', 'to', 'the', 'arbitrary', 'whims']
# 15 to
# it chooes else
# ['deemed', 'irrelevant', 'completely', 'subordinated', 'to', 'the', 'arbitrary', 'whims', 'of']
# 16 the
# it chooes else
# ['irrelevant', 'completely', 'subordinated', 'to', 'the', 'arbitrary', 'whims', 'of', 'politicians']
# 17 arbitrary
# it chooes else
# ['completely', 'subordinated', 'to', 'the', 'arbitrary', 'whims', 'of', 'politicians', 'all']
# 18 whims
# it chooes else
# ['subordinated', 'to', 'the', 'arbitrary', 'whims', 'of', 'politicians', 'all', 'in']
# 19 of
# it chooes else
# ['to', 'the', 'arbitrary', 'whims', 'of', 'politicians', 'all', 'in', 'the']
# 20 politicians
# it chooes else
# ['the', 'arbitrary', 'whims', 'of', 'politicians', 'all', 'in', 'the', 'name']
# 21 all
# it chooes else
# ['arbitrary', 'whims', 'of', 'politicians', 'all', 'in', 'the', 'name', 'of']
# 22 in
# it chooes else
# ['whims', 'of', 'politicians', 'all', 'in', 'the', 'name', 'of', 'safety']
# 23 the
# it chooes -4
# ['of', 'politicians', 'all', 'in', 'the', 'name', 'of', 'safety', None]
# 24 name
# it chooes -3
# ['politicians', 'all', 'in', 'the', 'name', 'of', 'safety', None, None]
# 25 of
# it chooes -2
# ['all', 'in', 'the', 'name', 'of', 'safety', None, None, None]
# 26 safety
# it chooes -1
# ['in', 'the', 'name', 'of', 'safety', None, None, None, None]
# 3630
# 19
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'the', 'olympic', 'games', 'postponed']
# 1 the
# it chooes 1
# [None, None, None, 'with', 'the', 'olympic', 'games', 'postponed', 'until']
# 2 Olympic
# it chooes 2
# [None, None, 'with', 'the', 'olympic', 'games', 'postponed', 'until', 'cinemas']
# 3 Games
# it chooes 3
# [None, 'with', 'the', 'olympic', 'games', 'postponed', 'until', 'cinemas', 'closed']
# 4 postponed
# it chooes else
# ['with', 'the', 'olympic', 'games', 'postponed', 'until', 'cinemas', 'closed', 'across']
# 5 until
# it chooes else
# ['the', 'olympic', 'games', 'postponed', 'until', 'cinemas', 'closed', 'across', 'the']
# 6 cinemas
# it chooes else
# ['olympic', 'games', 'postponed', 'until', 'cinemas', 'closed', 'across', 'the', 'country']
# 7 closed
# it chooes else
# ['games', 'postponed', 'until', 'cinemas', 'closed', 'across', 'the', 'country', 'whole']
# 8 across
# it chooes else
# ['postponed', 'until', 'cinemas', 'closed', 'across', 'the', 'country', 'whole', 'segments']
# 9 the
# it chooes else
# ['until', 'cinemas', 'closed', 'across', 'the', 'country', 'whole', 'segments', 'of']
# 10 country
# it chooes else
# ['cinemas', 'closed', 'across', 'the', 'country', 'whole', 'segments', 'of', 'the']
# 11 whole
# it chooes else
# ['closed', 'across', 'the', 'country', 'whole', 'segments', 'of', 'the', 'advertising']
# 12 segments
# it chooes else
# ['across', 'the', 'country', 'whole', 'segments', 'of', 'the', 'advertising', 'market']
# 13 of
# it chooes else
# ['the', 'country', 'whole', 'segments', 'of', 'the', 'advertising', 'market', 'have']
# 14 the
# it chooes else
# ['country', 'whole', 'segments', 'of', 'the', 'advertising', 'market', 'have', 'evaporated']
# 15 advertising
# it chooes -4
# ['whole', 'segments', 'of', 'the', 'advertising', 'market', 'have', 'evaporated', None]
# 16 market
# it chooes -3
# ['segments', 'of', 'the', 'advertising', 'market', 'have', 'evaporated', None, None]
# 17 have
# it chooes -2
# ['of', 'the', 'advertising', 'market', 'have', 'evaporated', None, None, None]
# 18 evaporated
# it chooes -1
# ['the', 'advertising', 'market', 'have', 'evaporated', None, None, None, None]
# 3631
# 34
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'this', 'in', 'mind', 'the']
# 1 this
# it chooes 1
# [None, None, None, 'with', 'this', 'in', 'mind', 'the', 'trump']
# 2 in
# it chooes 2
# [None, None, 'with', 'this', 'in', 'mind', 'the', 'trump', 'administration']
# 3 mind
# it chooes 3
# [None, 'with', 'this', 'in', 'mind', 'the', 'trump', 'administration', 'reportedly']
# 4 the
# it chooes else
# ['with', 'this', 'in', 'mind', 'the', 'trump', 'administration', 'reportedly', 'hopes']
# 5 Trump
# it chooes else
# ['this', 'in', 'mind', 'the', 'trump', 'administration', 'reportedly', 'hopes', 'reduce']
# 6 administration
# it chooes else
# ['in', 'mind', 'the', 'trump', 'administration', 'reportedly', 'hopes', 'reduce', 'poverty']
# 7 reportedly
# it chooes else
# ['mind', 'the', 'trump', 'administration', 'reportedly', 'hopes', 'reduce', 'poverty', 'in']
# 8 hopes
# it chooes else
# ['the', 'trump', 'administration', 'reportedly', 'hopes', 'reduce', 'poverty', 'in', 'the']
# 9 reduce
# it chooes else
# ['trump', 'administration', 'reportedly', 'hopes', 'reduce', 'poverty', 'in', 'the', 'united']
# 10 poverty
# it chooes else
# ['administration', 'reportedly', 'hopes', 'reduce', 'poverty', 'in', 'the', 'united', 'states']
# 11 in
# it chooes else
# ['reportedly', 'hopes', 'reduce', 'poverty', 'in', 'the', 'united', 'states', 'by']
# 12 the
# it chooes else
# ['hopes', 'reduce', 'poverty', 'in', 'the', 'united', 'states', 'by', 'making']
# 13 United
# it chooes else
# ['reduce', 'poverty', 'in', 'the', 'united', 'states', 'by', 'making', 'a']
# 14 States
# it chooes else
# ['poverty', 'in', 'the', 'united', 'states', 'by', 'making', 'a', 'material']
# 15 by
# it chooes else
# ['in', 'the', 'united', 'states', 'by', 'making', 'a', 'material', 'difference']
# 16 making
# it chooes else
# ['the', 'united', 'states', 'by', 'making', 'a', 'material', 'difference', 'in']
# 17 a
# it chooes else
# ['united', 'states', 'by', 'making', 'a', 'material', 'difference', 'in', 'struggling']
# 18 material
# it chooes else
# ['states', 'by', 'making', 'a', 'material', 'difference', 'in', 'struggling', 'families']
# 19 difference
# it chooes else
# ['by', 'making', 'a', 'material', 'difference', 'in', 'struggling', 'families', 'finances']
# 20 in
# it chooes else
# ['making', 'a', 'material', 'difference', 'in', 'struggling', 'families', 'finances', 'by']
# 21 struggling
# it chooes else
# ['a', 'material', 'difference', 'in', 'struggling', 'families', 'finances', 'by', 'tinkering']
# 22 families
# it chooes else
# ['material', 'difference', 'in', 'struggling', 'families', 'finances', 'by', 'tinkering', 'with']
# 23 finances
# it chooes else
# ['difference', 'in', 'struggling', 'families', 'finances', 'by', 'tinkering', 'with', 'the']
# 24 by
# it chooes else
# ['in', 'struggling', 'families', 'finances', 'by', 'tinkering', 'with', 'the', 'threshold']
# 25 tinkering
# it chooes else
# ['struggling', 'families', 'finances', 'by', 'tinkering', 'with', 'the', 'threshold', 'for']
# 26 with
# it chooes else
# ['families', 'finances', 'by', 'tinkering', 'with', 'the', 'threshold', 'for', 'what']
# 27 the
# it chooes else
# ['finances', 'by', 'tinkering', 'with', 'the', 'threshold', 'for', 'what', 'counts']
# 28 threshold
# it chooes else
# ['by', 'tinkering', 'with', 'the', 'threshold', 'for', 'what', 'counts', 'as']
# 29 for
# it chooes else
# ['tinkering', 'with', 'the', 'threshold', 'for', 'what', 'counts', 'as', 'poverty']
# 30 what
# it chooes -4
# ['with', 'the', 'threshold', 'for', 'what', 'counts', 'as', 'poverty', None]
# 31 counts
# it chooes -3
# ['the', 'threshold', 'for', 'what', 'counts', 'as', 'poverty', None, None]
# 32 as
# it chooes -2
# ['threshold', 'for', 'what', 'counts', 'as', 'poverty', None, None, None]
# 33 poverty
# it chooes -1
# ['for', 'what', 'counts', 'as', 'poverty', None, None, None, None]
# 3632
# 32
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'justices', 'appointed', 'in', 'recent']
# 1 justices
# it chooes 1
# [None, None, None, 'with', 'justices', 'appointed', 'in', 'recent', 'years']
# 2 appointed
# it chooes 2
# [None, None, 'with', 'justices', 'appointed', 'in', 'recent', 'years', 'by']
# 3 in
# it chooes 3
# [None, 'with', 'justices', 'appointed', 'in', 'recent', 'years', 'by', 'president']
# 4 recent
# it chooes else
# ['with', 'justices', 'appointed', 'in', 'recent', 'years', 'by', 'president', 'donald']
# 5 years
# it chooes else
# ['justices', 'appointed', 'in', 'recent', 'years', 'by', 'president', 'donald', 'trump']
# 6 by
# it chooes else
# ['appointed', 'in', 'recent', 'years', 'by', 'president', 'donald', 'trump', 'the']
# 7 President
# it chooes else
# ['in', 'recent', 'years', 'by', 'president', 'donald', 'trump', 'the', 'supreme']
# 8 Donald
# it chooes else
# ['recent', 'years', 'by', 'president', 'donald', 'trump', 'the', 'supreme', 'court']
# 9 Trump
# it chooes else
# ['years', 'by', 'president', 'donald', 'trump', 'the', 'supreme', 'court', 'has']
# 10 the
# it chooes else
# ['by', 'president', 'donald', 'trump', 'the', 'supreme', 'court', 'has', 'appeared']
# 11 Supreme
# it chooes else
# ['president', 'donald', 'trump', 'the', 'supreme', 'court', 'has', 'appeared', 'primed']
# 12 Court
# it chooes else
# ['donald', 'trump', 'the', 'supreme', 'court', 'has', 'appeared', 'primed', 'ready']
# 13 has
# it chooes else
# ['trump', 'the', 'supreme', 'court', 'has', 'appeared', 'primed', 'ready', 'deliver']
# 14 appeared
# it chooes else
# ['the', 'supreme', 'court', 'has', 'appeared', 'primed', 'ready', 'deliver', 'a']
# 15 primed
# it chooes else
# ['supreme', 'court', 'has', 'appeared', 'primed', 'ready', 'deliver', 'a', 'huge']
# 16 ready
# it chooes else
# ['court', 'has', 'appeared', 'primed', 'ready', 'deliver', 'a', 'huge', 'victory']
# 17 deliver
# it chooes else
# ['has', 'appeared', 'primed', 'ready', 'deliver', 'a', 'huge', 'victory', 'for']
# 18 a
# it chooes else
# ['appeared', 'primed', 'ready', 'deliver', 'a', 'huge', 'victory', 'for', 'conservatives']
# 19 huge
# it chooes else
# ['primed', 'ready', 'deliver', 'a', 'huge', 'victory', 'for', 'conservatives', 'looking']
# 20 victory
# it chooes else
# ['ready', 'deliver', 'a', 'huge', 'victory', 'for', 'conservatives', 'looking', 'roll']
# 21 for
# it chooes else
# ['deliver', 'a', 'huge', 'victory', 'for', 'conservatives', 'looking', 'roll', 'back']
# 22 conservatives
# it chooes else
# ['a', 'huge', 'victory', 'for', 'conservatives', 'looking', 'roll', 'back', 'abortion']
# 23 looking
# it chooes else
# ['huge', 'victory', 'for', 'conservatives', 'looking', 'roll', 'back', 'abortion', 'rights']
# 24 roll
# it chooes else
# ['victory', 'for', 'conservatives', 'looking', 'roll', 'back', 'abortion', 'rights', 'in']
# 25 back
# it chooes else
# ['for', 'conservatives', 'looking', 'roll', 'back', 'abortion', 'rights', 'in', 'the']
# 26 abortion
# it chooes else
# ['conservatives', 'looking', 'roll', 'back', 'abortion', 'rights', 'in', 'the', 'united']
# 27 rights
# it chooes else
# ['looking', 'roll', 'back', 'abortion', 'rights', 'in', 'the', 'united', 'states']
# 28 in
# it chooes -4
# ['roll', 'back', 'abortion', 'rights', 'in', 'the', 'united', 'states', None]
# 29 the
# it chooes -3
# ['back', 'abortion', 'rights', 'in', 'the', 'united', 'states', None, None]
# 30 United
# it chooes -2
# ['abortion', 'rights', 'in', 'the', 'united', 'states', None, None, None]
# 31 States
# it chooes -1
# ['rights', 'in', 'the', 'united', 'states', None, None, None, None]
# 3633
# 41
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'u.s.', 'president', 'donald', 'trump']
# 1 U.S.
# it chooes 1
# [None, None, None, 'with', 'u.s.', 'president', 'donald', 'trump', 'announcement']
# 2 President
# it chooes 2
# [None, None, 'with', 'u.s.', 'president', 'donald', 'trump', 'announcement', 'on']
# 3 Donald
# it chooes 3
# [None, 'with', 'u.s.', 'president', 'donald', 'trump', 'announcement', 'on', 'thursday']
# 4 Trump
# it chooes else
# ['with', 'u.s.', 'president', 'donald', 'trump', 'announcement', 'on', 'thursday', 'of']
# 5 announcement
# it chooes else
# ['u.s.', 'president', 'donald', 'trump', 'announcement', 'on', 'thursday', 'of', 'tariffs']
# 6 on
# it chooes else
# ['president', 'donald', 'trump', 'announcement', 'on', 'thursday', 'of', 'tariffs', 'on']
# 7 Thursday
# it chooes else
# ['donald', 'trump', 'announcement', 'on', 'thursday', 'of', 'tariffs', 'on', 'another']
# 8 of
# it chooes else
# ['trump', 'announcement', 'on', 'thursday', 'of', 'tariffs', 'on', 'another', 'of']
# 9 tariffs
# it chooes else
# ['announcement', 'on', 'thursday', 'of', 'tariffs', 'on', 'another', 'of', 'chinese']
# 10 on
# it chooes else
# ['on', 'thursday', 'of', 'tariffs', 'on', 'another', 'of', 'chinese', 'imports']
# 11 another
# it chooes else
# ['thursday', 'of', 'tariffs', 'on', 'another', 'of', 'chinese', 'imports', 'nearly']
# 12 of
# it chooes else
# ['of', 'tariffs', 'on', 'another', 'of', 'chinese', 'imports', 'nearly', 'all']
# 13 Chinese
# it chooes else
# ['tariffs', 'on', 'another', 'of', 'chinese', 'imports', 'nearly', 'all', 'goods']
# 14 imports
# it chooes else
# ['on', 'another', 'of', 'chinese', 'imports', 'nearly', 'all', 'goods', 'from']
# 15 nearly
# it chooes else
# ['another', 'of', 'chinese', 'imports', 'nearly', 'all', 'goods', 'from', 'china']
# 16 all
# it chooes else
# ['of', 'chinese', 'imports', 'nearly', 'all', 'goods', 'from', 'china', 'will']
# 17 goods
# it chooes else
# ['chinese', 'imports', 'nearly', 'all', 'goods', 'from', 'china', 'will', 'be']
# 18 from
# it chooes else
# ['imports', 'nearly', 'all', 'goods', 'from', 'china', 'will', 'be', 'subject']
# 19 China
# it chooes else
# ['nearly', 'all', 'goods', 'from', 'china', 'will', 'be', 'subject', 'to']
# 20 will
# it chooes else
# ['all', 'goods', 'from', 'china', 'will', 'be', 'subject', 'to', 'import']
# 21 be
# it chooes else
# ['goods', 'from', 'china', 'will', 'be', 'subject', 'to', 'import', 'taxes']
# 22 subject
# it chooes else
# ['from', 'china', 'will', 'be', 'subject', 'to', 'import', 'taxes', 'trump']
# 23 to
# it chooes else
# ['china', 'will', 'be', 'subject', 'to', 'import', 'taxes', 'trump', 'says']
# 24 import
# it chooes else
# ['will', 'be', 'subject', 'to', 'import', 'taxes', 'trump', 'says', 'they']
# 25 taxes
# it chooes else
# ['be', 'subject', 'to', 'import', 'taxes', 'trump', 'says', 'they', 'generate']
# 26 Trump
# it chooes else
# ['subject', 'to', 'import', 'taxes', 'trump', 'says', 'they', 'generate', 'billions']
# 27 says
# it chooes else
# ['to', 'import', 'taxes', 'trump', 'says', 'they', 'generate', 'billions', 'of']
# 28 they
# it chooes else
# ['import', 'taxes', 'trump', 'says', 'they', 'generate', 'billions', 'of', 'dollars']
# 29 generate
# it chooes else
# ['taxes', 'trump', 'says', 'they', 'generate', 'billions', 'of', 'dollars', 'in']
# 30 billions
# it chooes else
# ['trump', 'says', 'they', 'generate', 'billions', 'of', 'dollars', 'in', 'revenues']
# 31 of
# it chooes else
# ['says', 'they', 'generate', 'billions', 'of', 'dollars', 'in', 'revenues', 'for']
# 32 dollars
# it chooes else
# ['they', 'generate', 'billions', 'of', 'dollars', 'in', 'revenues', 'for', 'the']
# 33 in
# it chooes else
# ['generate', 'billions', 'of', 'dollars', 'in', 'revenues', 'for', 'the', 'u.s.']
# 34 revenues
# it chooes else
# ['billions', 'of', 'dollars', 'in', 'revenues', 'for', 'the', 'u.s.', 'treasury']
# 35 for
# it chooes else
# ['of', 'dollars', 'in', 'revenues', 'for', 'the', 'u.s.', 'treasury', 'from']
# 36 the
# it chooes else
# ['dollars', 'in', 'revenues', 'for', 'the', 'u.s.', 'treasury', 'from', 'china']
# 37 U.S.
# it chooes -4
# ['in', 'revenues', 'for', 'the', 'u.s.', 'treasury', 'from', 'china', None]
# 38 Treasury
# it chooes -3
# ['revenues', 'for', 'the', 'u.s.', 'treasury', 'from', 'china', None, None]
# 39 from
# it chooes -2
# ['for', 'the', 'u.s.', 'treasury', 'from', 'china', None, None, None]
# 40 China
# it chooes -1
# ['the', 'u.s.', 'treasury', 'from', 'china', None, None, None, None]
# 3634
# 32
# 0 With
# it chooes 0
# [None, None, None, None, 'with', 'president', 'donald', 'trump', 'signaling']
# 1 President
# it chooes 1
# [None, None, None, 'with', 'president', 'donald', 'trump', 'signaling', 'that']
# 2 Donald
# it chooes 2
# [None, None, 'with', 'president', 'donald', 'trump', 'signaling', 'that', 'he']
# 3 Trump
# it chooes 3
# [None, 'with', 'president', 'donald', 'trump', 'signaling', 'that', 'he', "'s"]
# 4 signaling
# it chooes else
# ['with', 'president', 'donald', 'trump', 'signaling', 'that', 'he', "'s", 'eager']
# 5 that
# it chooes else
# ['president', 'donald', 'trump', 'signaling', 'that', 'he', "'s", 'eager', 'for']
# 6 he
# it chooes else
# ['donald', 'trump', 'signaling', 'that', 'he', "'s", 'eager', 'for', 'the']
# 7 's
# it chooes else
# ['trump', 'signaling', 'that', 'he', "'s", 'eager', 'for', 'the', 'country']
# 8 eager
# it chooes else
# ['signaling', 'that', 'he', "'s", 'eager', 'for', 'the', 'country', 'relax']
# 9 for
# it chooes else
# ['that', 'he', "'s", 'eager', 'for', 'the', 'country', 'relax', 'stringent']
# 10 the
# it chooes else
# ['he', "'s", 'eager', 'for', 'the', 'country', 'relax', 'stringent', 'measures']
# 11 country
# it chooes else
# ["'s", 'eager', 'for', 'the', 'country', 'relax', 'stringent', 'measures', 'meant']
# 12 relax
# it chooes else
# ['eager', 'for', 'the', 'country', 'relax', 'stringent', 'measures', 'meant', 'stem']
# 13 stringent
# it chooes else
# ['for', 'the', 'country', 'relax', 'stringent', 'measures', 'meant', 'stem', 'the']
# 14 measures
# it chooes else
# ['the', 'country', 'relax', 'stringent', 'measures', 'meant', 'stem', 'the', 'tide']
# 15 meant
# it chooes else
# ['country', 'relax', 'stringent', 'measures', 'meant', 'stem', 'the', 'tide', 'of']
# 16 stem
# it chooes else
# ['relax', 'stringent', 'measures', 'meant', 'stem', 'the', 'tide', 'of', 'the']
# 17 the
# it chooes else
# ['stringent', 'measures', 'meant', 'stem', 'the', 'tide', 'of', 'the', 'covid-19']
# 18 tide
# it chooes else
# ['measures', 'meant', 'stem', 'the', 'tide', 'of', 'the', 'covid-19', 'pandemic']
# 19 of
# it chooes else
# ['meant', 'stem', 'the', 'tide', 'of', 'the', 'covid-19', 'pandemic', 'it']
# 20 the
# it chooes else
# ['stem', 'the', 'tide', 'of', 'the', 'covid-19', 'pandemic', 'it', "'s"]
# 21 Covid-19
# it chooes else
# ['the', 'tide', 'of', 'the', 'covid-19', 'pandemic', 'it', "'s", 'important']
# 22 pandemic
# it chooes else
# ['tide', 'of', 'the', 'covid-19', 'pandemic', 'it', "'s", 'important', 'realize']
# 23 it
# it chooes else
# ['of', 'the', 'covid-19', 'pandemic', 'it', "'s", 'important', 'realize', 'how']
# 24 's
# it chooes else
# ['the', 'covid-19', 'pandemic', 'it', "'s", 'important', 'realize', 'how', 'dangerous']
# 25 important
# it chooes else
# ['covid-19', 'pandemic', 'it', "'s", 'important', 'realize', 'how', 'dangerous', 'this']
# 26 realize
# it chooes else
# ['pandemic', 'it', "'s", 'important', 'realize', 'how', 'dangerous', 'this', 'idea']
# 27 how
# it chooes else
# ['it', "'s", 'important', 'realize', 'how', 'dangerous', 'this', 'idea', 'is']
# 28 dangerous
# it chooes -4
# ["'s", 'important', 'realize', 'how', 'dangerous', 'this', 'idea', 'is', None]
# 29 this
# it chooes -3
# ['important', 'realize', 'how', 'dangerous', 'this', 'idea', 'is', None, None]
# 30 idea
# it chooes -2
# ['realize', 'how', 'dangerous', 'this', 'idea', 'is', None, None, None]
# 31 is
# it chooes -1
# ['how', 'dangerous', 'this', 'idea', 'is', None, None, None, None]
# 3635
# 50
# 0 Within
# it chooes 0
# [None, None, None, None, 'within', 'weeks', 'of', 'floyd', 'passing']
# 1 weeks
# it chooes 1
# [None, None, None, 'within', 'weeks', 'of', 'floyd', 'passing', 'in']
# 2 of
# it chooes 2
# [None, None, 'within', 'weeks', 'of', 'floyd', 'passing', 'in', 'minneapolis']
# 3 Floyd
# it chooes 3
# [None, 'within', 'weeks', 'of', 'floyd', 'passing', 'in', 'minneapolis', 'police']
# 4 passing
# it chooes else
# ['within', 'weeks', 'of', 'floyd', 'passing', 'in', 'minneapolis', 'police', 'custody']
# 5 in
# it chooes else
# ['weeks', 'of', 'floyd', 'passing', 'in', 'minneapolis', 'police', 'custody', 'militant']
# 6 Minneapolis
# it chooes else
# ['of', 'floyd', 'passing', 'in', 'minneapolis', 'police', 'custody', 'militant', 'social']
# 7 police
# it chooes else
# ['floyd', 'passing', 'in', 'minneapolis', 'police', 'custody', 'militant', 'social', 'justice']
# 8 custody
# it chooes else
# ['passing', 'in', 'minneapolis', 'police', 'custody', 'militant', 'social', 'justice', 'warriors']
# 9 militant
# it chooes else
# ['in', 'minneapolis', 'police', 'custody', 'militant', 'social', 'justice', 'warriors', 'racked']
# 10 social
# it chooes else
# ['minneapolis', 'police', 'custody', 'militant', 'social', 'justice', 'warriors', 'racked', 'up']
# 11 justice
# it chooes else
# ['police', 'custody', 'militant', 'social', 'justice', 'warriors', 'racked', 'up', 'an']
# 12 warriors
# it chooes else
# ['custody', 'militant', 'social', 'justice', 'warriors', 'racked', 'up', 'an', 'estimated']
# 13 racked
# it chooes else
# ['militant', 'social', 'justice', 'warriors', 'racked', 'up', 'an', 'estimated', 'in']
# 14 up
# it chooes else
# ['social', 'justice', 'warriors', 'racked', 'up', 'an', 'estimated', 'in', 'damage']
# 15 an
# it chooes else
# ['justice', 'warriors', 'racked', 'up', 'an', 'estimated', 'in', 'damage', 'causing']
# 16 estimated
# it chooes else
# ['warriors', 'racked', 'up', 'an', 'estimated', 'in', 'damage', 'causing', 'the']
# 17 in
# it chooes else
# ['racked', 'up', 'an', 'estimated', 'in', 'damage', 'causing', 'the', 'costliest']
# 18 damage
# it chooes else
# ['up', 'an', 'estimated', 'in', 'damage', 'causing', 'the', 'costliest', 'outbreak']
# 19 causing
# it chooes else
# ['an', 'estimated', 'in', 'damage', 'causing', 'the', 'costliest', 'outbreak', 'of']
# 20 the
# it chooes else
# ['estimated', 'in', 'damage', 'causing', 'the', 'costliest', 'outbreak', 'of', 'political']
# 21 costliest
# it chooes else
# ['in', 'damage', 'causing', 'the', 'costliest', 'outbreak', 'of', 'political', 'upheaval']
# 22 outbreak
# it chooes else
# ['damage', 'causing', 'the', 'costliest', 'outbreak', 'of', 'political', 'upheaval', 'in']
# 23 of
# it chooes else
# ['causing', 'the', 'costliest', 'outbreak', 'of', 'political', 'upheaval', 'in', 'u.s.']
# 24 political
# it chooes else
# ['the', 'costliest', 'outbreak', 'of', 'political', 'upheaval', 'in', 'u.s.', 'history']
# 25 upheaval
# it chooes else
# ['costliest', 'outbreak', 'of', 'political', 'upheaval', 'in', 'u.s.', 'history', 'devastating']
# 26 in
# it chooes else
# ['outbreak', 'of', 'political', 'upheaval', 'in', 'u.s.', 'history', 'devastating', 'minority']
# 27 U.S.
# it chooes else
# ['of', 'political', 'upheaval', 'in', 'u.s.', 'history', 'devastating', 'minority', 'businesses']
# 28 history
# it chooes else
# ['political', 'upheaval', 'in', 'u.s.', 'history', 'devastating', 'minority', 'businesses', 'while']
# 29 devastating
# it chooes else
# ['upheaval', 'in', 'u.s.', 'history', 'devastating', 'minority', 'businesses', 'while', 'kicking']
# 30 minority
# it chooes else
# ['in', 'u.s.', 'history', 'devastating', 'minority', 'businesses', 'while', 'kicking', 'off']
# 31 businesses
# it chooes else
# ['u.s.', 'history', 'devastating', 'minority', 'businesses', 'while', 'kicking', 'off', 'an']
# 32 while
# it chooes else
# ['history', 'devastating', 'minority', 'businesses', 'while', 'kicking', 'off', 'an', 'entire']
# 33 kicking
# it chooes else
# ['devastating', 'minority', 'businesses', 'while', 'kicking', 'off', 'an', 'entire', 'summer']
# 34 off
# it chooes else
# ['minority', 'businesses', 'while', 'kicking', 'off', 'an', 'entire', 'summer', 'of']
# 35 an
# it chooes else
# ['businesses', 'while', 'kicking', 'off', 'an', 'entire', 'summer', 'of', 'chaos']
# 36 entire
# it chooes else
# ['while', 'kicking', 'off', 'an', 'entire', 'summer', 'of', 'chaos', 'engulfing']
# 37 summer
# it chooes else
# ['kicking', 'off', 'an', 'entire', 'summer', 'of', 'chaos', 'engulfing', 'the']
# ...
# 12 because
# it chooes else
# ['your', 'school', 'is', 'teaching', 'because', 'the', 'left', 'only', 'wants']
# 13 the
# it chooes else
# ['school', 'is', 'teaching', 'because', 'the', 'left', 'only', 'wants', 'teach']
# 14 left
# it chooes else
# ['is', 'teaching', 'because', 'the', 'left', 'only', 'wants', 'teach', 'your']
# 15 only
# it chooes else
# ['teaching', 'because', 'the', 'left', 'only', 'wants', 'teach', 'your', 'kids']
# 16 wants
# it chooes else
# ['because', 'the', 'left', 'only', 'wants', 'teach', 'your', 'kids', 'engage']
# 17 teach
# it chooes else
# ['the', 'left', 'only', 'wants', 'teach', 'your', 'kids', 'engage', 'in']
# 18 your
# it chooes else
# ['left', 'only', 'wants', 'teach', 'your', 'kids', 'engage', 'in', 'loveless']
# 19 kids
# it chooes else
# ['only', 'wants', 'teach', 'your', 'kids', 'engage', 'in', 'loveless', 'sex']
# 20 engage
# it chooes else
# ['wants', 'teach', 'your', 'kids', 'engage', 'in', 'loveless', 'sex', 'the']
# 21 in
# it chooes else
# ['teach', 'your', 'kids', 'engage', 'in', 'loveless', 'sex', 'the', 'sanctity']
# 22 loveless
# it chooes else
# ['your', 'kids', 'engage', 'in', 'loveless', 'sex', 'the', 'sanctity', 'of']
# 23 sex
# it chooes else
# ['kids', 'engage', 'in', 'loveless', 'sex', 'the', 'sanctity', 'of', 'abortion']
# 24 the
# it chooes else
# ['engage', 'in', 'loveless', 'sex', 'the', 'sanctity', 'of', 'abortion', 'why']
# 25 sanctity
# it chooes else
# ['in', 'loveless', 'sex', 'the', 'sanctity', 'of', 'abortion', 'why', 'america']
# 26 of
# it chooes else
# ['loveless', 'sex', 'the', 'sanctity', 'of', 'abortion', 'why', 'america', 'is']
# 27 abortion
# it chooes else
# ['sex', 'the', 'sanctity', 'of', 'abortion', 'why', 'america', 'is', 'evil']
# 28 why
# it chooes else
# ['the', 'sanctity', 'of', 'abortion', 'why', 'america', 'is', 'evil', 'that']
# 29 America
# it chooes else
# ['sanctity', 'of', 'abortion', 'why', 'america', 'is', 'evil', 'that', 'men']
# 30 is
# it chooes else
# ['of', 'abortion', 'why', 'america', 'is', 'evil', 'that', 'men', 'are']
# 31 evil
# it chooes else
# ['abortion', 'why', 'america', 'is', 'evil', 'that', 'men', 'are', 'women']
# 32 that
# it chooes else
# ['why', 'america', 'is', 'evil', 'that', 'men', 'are', 'women', 'women']
# 33 men
# it chooes else
# ['america', 'is', 'evil', 'that', 'men', 'are', 'women', 'women', 'are']
# 34 are
# it chooes else
# ['is', 'evil', 'that', 'men', 'are', 'women', 'women', 'are', 'men']
# 35 women
# it chooes else
# ['evil', 'that', 'men', 'are', 'women', 'women', 'are', 'men', 'that']
# 36 women
# it chooes else
# ['that', 'men', 'are', 'women', 'women', 'are', 'men', 'that', 'global']
# 37 are
# it chooes else
# ['men', 'are', 'women', 'women', 'are', 'men', 'that', 'global', 'warming']
# 38 men
# it chooes else
# ['are', 'women', 'women', 'are', 'men', 'that', 'global', 'warming', 'is']
# 39 that
# it chooes else
# ['women', 'women', 'are', 'men', 'that', 'global', 'warming', 'is', 'real']
# 40 Global
# it chooes else
# ['women', 'are', 'men', 'that', 'global', 'warming', 'is', 'real', 'it']
# 41 Warming
# it chooes else
# ['are', 'men', 'that', 'global', 'warming', 'is', 'real', 'it', '’s']
# 42 is
# it chooes -4
# ['men', 'that', 'global', 'warming', 'is', 'real', 'it', '’s', None]
# 43 real
# it chooes -3
# ['that', 'global', 'warming', 'is', 'real', 'it', '’s', None, None]
# 44 It
# it chooes -2
# ['global', 'warming', 'is', 'real', 'it', '’s', None, None, None]
# 45 ’s
# it chooes -1
# ['warming', 'is', 'real', 'it', '’s', None, None, None, None]
# 3669
# 12
# 0 You
# it chooes 0
# [None, None, None, None, 'you', '’ve', 'heard', 'of', 'jim']
# 1 ’ve
# it chooes 1
# [None, None, None, 'you', '’ve', 'heard', 'of', 'jim', 'crow']
# 2 heard
# it chooes 2
# [None, None, 'you', '’ve', 'heard', 'of', 'jim', 'crow', 'southern']
# 3 of
# it chooes 3
# [None, 'you', '’ve', 'heard', 'of', 'jim', 'crow', 'southern', 'segregation']
# 4 Jim
# it chooes else
# ['you', '’ve', 'heard', 'of', 'jim', 'crow', 'southern', 'segregation', 'that']
# 5 Crow
# it chooes else
# ['’ve', 'heard', 'of', 'jim', 'crow', 'southern', 'segregation', 'that', 'was']
# 6 Southern
# it chooes else
# ['heard', 'of', 'jim', 'crow', 'southern', 'segregation', 'that', 'was', 'all']
# 7 Segregation
# it chooes else
# ['of', 'jim', 'crow', 'southern', 'segregation', 'that', 'was', 'all', 'democrats']
# 8 That
# it chooes -4
# ['jim', 'crow', 'southern', 'segregation', 'that', 'was', 'all', 'democrats', None]
# 9 was
# it chooes -3
# ['crow', 'southern', 'segregation', 'that', 'was', 'all', 'democrats', None, None]
# 10 ALL
# it chooes -2
# ['southern', 'segregation', 'that', 'was', 'all', 'democrats', None, None, None]
# 11 Democrats
# it chooes -1
# ['segregation', 'that', 'was', 'all', 'democrats', None, None, None, None]
# 3670
# 20
# 0 Young
# it chooes 0
# [None, None, None, None, 'young', 'female', 'athletes', 'dreams', 'accomplishments']
# 1 female
# it chooes 1
# [None, None, None, 'young', 'female', 'athletes', 'dreams', 'accomplishments', 'have']
# 2 athletes
# it chooes 2
# [None, None, 'young', 'female', 'athletes', 'dreams', 'accomplishments', 'have', 'been']
# 3 dreams
# it chooes 3
# [None, 'young', 'female', 'athletes', 'dreams', 'accomplishments', 'have', 'been', 'dashed']
# 4 accomplishments
# it chooes else
# ['young', 'female', 'athletes', 'dreams', 'accomplishments', 'have', 'been', 'dashed', 'across']
# 5 have
# it chooes else
# ['female', 'athletes', 'dreams', 'accomplishments', 'have', 'been', 'dashed', 'across', 'the']
# 6 been
# it chooes else
# ['athletes', 'dreams', 'accomplishments', 'have', 'been', 'dashed', 'across', 'the', 'country']
# 7 dashed
# it chooes else
# ['dreams', 'accomplishments', 'have', 'been', 'dashed', 'across', 'the', 'country', 'when']
# 8 across
# it chooes else
# ['accomplishments', 'have', 'been', 'dashed', 'across', 'the', 'country', 'when', 'competing']
# 9 the
# it chooes else
# ['have', 'been', 'dashed', 'across', 'the', 'country', 'when', 'competing', 'against']
# 10 country
# it chooes else
# ['been', 'dashed', 'across', 'the', 'country', 'when', 'competing', 'against', 'biological']
# 11 when
# it chooes else
# ['dashed', 'across', 'the', 'country', 'when', 'competing', 'against', 'biological', 'males']
# 12 competing
# it chooes else
# ['across', 'the', 'country', 'when', 'competing', 'against', 'biological', 'males', 'who']
# 13 against
# it chooes else
# ['the', 'country', 'when', 'competing', 'against', 'biological', 'males', 'who', 'identify']
# 14 biological
# it chooes else
# ['country', 'when', 'competing', 'against', 'biological', 'males', 'who', 'identify', 'as']
# 15 males
# it chooes else
# ['when', 'competing', 'against', 'biological', 'males', 'who', 'identify', 'as', 'females']
# 16 who
# it chooes -4
# ['competing', 'against', 'biological', 'males', 'who', 'identify', 'as', 'females', None]
# 17 identify
# it chooes -3
# ['against', 'biological', 'males', 'who', 'identify', 'as', 'females', None, None]
# 18 as
# it chooes -2
# ['biological', 'males', 'who', 'identify', 'as', 'females', None, None, None]
# 19 females
# it chooes -1
# ['males', 'who', 'identify', 'as', 'females', None, None, None, None]
# 3671
# 23
# 0 Young
# it chooes 0
# [None, None, None, None, 'young', 'white', 'men', 'reacting', 'to']
# 1 white
# it chooes 1
# [None, None, None, 'young', 'white', 'men', 'reacting', 'to', 'social']
# 2 men
# it chooes 2
# [None, None, 'young', 'white', 'men', 'reacting', 'to', 'social', 'educational']
# 3 reacting
# it chooes 3
# [None, 'young', 'white', 'men', 'reacting', 'to', 'social', 'educational', 'constructs']
# 4 to
# it chooes else
# ['young', 'white', 'men', 'reacting', 'to', 'social', 'educational', 'constructs', 'that']
# 5 social
# it chooes else
# ['white', 'men', 'reacting', 'to', 'social', 'educational', 'constructs', 'that', 'paint']
# 6 educational
# it chooes else
# ['men', 'reacting', 'to', 'social', 'educational', 'constructs', 'that', 'paint', 'them']
# 7 constructs
# it chooes else
# ['reacting', 'to', 'social', 'educational', 'constructs', 'that', 'paint', 'them', 'as']
# 8 that
# it chooes else
# ['to', 'social', 'educational', 'constructs', 'that', 'paint', 'them', 'as', 'the']
# 9 paint
# it chooes else
# ['social', 'educational', 'constructs', 'that', 'paint', 'them', 'as', 'the', 'embodiment']
# 10 them
# it chooes else
# ['educational', 'constructs', 'that', 'paint', 'them', 'as', 'the', 'embodiment', 'of']
# 11 as
# it chooes else
# ['constructs', 'that', 'paint', 'them', 'as', 'the', 'embodiment', 'of', 'historical']
# 12 the
# it chooes else
# ['that', 'paint', 'them', 'as', 'the', 'embodiment', 'of', 'historical', 'evil']
# 13 embodiment
# it chooes else
# ['paint', 'them', 'as', 'the', 'embodiment', 'of', 'historical', 'evil', 'are']
# 14 of
# it chooes else
# ['them', 'as', 'the', 'embodiment', 'of', 'historical', 'evil', 'are', 'fertile']
# 15 historical
# it chooes else
# ['as', 'the', 'embodiment', 'of', 'historical', 'evil', 'are', 'fertile', 'ground']
# 16 evil
# it chooes else
# ['the', 'embodiment', 'of', 'historical', 'evil', 'are', 'fertile', 'ground', 'for']
# 17 are
# it chooes else
# ['embodiment', 'of', 'historical', 'evil', 'are', 'fertile', 'ground', 'for', 'white']
# 18 fertile
# it chooes else
# ['of', 'historical', 'evil', 'are', 'fertile', 'ground', 'for', 'white', 'supremacists']
# 19 ground
# it chooes -4
# ['historical', 'evil', 'are', 'fertile', 'ground', 'for', 'white', 'supremacists', None]
# 20 for
# it chooes -3
# ['evil', 'are', 'fertile', 'ground', 'for', 'white', 'supremacists', None, None]
# 21 white
# it chooes -2
# ['are', 'fertile', 'ground', 'for', 'white', 'supremacists', None, None, None]
# 22 supremacists
# it chooes -1
# ['fertile', 'ground', 'for', 'white', 'supremacists', None, None, None, None]
# 3672
# 32
# 0 Young
# it chooes 0
# [None, None, None, None, 'young', 'women', 'taking', 'part', 'in']
# 1 women
# it chooes 1
# [None, None, None, 'young', 'women', 'taking', 'part', 'in', 'high']
# 2 taking
# it chooes 2
# [None, None, 'young', 'women', 'taking', 'part', 'in', 'high', 'school']
# 3 part
# it chooes 3
# [None, 'young', 'women', 'taking', 'part', 'in', 'high', 'school', 'college']
# 4 in
# it chooes else
# ['young', 'women', 'taking', 'part', 'in', 'high', 'school', 'college', 'athletics']
# 5 high
# it chooes else
# ['women', 'taking', 'part', 'in', 'high', 'school', 'college', 'athletics', 'across']
# 6 school
# it chooes else
# ['taking', 'part', 'in', 'high', 'school', 'college', 'athletics', 'across', 'the']
# 7 college
# it chooes else
# ['part', 'in', 'high', 'school', 'college', 'athletics', 'across', 'the', 'country']
# 8 athletics
# it chooes else
# ['in', 'high', 'school', 'college', 'athletics', 'across', 'the', 'country', 'have']
# 9 across
# it chooes else
# ['high', 'school', 'college', 'athletics', 'across', 'the', 'country', 'have', 'had']
# 10 the
# it chooes else
# ['school', 'college', 'athletics', 'across', 'the', 'country', 'have', 'had', 'their']
# 11 country
# it chooes else
# ['college', 'athletics', 'across', 'the', 'country', 'have', 'had', 'their', 'dreams']
# 12 have
# it chooes else
# ['athletics', 'across', 'the', 'country', 'have', 'had', 'their', 'dreams', 'of']
# 13 had
# it chooes else
# ['across', 'the', 'country', 'have', 'had', 'their', 'dreams', 'of', 'winning']
# 14 their
# it chooes else
# ['the', 'country', 'have', 'had', 'their', 'dreams', 'of', 'winning', 'dashed']
# 15 dreams
# it chooes else
# ['country', 'have', 'had', 'their', 'dreams', 'of', 'winning', 'dashed', 'by']
# 16 of
# it chooes else
# ['have', 'had', 'their', 'dreams', 'of', 'winning', 'dashed', 'by', 'the']
# 17 winning
# it chooes else
# ['had', 'their', 'dreams', 'of', 'winning', 'dashed', 'by', 'the', 'movement']
# 18 dashed
# it chooes else
# ['their', 'dreams', 'of', 'winning', 'dashed', 'by', 'the', 'movement', 'allow']
# 19 by
# it chooes else
# ['dreams', 'of', 'winning', 'dashed', 'by', 'the', 'movement', 'allow', 'biological']
# 20 the
# it chooes else
# ['of', 'winning', 'dashed', 'by', 'the', 'movement', 'allow', 'biological', 'male']
# 21 movement
# it chooes else
# ['winning', 'dashed', 'by', 'the', 'movement', 'allow', 'biological', 'male', 'who']
# 22 allow
# it chooes else
# ['dashed', 'by', 'the', 'movement', 'allow', 'biological', 'male', 'who', 'identify']
# 23 biological
# it chooes else
# ['by', 'the', 'movement', 'allow', 'biological', 'male', 'who', 'identify', 'as']
# 24 male
# it chooes else
# ['the', 'movement', 'allow', 'biological', 'male', 'who', 'identify', 'as', 'female']
# 25 who
# it chooes else
# ['movement', 'allow', 'biological', 'male', 'who', 'identify', 'as', 'female', 'compete']
# 26 identify
# it chooes else
# ['allow', 'biological', 'male', 'who', 'identify', 'as', 'female', 'compete', 'against']
# 27 as
# it chooes else
# ['biological', 'male', 'who', 'identify', 'as', 'female', 'compete', 'against', 'them']
# 28 female
# it chooes -4
# ['male', 'who', 'identify', 'as', 'female', 'compete', 'against', 'them', None]
# 29 compete
# it chooes -3
# ['who', 'identify', 'as', 'female', 'compete', 'against', 'them', None, None]
# 30 against
# it chooes -2
# ['identify', 'as', 'female', 'compete', 'against', 'them', None, None, None]
# 31 them
# it chooes -1
# ['as', 'female', 'compete', 'against', 'them', None, None, None, None]
# 3673
# 32
# 0 YouTube
# it chooes 0
# [None, None, None, None, 'youtube', 'is', 'making', 'clear', 'there']
# 1 is
# it chooes 1
# [None, None, None, 'youtube', 'is', 'making', 'clear', 'there', 'will']
# 2 making
# it chooes 2
# [None, None, 'youtube', 'is', 'making', 'clear', 'there', 'will', 'be']
# 3 clear
# it chooes 3
# [None, 'youtube', 'is', 'making', 'clear', 'there', 'will', 'be', 'no']
# 4 there
# it chooes else
# ['youtube', 'is', 'making', 'clear', 'there', 'will', 'be', 'no', 'birtherism']
# 5 will
# it chooes else
# ['is', 'making', 'clear', 'there', 'will', 'be', 'no', 'birtherism', 'on']
# 6 be
# it chooes else
# ['making', 'clear', 'there', 'will', 'be', 'no', 'birtherism', 'on', 'its']
# 7 no
# it chooes else
# ['clear', 'there', 'will', 'be', 'no', 'birtherism', 'on', 'its', 'platform']
# 8 birtherism
# it chooes else
# ['there', 'will', 'be', 'no', 'birtherism', 'on', 'its', 'platform', 'during']
# 9 on
# it chooes else
# ['will', 'be', 'no', 'birtherism', 'on', 'its', 'platform', 'during', 'this']
# 10 its
# it chooes else
# ['be', 'no', 'birtherism', 'on', 'its', 'platform', 'during', 'this', 'year']
# 11 platform
# it chooes else
# ['no', 'birtherism', 'on', 'its', 'platform', 'during', 'this', 'year', 'u.s.']
# 12 during
# it chooes else
# ['birtherism', 'on', 'its', 'platform', 'during', 'this', 'year', 'u.s.', 'presidential']
# 13 this
# it chooes else
# ['on', 'its', 'platform', 'during', 'this', 'year', 'u.s.', 'presidential', 'election']
# 14 year
# it chooes else
# ['its', 'platform', 'during', 'this', 'year', 'u.s.', 'presidential', 'election', 'a']
# 15 U.S.
# it chooes else
# ['platform', 'during', 'this', 'year', 'u.s.', 'presidential', 'election', 'a', 'belated']
# 16 presidential
# it chooes else
# ['during', 'this', 'year', 'u.s.', 'presidential', 'election', 'a', 'belated', 'response']
# 17 election
# it chooes else
# ['this', 'year', 'u.s.', 'presidential', 'election', 'a', 'belated', 'response', 'to']
# 18 a
# it chooes else
# ['year', 'u.s.', 'presidential', 'election', 'a', 'belated', 'response', 'to', 'a']
# 19 belated
# it chooes else
# ['u.s.', 'presidential', 'election', 'a', 'belated', 'response', 'to', 'a', 'type']
# 20 response
# it chooes else
# ['presidential', 'election', 'a', 'belated', 'response', 'to', 'a', 'type', 'of']
# 21 to
# it chooes else
# ['election', 'a', 'belated', 'response', 'to', 'a', 'type', 'of', 'conspiracy']
# 22 a
# it chooes else
# ['a', 'belated', 'response', 'to', 'a', 'type', 'of', 'conspiracy', 'theory']
# 23 type
# it chooes else
# ['belated', 'response', 'to', 'a', 'type', 'of', 'conspiracy', 'theory', 'more']
# 24 of
# it chooes else
# ['response', 'to', 'a', 'type', 'of', 'conspiracy', 'theory', 'more', 'prevalent']
# 25 conspiracy
# it chooes else
# ['to', 'a', 'type', 'of', 'conspiracy', 'theory', 'more', 'prevalent', 'in']
# 26 theory
# it chooes else
# ['a', 'type', 'of', 'conspiracy', 'theory', 'more', 'prevalent', 'in', 'the']
# 27 more
# it chooes else
# ['type', 'of', 'conspiracy', 'theory', 'more', 'prevalent', 'in', 'the', 'race']
# 28 prevalent
# it chooes -4
# ['of', 'conspiracy', 'theory', 'more', 'prevalent', 'in', 'the', 'race', None]
# 29 in
# it chooes -3
# ['conspiracy', 'theory', 'more', 'prevalent', 'in', 'the', 'race', None, None]
# 30 the
# it chooes -2
# ['theory', 'more', 'prevalent', 'in', 'the', 'race', None, None, None]
# 31 race
# it chooes -1
# ['more', 'prevalent', 'in', 'the', 'race', None, None, None, None]

# %%
# token itself
for index, row in dt.iterrows():
    print(index)
    for i, token in enumerate(row.spacy_lg_dict):
        print(i, token['text'])
        if token['window_text'] != None and token['window_lemma'] != None:
            window_text = token['window_text']
            window_lemma = token['window_lemma']

            # words
            c1, c2, c_m, c3, c4 = None, None, None, None, None
            if window_text[2] != None and window_text[3] != None:
                c1 = window_text[2] + ' ' + window_text[3] + ' ' + token['text_low']
            if window_text[3] != None:
                c2 = window_text[3] + ' ' + token['text_low']
            if window_text[3] != None and window_text[5] != None:
                c_m = window_text[3] + ' ' + token['text_low'] + ' ' + window_text[5]
            if window_text[5] != None:
                c3 = token['text_low'] + ' ' + window_text[5]
            if window_text[5] != None and window_text[6] != None:
                c4 = token['text_low'] + ' ' + window_text[5] + ' ' + window_text[6]

            # lemmas
            c1l, c2l, c_ml, c3l, c4l = None, None, None, None, None
            if window_lemma[2] != None and window_lemma[3] != None:
                c1l = window_lemma[2] + ' ' + window_lemma[3] + ' ' + token['lemma_low']
            if window_lemma[3] != None:
                c2l = window_lemma[3] + ' ' + token['lemma_low']
            if window_lemma[3] != None and window_lemma[5] != None:
                c_ml = window_lemma[3] + ' ' + token['lemma_low'] + ' ' + window_lemma[5]
            if window_lemma[5] != None:
                c3l = token['lemma_low'] + ' ' + window_lemma[5]
            if window_lemma[5] != None and window_text[6] != None:
                c4l = token['lemma_low'] + ' ' + window_lemma[5] + ' ' + window_lemma[6]

            # assertive verbs
            if token['text_low'] in assertive_verbs or c1 in assertive_verbs or c2 in assertive_verbs or \
            c_m in assertive_verbs or c3 in assertive_verbs or c4 in assertive_verbs or \
            token['lemma_low'] in assertive_verbs or c1l in assertive_verbs or c2l in assertive_verbs or \
            c_ml in assertive_verbs or c3l in assertive_verbs or c4l in assertive_verbs:
                token['assertive_verbs'] = 1
            else:
                token['assertive_verbs'] = 0   

            # factive verbs
            if token['text_low'] in factive_verbs or c1 in factive_verbs or c2 in factive_verbs or \
            c_m in factive_verbs or c3 in factive_verbs or c4 in factive_verbs or \
            token['lemma_low'] in factive_verbs or c1l in factive_verbs or c2l in factive_verbs or \
            c_ml in factive_verbs or c3l in factive_verbs or c4l in factive_verbs:
                token['factive_verbs'] = 1
            else:
                token['factive_verbs'] = 0   

            # report verbs
            if token['text_low'] in report_verbs or c1 in report_verbs or c2 in report_verbs or \
            c_m in report_verbs or c3 in report_verbs or c4 in report_verbs or \
            token['lemma_low'] in report_verbs or c1l in report_verbs or c2l in report_verbs or \
            c_ml in report_verbs or c3l in report_verbs or c4l in report_verbs:
                token['report_verbs'] = 1
            else:
                token['report_verbs'] = 0

            # hedges
            if token['text_low'] in hedges or c1 in hedges or c2 in hedges or \
            c_m in hedges or c3 in hedges or c4 in hedges or \
            token['lemma_low'] in hedges or c1l in hedges or c2l in hedges or \
            c_ml in hedges or c3l in hedges or c4l in hedges:
                token['hedges'] = 1
            else:
                token['hedges'] = 0

            # boosters
            if token['text_low'] in boosters or c1 in boosters or c2 in boosters or \
            c_m in boosters or c3 in boosters or c4 in boosters or \
            token['lemma_low'] in boosters or c1l in boosters or c2l in boosters or \
            c_ml in boosters or c3l in boosters or c4l in boosters:
                token['boosters'] = 1
            else:
                token['boosters'] = 0
                
            # implicative verbs
            if token['text_low'] in implicative_verbs or c1 in implicative_verbs or c2 in implicative_verbs or \
            c_m in implicative_verbs or c3 in implicative_verbs or c4 in implicative_verbs or \
            token['lemma_low'] in implicative_verbs or c1l in implicative_verbs or c2l in implicative_verbs or \
            c_ml in implicative_verbs or c3l in implicative_verbs or c4l in implicative_verbs:
                token['implicative_verbs'] = 1
            else:
                token['implicative_verbs'] = 0
            
        
        else:
            # assertive verbs
            if token['text_low'] in assertive_verbs or token['lemma_low'] in assertive_verbs:
                token['assertive_verbs'] = 1
            else:
                token['assertive_verbs'] = 0 

            # factive verbs
            if token['text_low'] in factive_verbs or token['lemma_low'] in factive_verbs:
                token['factive_verbs'] = 1
            else:
                token['factive_verbs'] = 0   

            # report verbs
            if token['text_low'] in report_verbs or token['lemma_low'] in report_verbs:
                token['report_verbs'] = 1
            else:
                token['report_verbs'] = 0

            # hedges
            if token['text_low'] in hedges or token['lemma_low'] in hedges:
                token['hedges'] = 1
            else:
                token['hedges'] = 0

            # boosters
            if token['text_low'] in boosters or token['lemma_low'] in boosters:
                token['boosters'] = 1
            else:
                token['boosters'] = 0
                
            # implicative verbs
            if token['text_low'] in implicative_verbs or token['lemma_low'] in implicative_verbs:
                token['implicative_verbs'] = 1
            else:
                token['implicative_verbs'] = 0
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 10 cause
# 11 autism
# 12 as
# 13 he
# 14 did
# 15 during
# 16 the
# 17 presidential
# 18 debates
# 19 many
# 20 parents
# 21 may
# 22 choose
# 23 vaccinate
# 24 putting
# 25 children
# 26 at
# 27 unnecessary
# 28 risk
# 3523
# 0 When
# 1 a
# 2 newly
# 3 organized
# 4 vaccine
# 5 research
# 6 group
# 7 at
# 8 the
# 9 U.S.
# 10 National
# 11 Institutes
# 12 of
# 13 Health
# 14 NIH
# 15 met
# 16 for
# 17 the
# 18 first
# 19 time
# 20 this
# 21 week
# 22 its
# 23 members
# 24 had
# 25 expected
# 26 be
# 27 able
# 28 ease
# 29 into
# 30 their
# 31 work
# 32 their
# 33 mandate
# 34 is
# 35 conduct
# 36 human
# 37 trials
# 38 for
# 39 emerging
# 40 health
# 41 threats
# 42 their
# 43 first
# 44 assignment
# 45 came
# 46 at
# 47 shocking
# 48 speed
# 3524
# 0 When
# 1 a
# 2 supporter
# 3 told
# 4 Warren
# 5 public
# 6 schools
# 7 need
# 8 teach
# 9 more
# 10 about
# 11 LGBTQ
# 12 history
# 13 sex
# 14 education
# 15 the
# 16 Massachusetts
# 17 senator
# 18 replied
# 19 her
# 20 education
# 21 secretary
# 22 would
# 23 have
# 24 be
# 25 interviewed
# 26 by
# 27 a
# 28 transgender
# 29 child
# 3525
# 0 When
# 1 carrying
# 2 a
# 3 firearm
# 4 you
# 5 have
# 6 the
# 7 ultimate
# 8 power
# 9 of
# 10 force
# 11 in
# 12 your
# 13 control
# 3526
# 0 When
# 1 Democrats
# 2 are
# 3 releasing
# 4 violent
# 5 criminals
# 6 encouraging
# 7 illegal
# 8 immigration
# 9 passing
# 10 laws
# 11 disarm
# 12 you
# 13 while
# 14 turning
# 15 the
# 16 police
# 17 into
# 18 eunuchs
# 19 it
# 20 ’s
# 21 over
# 3527
# 0 When
# 1 did
# 2 it
# 3 become
# 4 racist
# 5 like
# 6 the
# 7 national
# 8 anthem
# 9 Mount
# 10 Rushmore
# 3528
# 0 When
# 1 did
# 2 vaccines
# 3 become
# 4 politicized
# 5 Amid
# 6 a
# 7 measles
# 8 outbreak
# 9 suddenly
# 10 Republicans
# 11 support
# 12 anti
# 13 -
# 14 vaxxers
# 3529
# 0 When
# 1 far
# 2 right
# 3 white
# 4 evangelicals
# 5 white
# 6 nationalists
# 7 coronavirus
# 8 truthers
# 9 rail
# 10 against
# 11 social
# 12 distancing
# 13 encourage
# 14 large
# 15 gatherings
# 16 they
# 17 are
# 18 encouraging
# 19 suicidal
# 20 behavior
# 21 there
# 22 have
# 23 been
# 24 many
# 25 examples
# 3530
# 0 When
# 1 greed
# 2 power
# 3 are
# 4 exercised
# 5 by
# 6 giant
# 7 multinational
# 8 corporations
# 9 that
# 10 escape
# 11 the
# 12 discipline
# 13 of
# 14 the
# 15 nation
# 16 state
# 17 the
# 18 potential
# 19 for
# 20 evil
# 21 becomes
# 22 infinite
# 23 in
# 24 nature
# 3531
# 0 When
# 1 he
# 2 finally
# 3 spoke
# 4 in
# 5 the
# 6 Rose
# 7 Garden
# 8 on
# 9 Monday
# 10 Trump
# 11 threatened
# 12 deploy
# 13 the
# 14 military
# 15 against
# 16 American
# 17 citizens
# 18 if
# 19 the
# 20 governors
# 21 did
# 22 take
# 23 his
# 24 advice
# 25 for
# 26 a
# 27 more
# 28 forceful
# 29 crackdown
# 30 This
# 31 threat
# 32 did
# 33 appear
# 34 cow
# 35 anyone
# 36 only
# 37 increased
# 38 the
# 39 anger
# 3532
# 0 When
# 1 I
# 2 opened
# 3 Britain
# 4 bestselling
# 5 tabloid
# 6 conservative
# 7 Sunday
# 8 newspaper
# 9 I
# 10 was
# 11 greeted
# 12 by
# 13 a
# 14 double
# 15 page
# 16 spread
# 17 showing
# 18 a
# 19 vast
# 20 mob
# 21 of
# 22 Black
# 23 Lives
# 24 Matter
# 25 activists
# 26 marching
# 27 on
# 28 Downing
# 29 Street
# 30 in
# 31 London
# 3533
# 0 When
# 1 it
# 2 comes
# 3 to
# 4 the
# 5 Green
# 6 New
# 7 Deal
# 8 blueprint
# 9 address
# 10 the
# 11 climate
# 12 crisis
# 13 Republicans
# 14 generally
# 15 like
# 16 pretend
# 17 it
# 18 calls
# 19 for
# 20 the
# 21 elimination
# 22 of
# 23 hamburgers
# 3534
# 0 When
# 1 Mexico
# 2 leader
# 3 enters
# 4 the
# 5 White
# 6 House
# 7 meet
# 8 President
# 9 Donald
# 10 Trump
# 11 on
# 12 Wednesday
# 13 he
# 14 will
# 15 do
# 16 so
# 17 only
# 18 as
# 19 a
# 20 hostage
# 21 to
# 22 the
# 23 whims
# 24 of
# 25 his
# 26 U.S.
# 27 counterpart
# 28 also
# 29 as
# 30 partner
# 31 in
# 32 an
# 33 unlikely
# 34 alliance
# 35 that
# 36 has
# 37 benefited
# 38 both
# 39 men
# 3535
# 0 When
# 1 parents
# 2 borrow
# 3 the
# 4 debt
# 5 can
# 6 weigh
# 7 down
# 8 families
# 9 for
# 10 generations
# 11 the
# 12 burden
# 13 falls
# 14 particularly
# 15 hard
# 16 on
# 17 low
# 18 income
# 19 black
# 20 families
# 3536
# 0 When
# 1 President
# 2 Trump
# 3 rolled
# 4 out
# 5 his
# 6 recent
# 7 budget
# 8 proposal
# 9 it
# 10 made
# 11 some
# 12 cuts
# 13 that
# 14 were
# 15 always
# 16 going
# 17 cause
# 18 controversy
# 19 For
# 20 thing
# 21 his
# 22 plan
# 23 would
# 24 slash
# 25 subsidized
# 26 student
# 27 loan
# 28 repayment
# 29 plans
# 30 let
# 31 the
# 32 government
# 33 crack
# 34 down
# 35 on
# 36 missed
# 37 payments
# 3537
# 0 When
# 1 prioritizing
# 2 healthcare
# 3 workers
# 4 the
# 5 panel
# 6 noted
# 7 that
# 8 vaccines
# 9 should
# 10 go
# 11 first
# 12 to
# 13 people
# 14 who
# 15 have
# 16 the
# 17 most
# 18 contact
# 19 with
# 20 patients
# 3538
# 0 When
# 1 Republicans
# 2 warned
# 3 Democrats
# 4 that
# 5 impeachment
# 6 was
# 7 a
# 8 waste
# 9 of
# 10 time
# 11 a
# 12 divisive
# 13 partisan
# 14 exercise
# 15 a
# 16 distraction
# 17 from
# 18 the
# 19 real
# 20 issues
# 21 facing
# 22 the
# 23 country
# 24 a
# 25 lesson
# 26 Republicans
# 27 learned
# 28 the
# 29 hard
# 30 way
# 31 in
# 32 Bill
# 33 Clinton
# 34 impeachment
# 35 years
# 36 before
# 37 Democrats
# 38 ignored
# 39 them
# 3539
# 0 When
# 1 the
# 2 left
# 3 is
# 4 emboldened
# 5 cities
# 6 burn
# 7 statues
# 8 topple
# 9 careers
# 10 people
# 11 are
# 12 disappeared
# 13 good
# 14 men
# 15 are
# 16 murdered
# 17 civil
# 18 liberties
# 19 are
# 20 trampled
# 21 the
# 22 dual
# 23 horrors
# 24 of
# 25 blacklisting
# 26 censorship
# 27 reign
# 28 supreme
# 3540
# 0 When
# 1 the
# 2 men
# 3 basketball
# 4 Final
# 5 Four
# 6 tips
# 7 off
# 8 Saturday
# 9 in
# 10 Minneapolis
# 11 the
# 12 NCAA
# 13 biggest
# 14 most
# 15 lucrative
# 16 event
# 17 will
# 18 proceed
# 19 as
# 20 it
# 21 normally
# 22 does
# 23 the
# 24 athletes
# 25 on
# 26 the
# 27 floor
# 28 for
# 29 Virginia
# 30 Auburn
# 31 Michigan
# 32 State
# 33 Texas
# 34 Tech
# 35 will
# 36 play
# 37 games
# 38 that
# 39 generate
# 40 hundreds
# 41 of
# 42 millions
# 43 of
# 44 dollars
# 45 in
# 46 total
# 47 revenue
# 48 for
# 49 their
# 50 schools
# 51 the
# 52 NCAA
# 53 broadcast
# 54 companies
# 55 the
# 56 coaches
# 57 athletic
# 58 directors
# 59 TV
# 60 executives
# 61 NCAA
# 62 suits
# 63 will
# 64 share
# 65 in
# 66 the
# 67 riches
# 68 athletes
# 69 themselves
# 70 still
# 71 wo
# 72 receive
# 73 their
# 74 fair
# 75 share
# 76 thanks
# 77 to
# 78 a
# 79 recent
# 80 federal
# 81 court
# 82 decision
# 83 that
# 84 wo
# 85 change
# 86 in
# 87 the
# 88 immediate
# 89 future
# 3541
# 0 When
# 1 the
# 2 Muslim
# 3 ban
# 4 was
# 5 first
# 6 enacted
# 7 it
# 8 triggered
# 9 chaos
# 10 at
# 11 airports
# 12 prompted
# 13 widespread
# 14 protest
# 15 legal
# 16 challenges
# 17 it
# 18 continues
# 19 impose
# 20 devastating
# 21 costs
# 22 on
# 23 families
# 24 people
# 25 who
# 26 wish
# 27 come
# 28 to
# 29 the
# 30 U.S.
# 3542
# 0 When
# 1 the
# 2 nation
# 3 highest
# 4 civilian
# 5 honor
# 6 went
# 7 to
# 8 a
# 9 right
# 10 wing
# 11 media
# 12 personality
# 13 it
# 14 served
# 15 as
# 16 an
# 17 oddly
# 18 appropriate
# 19 capstone
# 20 to
# 21 Trump
# 22 broader
# 23 goals
# 3543
# 0 When
# 1 Trump
# 2 entered
# 3 the
# 4 White
# 5 House
# 6 in
# 7 Lopez
# 8 Obrador
# 9 likened
# 10 the
# 11 American
# 12 to
# 13 Adolf
# 14 Hitler
# 15 for
# 16 his
# 17 attitude
# 18 toward
# 19 migrants
# 3544
# 0 When
# 1 sadists
# 2 in
# 3 uniform
# 4 shoved
# 5 an
# 6 elderly
# 7 man
# 8 to
# 9 the
# 10 ground
# 11 for
# 12 the
# 13 crime
# 14 of
# 15 approaching
# 16 them
# 17 causing
# 18 him
# 19 a
# 20 critical
# 21 head
# 22 injury
# 23 their
# 24 fellow
# 25 cops
# 26 made
# 27 no
# 28 attempt
# 29 help
# 30 the
# 31 victim
# 3545
# 0 When
# 1 U.S.
# 2 schools
# 3 begin
# 4 the
# 5 next
# 6 academic
# 7 year
# 8 with
# 9 the
# 10 country
# 11 still
# 12 fighting
# 13 the
# 14 coronavirus
# 15 pandemic
# 16 students
# 17 should
# 18 spend
# 19 half
# 20 their
# 21 time
# 22 in
# 23 classrooms
# 24 half
# 25 doing
# 26 online
# 27 activities
# 28 that
# 29 pinpoint
# 30 their
# 31 individual
# 32 learning
# 33 style
# 34 such
# 35 as
# 36 videos
# 37 reading
# 3546
# 0 Whether
# 1 it
# 2 is
# 3 due
# 4 to
# 5 gaffes
# 6 his
# 7 inability
# 8 complete
# 9 some
# 10 sentences
# 11 lack
# 12 of
# 13 knowledge
# 14 on
# 15 a
# 16 subject
# 17 Biden
# 18 has
# 19 proven
# 20 that
# 21 interviews
# 22 are
# 23 for
# 24 him
# 25 the
# 26 media
# 27 has
# 28 covered
# 29 accordingly
# 3547
# 0 Whether
# 1 you
# 2 find
# 3 Trump
# 4 buffoonery
# 5 utterly
# 6 disgraceful
# 7 a
# 8 sign
# 9 of
# 10 authenticity
# 11 may
# 12 mark
# 13 our
# 14 central
# 15 political
# 16 divide
# 17 today
# 3548
# 0 Which
# 1 is
# 2 why
# 3 Republicans
# 4 like
# 5 McConnell
# 6 complaining
# 7 about
# 8 federal
# 9 entitlements
# 10 is
# 11 so
# 12 laughable
# 3549
# 0 While
# 1 a
# 2 number
# 3 of
# 4 transgender
# 5 advocates
# 6 LGBTQ
# 7 health
# 8 experts
# 9 applauded
# 10 P&G
# 11 decision
# 12 redesign
# 13 the
# 14 Always
# 15 packaging
# 16 by
# 17 removing
# 18 the
# 19 female
# 20 signs
# 21 the
# 22 company
# 23 announcement
# 24 sparked
# 25 criticism
# 26 online
# 27 including
# 28 a
# 29 bounty
# 30 of
# 31 transphobic
# 32 commentary
# 3550
# 0 While
# 1 Americans
# 2 still
# 3 cling
# 4 to
# 5 sexist
# 6 gender
# 7 roles
# 8 at
# 9 home
# 10 overwhelming
# 11 majorities
# 12 believe
# 13 that
# 14 sex
# 15 discrimination
# 16 in
# 17 public
# 18 spaces
# 19 should
# 20 be
# 21 illegal
# 3551
# 0 While
# 1 Barr
# 2 Republican
# 3 President
# 4 Donald
# 5 Trump
# 6 have
# 7 focused
# 8 blame
# 9 on
# 10 Antifa
# 11 a
# 12 loosely
# 13 organized
# 14 anti
# 15 -
# 16 fascist
# 17 movement
# 18 federal
# 19 prosecutors
# 20 in
# 21 Las
# 22 Vegas
# 23 on
# 24 Wednesday
# 25 charged
# 26 members
# 27 of
# 28 the
# 29 far
# 30 right
# 31 Boogaloo
# 32 movement
# 33 with
# 34 planning
# 35 cause
# 36 violence
# 37 destruction
# 38 during
# 39 protests
# 3552
# 0 While
# 1 Brazil
# 2 has
# 3 taken
# 4 the
# 5 lead
# 6 in
# 7 a
# 8 direct
# 9 attack
# 10 on
# 11 the
# 12 Amazon
# 13 with
# 14 Bolsonaro
# 15 adding
# 16 a
# 17 racial
# 18 element
# 19 to
# 20 his
# 21 attack
# 22 on
# 23 indigenous
# 24 people
# 25 the
# 26 pressure
# 27 open
# 28 the
# 29 Amazonian
# 30 forests
# 31 to
# 32 agriculture
# 33 logging
# 34 mining
# 35 is
# 36 just
# 37 limited
# 38 to
# 39 Brazil
# 3553
# 0 While
# 1 conservatives
# 2 may
# 3 find
# 4 comfort
# 5 in
# 6 the
# 7 old
# 8 saw
# 9 that
# 10 those
# 11 who
# 12 are
# 13 liberal
# 14 at
# 15 have
# 16 no
# 17 heart
# 18 those
# 19 who
# 20 are
# 21 conservative
# 22 at
# 23 have
# 24 no
# 25 brain
# 26 the
# 27 truth
# 28 as
# 29 Levin
# 30 knows
# 31 is
# 32 that
# 33 those
# 34 who
# 35 are
# 36 statists
# 37 at
# 38 usually
# 39 end
# 40 up
# 41 statists
# 42 at
# 43 he
# 44 ’s
# 45 content
# 46 allow
# 47 time
# 48 take
# 49 its
# 50 uncertain
# 51 political
# 52 toll
# 3554
# 0 While
# 1 corporate
# 2 media
# 3 hypocritical
# 4 politicians
# 5 others
# 6 labeled
# 7 anyone
# 8 in
# 9 favor
# 10 of
# 11 reopening
# 12 the
# 13 economy
# 14 getting
# 15 kids
# 16 back
# 17 in
# 18 school
# 19 even
# 20 gathering
# 21 for
# 22 holidays
# 23 a
# 24 grandma
# 25 killer
# 26 expert
# 27 in
# 28 ethics
# 29 health
# 30 policy
# 31 in
# 32 the
# 33 New
# 34 York
# 35 Times
# 36 says
# 37 that
# 38 vaccinating
# 39 elderly
# 40 people
# 41 first
# 42 is
# 43 racist
# 3555
# 0 While
# 1 Democrat
# 2 presidential
# 3 hopefuls
# 4 aim
# 5 weaponize
# 6 the
# 7 tax
# 8 cuts
# 9 Elaine
# 10 Parker
# 11 chief
# 12 communications
# 13 officer
# 14 of
# 15 Job
# 16 Creators
# 17 Network
# 18 JCN
# 19 told
# 20 Breitbart
# 21 News
# 22 in
# 23 an
# 24 exclusive
# 25 interview
# 26 in
# 27 January
# 28 that
# 29 it
# 30 is
# 31 precisely
# 32 what
# 33 will
# 34 assist
# 35 Trump
# 36 in
# 37 making
# 38 his
# 39 case
# 40 to
# 41 the
# 42 American
# 43 people
# 3556
# 0 While
# 1 Democrats
# 2 were
# 3 busy
# 4 diverting
# 5 the
# 6 attention
# 7 energy
# 8 of
# 9 the
# 10 entire
# 11 country
# 12 into
# 13 a
# 14 pointless
# 15 trial
# 16 that
# 17 could
# 18 possibly
# 19 have
# 20 ended
# 21 in
# 22 anything
# 23 other
# 24 than
# 25 President
# 26 Donald
# 27 Trump
# 28 acquittal
# 3557
# 0 While
# 1 Democrats
# 2 were
# 3 diverting
# 4 the
# 5 attention
# 6 energy
# 7 of
# 8 the
# 9 entire
# 10 country
# 11 into
# 12 a
# 13 pointless
# 14 trial
# 15 that
# 16 could
# 17 possibly
# 18 have
# 19 ended
# 20 in
# 21 anything
# 22 other
# 23 than
# 24 President
# 25 Donald
# 26 Trump
# 27 acquittal
# 3558
# 0 While
# 1 Democrats
# 2 were
# 3 persistent
# 4 in
# 5 their
# 6 questioning
# 7 the
# 8 hearing
# 9 retained
# 10 a
# 11 respectful
# 12 tone
# 13 Barrett
# 14 remained
# 15 even
# 16 tempered
# 17 while
# 18 nimbly
# 19 sidestepping
# 20 questions
# 21 on
# 22 her
# 23 views
# 24 on
# 25 abortion
# 26 LGBT
# 27 rights
# 28 gun
# 29 control
# 30 voting
# 31 rights
# 3559
# 0 While
# 1 each
# 2 sport
# 3 has
# 4 its
# 5 own
# 6 rules
# 7 with
# 8 regards
# 9 to
# 10 religious
# 11 headwear
# 12 Muslim
# 13 women
# 14 who
# 15 compete
# 16 while
# 17 wearing
# 18 a
# 19 hijab
# 20 have
# 21 faced
# 22 a
# 23 litany
# 24 of
# 25 obstacles
# 3560
# 0 While
# 1 emphasizing
# 2 he
# 3 ’s
# 4 singling
# 5 out
# 6 party
# 7 Cohen
# 8 warned
# 9 about
# 10 the
# 11 danger
# 12 of
# 13 normalizing
# 14 white
# 15 supremacist
# 16 ideology
# 3561
# 0 While
# 1 falling
# 2 short
# 3 of
# 4 calling
# 5 half
# 6 the
# 7 nation
# 8 deplorable
# 9 as
# 10 former
# 11 Secretary
# 12 of
# 13 State
# 14 Hillary
# 15 Clinton
# 16 did
# 17 in
# 18 the
# 19 comments
# 20 echo
# 21 a
# 22 deep
# 23 disdain
# 24 for
# 25 a
# 26 large
# 27 population
# 28 of
# 29 the
# 30 country
# 31 increasingly
# 32 perpetuated
# 33 by
# 34 left
# 35 wing
# 36 elites
# 37 in
# 38 the
# 39 wake
# 40 of
# 41 the
# 42 George
# 43 Floyd
# 44 protests
# 45 characterizing
# 46 the
# 47 U.S.
# 48 as
# 49 irredeemably
# 50 racist
# 3562
# 0 While
# 1 health
# 2 experts
# 3 say
# 4 a
# 5 vaccine
# 6 prevent
# 7 infection
# 8 is
# 9 needed
# 10 return
# 11 life
# 12 to
# 13 normal
# 14 the
# 15 survey
# 16 points
# 17 to
# 18 a
# 19 potential
# 20 trust
# 21 issue
# 22 for
# 23 the
# 24 Trump
# 25 administration
# 26 already
# 27 under
# 28 fire
# 29 for
# 30 its
# 31 often
# 32 contradictory
# 33 safety
# 34 guidance
# 35 during
# 36 the
# 37 pandemic
# 3563
# 0 While
# 1 his
# 2 supporters
# 3 have
# 4 included
# 5 many
# 6 strains
# 7 of
# 8 nationalism
# 9 populism
# 10 he
# 11 did
# 12 run
# 13 as
# 14 a
# 15 Republican
# 16 this
# 17 will
# 18 hopefully
# 19 work
# 20 in
# 21 his
# 22 favor
# 23 Many
# 24 Americans
# 25 are
# 26 hopeful
# 27 excited
# 28 looking
# 29 forward
# 30 to
# 31 a
# 32 Trump
# 33 presidency
# 34 Here
# 35 are
# 36 some
# 37 of
# 38 the
# 39 reasons
# 40 why
# 3564
# 0 While
# 1 it
# 2 ’s
# 3 perfectly
# 4 evident
# 5 that
# 6 Trump
# 7 does
# 8 have
# 9 racist
# 10 supporters
# 11 which
# 12 he
# 13 is
# 14 suspiciously
# 15 reluctant
# 16 condemn
# 17 many
# 18 contend
# 19 that
# 20 Trumpism
# 21 is
# 22 itself
# 23 racist
# 24 merely
# 25 a
# 26 justified
# 27 reaction
# 28 to
# 29 the
# 30 Left
# 31 racial
# 32 patronage
# 3565
# 0 While
# 1 Lecturing
# 2 Americans
# 3 On
# 4 Racism
# 5 Big
# 6 Business
# 7 Opposes
# 8 Ban
# 9 On
# 10 Using
# 11 Foreign
# 12 Slave
# 13 Labor
# 3566
# 0 While
# 1 low
# 2 unemployment
# 3 steadily
# 4 if
# 5 slowly
# 6 rising
# 7 wages
# 8 have
# 9 improved
# 10 the
# 11 fortunes
# 12 of
# 13 lower
# 14 income
# 15 Americans
# 16 these
# 17 gains
# 18 pale
# 19 in
# 20 comparison
# 21 to
# 22 the
# 23 investment
# 24 gains
# 25 realized
# 26 by
# 27 the
# 28 wealthy
# 29 few
# 3567
# 0 While
# 1 many
# 2 things
# 3 were
# 4 certain
# 5 change
# 6 the
# 7 president
# 8 felt
# 9 sure
# 10 that
# 11 element
# 12 of
# 13 continuity
# 14 would
# 15 persist
# 16 the
# 17 United
# 18 States
# 19 would
# 20 determine
# 21 history
# 22 onward
# 23 course
# 3568
# 0 While
# 1 many
# 2 women
# 3 the
# 4 men
# 5 who
# 6 love
# 7 them
# 8 are
# 9 well
# 10 aware
# 11 that
# 12 spurred
# 13 on
# 14 by
# 15 the
# 16 Vatican
# 17 United
# 18 States
# 19 Conference
# 20 of
# 21 Catholic
# 22 Bishops
# 23 USCCB
# 24 the
# 25 so
# 26 called
# 27 personhood
# 28 movement
# 29 Republicans
# 30 are
# 31 working
# 32 feverishly
# 33 eradicate
# 34 women
# 35 reproductive
# 36 rights
# 3569
# 0 While
# 1 most
# 2 national
# 3 attention
# 4 has
# 5 been
# 6 focused
# 7 on
# 8 massive
# 9 demonstrations
# 10 violent
# 11 clashes
# 12 with
# 13 police
# 14 in
# 15 the
# 16 United
# 17 States
# 18 biggest
# 19 cities
# 20 like
# 21 New
# 22 York
# 23 Los
# 24 Angeles
# 25 hundreds
# 26 of
# 27 spontaneous
# 28 demonstrations
# 29 have
# 30 popped
# 31 up
# 32 in
# 33 little
# 34 towns
# 35 rural
# 36 areas
# 37 across
# 38 the
# 39 nation
# 40 in
# 41 recent
# 42 days
# 3570
# 0 While
# 1 no
# 2 one
# 3 is
# 4 praising
# 5 Trump
# 6 as
# 7 a
# 8 thought
# 9 leader
# 10 in
# 11 the
# 12 way
# 13 Limbaugh
# 14 has
# 15 been
# 16 he
# 17 ’s
# 18 undeniably
# 19 made
# 20 conservative
# 21 ideas
# 22 tangible
# 23 for
# 24 average
# 25 Americans
# 3571
# 0 While
# 1 NYC
# 2 has
# 3 largely
# 4 tamed
# 5 the
# 6 lethal
# 7 highly
# 8 contagious
# 9 coronavirus
# 10 another
# 11 epidemic
# 12 is
# 13 starting
# 14 rear
# 15 its
# 16 ugly
# 17 head
# 18 in
# 19 the
# 20 city
# 21 once
# 22 again
# 23 violent
# 24 crimes
# 3572
# 0 While
# 1 Omar
# 2 is
# 3 in
# 4 no
# 5 danger
# 6 of
# 7 being
# 8 held
# 9 accountable
# 10 for
# 11 her
# 12 extremism
# 13 her
# 14 ascent
# 15 to
# 16 rock
# 17 star
# 18 status
# 19 among
# 20 Democrats
# 21 their
# 22 media
# 23 cheering
# 24 section
# 25 gives
# 26 the
# 27 lie
# 28 to
# 29 their
# 30 claims
# 31 be
# 32 standing
# 33 up
# 34 against
# 35 hate
# 36 antisemitism
# 3573
# 0 While
# 1 opportunity
# 2 zone
# 3 program
# 4 that
# 5 offers
# 6 tax
# 7 breaks
# 8 to
# 9 investors
# 10 who
# 11 put
# 12 money
# 13 into
# 14 specially
# 15 designated
# 16 areas
# 17 was
# 18 pitched
# 19 as
# 20 a
# 21 way
# 22 help
# 23 struggling
# 24 neighborhoods
# 25 ProPublica
# 26 others
# 27 have
# 28 documented
# 29 how
# 30 the
# 31 process
# 32 has
# 33 appeared
# 34 benefit
# 35 billionaires
# 36 with
# 37 investments
# 38 in
# 39 areas
# 40 that
# 41 should
# 42 have
# 43 qualified
# 3574
# 0 While
# 1 Pace
# 2 receives
# 3 her
# 4 spiritual
# 5 grace
# 6 from
# 7 a
# 8 Christian
# 9 God
# 10 science
# 11 has
# 12 shown
# 13 that
# 14 faith
# 15 in
# 16 a
# 17 supernatural
# 18 wonder
# 19 whatever
# 20 it
# 21 may
# 22 be
# 23 that
# 24 bears
# 25 powerful
# 26 benefits
# 27 on
# 28 an
# 29 individual
# 30 mental
# 31 even
# 32 physical
# 33 well
# 34 being
# 3575
# 0 While
# 1 Pence
# 2 the
# 3 president
# 4 have
# 5 tried
# 6 paint
# 7 a
# 8 rosier
# 9 picture
# 10 of
# 11 the
# 12 virus
# 13 project
# 14 a
# 15 return
# 16 to
# 17 normalcy
# 18 some
# 19 members
# 20 of
# 21 the
# 22 task
# 23 force
# 24 are
# 25 eager
# 26 resume
# 27 appearances
# 28 from
# 29 White
# 30 House
# 31 grounds
# 3576
# 0 While
# 1 President
# 2 Donald
# 3 Trump
# 4 impeachment
# 5 trial
# 6 had
# 7 been
# 8 wrapping
# 9 up
# 10 he
# 11 expanded
# 12 of
# 13 his
# 14 most
# 15 controversial
# 16 inflammatory
# 17 policies
# 18 with
# 19 little
# 20 fanfare
# 21 minimal
# 22 opposition
# 23 the
# 24 travel
# 25 ban
# 26 on
# 27 people
# 28 from
# 29 multiple
# 30 Muslim
# 31 majority
# 32 countries
# 3577
# 0 While
# 1 President
# 2 Trump
# 3 visited
# 4 the
# 5 southern
# 6 border
# 7 Thursday
# 8 Democratic
# 9 darling
# 10 Beto
# 11 O’Rourke
# 12 visited
# 13 the
# 14 dentist
# 15 posting
# 16 a
# 17 bizarre
# 18 video
# 19 showing
# 20 him
# 21 getting
# 22 a
# 23 mouth
# 24 wide
# 25 open
# 26 cleaning
# 27 in
# 28 order
# 29 highlight
# 30 the
# 31 story
# 32 of
# 33 his
# 34 dental
# 35 hygienist
# 36 ’s
# 37 upbringing
# 38 in
# 39 El
# 40 Paso
# 3578
# 0 While
# 1 riots
# 2 raged
# 3 across
# 4 the
# 5 United
# 6 States
# 7 over
# 8 Floyd
# 9 death
# 10 editors
# 11 on
# 12 Wikipedia
# 13 promptly
# 14 set
# 15 out
# 16 spin
# 17 the
# 18 narrative
# 19 of
# 20 the
# 21 unrest
# 22 against
# 23 Trump
# 3579
# 0 While
# 1 sexual
# 2 ambiguity
# 3 does
# 4 occasionally
# 5 occur
# 6 the
# 7 authors
# 8 note
# 9 intersex
# 10 individuals
# 11 are
# 12 extremely
# 13 rare
# 14 they
# 15 are
# 16 a
# 17 third
# 18 sex
# 19 proof
# 20 that
# 21 sex
# 22 is
# 23 a
# 24 spectrum
# 25 a
# 26 social
# 27 construct
# 3580
# 0 While
# 1 Snapchat
# 2 is
# 3 happy
# 4 blame
# 5 President
# 6 Trump
# 7 who
# 8 is
# 9 working
# 10 restore
# 11 order
# 12 for
# 13 the
# 14 ongoing
# 15 violence
# 16 it
# 17 has
# 18 said
# 19 anything
# 20 about
# 21 support
# 22 for
# 23 the
# 24 domestic
# 25 terrorist
# 26 Antifa
# 27 movement
# 28 on
# 29 its
# 30 platform
# 3581
# 0 While
# 1 the
# 2 announcement
# 3 identifies
# 4 cases
# 5 of
# 6 alleged
# 7 police
# 8 misconduct
# 9 it
# 10 does
# 11 mention
# 12 violence
# 13 accompanying
# 14 the
# 15 protests
# 16 over
# 17 Floyd
# 18 death
# 19 that
# 20 the
# 21 Foundation
# 22 is
# 23 now
# 24 backing
# 3582
# 0 While
# 1 the
# 2 major
# 3 baseball
# 4 leagues
# 5 wo
# 6 be
# 7 affected
# 8 much
# 9 by
# 10 tariffs
# 11 on
# 12 Chinese
# 13 imports
# 14 everyone
# 15 from
# 16 Double
# 17 A
# 18 players
# 19 down
# 20 through
# 21 the
# 22 office
# 23 softball
# 24 team
# 25 will
# 26 be
# 3583
# 0 While
# 1 the
# 2 majority
# 3 of
# 4 Americans
# 5 seem
# 6 accept
# 7 scientific
# 8 information
# 9 about
# 10 the
# 11 deadly
# 12 coronavirus
# 13 are
# 14 wary
# 15 of
# 16 reopening
# 17 the
# 18 country
# 19 before
# 20 we
# 21 can
# 22 be
# 23 sure
# 24 it
# 25 ’s
# 26 safe
# 27 segment
# 28 of
# 29 the
# 30 population
# 31 is
# 32 driving
# 33 the
# 34 opposite
# 35 narrative
# 36 This
# 37 group
# 38 is
# 39 small
# 40 vocal
# 41 represents
# 42 a
# 43 predictable
# 44 if
# 45 threatening
# 46 merging
# 47 of
# 48 forces
# 3584
# 0 While
# 1 the
# 2 mayor
# 3 has
# 4 severely
# 5 curtailed
# 6 religious
# 7 practice
# 8 in
# 9 the
# 10 city
# 11 he
# 12 has
# 13 defended
# 14 the
# 15 rights
# 16 of
# 17 citizens
# 18 form
# 19 huge
# 20 gatherings
# 21 protest
# 22 even
# 23 violently
# 24 obviously
# 25 without
# 26 social
# 27 distancing
# 28 masks
# 29 except
# 30 perhaps
# 31 antifa
# 32 masks
# 3585
# 0 While
# 1 the
# 2 overwhelming
# 3 majority
# 4 of
# 5 Americans
# 6 choose
# 7 have
# 8 their
# 9 children
# 10 vaccinated
# 11 the
# 12 number
# 13 of
# 14 children
# 15 who
# 16 go
# 17 completely
# 18 unvaccinated
# 19 is
# 20 rising
# 3586
# 0 While
# 1 the
# 2 piece
# 3 fairly
# 4 analyzes
# 5 the
# 6 fracturing
# 7 of
# 8 the
# 9 white
# 10 nationalist
# 11 movement
# 12 it
# 13 makes
# 14 the
# 15 bizarre
# 16 claim
# 17 that
# 18 ideas
# 19 that
# 20 are
# 21 widely
# 22 popular
# 23 amongst
# 24 mainstream
# 25 conservatives
# 26 such
# 27 as
# 28 ending
# 29 affirmative
# 30 action
# 31 are
# 32 actually
# 33 white
# 34 nationalist
# 35 in
# 36 origin
# 3587
# 0 While
# 1 the
# 2 press
# 3 had
# 4 no
# 5 problem
# 6 regurgitating
# 7 the
# 8 propaganda
# 9 Ben
# 10 Rhodes
# 11 created
# 12 in
# 13 the
# 14 D.C.
# 15 echo
# 16 chamber
# 17 sell
# 18 President
# 19 Obama
# 20 disastrous
# 21 Iran
# 22 deal
# 23 with
# 24 Trump
# 25 corporate
# 26 media
# 27 has
# 28 opted
# 29 limit
# 30 coverage
# 31 of
# 32 Iran
# 33 horrific
# 34 human
# 35 rights
# 36 abuses
# 3588
# 0 While
# 1 the
# 2 stupid
# 3 Democrats
# 4 who
# 5 vote
# 6 for
# 7 Democrats
# 8 stress
# 9 worry
# 10 about
# 11 another
# 12 round
# 13 of
# 14 looting
# 15 burning
# 16 this
# 17 weekend
# 18 in
# 19 their
# 20 Democrat
# 21 run
# 22 cities
# 23 all
# 24 I
# 25 ’m
# 26 worried
# 27 about
# 28 is
# 29 the
# 30 weather
# 3589
# 0 While
# 1 the
# 2 threat
# 3 of
# 4 anti
# 5 -
# 6 trans
# 7 bills
# 8 being
# 9 passed
# 10 into
# 11 law
# 12 is
# 13 real
# 14 present
# 15 all
# 16 such
# 17 legislation
# 18 will
# 19 almost
# 20 certainly
# 21 be
# 22 challenged
# 23 in
# 24 the
# 25 courts
# 26 immediately
# 27 upon
# 28 passing
# 29 before
# 30 it
# 31 can
# 32 be
# 33 fully
# 34 implemented
# 3590
# 0 While
# 1 the
# 2 workaday
# 3 majority
# 4 of
# 5 Americans
# 6 continue
# 7 be
# 8 mired
# 9 in
# 10 our
# 11 low
# 12 wage
# 13 economy
# 14 the
# 15 precious
# 16 few
# 17 at
# 18 the
# 19 tippy
# 20 top
# 21 soared
# 22 out
# 23 of
# 24 sight
# 25 in
# 3591
# 0 While
# 1 these
# 2 many
# 3 similarities
# 4 between
# 5 Green
# 6 New
# 7 Deal
# 8 the
# 9 constitution
# 10 ushered
# 11 in
# 12 by
# 13 Venezuelan
# 14 leftist
# 15 dictator
# 16 Hugo
# 17 Chavez
# 18 in
# 19 may
# 20 be
# 21 just
# 22 happenstance
# 23 the
# 24 important
# 25 thing
# 26 remember
# 27 is
# 28 that
# 29 Venezuela
# 30 under
# 31 its
# 32 new
# 33 constitution
# 34 has
# 35 become
# 36 a
# 37 disaster
# 38 zone
# 3592
# 0 While
# 1 Trump
# 2 has
# 3 stopped
# 4 short
# 5 of
# 6 invoking
# 7 the
# 8 act
# 9 use
# 10 the
# 11 military
# 12 enforce
# 13 laws
# 14 domestically
# 15 he
# 16 ’s
# 17 kept
# 18 the
# 19 option
# 20 open
# 21 fomenting
# 22 further
# 23 unrest
# 24 division
# 25 Rather
# 26 than
# 27 staging
# 28 photo
# 29 opportunities
# 30 while
# 31 awkwardly
# 32 holding
# 33 a
# 34 Bible
# 35 in
# 36 Lafayette
# 37 Square
# 38 Trump
# 39 would
# 40 have
# 41 issued
# 42 a
# 43 formal
# 44 proclamation
# 45 calling
# 46 on
# 47 the
# 48 insurgents
# 49 disperse
# 50 if
# 51 he
# 52 ’s
# 53 serious
# 54 about
# 55 the
# 56 application
# 57 of
# 58 the
# 59 Insurrection
# 60 Act
# 3593
# 0 While
# 1 in
# 2 the
# 3 wake
# 4 of
# 5 the
# 6 El
# 7 Paso
# 8 murders
# 9 the
# 10 media
# 11 most
# 12 of
# 13 our
# 14 politicians
# 15 are
# 16 acting
# 17 shocked
# 18 that
# 19 there
# 20 are
# 21 armed
# 22 racists
# 23 in
# 24 America
# 25 who
# 26 are
# 27 trying
# 28 terrify
# 29 people
# 30 of
# 31 color
# 32 the
# 33 reality
# 34 is
# 35 that
# 36 it
# 37 ’s
# 38 pretty
# 39 much
# 40 always
# 41 been
# 42 that
# 43 way
# 44 here
# 45 in
# 46 the
# 47 United
# 48 States
# 3594
# 0 While
# 1 in
# 2 the
# 3 wake
# 4 of
# 5 the
# 6 El
# 7 Paso
# 8 murders
# 9 the
# 10 media
# 11 most
# 12 of
# 13 our
# 14 politicians
# 15 are
# 16 acting
# 17 shocked—“shocked
# 18 I
# 19 tell
# 20 you!”—that
# 21 there
# 22 are
# 23 armed
# 24 racists
# 25 in
# 26 America
# 27 who
# 28 are
# 29 trying
# 30 terrify
# 31 people
# 32 of
# 33 color
# 34 the
# 35 reality
# 36 is
# 37 that
# 38 it
# 39 ’s
# 40 pretty
# 41 much
# 42 always
# 43 been
# 44 that
# 45 way
# 46 here
# 47 in
# 48 the
# 49 United
# 50 States
# 3595
# 0 White
# 1 House
# 2 National
# 3 Economic
# 4 Council
# 5 Director
# 6 Larry
# 7 Kudlow
# 8 said
# 9 on
# 10 Friday
# 11 that
# 12 he
# 13 did
# 14 favor
# 15 a
# 16 higher
# 17 federal
# 18 tax
# 19 on
# 20 gasoline
# 21 fund
# 22 an
# 23 infrastructure
# 24 program
# 25 if
# 26 states
# 27 wanted
# 28 raise
# 29 their
# 30 own
# 31 gas
# 32 taxes
# 33 that
# 34 was
# 35 up
# 36 to
# 37 them
# 3596
# 0 White
# 1 House
# 2 Press
# 3 Secretary
# 4 Kayleigh
# 5 McEnany
# 6 voiced
# 7 tepid
# 8 support
# 9 for
# 10 Defense
# 11 Secretary
# 12 Mark
# 13 Esper
# 14 after
# 15 he
# 16 stated
# 17 Wednesday
# 18 that
# 19 he
# 20 did
# 21 support
# 22 invoking
# 23 the
# 24 Insurrection
# 25 Act
# 26 which
# 27 would
# 28 allow
# 29 active
# 30 duty
# 31 troops
# 32 act
# 33 in
# 34 domestic
# 35 law
# 36 enforcement
# 37 roles
# 3597
# 0 White
# 1 House
# 2 senior
# 3 adviser
# 4 Jared
# 5 Kushner
# 6 criticized
# 7 athletes
# 8 others
# 9 who
# 10 have
# 11 protested
# 12 against
# 13 U.S.
# 14 racism
# 15 on
# 16 social
# 17 media
# 18 basketball
# 19 courts
# 20 suggested
# 21 that
# 22 Black
# 23 people
# 24 had
# 25 want
# 26 succeed
# 27 for
# 28 policies
# 29 change
# 3598
# 0 White
# 1 mobs
# 2 have
# 3 once
# 4 again
# 5 moved
# 6 out
# 7 of
# 8 the
# 9 shadows
# 10 into
# 11 the
# 12 limelight
# 13 during
# 14 this
# 15 Trump
# 16 moment
# 3599
# 0 White
# 1 nationalism
# 2 fueled
# 3 violence
# 4 is
# 5 on
# 6 the
# 7 rise
# 8 FBI
# 9 is
# 10 slow
# 11 call
# 12 it
# 13 domestic
# 14 terrorism
# 3600
# 0 White
# 1 nationalist
# 2 arrested
# 3 for
# 4 alleged
# 5 threat
# 6 against
# 7 Ohio
# 8 Jewish
# 9 community
# 10 center
# 3601
# 0 White
# 1 nationalists
# 2 also
# 3 expressed
# 4 excitement
# 5 Tuesday
# 6 about
# 7 Trump
# 8 plan
# 9 use
# 10 an
# 11 executive
# 12 order
# 13 end
# 14 birthright
# 15 citizenship
# 16 the
# 17 automatic
# 18 grant
# 19 of
# 20 citizen
# 21 status
# 22 to
# 23 anyone
# 24 born
# 25 in
# 26 the
# 27 United
# 28 States
# 3602
# 0 White
# 1 people
# 2 are
# 3 being
# 4 asked
# 5 pushed
# 6 take
# 7 stock
# 8 of
# 9 their
# 10 whiteness
# 11 identify
# 12 with
# 13 it
# 14 more
# 15 This
# 16 is
# 17 a
# 18 remarkably
# 19 bad
# 20 idea
# 3603
# 0 White
# 1 supremacist
# 2 violent
# 3 extremists
# 4 can
# 5 generally
# 6 be
# 7 characterized
# 8 by
# 9 hatred
# 10 for
# 11 immigrants
# 12 ethnic
# 13 minorities
# 14 often
# 15 combining
# 16 these
# 17 prejudices
# 18 with
# 19 virulent
# 20 anti
# 21 -
# 22 Semitism
# 23 anti
# 24 -
# 25 Muslim
# 26 views
# 27 the
# 28 DHS
# 29 report
# 30 states
# 3604
# 0 Whitmer
# 1 takes
# 2 on
# 3 Trump
# 4 for
# 5 claiming
# 6 the
# 7 economy
# 8 is
# 9 booming
# 10 asking
# 11 for
# 12 whom
# 13 She
# 14 details
# 15 local
# 16 pieces
# 17 of
# 18 legislation
# 19 Dem
# 20 Governors
# 21 are
# 22 working
# 23 on
# 24 before
# 25 claiming
# 26 Democrats
# 27 are
# 28 the
# 29 ones
# 30 who
# 31 actually
# 32 fight
# 33 for
# 34 hardworking
# 35 Americans
# 3605
# 0 WHO
# 1 is
# 2 working
# 3 ensure
# 4 fair
# 5 vaccine
# 6 distribution
# 7 in
# 8 the
# 9 meantime
# 10 it
# 11 is
# 12 key
# 13 suppress
# 14 the
# 15 virus
# 16 spread
# 17 said
# 18 Mike
# 19 Ryan
# 20 head
# 21 of
# 22 WHO
# 23 emergencies
# 24 program
# 25 as
# 26 daily
# 27 new
# 28 cases
# 29 around
# 30 the
# 31 globe
# 32 are
# 33 at
# 34 near
# 35 record
# 36 levels
# 3606
# 0 Why
# 1 are
# 2 members
# 3 of
# 4 the
# 5 fairer
# 6 sex
# 7 on
# 8 the
# 9 frontlines
# 10 of
# 11 riotous
# 12 efforts
# 13 support
# 14 a
# 15 movement
# 16 that
# 17 insists
# 18 they
# 19 're
# 20 racist
# 21 capitalism
# 22 is
# 23 racist
# 24 the
# 25 whole
# 26 system
# 27 is
# 28 racist
# 3607
# 0 Why
# 1 did
# 2 Democrats
# 3 vote
# 4 overwhelmingly
# 5 against
# 6 a
# 7 bill
# 8 that
# 9 would
# 10 require
# 11 infants
# 12 born
# 13 alive
# 14 after
# 15 abortion
# 16 be
# 17 treated
# 18 as
# 19 any
# 20 other
# 21 infant
# 22 born
# 23 at
# 24 that
# 25 gestational
# 26 age
# 27 Because
# 28 abortion
# 29 is
# 30 the
# 31 right
# 32 destroy
# 33 own
# 34 child
# 35 if
# 36 a
# 37 woman
# 38 chose
# 39 kill
# 40 her
# 41 baby
# 42 to
# 43 the
# 44 left
# 45 it
# 46 would
# 47 seem
# 48 a
# 49 violation
# 50 of
# 51 her
# 52 so
# 53 called
# 54 right
# 55 choose
# 56 for
# 57 doctors
# 58 try
# 59 save
# 60 that
# 61 baby
# 3608
# 0 Why
# 1 did
# 2 Trump
# 3 offer
# 4 up
# 5 this
# 6 cards
# 7 That
# 8 's
# 9 because
# 10 his
# 11 vaunted
# 12 skills
# 13 in
# 14 making
# 15 the
# 16 deal
# 17 absolutely
# 18 failed
# 19 budge
# 20 the
# 21 prices
# 22 from
# 23 pharmaceutical
# 24 companies
# 25 a
# 26 deal
# 27 that
# 28 had
# 29 been
# 30 in
# 31 the
# 32 works
# 33 for
# 34 months
# 35 absolutely
# 36 collapsed
# 3609
# 0 Why
# 1 women
# 2 have
# 3 abortions
# 4 is
# 5 a
# 6 topic
# 7 much
# 8 discussed
# 9 by
# 10 those
# 11 who
# 12 argue
# 13 that
# 14 ending
# 15 a
# 16 life
# 17 in
# 18 the
# 19 womb
# 20 is
# 21 sometimes
# 22 necessary
# 3610
# 0 Wikipedia
# 1 coverage
# 2 of
# 3 other
# 4 contentious
# 5 political
# 6 topics
# 7 such
# 8 as
# 9 abortion
# 10 were
# 11 also
# 12 criticized
# 13 with
# 14 Sanger
# 15 singling
# 16 out
# 17 Wikipedia
# 18 claiming
# 19 abortion
# 20 is
# 21 of
# 22 the
# 23 safest
# 24 procedures
# 25 in
# 26 medicine
# 3611
# 0 Wikipedia
# 1 own
# 2 articles
# 3 on
# 4 the
# 5 Floyd
# 6 protests
# 7 similarly
# 8 reflect
# 9 the
# 10 Foundation
# 11 abandonment
# 12 of
# 13 neutrality
# 14 by
# 15 being
# 16 unduly
# 17 skewed
# 18 towards
# 19 smearing
# 20 President
# 21 Donald
# 22 Trump
# 23 while
# 24 downplaying
# 25 protestor
# 26 violence
# 27 the
# 28 violent
# 29 Antifa
# 30 group
# 31 involvement
# 3612
# 0 WILL
# 1 noted
# 2 gender
# 3 dysphoria
# 4 is
# 5 a
# 6 mental
# 7 health
# 8 issue
# 9 parents
# 10 have
# 11 the
# 12 right
# 13 make
# 14 healthcare
# 15 decisions
# 16 on
# 17 behalf
# 18 of
# 19 their
# 20 children
# 3613
# 0 Will
# 1 the
# 2 American
# 3 people
# 4 follow
# 5 the
# 6 commands
# 7 of
# 8 Donald
# 9 Trump
# 10 coronavirus
# 11 death
# 12 cult
# 3614
# 0 Wilson
# 1 Ali
# 2 have
# 3 received
# 4 death
# 5 threats
# 6 for
# 7 the
# 8 crime
# 9 of
# 10 poking
# 11 fun
# 12 at
# 13 Donald
# 14 Trump
# 15 the
# 16 members
# 17 of
# 18 his
# 19 political
# 20 cult
# 3615
# 0 Wilton
# 1 Gregory
# 2 the
# 3 first
# 4 African
# 5 American
# 6 be
# 7 named
# 8 as
# 9 cardinal
# 10 known
# 11 as
# 12 a
# 13 refined
# 14 diplomat
# 15 made
# 16 headlines
# 17 when
# 18 he
# 19 blasted
# 20 President
# 21 Donald
# 22 Trump
# 23 photo
# 24 opportunity
# 25 hoisting
# 26 a
# 27 Bible
# 28 at
# 29 a
# 30 Washington
# 31 church
# 32 after
# 33 police
# 34 used
# 35 tear
# 36 gas
# 37 clear
# 38 demonstrators
# 39 in
# 40 June
# 3616
# 0 Wimbledon
# 1 champion
# 2 Navratilova
# 3 who
# 4 has
# 5 campaigned
# 6 for
# 7 gay
# 8 rights
# 9 suffered
# 10 abuse
# 11 when
# 12 she
# 13 came
# 14 out
# 15 in
# 16 the
# 17 1980s
# 18 argued
# 19 trans
# 20 women
# 21 have
# 22 unfair
# 23 physical
# 24 advantages
# 3617
# 0 Winston
# 1 Churchill
# 2 was
# 3 a
# 4 racist
# 5 so
# 6 the
# 7 Black
# 8 Lives
# 9 Matter
# 10 graffiti
# 11 says
# 12 on
# 13 the
# 14 plinth
# 15 of
# 16 his
# 17 statue
# 18 in
# 19 London
# 20 Parliament
# 21 Square
# 22 which
# 23 is
# 24 bound
# 25 be
# 26 pulled
# 27 down
# 28 by
# 29 hard
# 30 left
# 31 activists
# 32 sooner
# 33 later
# 34 because
# 35 the
# 36 police
# 37 do
# 38 seem
# 39 have
# 40 that
# 41 much
# 42 of
# 43 an
# 44 appetite
# 45 save
# 46 it
# 3618
# 0 With
# 1 Democrats
# 2 fuming
# 3 over
# 4 Trump
# 5 push
# 6 for
# 7 a
# 8 border
# 9 wall
# 10 amid
# 11 a
# 12 still
# 13 unresolved
# 14 funding
# 15 standoff
# 16 those
# 17 guest
# 18 lists
# 19 signal
# 20 the
# 21 president
# 22 could
# 23 face
# 24 a
# 25 tough
# 26 crowd
# 3619
# 0 With
# 1 hundreds
# 2 of
# 3 potential
# 4 vaccines
# 5 in
# 6 various
# 7 stages
# 8 of
# 9 development
# 10 around
# 11 the
# 12 world
# 13 Russia
# 14 was
# 15 the
# 16 first
# 17 country
# 18 license
# 19 its
# 20 vaccine
# 21 for
# 22 public
# 23 use
# 24 alongside
# 25 China
# 26 has
# 27 been
# 28 deploying
# 29 the
# 30 shots
# 31 before
# 32 full
# 33 efficacy
# 34 trials
# 35 are
# 36 complete
# 3620
# 0 With
# 1 it
# 2 ’s
# 3 bothsidesism
# 4 pro
# 5 -
# 6 Trump
# 7 onesiderism
# 8 the
# 9 New
# 10 York
# 11 Times
# 12 is
# 13 flailing
# 3621
# 0 With
# 1 June
# 2 marking
# 3 the
# 4 start
# 5 of
# 6 the
# 7 annual
# 8 Pride
# 9 month
# 10 when
# 11 many
# 12 gay
# 13 trans
# 14 people
# 15 commemorate
# 16 riots
# 17 against
# 18 police
# 19 brutality
# 20 in
# 21 in
# 22 New
# 23 York
# 24 City
# 25 Brown
# 26 called
# 27 on
# 28 the
# 29 LGBT+
# 30 community
# 31 recall
# 32 the
# 33 protest
# 34 driven
# 35 roots
# 36 of
# 37 the
# 38 celebration
# 3622
# 0 With
# 1 just
# 2 over
# 3 a
# 4 year
# 5 left
# 6 in
# 7 President
# 8 Donald
# 9 Trump
# 10 first
# 11 term
# 12 another
# 13 late
# 14 breaking
# 15 news
# 16 item
# 17 barely
# 18 made
# 19 waves
# 20 The
# 21 Interior
# 22 Department
# 23 which
# 24 manages
# 25 the
# 26 majority
# 27 of
# 28 the
# 29 federal
# 30 government
# 31 public
# 32 lands
# 33 deleted
# 34 sexual
# 35 orientation
# 36 from
# 37 its
# 38 anti
# 39 -
# 40 discrimination
# 41 guidelines
# 3623
# 0 With
# 1 many
# 2 formal
# 3 Juneteenth
# 4 events
# 5 canceled
# 6 due
# 7 to
# 8 coronavirus
# 9 concerns
# 10 activists
# 11 instead
# 12 organized
# 13 a
# 14 host
# 15 of
# 16 virtual
# 17 observances
# 18 online
# 19 as
# 20 well
# 21 as
# 22 street
# 23 marches
# 24 car
# 25 caravans
# 26 through
# 27 several
# 28 major
# 29 cities
# 3624
# 0 With
# 1 more
# 2 than
# 3 people
# 4 killed
# 5 by
# 6 gun
# 7 violence
# 8 in
# 9 the
# 10 United
# 11 States
# 12 last
# 13 year
# 14 counting
# 15 suicides
# 16 Democrats
# 17 running
# 18 for
# 19 their
# 20 party
# 21 presidential
# 22 nomination
# 23 are
# 24 pointing
# 25 to
# 26 inaction
# 27 in
# 28 Washington
# 29 as
# 30 evidence
# 31 they
# 32 should
# 33 be
# 34 chosen
# 35 run
# 36 against
# 37 Republican
# 38 President
# 39 Donald
# 40 Trump
# 3625
# 0 With
# 1 more
# 2 than
# 3 reported
# 4 cases
# 5 of
# 6 the
# 7 disease
# 8 the
# 9 viral
# 10 outbreak
# 11 continues
# 12 create
# 13 uncertainty
# 14 about
# 15 future
# 16 competitions
# 17 from
# 18 track
# 19 field
# 20 Formula
# 21 to
# 22 the
# 23 ultimate
# 24 global
# 25 event
# 26 the
# 27 Tokyo
# 28 Olympics
# 3626
# 0 With
# 1 our
# 2 climate
# 3 impacted
# 4 world
# 5 now
# 6 highly
# 7 prone
# 8 to
# 9 fires
# 10 extreme
# 11 storms
# 12 sea
# 13 level
# 14 rise
# 15 nuclear
# 16 energy
# 17 is
# 18 touted
# 19 as
# 20 a
# 21 possible
# 22 replacement
# 23 for
# 24 the
# 25 burning
# 26 of
# 27 fossil
# 28 fuels
# 29 for
# 30 energy
# 31 the
# 32 leading
# 33 cause
# 34 of
# 35 climate
# 36 change
# 3627
# 0 With
# 1 protests
# 2 over
# 3 racial
# 4 injustice
# 5 continuing
# 6 roil
# 7 the
# 8 United
# 9 States
# 10 Queer
# 11 Eye
# 12 star
# 13 Karamo
# 14 Brown
# 15 has
# 16 called
# 17 on
# 18 LGBT+
# 19 people
# 20 recognize
# 21 the
# 22 racism
# 23 transphobia
# 24 in
# 25 the
# 26 community
# 27 remember
# 28 the
# 29 radical
# 30 roots
# 31 of
# 32 the
# 33 gay
# 34 rights
# 35 movement
# 3628
# 0 With
# 1 radical
# 2 feminists
# 3 extremist
# 4 trans
# 5 activists
# 6 seeking
# 7 have
# 8 her
# 9 publishers
# 10 film
# 11 associates
# 12 ban
# 13 her
# 14 from
# 15 earning
# 16 a
# 17 living
# 18 she
# 19 understands
# 20 how
# 21 the
# 22 radical
# 23 left
# 24 seeks
# 25 merely
# 26 disagree
# 27 with
# 28 their
# 29 opponents
# 30 destroy
# 31 them
# 32 utterly
# 33 as
# 34 human
# 35 beings
# 3629
# 0 With
# 1 the
# 2 arrival
# 3 of
# 4 virus
# 5 our
# 6 legal
# 7 rights
# 8 seem
# 9 have
# 10 been
# 11 deemed
# 12 irrelevant
# 13 completely
# 14 subordinated
# 15 to
# 16 the
# 17 arbitrary
# 18 whims
# 19 of
# 20 politicians
# 21 all
# 22 in
# 23 the
# 24 name
# 25 of
# 26 safety
# 3630
# 0 With
# 1 the
# 2 Olympic
# 3 Games
# 4 postponed
# 5 until
# 6 cinemas
# 7 closed
# 8 across
# 9 the
# 10 country
# 11 whole
# 12 segments
# 13 of
# 14 the
# 15 advertising
# 16 market
# 17 have
# 18 evaporated
# 3631
# 0 With
# 1 this
# 2 in
# 3 mind
# 4 the
# 5 Trump
# 6 administration
# 7 reportedly
# 8 hopes
# 9 reduce
# 10 poverty
# 11 in
# 12 the
# 13 United
# 14 States
# 15 by
# 16 making
# 17 a
# 18 material
# 19 difference
# 20 in
# 21 struggling
# 22 families
# 23 finances
# 24 by
# 25 tinkering
# 26 with
# 27 the
# 28 threshold
# 29 for
# 30 what
# 31 counts
# 32 as
# 33 poverty
# 3632
# 0 With
# 1 justices
# 2 appointed
# 3 in
# 4 recent
# 5 years
# 6 by
# 7 President
# 8 Donald
# 9 Trump
# 10 the
# 11 Supreme
# 12 Court
# 13 has
# 14 appeared
# 15 primed
# 16 ready
# 17 deliver
# 18 a
# 19 huge
# 20 victory
# 21 for
# 22 conservatives
# 23 looking
# 24 roll
# 25 back
# 26 abortion
# 27 rights
# 28 in
# 29 the
# 30 United
# 31 States
# 3633
# 0 With
# 1 U.S.
# 2 President
# 3 Donald
# 4 Trump
# 5 announcement
# 6 on
# 7 Thursday
# 8 of
# 9 tariffs
# 10 on
# 11 another
# 12 of
# 13 Chinese
# 14 imports
# 15 nearly
# 16 all
# 17 goods
# 18 from
# 19 China
# 20 will
# 21 be
# 22 subject
# 23 to
# 24 import
# 25 taxes
# 26 Trump
# 27 says
# 28 they
# 29 generate
# 30 billions
# 31 of
# 32 dollars
# 33 in
# 34 revenues
# 35 for
# 36 the
# 37 U.S.
# 38 Treasury
# 39 from
# 40 China
# 3634
# 0 With
# 1 President
# 2 Donald
# 3 Trump
# 4 signaling
# 5 that
# 6 he
# 7 's
# 8 eager
# 9 for
# 10 the
# 11 country
# 12 relax
# 13 stringent
# 14 measures
# 15 meant
# 16 stem
# 17 the
# 18 tide
# 19 of
# 20 the
# 21 Covid-19
# 22 pandemic
# 23 it
# 24 's
# 25 important
# 26 realize
# 27 how
# 28 dangerous
# 29 this
# 30 idea
# 31 is
# 3635
# 0 Within
# 1 weeks
# 2 of
# 3 Floyd
# 4 passing
# 5 in
# 6 Minneapolis
# 7 police
# 8 custody
# 9 militant
# 10 social
# 11 justice
# 12 warriors
# 13 racked
# 14 up
# 15 an
# 16 estimated
# 17 in
# 18 damage
# 19 causing
# 20 the
# 21 costliest
# 22 outbreak
# 23 of
# 24 political
# 25 upheaval
# 26 in
# 27 U.S.
# 28 history
# 29 devastating
# 30 minority
# 31 businesses
# 32 while
# 33 kicking
# 34 off
# 35 an
# 36 entire
# 37 summer
# 38 of
# 39 chaos
# 40 engulfing
# 41 the
# 42 nation
# 43 major
# 44 cities
# 45 eventually
# 46 spreading
# 47 to
# 48 the
# 49 suburbs
# 3636
# 0 Witness
# 1 for
# 2 instance
# 3 the
# 4 wacky
# 5 nonsense
# 6 New
# 7 York
# 8 mayor
# 9 current
# 10 Trump
# 11 flunky
# 12 Rudy
# 13 Giuliani
# 14 addressed
# 15 to
# 16 Salon
# 17 Roger
# 18 Sollenberger
# 19 during
# 20 a
# 21 text
# 22 interview
# 23 this
# 24 week
# 3637
# 0 Women
# 1 in
# 2 power
# 3 must
# 4 pay
# 5 a
# 6 significant
# 7 tax
# 8 on
# 9 their
# 10 limited
# 11 time
# 12 sit
# 13 for
# 14 manicures
# 15 blowouts
# 16 brow
# 17 waxes
# 18 braids
# 19 rather
# 20 than
# 21 meeting
# 22 with
# 23 constituents
# 24 reviewing
# 25 legislation
# 26 conducting
# 27 investigations
# 28 chasing
# 29 a
# 30 story
# 31 traveling
# 32 to
# 33 their
# 34 districts
# 35 reviewing
# 36 their
# 37 notes
# 38 spending
# 39 time
# 40 with
# 41 their
# 42 families
# 3638
# 0 Women
# 1 were
# 2 allowed
# 3 into
# 4 Saudi
# 5 sports
# 6 stadiums
# 7 a
# 8 year
# 9 ago
# 10 for
# 11 the
# 12 first
# 13 time
# 14 watch
# 15 soccer
# 16 matches
# 17 although
# 18 they
# 19 were
# 20 segregated
# 21 in
# 22 the
# 23 stands
# 24 sticking
# 25 to
# 26 the
# 27 family
# 28 section
# 29 away
# 30 from
# 31 all
# 32 male
# 33 crowds
# 34 elsewhere
# 3639
# 0 Women
# 1 rights
# 2 advocates
# 3 were
# 4 relieved
# 5 late
# 6 Monday
# 7 when
# 8 Senate
# 9 Democrats
# 10 blocked
# 11 an
# 12 extreme
# 13 anti
# 14 -
# 15 choice
# 16 bill
# 17 from
# 18 advancing
# 19 to
# 20 a
# 21 floor
# 22 debate
# 23 were
# 24 soon
# 25 outraged
# 26 by
# 27 President
# 28 Donald
# 29 Trump
# 30 lies
# 31 about
# 32 abortion
# 33 care
# 34 as
# 35 well
# 36 as
# 37 the
# 38 corporate
# 39 media
# 40 for
# 41 enabling
# 42 his
# 43 blatantly
# 44 false
# 45 characterization
# 46 of
# 47 the
# 48 bill
# 49 stand
# 3640
# 0 Wo
# 1 it
# 2 be
# 3 absurdly
# 4 difficult
# 5 enforce
# 6 new
# 7 gun
# 8 control
# 9 laws
# 10 move
# 11 toward
# 12 the
# 13 outright
# 14 confiscation
# 15 that
# 16 is
# 17 always
# 18 forever
# 19 the
# 20 Left
# 21 ultimate
# 22 goal
# 23 after
# 24 a
# 25 year
# 26 of
# 27 record
# 28 breaking
# 29 gun
# 30 sales
# 3641
# 0 Working
# 1 class
# 2 Americans
# 3 like
# 4 those
# 5 who
# 6 make
# 7 up
# 8 the
# 9 majority
# 10 of
# 11 South
# 12 Bend
# 13 residents
# 14 have
# 15 secured
# 16 the
# 17 largest
# 18 wage
# 19 hikes
# 20 in
# 21 the
# 22 nation
# 23 compared
# 24 to
# 25 all
# 26 other
# 27 economic
# 28 demographic
# 29 groups
# 30 a
# 31 direct
# 32 result
# 33 of
# 34 Trump
# 35 tightening
# 36 the
# 37 labor
# 38 market
# 3642
# 0 Workplace
# 1 bias
# 2 against
# 3 gay
# 4 transgender
# 5 employees
# 6 has
# 7 remained
# 8 legal
# 9 in
# 10 much
# 11 of
# 12 the
# 13 country
# 14 with
# 15 U.S.
# 16 states
# 17 lacking
# 18 comprehensive
# 19 measures
# 20 against
# 21 employment
# 22 discrimination
# 3643
# 0 World
# 1 leaders
# 2 organisations
# 3 pledged
# 4 fund
# 5 a
# 6 possible
# 7 vaccine
# 8 treatments
# 9 many
# 10 hoping
# 11 explicitly
# 12 ensure
# 13 that
# 14 no
# 15 country
# 16 on
# 17 Earth
# 18 would
# 19 be
# 20 left
# 21 out
# 22 the
# 23 United
# 24 States
# 25 did
# 26 contribute
# 3644
# 0 Worth
# 1 noting
# 2 however
# 3 is
# 4 that
# 5 Democrats
# 6 have
# 7 also
# 8 been
# 9 notably
# 10 faced
# 11 on
# 12 gun
# 13 control
# 3645
# 0 Writing
# 1 in
# 2 today
# 3 Wall
# 4 Street
# 5 Journal
# 6 Pence
# 7 denies
# 8 that
# 9 there
# 10 is
# 11 such
# 12 a
# 13 thing
# 14 as
# 15 a
# 16 second
# 17 wave
# 18 to
# 19 the
# 20 pandemic
# 21 he
# 22 does
# 23 mean
# 24 because
# 25 we
# 26 have
# 27 exited
# 28 the
# 29 first
# 30 wave
# 3646
# 0 Yale
# 1 psychiatrist
# 2 explains
# 3 why
# 4 the
# 5 coronavirus
# 6 pandemic
# 7 Donald
# 8 Trump
# 9 irrational
# 10 cult
# 11 is
# 12 a
# 13 deadly
# 14 combination
# 3647
# 0 Yep
# 1 after
# 2 openly
# 3 committing
# 4 adultery
# 5 against
# 6 the
# 7 Republican
# 8 Party
# 9 these
# 10 shameless
# 11 cheats
# 12 honestly
# 13 believed
# 14 the
# 15 Democrat
# 16 Party
# 17 would
# 18 make
# 19 them
# 20 equal
# 21 trusted
# 22 partners
# 23 in
# 24 the
# 25 family
# 26 business
# 3648
# 0 Yes
# 1 Trump
# 2 the
# 3 right
# 4 are
# 5 embracing
# 6 celebrating
# 7 death
# 8 It
# 9 is
# 10 ghoulish
# 11 It
# 12 is
# 13 also
# 14 more
# 15 illustration
# 16 that
# 17 the
# 18 Age
# 19 of
# 20 Trump
# 21 is
# 22 an
# 23 American
# 24 dystopia
# 25 where
# 26 what
# 27 was
# 28 previously
# 29 unimaginable
# 30 for
# 31 most
# 32 decent
# 33 people
# 34 has
# 35 become
# 36 normal
# 3649
# 0 Yes
# 1 he
# 2 might
# 3 be
# 4 a
# 5 demented
# 6 Stalinist
# 7 eager
# 8 flood
# 9 America
# 10 with
# 11 illegal
# 12 aliens
# 13 take
# 14 away
# 15 our
# 16 guns
# 17 health
# 18 insurance
# 19 he
# 20 sure
# 21 gave
# 22 those
# 23 venal
# 24 Never
# 25 Trumpers
# 26 a
# 27 sweet
# 28 face
# 29 job
# 30 Saturday
# 31 night
# 32 in
# 33 Nevada
# 34 now
# 35 I
# 36 ca
# 37 tell
# 38 if
# 39 my
# 40 tears
# 41 come
# 42 from
# 43 joy
# 44 laughter
# 3650
# 0 Yes
# 1 the
# 2 rich
# 3 are
# 4 rich
# 5 want
# 6 stay
# 7 that
# 8 way
# 9 yet
# 10 at
# 11 the
# 12 same
# 13 time
# 14 fat
# 15 cats
# 16 now
# 17 lean
# 18 left
# 19 even
# 20 far
# 21 left
# 22 on
# 23 cultural
# 24 issues
# 25 they
# 26 want
# 27 you
# 28 do
# 29 as
# 30 you
# 31 ’re
# 32 told
# 3651
# 0 Yes
# 1 there
# 2 may
# 3 still
# 4 be
# 5 time
# 6 for
# 7 the
# 8 union
# 9 membership
# 10 change
# 11 its
# 12 thinking
# 13 if
# 14 the
# 15 players
# 16 reject
# 17 the
# 18 proposal
# 19 at
# 20 least
# 21 marketing
# 22 expert
# 23 said
# 24 a
# 25 no
# 26 vote
# 27 now
# 28 could
# 29 mean
# 30 short-
# 31 long
# 32 term
# 33 disaster
# 3652
# 0 Biden
# 1 finds
# 2 himself
# 3 in
# 4 an
# 5 increasingly
# 6 competitive
# 7 race
# 8 with
# 9 Sanders
# 10 the
# 11 U.S.
# 12 senator
# 13 who
# 14 came
# 15 close
# 16 to
# 17 winning
# 18 the
# 19 Nevada
# 20 caucus
# 21 finds
# 22 support
# 23 with
# 24 some
# 25 of
# 26 the
# 27 same
# 28 voters
# 3653
# 0 bizarrely
# 1 the
# 2 entirety
# 3 of
# 4 the
# 5 Establishment
# 6 from
# 7 Prime
# 8 Minister
# 9 Boris
# 10 Johnson
# 11 downwards
# 12 the
# 13 bodies
# 14 representing
# 15 every
# 16 cultural
# 17 institution
# 18 from
# 19 the
# 20 Church
# 21 of
# 22 England
# 23 to
# 24 the
# 25 Football
# 26 Association
# 27 have
# 28 been
# 29 grovelling
# 30 fawning
# 31 kowtowing
# 32 to
# 33 BLM
# 34 as
# 35 if
# 36 its
# 37 name
# 38 were
# 39 be
# 40 taken
# 41 at
# 42 face
# 43 value
# 3654
# 0 Yet
# 1 every
# 2 nation
# 3 except
# 4 Mongolia
# 5 Greenland
# 6 recorded
# 7 dozens
# 8 to
# 9 thousands
# 10 of
# 11 deaths
# 12 no
# 13 matter
# 14 what
# 15 they
# 16 tried
# 17 even
# 18 socialist
# 19 systems
# 20 with
# 21 draconian
# 22 lockdowns
# 23 like
# 24 Italy
# 25 deaths
# 26 per
# 27 Spain
# 28 the
# 29 United
# 30 Kingdom
# 3655
# 0 it
# 1 far
# 2 better
# 3 applies
# 4 to
# 5 unelected
# 6 career
# 7 bureaucrats
# 8 use
# 9 of
# 10 their
# 11 power
# 12 prosecute
# 13 their
# 14 political
# 15 enemies
# 16 which
# 17 comprises
# 18 the
# 19 heart
# 20 of
# 21 the
# 22 resistance
# 23 to
# 24 Republican
# 25 rule
# 26 that
# 27 will
# 28 endure
# 29 so
# 30 long
# 31 as
# 32 bureaucracy
# 33 has
# 34 enough
# 35 power
# 36 challenged
# 37 elected
# 38 branches
# 39 of
# 40 government
# 41 This
# 42 bureacracy
# 43 weaponization
# 44 was
# 45 also
# 46 a
# 47 hallmark
# 48 of
# 49 the
# 50 Obama
# 51 presidency
# 52 with
# 53 ironies
# 54 of
# 55 ironies
# 56 perhaps
# 57 the
# 58 biggest
# 59 evidences
# 60 again
# 61 coming
# 62 from
# 63 the
# 64 Department
# 65 of
# 66 Justice
# 67 under
# 68 attorneys
# 69 general
# 70 Eric
# 71 Holder
# 72 Loretta
# 73 Lynch
# 3656
# 0 it
# 1 's
# 2 merely
# 3 the
# 4 tip
# 5 of
# 6 the
# 7 iceberg
# 8 of
# 9 war
# 10 criminals
# 11 lurking
# 12 working
# 13 on
# 14 U.S.
# 15 turf
# 3657
# 0 Merril
# 1 Hoge
# 2 a
# 3 former
# 4 running
# 5 back
# 6 for
# 7 the
# 8 NFL
# 9 Pittsburgh
# 10 Steelers
# 11 Chicago
# 12 Bears
# 13 later
# 14 turned
# 15 ESPN
# 16 analyst
# 17 has
# 18 been
# 19 of
# 20 the
# 21 most
# 22 outspoken
# 23 critics
# 24 against
# 25 the
# 26 alarm
# 27 surrounding
# 28 CTE
# 29 studies
# 30 putting
# 31 much
# 32 of
# 33 the
# 34 research
# 35 down
# 36 to
# 37 science
# 38 fiction
# 39 misleading
# 40 science
# 41 far
# 42 from
# 43 a
# 44 factual
# 45 realm
# 3658
# 0 MLB
# 1 with
# 2 an
# 3 exhaustive
# 4 page
# 5 health
# 6 safety
# 7 operations
# 8 manual
# 9 will
# 10 attempt
# 11 become
# 12 the
# 13 first
# 14 major
# 15 sport
# 16 return
# 17 on
# 18 July
# 19 with
# 20 nationally
# 21 televised
# 22 games
# 23 the
# 24 rest
# 25 of
# 26 the
# 27 teams
# 28 scheduled
# 29 start
# 30 July
# 3659
# 0 Yet
# 1 no
# 2 one
# 3 denies
# 4 that
# 5 older
# 6 nuclear
# 7 plants
# 8 with
# 9 an
# 10 aged
# 11 infrastructure
# 12 often
# 13 surpassing
# 14 expected
# 15 lifetimes
# 16 are
# 17 extremely
# 18 inefficient
# 19 run
# 20 a
# 21 higher
# 22 risk
# 23 of
# 24 disaster
# 3660
# 0 Omar
# 1 is
# 2 unashamed
# 3 about
# 4 being
# 5 linked
# 6 to
# 7 this
# 8 kind
# 9 of
# 10 hate
# 11 even
# 12 claiming
# 13 that
# 14 while
# 15 she
# 16 opposes
# 17 economic
# 18 sanctions
# 19 on
# 20 the
# 21 tyrannical
# 22 terrorist
# 23 supporting
# 24 Iranian
# 25 regime
# 26 she
# 27 thinks
# 28 boycotts
# 29 of
# 30 Israel
# 31 are
# 32 justified
# 3661
# 0 Yet
# 1 the
# 2 drumbeat
# 3 for
# 4 censorship
# 5 goes
# 6 on
# 7 as
# 8 the
# 9 politicians
# 10 whose
# 11 ideas
# 12 find
# 13 favor
# 14 with
# 15 the
# 16 mainstream
# 17 media
# 18 want
# 19 make
# 20 sure
# 21 theirs
# 22 are
# 23 the
# 24 only
# 25 ideas
# 26 you
# 27 ever
# 28 get
# 29 hear
# 30 Today
# 31 it
# 32 will
# 33 be
# 34 about
# 35 money
# 36 only
# 37 because
# 38 money
# 39 is
# 40 the
# 41 means
# 42 spread
# 43 ideas
# 3662
# 0 Yet
# 1 the
# 2 gender
# 3 ideology
# 4 is
# 5 rapidly
# 6 gaining
# 7 power
# 8 aided
# 9 by
# 10 huge
# 11 donations
# 12 from
# 13 wealthy
# 14 individuals
# 15 medical
# 16 companies
# 3663
# 0 the
# 1 overwhelming
# 2 narrative
# 3 across
# 4 social
# 5 media
# 6 today
# 7 depressingly
# 8 across
# 9 much
# 10 of
# 11 the
# 12 mainstream
# 13 media
# 14 is
# 15 that
# 16 these
# 17 ugly
# 18 sinister
# 19 shows
# 20 of
# 21 force
# 22 by
# 23 the
# 24 triumphant
# 25 radical
# 26 left
# 27 are
# 28 something
# 29 almost
# 30 charming
# 31 admirable
# 32 rather
# 33 than
# 34 something
# 35 we
# 36 should
# 37 all
# 38 fear
# 3664
# 0 Yet
# 1 when
# 2 researchers
# 3 in
# 4 the
# 5 U.S.
# 6 have
# 7 been
# 8 so
# 9 corrupt
# 10 they
# 11 have
# 12 gone
# 13 to
# 14 jail
# 15 mainstream
# 16 scientists
# 17 still
# 18 accept
# 19 their
# 20 research
# 3665
# 0 the
# 1 Trump
# 2 family
# 3 his
# 4 allies
# 5 are
# 6 evidently
# 7 using
# 8 this
# 9 national
# 10 emergency
# 11 enrich
# 12 themselves
# 3666
# 0 You
# 1 may
# 2 remember
# 3 that
# 4 hours
# 5 after
# 6 America
# 7 was
# 8 attacked
# 9 by
# 10 al
# 11 Qaeda
# 12 on
# 13 thousands
# 14 of
# 15 Muslims
# 16 regular
# 17 folks
# 18 celebrated
# 19 in
# 20 the
# 21 streets
# 3667
# 0 You
# 1 may
# 2 remember
# 3 that
# 4 NBC
# 5 journalist
# 6 Nancy
# 7 Snyderman
# 8 broke
# 9 her
# 10 Ebola
# 11 quarantine
# 12 to
# 13 the
# 14 outrage
# 15 of
# 16 her
# 17 neighbors
# 3668
# 0 You
# 1 need
# 2 keep
# 3 a
# 4 close
# 5 eye
# 6 on
# 7 what
# 8 your
# 9 school
# 10 is
# 11 teaching
# 12 because
# 13 the
# 14 left
# 15 only
# 16 wants
# 17 teach
# 18 your
# 19 kids
# 20 engage
# 21 in
# 22 loveless
# 23 sex
# 24 the
# 25 sanctity
# 26 of
# 27 abortion
# 28 why
# 29 America
# 30 is
# 31 evil
# 32 that
# 33 men
# 34 are
# 35 women
# 36 women
# 37 are
# 38 men
# 39 that
# 40 Global
# 41 Warming
# 42 is
# 43 real
# 44 It
# 45 ’s
# 3669
# 0 You
# 1 ’ve
# 2 heard
# 3 of
# 4 Jim
# 5 Crow
# 6 Southern
# 7 Segregation
# 8 That
# 9 was
# 10 ALL
# 11 Democrats
# 3670
# 0 Young
# 1 female
# 2 athletes
# 3 dreams
# 4 accomplishments
# 5 have
# 6 been
# 7 dashed
# 8 across
# 9 the
# 10 country
# 11 when
# 12 competing
# 13 against
# 14 biological
# 15 males
# 16 who
# 17 identify
# 18 as
# 19 females
# 3671
# 0 Young
# 1 white
# 2 men
# 3 reacting
# 4 to
# 5 social
# 6 educational
# 7 constructs
# 8 that
# 9 paint
# 10 them
# 11 as
# 12 the
# 13 embodiment
# 14 of
# 15 historical
# 16 evil
# 17 are
# 18 fertile
# 19 ground
# 20 for
# 21 white
# 22 supremacists
# 3672
# 0 Young
# 1 women
# 2 taking
# 3 part
# 4 in
# 5 high
# 6 school
# 7 college
# 8 athletics
# 9 across
# 10 the
# 11 country
# 12 have
# 13 had
# 14 their
# 15 dreams
# 16 of
# 17 winning
# 18 dashed
# 19 by
# 20 the
# 21 movement
# 22 allow
# 23 biological
# 24 male
# 25 who
# 26 identify
# 27 as
# 28 female
# 29 compete
# 30 against
# 31 them
# 3673
# 0 YouTube
# 1 is
# 2 making
# 3 clear
# 4 there
# 5 will
# 6 be
# 7 no
# 8 birtherism
# 9 on
# 10 its
# 11 platform
# 12 during
# 13 this
# 14 year
# 15 U.S.
# 16 presidential
# 17 election
# 18 a
# 19 belated
# 20 response
# 21 to
# 22 a
# 23 type
# 24 of
# 25 conspiracy
# 26 theory
# 27 more
# 28 prevalent
# 29 in
# 30 the
# 31 race

# %%
# token in context -2 (c1)
for index, row in dt.iterrows():
    print(index)
    for i, token in enumerate(row.spacy_lg_dict):
        print(i, token['text_low_C1'])
        if token['text_low_C1'] == None:
            token['assertive_verbs_C1'] = 0
            token['factive_verbs_C1'] = 0
            token['report_verbs_C1'] = 0
            token['hedges_C1'] = 0
            token['boosters_C1'] = 0
            token['implicative_verbs_C1'] = 0
        else:
            if token['window_text'] != None and token['window_lemma'] != None:
                window_text = token['window_text']
                window_lemma = token['window_lemma']

              # 0 1 <2> 3 4 5 6 7 8
              # token['text_low_C1']
              # token['lemma_low_C1']
                # words
                c1, c2, c_m, c3, c4 = None, None, None, None, None
                if window_text[0] != None and window_text[1] != None:
                    c1 = window_text[0] + ' ' + window_text[1] + ' ' + token['text_low_C1']
                if window_text[1] != None:
                    c2 = window_text[1] + ' ' + token['text_low_C1']
                if window_text[1] != None and window_text[3] != None:
                    c_m = window_text[1] + ' ' + token['text_low_C1'] + ' ' + window_text[3]
                if window_text[3] != None:
                    c3 = token['text_low_C1'] + ' ' + window_text[3]
                if window_text[3] != None and window_text[4] != None:
                    c4 = token['text_low_C1'] + ' ' + window_text[3] + ' ' + window_text[4]

                # lemmas
                c1l, c2l, c_ml, c3l, c4l = None, None, None, None, None
                if window_lemma[0] != None and window_lemma[1] != None:
                    c1l = window_lemma[0] + ' ' + window_lemma[1] + ' ' + token['lemma_low_C1']
                if window_lemma[1] != None:
                    c2l = window_lemma[1] + ' ' + token['lemma_low_C1']
                if window_lemma[1] != None and window_lemma[3] != None:
                    c_ml = window_lemma[1] + ' ' + token['lemma_low_C1'] + ' ' + window_lemma[3]
                if window_lemma[3] != None:
                    c3l = token['lemma_low_C1'] + ' ' + window_lemma[3]
                if window_lemma[3] != None and window_text[4] != None:
                    c4l = token['lemma_low_C1'] + ' ' + window_lemma[3] + ' ' + window_lemma[4]

                # assertive verbs
                if token['text_low_C1'] in assertive_verbs or c1 in assertive_verbs or c2 in assertive_verbs or \
                c_m in assertive_verbs or c3 in assertive_verbs or c4 in assertive_verbs or \
                token['lemma_low_C1'] in assertive_verbs or c1l in assertive_verbs or c2l in assertive_verbs or \
                c_ml in assertive_verbs or c3l in assertive_verbs or c4l in assertive_verbs:
                    token['assertive_verbs_C1'] = 1
                else:
                    token['assertive_verbs_C1'] = 0   

                # factive verbs
                if token['text_low_C1'] in factive_verbs or c1 in factive_verbs or c2 in factive_verbs or \
                c_m in factive_verbs or c3 in factive_verbs or c4 in factive_verbs or \
                token['lemma_low_C1'] in factive_verbs or c1l in factive_verbs or c2l in factive_verbs or \
                c_ml in factive_verbs or c3l in factive_verbs or c4l in factive_verbs:
                    token['factive_verbs_C1'] = 1
                else:
                    token['factive_verbs_C1'] = 0   

                # report verbs
                if token['text_low_C1'] in report_verbs or c1 in report_verbs or c2 in report_verbs or \
                c_m in report_verbs or c3 in report_verbs or c4 in report_verbs or \
                token['lemma_low_C1'] in report_verbs or c1l in report_verbs or c2l in report_verbs or \
                c_ml in report_verbs or c3l in report_verbs or c4l in report_verbs:
                    token['report_verbs_C1'] = 1
                else:
                    token['report_verbs_C1'] = 0

                # hedges
                if token['text_low_C1'] in hedges or c1 in hedges or c2 in hedges or \
                c_m in hedges or c3 in hedges or c4 in hedges or \
                token['lemma_low_C1'] in hedges or c1l in hedges or c2l in hedges or \
                c_ml in hedges or c3l in hedges or c4l in hedges:
                    token['hedges_C1'] = 1
                else:
                    token['hedges_C1'] = 0

                # boosters
                if token['text_low_C1'] in boosters or c1 in boosters or c2 in boosters or \
                c_m in boosters or c3 in boosters or c4 in boosters or \
                token['lemma_low_C1'] in boosters or c1l in boosters or c2l in boosters or \
                c_ml in boosters or c3l in boosters or c4l in boosters:
                    token['boosters_C1'] = 1
                else:
                    token['boosters_C1'] = 0
                    
                # implicative verbs
                if token['text_low_C1'] in implicative_verbs or c1 in implicative_verbs or c2 in implicative_verbs or \
                c_m in implicative_verbs or c3 in implicative_verbs or c4 in implicative_verbs or \
                token['lemma_low_C1'] in implicative_verbs or c1l in implicative_verbs or c2l in implicative_verbs or \
                c_ml in implicative_verbs or c3l in implicative_verbs or c4l in implicative_verbs:
                    token['implicative_verbs_C1'] = 1
                else:
                    token['implicative_verbs_C1'] = 0

            else:
                # assertive verbs
                if token['text_low_C1'] in assertive_verbs or token['lemma_low_C1'] in assertive_verbs:
                    token['assertive_verbs_C1'] = 1
                else:
                    token['assertive_verbs_C1'] = 0 

                # factive verbs
                if token['text_low_C1'] in factive_verbs or token['lemma_low_C1'] in factive_verbs:
                    token['factive_verbs_C1'] = 1
                else:
                    token['factive_verbs_C1'] = 0   

                # report verbs
                if token['text_low_C1'] in report_verbs or token['lemma_low_C1'] in report_verbs:
                    token['report_verbs_C1'] = 1
                else:
                    token['report_verbs_C1'] = 0

                # hedges
                if token['text_low_C1'] in hedges or token['lemma_low_C1'] in hedges:
                    token['hedges_C1'] = 1
                else:
                    token['hedges_C1'] = 0

                # boosters
                if token['text_low_C1'] in boosters or token['lemma_low_C1'] in boosters:
                    token['boosters_C1'] = 1
                else:
                    token['boosters_C1'] = 0
                    
                # implicative verbs
                if token['text_low_C1'] in implicative_verbs or token['lemma_low_C1'] in implicative_verbs:
                    token['implicative_verbs_C1'] = 1
                else:
                    token['implicative_verbs_C1'] = 0
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 10 that
# 11 vaccines
# 12 cause
# 13 autism
# 14 as
# 15 he
# 16 did
# 17 during
# 18 the
# 19 presidential
# 20 debates
# 21 many
# 22 parents
# 23 may
# 24 choose
# 25 vaccinate
# 26 putting
# 27 children
# 28 at
# 3523
# 0 None
# 1 None
# 2 when
# 3 a
# 4 newly
# 5 organized
# 6 vaccine
# 7 research
# 8 group
# 9 at
# 10 the
# 11 u.s.
# 12 national
# 13 institutes
# 14 of
# 15 health
# 16 nih
# 17 met
# 18 for
# 19 the
# 20 first
# 21 time
# 22 this
# 23 week
# 24 its
# 25 members
# 26 had
# 27 expected
# 28 be
# 29 able
# 30 ease
# 31 into
# 32 their
# 33 work
# 34 their
# 35 mandate
# 36 is
# 37 conduct
# 38 human
# 39 trials
# 40 for
# 41 emerging
# 42 health
# 43 threats
# 44 their
# 45 first
# 46 assignment
# 47 came
# 48 at
# 3524
# 0 None
# 1 None
# 2 when
# 3 a
# 4 supporter
# 5 told
# 6 warren
# 7 public
# 8 schools
# 9 need
# 10 teach
# 11 more
# 12 about
# 13 lgbtq
# 14 history
# 15 sex
# 16 education
# 17 the
# 18 massachusetts
# 19 senator
# 20 replied
# 21 her
# 22 education
# 23 secretary
# 24 would
# 25 have
# 26 be
# 27 interviewed
# 28 by
# 29 a
# 3525
# 0 None
# 1 None
# 2 when
# 3 carrying
# 4 a
# 5 firearm
# 6 you
# 7 have
# 8 the
# 9 ultimate
# 10 power
# 11 of
# 12 force
# 13 in
# 3526
# 0 None
# 1 None
# 2 when
# 3 democrats
# 4 are
# 5 releasing
# 6 violent
# 7 criminals
# 8 encouraging
# 9 illegal
# 10 immigration
# 11 passing
# 12 laws
# 13 disarm
# 14 you
# 15 while
# 16 turning
# 17 the
# 18 police
# 19 into
# 20 eunuchs
# 21 it
# 3527
# 0 None
# 1 None
# 2 when
# 3 did
# 4 it
# 5 become
# 6 racist
# 7 like
# 8 the
# 9 national
# 10 anthem
# 3528
# 0 None
# 1 None
# 2 when
# 3 did
# 4 vaccines
# 5 become
# 6 politicized
# 7 amid
# 8 a
# 9 measles
# 10 outbreak
# 11 suddenly
# 12 republicans
# 13 support
# 14 anti
# 3529
# 0 None
# 1 None
# 2 when
# 3 far
# 4 right
# 5 white
# 6 evangelicals
# 7 white
# 8 nationalists
# 9 coronavirus
# 10 truthers
# 11 rail
# 12 against
# 13 social
# 14 distancing
# 15 encourage
# 16 large
# 17 gatherings
# 18 they
# 19 are
# 20 encouraging
# 21 suicidal
# 22 behavior
# 23 there
# 24 have
# 25 been
# 3530
# 0 None
# 1 None
# 2 when
# 3 greed
# 4 power
# 5 are
# 6 exercised
# 7 by
# 8 giant
# 9 multinational
# 10 corporations
# 11 that
# 12 escape
# 13 the
# 14 discipline
# 15 of
# 16 the
# 17 nation
# 18 state
# 19 the
# 20 potential
# 21 for
# 22 evil
# 23 becomes
# 24 infinite
# 3531
# 0 None
# 1 None
# 2 when
# 3 he
# 4 finally
# 5 spoke
# 6 in
# 7 the
# 8 rose
# 9 garden
# 10 on
# 11 monday
# 12 trump
# 13 threatened
# 14 deploy
# 15 the
# 16 military
# 17 against
# 18 american
# 19 citizens
# 20 if
# 21 the
# 22 governors
# 23 did
# 24 take
# 25 his
# 26 advice
# 27 for
# 28 a
# 29 more
# 30 forceful
# 31 crackdown
# 32 this
# 33 threat
# 34 did
# 35 appear
# 36 cow
# 37 anyone
# 38 only
# 39 increased
# 3532
# 0 None
# 1 None
# 2 when
# 3 i
# 4 opened
# 5 britain
# 6 bestselling
# 7 tabloid
# 8 conservative
# 9 sunday
# 10 newspaper
# 11 i
# 12 was
# 13 greeted
# 14 by
# 15 a
# 16 double
# 17 page
# 18 spread
# 19 showing
# 20 a
# 21 vast
# 22 mob
# 23 of
# 24 black
# 25 lives
# 26 matter
# 27 activists
# 28 marching
# 29 on
# 30 downing
# 31 street
# 3533
# 0 None
# 1 None
# 2 when
# 3 it
# 4 comes
# 5 to
# 6 the
# 7 green
# 8 new
# 9 deal
# 10 blueprint
# 11 address
# 12 the
# 13 climate
# 14 crisis
# 15 republicans
# 16 generally
# 17 like
# 18 pretend
# 19 it
# 20 calls
# 21 for
# 22 the
# 23 elimination
# 3534
# 0 None
# 1 None
# 2 when
# 3 mexico
# 4 leader
# 5 enters
# 6 the
# 7 white
# 8 house
# 9 meet
# 10 president
# 11 donald
# 12 trump
# 13 on
# 14 wednesday
# 15 he
# 16 will
# 17 do
# 18 so
# 19 only
# 20 as
# 21 a
# 22 hostage
# 23 to
# 24 the
# 25 whims
# 26 of
# 27 his
# 28 u.s.
# 29 counterpart
# 30 also
# 31 as
# 32 partner
# 33 in
# 34 an
# 35 unlikely
# 36 alliance
# 37 that
# 38 has
# 39 benefited
# 3535
# 0 None
# 1 None
# 2 when
# 3 parents
# 4 borrow
# 5 the
# 6 debt
# 7 can
# 8 weigh
# 9 down
# 10 families
# 11 for
# 12 generations
# 13 the
# 14 burden
# 15 falls
# 16 particularly
# 17 hard
# 18 on
# 19 low
# 20 income
# 3536
# 0 None
# 1 None
# 2 when
# 3 president
# 4 trump
# 5 rolled
# 6 out
# 7 his
# 8 recent
# 9 budget
# 10 proposal
# 11 it
# 12 made
# 13 some
# 14 cuts
# 15 that
# 16 were
# 17 always
# 18 going
# 19 cause
# 20 controversy
# 21 for
# 22 thing
# 23 his
# 24 plan
# 25 would
# 26 slash
# 27 subsidized
# 28 student
# 29 loan
# 30 repayment
# 31 plans
# 32 let
# 33 the
# 34 government
# 35 crack
# 36 down
# 37 on
# 3537
# 0 None
# 1 None
# 2 when
# 3 prioritizing
# 4 healthcare
# 5 workers
# 6 the
# 7 panel
# 8 noted
# 9 that
# 10 vaccines
# 11 should
# 12 go
# 13 first
# 14 to
# 15 people
# 16 who
# 17 have
# 18 the
# 19 most
# 20 contact
# 3538
# 0 None
# 1 None
# 2 when
# 3 republicans
# 4 warned
# 5 democrats
# 6 that
# 7 impeachment
# 8 was
# 9 a
# 10 waste
# 11 of
# 12 time
# 13 a
# 14 divisive
# 15 partisan
# 16 exercise
# 17 a
# 18 distraction
# 19 from
# 20 the
# 21 real
# 22 issues
# 23 facing
# 24 the
# 25 country
# 26 a
# 27 lesson
# 28 republicans
# 29 learned
# 30 the
# 31 hard
# 32 way
# 33 in
# 34 bill
# 35 clinton
# 36 impeachment
# 37 years
# 38 before
# 39 democrats
# 3539
# 0 None
# 1 None
# 2 when
# 3 the
# 4 left
# 5 is
# 6 emboldened
# 7 cities
# 8 burn
# 9 statues
# 10 topple
# 11 careers
# 12 people
# 13 are
# 14 disappeared
# 15 good
# 16 men
# 17 are
# 18 murdered
# 19 civil
# 20 liberties
# 21 are
# 22 trampled
# 23 the
# 24 dual
# 25 horrors
# 26 of
# 27 blacklisting
# 28 censorship
# 3540
# 0 None
# 1 None
# 2 when
# 3 the
# 4 men
# 5 basketball
# 6 final
# 7 four
# 8 tips
# 9 off
# 10 saturday
# 11 in
# 12 minneapolis
# 13 the
# 14 ncaa
# 15 biggest
# 16 most
# 17 lucrative
# 18 event
# 19 will
# 20 proceed
# 21 as
# 22 it
# 23 normally
# 24 does
# 25 the
# 26 athletes
# 27 on
# 28 the
# 29 floor
# 30 for
# 31 virginia
# 32 auburn
# 33 michigan
# 34 state
# 35 texas
# 36 tech
# 37 will
# 38 play
# 39 games
# 40 that
# 41 generate
# 42 hundreds
# 43 of
# 44 millions
# 45 of
# 46 dollars
# 47 in
# 48 total
# 49 revenue
# 50 for
# 51 their
# 52 schools
# 53 the
# 54 ncaa
# 55 broadcast
# 56 companies
# 57 the
# 58 coaches
# 59 athletic
# 60 directors
# 61 tv
# 62 executives
# 63 ncaa
# 64 suits
# 65 will
# 66 share
# 67 in
# 68 the
# 69 riches
# 70 athletes
# 71 themselves
# 72 still
# 73 wo
# 74 receive
# 75 their
# 76 fair
# 77 share
# 78 thanks
# 79 to
# 80 a
# 81 recent
# 82 federal
# 83 court
# 84 decision
# 85 that
# 86 wo
# 87 change
# 88 in
# 89 the
# 3541
# 0 None
# 1 None
# 2 when
# 3 the
# 4 muslim
# 5 ban
# 6 was
# 7 first
# 8 enacted
# 9 it
# 10 triggered
# 11 chaos
# 12 at
# 13 airports
# 14 prompted
# 15 widespread
# 16 protest
# 17 legal
# 18 challenges
# 19 it
# 20 continues
# 21 impose
# 22 devastating
# 23 costs
# 24 on
# 25 families
# 26 people
# 27 who
# 28 wish
# 29 come
# 30 to
# 3542
# 0 None
# 1 None
# 2 when
# 3 the
# 4 nation
# 5 highest
# 6 civilian
# 7 honor
# 8 went
# 9 to
# 10 a
# 11 right
# 12 wing
# 13 media
# 14 personality
# 15 it
# 16 served
# 17 as
# 18 an
# 19 oddly
# 20 appropriate
# 21 capstone
# 22 to
# 23 trump
# 3543
# 0 None
# 1 None
# 2 when
# 3 trump
# 4 entered
# 5 the
# 6 white
# 7 house
# 8 in
# 9 lopez
# 10 obrador
# 11 likened
# 12 the
# 13 american
# 14 to
# 15 adolf
# 16 hitler
# 17 for
# 18 his
# 19 attitude
# 3544
# 0 None
# 1 None
# 2 when
# 3 sadists
# 4 in
# 5 uniform
# 6 shoved
# 7 an
# 8 elderly
# 9 man
# 10 to
# 11 the
# 12 ground
# 13 for
# 14 the
# 15 crime
# 16 of
# 17 approaching
# 18 them
# 19 causing
# 20 him
# 21 a
# 22 critical
# 23 head
# 24 injury
# 25 their
# 26 fellow
# 27 cops
# 28 made
# 29 no
# 30 attempt
# 31 help
# 3545
# 0 None
# 1 None
# 2 when
# 3 u.s.
# 4 schools
# 5 begin
# 6 the
# 7 next
# 8 academic
# 9 year
# 10 with
# 11 the
# 12 country
# 13 still
# 14 fighting
# 15 the
# 16 coronavirus
# 17 pandemic
# 18 students
# 19 should
# 20 spend
# 21 half
# 22 their
# 23 time
# 24 in
# 25 classrooms
# 26 half
# 27 doing
# 28 online
# 29 activities
# 30 that
# 31 pinpoint
# 32 their
# 33 individual
# 34 learning
# 35 style
# 36 such
# 37 as
# 3546
# 0 None
# 1 None
# 2 whether
# 3 it
# 4 is
# 5 due
# 6 to
# 7 gaffes
# 8 his
# 9 inability
# 10 complete
# 11 some
# 12 sentences
# 13 lack
# 14 of
# 15 knowledge
# 16 on
# 17 a
# 18 subject
# 19 biden
# 20 has
# 21 proven
# 22 that
# 23 interviews
# 24 are
# 25 for
# 26 him
# 27 the
# 28 media
# 29 has
# 3547
# 0 None
# 1 None
# 2 whether
# 3 you
# 4 find
# 5 trump
# 6 buffoonery
# 7 utterly
# 8 disgraceful
# 9 a
# 10 sign
# 11 of
# 12 authenticity
# 13 may
# 14 mark
# 15 our
# 16 central
# 17 political
# 3548
# 0 None
# 1 None
# 2 which
# 3 is
# 4 why
# 5 republicans
# 6 like
# 7 mcconnell
# 8 complaining
# 9 about
# 10 federal
# 11 entitlements
# 12 is
# 3549
# 0 None
# 1 None
# 2 while
# 3 a
# 4 number
# 5 of
# 6 transgender
# 7 advocates
# 8 lgbtq
# 9 health
# 10 experts
# 11 applauded
# 12 p&g
# 13 decision
# 14 redesign
# 15 the
# 16 always
# 17 packaging
# 18 by
# 19 removing
# 20 the
# 21 female
# 22 signs
# 23 the
# 24 company
# 25 announcement
# 26 sparked
# 27 criticism
# 28 online
# 29 including
# 30 a
# 31 bounty
# 32 of
# 3550
# 0 None
# 1 None
# 2 while
# 3 americans
# 4 still
# 5 cling
# 6 to
# 7 sexist
# 8 gender
# 9 roles
# 10 at
# 11 home
# 12 overwhelming
# 13 majorities
# 14 believe
# 15 that
# 16 sex
# 17 discrimination
# 18 in
# 19 public
# 20 spaces
# 21 should
# 3551
# 0 None
# 1 None
# 2 while
# 3 barr
# 4 republican
# 5 president
# 6 donald
# 7 trump
# 8 have
# 9 focused
# 10 blame
# 11 on
# 12 antifa
# 13 a
# 14 loosely
# 15 organized
# 16 anti
# 17 -
# 18 fascist
# 19 movement
# 20 federal
# 21 prosecutors
# 22 in
# 23 las
# 24 vegas
# 25 on
# 26 wednesday
# 27 charged
# 28 members
# 29 of
# 30 the
# 31 far
# 32 right
# 33 boogaloo
# 34 movement
# 35 with
# 36 planning
# 37 cause
# 38 violence
# 39 destruction
# 3552
# 0 None
# 1 None
# 2 while
# 3 brazil
# 4 has
# 5 taken
# 6 the
# 7 lead
# 8 in
# 9 a
# 10 direct
# 11 attack
# 12 on
# 13 the
# 14 amazon
# 15 with
# 16 bolsonaro
# 17 adding
# 18 a
# 19 racial
# 20 element
# 21 to
# 22 his
# 23 attack
# 24 on
# 25 indigenous
# 26 people
# 27 the
# 28 pressure
# 29 open
# 30 the
# 31 amazonian
# 32 forests
# 33 to
# 34 agriculture
# 35 logging
# 36 mining
# 37 is
# 38 just
# 39 limited
# 3553
# 0 None
# 1 None
# 2 while
# 3 conservatives
# 4 may
# 5 find
# 6 comfort
# 7 in
# 8 the
# 9 old
# 10 saw
# 11 that
# 12 those
# 13 who
# 14 are
# 15 liberal
# 16 at
# 17 have
# 18 no
# 19 heart
# 20 those
# 21 who
# 22 are
# 23 conservative
# 24 at
# 25 have
# 26 no
# 27 brain
# 28 the
# 29 truth
# 30 as
# 31 levin
# 32 knows
# 33 is
# 34 that
# 35 those
# 36 who
# 37 are
# 38 statists
# 39 at
# 40 usually
# 41 end
# 42 up
# 43 statists
# 44 at
# 45 he
# 46 ’s
# 47 content
# 48 allow
# 49 time
# 50 take
# 51 its
# 52 uncertain
# 3554
# 0 None
# 1 None
# 2 while
# 3 corporate
# 4 media
# 5 hypocritical
# 6 politicians
# 7 others
# 8 labeled
# 9 anyone
# 10 in
# 11 favor
# 12 of
# 13 reopening
# 14 the
# 15 economy
# 16 getting
# 17 kids
# 18 back
# 19 in
# 20 school
# 21 even
# 22 gathering
# 23 for
# 24 holidays
# 25 a
# 26 grandma
# 27 killer
# 28 expert
# 29 in
# 30 ethics
# 31 health
# 32 policy
# 33 in
# 34 the
# 35 new
# 36 york
# 37 times
# 38 says
# 39 that
# 40 vaccinating
# 41 elderly
# 42 people
# 43 first
# 3555
# 0 None
# 1 None
# 2 while
# 3 democrat
# 4 presidential
# 5 hopefuls
# 6 aim
# 7 weaponize
# 8 the
# 9 tax
# 10 cuts
# 11 elaine
# 12 parker
# 13 chief
# 14 communications
# 15 officer
# 16 of
# 17 job
# 18 creators
# 19 network
# 20 jcn
# 21 told
# 22 breitbart
# 23 news
# 24 in
# 25 an
# 26 exclusive
# 27 interview
# 28 in
# 29 january
# 30 that
# 31 it
# 32 is
# 33 precisely
# 34 what
# 35 will
# 36 assist
# 37 trump
# 38 in
# 39 making
# 40 his
# 41 case
# 42 to
# 43 the
# 3556
# 0 None
# 1 None
# 2 while
# 3 democrats
# 4 were
# 5 busy
# 6 diverting
# 7 the
# 8 attention
# 9 energy
# 10 of
# 11 the
# 12 entire
# 13 country
# 14 into
# 15 a
# 16 pointless
# 17 trial
# 18 that
# 19 could
# 20 possibly
# 21 have
# 22 ended
# 23 in
# 24 anything
# 25 other
# 26 than
# 27 president
# 28 donald
# 3557
# 0 None
# 1 None
# 2 while
# 3 democrats
# 4 were
# 5 diverting
# 6 the
# 7 attention
# 8 energy
# 9 of
# 10 the
# 11 entire
# 12 country
# 13 into
# 14 a
# 15 pointless
# 16 trial
# 17 that
# 18 could
# 19 possibly
# 20 have
# 21 ended
# 22 in
# 23 anything
# 24 other
# 25 than
# 26 president
# 27 donald
# 3558
# 0 None
# 1 None
# 2 while
# 3 democrats
# 4 were
# 5 persistent
# 6 in
# 7 their
# 8 questioning
# 9 the
# 10 hearing
# 11 retained
# 12 a
# 13 respectful
# 14 tone
# 15 barrett
# 16 remained
# 17 even
# 18 tempered
# 19 while
# 20 nimbly
# 21 sidestepping
# 22 questions
# 23 on
# 24 her
# 25 views
# 26 on
# 27 abortion
# 28 lgbt
# 29 rights
# 30 gun
# 31 control
# 3559
# 0 None
# 1 None
# 2 while
# 3 each
# 4 sport
# 5 has
# 6 its
# 7 own
# 8 rules
# 9 with
# 10 regards
# 11 to
# 12 religious
# 13 headwear
# 14 muslim
# 15 women
# 16 who
# 17 compete
# 18 while
# 19 wearing
# 20 a
# 21 hijab
# 22 have
# 23 faced
# 24 a
# 25 litany
# 3560
# 0 None
# 1 None
# 2 while
# 3 emphasizing
# 4 he
# 5 ’s
# 6 singling
# 7 out
# 8 party
# 9 cohen
# 10 warned
# 11 about
# 12 the
# 13 danger
# 14 of
# 15 normalizing
# 16 white
# 3561
# 0 None
# 1 None
# 2 while
# 3 falling
# 4 short
# 5 of
# 6 calling
# 7 half
# 8 the
# 9 nation
# 10 deplorable
# 11 as
# 12 former
# 13 secretary
# 14 of
# 15 state
# 16 hillary
# 17 clinton
# 18 did
# 19 in
# 20 the
# 21 comments
# 22 echo
# 23 a
# 24 deep
# 25 disdain
# 26 for
# 27 a
# 28 large
# 29 population
# 30 of
# 31 the
# 32 country
# 33 increasingly
# 34 perpetuated
# 35 by
# 36 left
# 37 wing
# 38 elites
# 39 in
# 40 the
# 41 wake
# 42 of
# 43 the
# 44 george
# 45 floyd
# 46 protests
# 47 characterizing
# 48 the
# 49 u.s.
# 50 as
# 3562
# 0 None
# 1 None
# 2 while
# 3 health
# 4 experts
# 5 say
# 6 a
# 7 vaccine
# 8 prevent
# 9 infection
# 10 is
# 11 needed
# 12 return
# 13 life
# 14 to
# 15 normal
# 16 the
# 17 survey
# 18 points
# 19 to
# 20 a
# 21 potential
# 22 trust
# 23 issue
# 24 for
# 25 the
# 26 trump
# 27 administration
# 28 already
# 29 under
# 30 fire
# 31 for
# 32 its
# 33 often
# 34 contradictory
# 35 safety
# 36 guidance
# 37 during
# 3563
# 0 None
# 1 None
# 2 while
# 3 his
# 4 supporters
# 5 have
# 6 included
# 7 many
# 8 strains
# 9 of
# 10 nationalism
# 11 populism
# 12 he
# 13 did
# 14 run
# 15 as
# 16 a
# 17 republican
# 18 this
# 19 will
# 20 hopefully
# 21 work
# 22 in
# 23 his
# 24 favor
# 25 many
# 26 americans
# 27 are
# 28 hopeful
# 29 excited
# 30 looking
# 31 forward
# 32 to
# 33 a
# 34 trump
# 35 presidency
# 36 here
# 37 are
# 38 some
# 39 of
# 40 the
# 3564
# 0 None
# 1 None
# 2 while
# 3 it
# 4 ’s
# 5 perfectly
# 6 evident
# 7 that
# 8 trump
# 9 does
# 10 have
# 11 racist
# 12 supporters
# 13 which
# 14 he
# 15 is
# 16 suspiciously
# 17 reluctant
# 18 condemn
# 19 many
# 20 contend
# 21 that
# 22 trumpism
# 23 is
# 24 itself
# 25 racist
# 26 merely
# 27 a
# 28 justified
# 29 reaction
# 30 to
# 31 the
# 32 left
# 3565
# 0 None
# 1 None
# 2 while
# 3 lecturing
# 4 americans
# 5 on
# 6 racism
# 7 big
# 8 business
# 9 opposes
# 10 ban
# 11 on
# 12 using
# 13 foreign
# 3566
# 0 None
# 1 None
# 2 while
# 3 low
# 4 unemployment
# 5 steadily
# 6 if
# 7 slowly
# 8 rising
# 9 wages
# 10 have
# 11 improved
# 12 the
# 13 fortunes
# 14 of
# 15 lower
# 16 income
# 17 americans
# 18 these
# 19 gains
# 20 pale
# 21 in
# 22 comparison
# 23 to
# 24 the
# 25 investment
# 26 gains
# 27 realized
# 28 by
# 29 the
# 3567
# 0 None
# 1 None
# 2 while
# 3 many
# 4 things
# 5 were
# 6 certain
# 7 change
# 8 the
# 9 president
# 10 felt
# 11 sure
# 12 that
# 13 element
# 14 of
# 15 continuity
# 16 would
# 17 persist
# 18 the
# 19 united
# 20 states
# 21 would
# 22 determine
# 23 history
# 3568
# 0 None
# 1 None
# 2 while
# 3 many
# 4 women
# 5 the
# 6 men
# 7 who
# 8 love
# 9 them
# 10 are
# 11 well
# 12 aware
# 13 that
# 14 spurred
# 15 on
# 16 by
# 17 the
# 18 vatican
# 19 united
# 20 states
# 21 conference
# 22 of
# 23 catholic
# 24 bishops
# 25 usccb
# 26 the
# 27 so
# 28 called
# 29 personhood
# 30 movement
# 31 republicans
# 32 are
# 33 working
# 34 feverishly
# 35 eradicate
# 36 women
# 3569
# 0 None
# 1 None
# 2 while
# 3 most
# 4 national
# 5 attention
# 6 has
# 7 been
# 8 focused
# 9 on
# 10 massive
# 11 demonstrations
# 12 violent
# 13 clashes
# 14 with
# 15 police
# 16 in
# 17 the
# 18 united
# 19 states
# 20 biggest
# 21 cities
# 22 like
# 23 new
# 24 york
# 25 los
# 26 angeles
# 27 hundreds
# 28 of
# 29 spontaneous
# 30 demonstrations
# 31 have
# 32 popped
# 33 up
# 34 in
# 35 little
# 36 towns
# 37 rural
# 38 areas
# 39 across
# 40 the
# 41 nation
# 42 in
# 3570
# 0 None
# 1 None
# 2 while
# 3 no
# 4 one
# 5 is
# 6 praising
# 7 trump
# 8 as
# 9 a
# 10 thought
# 11 leader
# 12 in
# 13 the
# 14 way
# 15 limbaugh
# 16 has
# 17 been
# 18 he
# 19 ’s
# 20 undeniably
# 21 made
# 22 conservative
# 23 ideas
# 24 tangible
# 25 for
# 3571
# 0 None
# 1 None
# 2 while
# 3 nyc
# 4 has
# 5 largely
# 6 tamed
# 7 the
# 8 lethal
# 9 highly
# 10 contagious
# 11 coronavirus
# 12 another
# 13 epidemic
# 14 is
# 15 starting
# 16 rear
# 17 its
# 18 ugly
# 19 head
# 20 in
# 21 the
# 22 city
# 23 once
# 24 again
# 3572
# 0 None
# 1 None
# 2 while
# 3 omar
# 4 is
# 5 in
# 6 no
# 7 danger
# 8 of
# 9 being
# 10 held
# 11 accountable
# 12 for
# 13 her
# 14 extremism
# 15 her
# 16 ascent
# 17 to
# 18 rock
# 19 star
# 20 status
# 21 among
# 22 democrats
# 23 their
# 24 media
# 25 cheering
# 26 section
# 27 gives
# 28 the
# 29 lie
# 30 to
# 31 their
# 32 claims
# 33 be
# 34 standing
# 35 up
# 36 against
# 3573
# 0 None
# 1 None
# 2 while
# 3 opportunity
# 4 zone
# 5 program
# 6 that
# 7 offers
# 8 tax
# 9 breaks
# 10 to
# 11 investors
# 12 who
# 13 put
# 14 money
# 15 into
# 16 specially
# 17 designated
# 18 areas
# 19 was
# 20 pitched
# 21 as
# 22 a
# 23 way
# 24 help
# 25 struggling
# 26 neighborhoods
# 27 propublica
# 28 others
# 29 have
# 30 documented
# 31 how
# 32 the
# 33 process
# 34 has
# 35 appeared
# 36 benefit
# 37 billionaires
# 38 with
# 39 investments
# 40 in
# 41 areas
# 42 that
# 43 should
# 3574
# 0 None
# 1 None
# 2 while
# 3 pace
# 4 receives
# 5 her
# 6 spiritual
# 7 grace
# 8 from
# 9 a
# 10 christian
# 11 god
# 12 science
# 13 has
# 14 shown
# 15 that
# 16 faith
# 17 in
# 18 a
# 19 supernatural
# 20 wonder
# 21 whatever
# 22 it
# 23 may
# 24 be
# 25 that
# 26 bears
# 27 powerful
# 28 benefits
# 29 on
# 30 an
# 31 individual
# 32 mental
# 33 even
# 34 physical
# 3575
# 0 None
# 1 None
# 2 while
# 3 pence
# 4 the
# 5 president
# 6 have
# 7 tried
# 8 paint
# 9 a
# 10 rosier
# 11 picture
# 12 of
# 13 the
# 14 virus
# 15 project
# 16 a
# 17 return
# 18 to
# 19 normalcy
# 20 some
# 21 members
# 22 of
# 23 the
# 24 task
# 25 force
# 26 are
# 27 eager
# 28 resume
# 29 appearances
# 30 from
# 31 white
# 3576
# 0 None
# 1 None
# 2 while
# 3 president
# 4 donald
# 5 trump
# 6 impeachment
# 7 trial
# 8 had
# 9 been
# 10 wrapping
# 11 up
# 12 he
# 13 expanded
# 14 of
# 15 his
# 16 most
# 17 controversial
# 18 inflammatory
# 19 policies
# 20 with
# 21 little
# 22 fanfare
# 23 minimal
# 24 opposition
# 25 the
# 26 travel
# 27 ban
# 28 on
# 29 people
# 30 from
# 31 multiple
# 32 muslim
# 3577
# 0 None
# 1 None
# 2 while
# 3 president
# 4 trump
# 5 visited
# 6 the
# 7 southern
# 8 border
# 9 thursday
# 10 democratic
# 11 darling
# 12 beto
# 13 o’rourke
# 14 visited
# 15 the
# 16 dentist
# 17 posting
# 18 a
# 19 bizarre
# 20 video
# 21 showing
# 22 him
# 23 getting
# 24 a
# 25 mouth
# 26 wide
# 27 open
# 28 cleaning
# 29 in
# 30 order
# 31 highlight
# 32 the
# 33 story
# 34 of
# 35 his
# 36 dental
# 37 hygienist
# 38 ’s
# 39 upbringing
# 40 in
# 3578
# 0 None
# 1 None
# 2 while
# 3 riots
# 4 raged
# 5 across
# 6 the
# 7 united
# 8 states
# 9 over
# 10 floyd
# 11 death
# 12 editors
# 13 on
# 14 wikipedia
# 15 promptly
# 16 set
# 17 out
# 18 spin
# 19 the
# 20 narrative
# 21 of
# 22 the
# 23 unrest
# 3579
# 0 None
# 1 None
# 2 while
# 3 sexual
# 4 ambiguity
# 5 does
# 6 occasionally
# 7 occur
# 8 the
# 9 authors
# 10 note
# 11 intersex
# 12 individuals
# 13 are
# 14 extremely
# 15 rare
# 16 they
# 17 are
# 18 a
# 19 third
# 20 sex
# 21 proof
# 22 that
# 23 sex
# 24 is
# 25 a
# 26 spectrum
# 27 a
# 3580
# 0 None
# 1 None
# 2 while
# 3 snapchat
# 4 is
# 5 happy
# 6 blame
# 7 president
# 8 trump
# 9 who
# 10 is
# 11 working
# 12 restore
# 13 order
# 14 for
# 15 the
# 16 ongoing
# 17 violence
# 18 it
# 19 has
# 20 said
# 21 anything
# 22 about
# 23 support
# 24 for
# 25 the
# 26 domestic
# 27 terrorist
# 28 antifa
# 29 movement
# 30 on
# 3581
# 0 None
# 1 None
# 2 while
# 3 the
# 4 announcement
# 5 identifies
# 6 cases
# 7 of
# 8 alleged
# 9 police
# 10 misconduct
# 11 it
# 12 does
# 13 mention
# 14 violence
# 15 accompanying
# 16 the
# 17 protests
# 18 over
# 19 floyd
# 20 death
# 21 that
# 22 the
# 23 foundation
# 24 is
# 3582
# 0 None
# 1 None
# 2 while
# 3 the
# 4 major
# 5 baseball
# 6 leagues
# 7 wo
# 8 be
# 9 affected
# 10 much
# 11 by
# 12 tariffs
# 13 on
# 14 chinese
# 15 imports
# 16 everyone
# 17 from
# 18 double
# 19 a
# 20 players
# 21 down
# 22 through
# 23 the
# 24 office
# 25 softball
# 26 team
# 3583
# 0 None
# 1 None
# 2 while
# 3 the
# 4 majority
# 5 of
# 6 americans
# 7 seem
# 8 accept
# 9 scientific
# 10 information
# 11 about
# 12 the
# 13 deadly
# 14 coronavirus
# 15 are
# 16 wary
# 17 of
# 18 reopening
# 19 the
# 20 country
# 21 before
# 22 we
# 23 can
# 24 be
# 25 sure
# 26 it
# 27 ’s
# 28 safe
# 29 segment
# 30 of
# 31 the
# 32 population
# 33 is
# 34 driving
# 35 the
# 36 opposite
# 37 narrative
# 38 this
# 39 group
# 40 is
# 41 small
# 42 vocal
# 43 represents
# 44 a
# 45 predictable
# 46 if
# 47 threatening
# 48 merging
# 3584
# 0 None
# 1 None
# 2 while
# 3 the
# 4 mayor
# 5 has
# 6 severely
# 7 curtailed
# 8 religious
# 9 practice
# 10 in
# 11 the
# 12 city
# 13 he
# 14 has
# 15 defended
# 16 the
# 17 rights
# 18 of
# 19 citizens
# 20 form
# 21 huge
# 22 gatherings
# 23 protest
# 24 even
# 25 violently
# 26 obviously
# 27 without
# 28 social
# 29 distancing
# 30 masks
# 31 except
# 32 perhaps
# 3585
# 0 None
# 1 None
# 2 while
# 3 the
# 4 overwhelming
# 5 majority
# 6 of
# 7 americans
# 8 choose
# 9 have
# 10 their
# 11 children
# 12 vaccinated
# 13 the
# 14 number
# 15 of
# 16 children
# 17 who
# 18 go
# 19 completely
# 20 unvaccinated
# 3586
# 0 None
# 1 None
# 2 while
# 3 the
# 4 piece
# 5 fairly
# 6 analyzes
# 7 the
# 8 fracturing
# 9 of
# 10 the
# 11 white
# 12 nationalist
# 13 movement
# 14 it
# 15 makes
# 16 the
# 17 bizarre
# 18 claim
# 19 that
# 20 ideas
# 21 that
# 22 are
# 23 widely
# 24 popular
# 25 amongst
# 26 mainstream
# 27 conservatives
# 28 such
# 29 as
# 30 ending
# 31 affirmative
# 32 action
# 33 are
# 34 actually
# 35 white
# 36 nationalist
# 3587
# 0 None
# 1 None
# 2 while
# 3 the
# 4 press
# 5 had
# 6 no
# 7 problem
# 8 regurgitating
# 9 the
# 10 propaganda
# 11 ben
# 12 rhodes
# 13 created
# 14 in
# 15 the
# 16 d.c.
# 17 echo
# 18 chamber
# 19 sell
# 20 president
# 21 obama
# 22 disastrous
# 23 iran
# 24 deal
# 25 with
# 26 trump
# 27 corporate
# 28 media
# 29 has
# 30 opted
# 31 limit
# 32 coverage
# 33 of
# 34 iran
# 35 horrific
# 36 human
# 3588
# 0 None
# 1 None
# 2 while
# 3 the
# 4 stupid
# 5 democrats
# 6 who
# 7 vote
# 8 for
# 9 democrats
# 10 stress
# 11 worry
# 12 about
# 13 another
# 14 round
# 15 of
# 16 looting
# 17 burning
# 18 this
# 19 weekend
# 20 in
# 21 their
# 22 democrat
# 23 run
# 24 cities
# 25 all
# 26 i
# 27 ’m
# 28 worried
# 29 about
# 30 is
# 3589
# 0 None
# 1 None
# 2 while
# 3 the
# 4 threat
# 5 of
# 6 anti
# 7 -
# 8 trans
# 9 bills
# 10 being
# 11 passed
# 12 into
# 13 law
# 14 is
# 15 real
# 16 present
# 17 all
# 18 such
# 19 legislation
# 20 will
# 21 almost
# 22 certainly
# 23 be
# 24 challenged
# 25 in
# 26 the
# 27 courts
# 28 immediately
# 29 upon
# 30 passing
# 31 before
# 32 it
# 33 can
# 34 be
# 3590
# 0 None
# 1 None
# 2 while
# 3 the
# 4 workaday
# 5 majority
# 6 of
# 7 americans
# 8 continue
# 9 be
# 10 mired
# 11 in
# 12 our
# 13 low
# 14 wage
# 15 economy
# 16 the
# 17 precious
# 18 few
# 19 at
# 20 the
# 21 tippy
# 22 top
# 23 soared
# 24 out
# 25 of
# 3591
# 0 None
# 1 None
# 2 while
# 3 these
# 4 many
# 5 similarities
# 6 between
# 7 green
# 8 new
# 9 deal
# 10 the
# 11 constitution
# 12 ushered
# 13 in
# 14 by
# 15 venezuelan
# 16 leftist
# 17 dictator
# 18 hugo
# 19 chavez
# 20 in
# 21 may
# 22 be
# 23 just
# 24 happenstance
# 25 the
# 26 important
# 27 thing
# 28 remember
# 29 is
# 30 that
# 31 venezuela
# 32 under
# 33 its
# 34 new
# 35 constitution
# 36 has
# 37 become
# 38 a
# 3592
# 0 None
# 1 None
# 2 while
# 3 trump
# 4 has
# 5 stopped
# 6 short
# 7 of
# 8 invoking
# 9 the
# 10 act
# 11 use
# 12 the
# 13 military
# 14 enforce
# 15 laws
# 16 domestically
# 17 he
# 18 ’s
# 19 kept
# 20 the
# 21 option
# 22 open
# 23 fomenting
# 24 further
# 25 unrest
# 26 division
# 27 rather
# 28 than
# 29 staging
# 30 photo
# 31 opportunities
# 32 while
# 33 awkwardly
# 34 holding
# 35 a
# 36 bible
# 37 in
# 38 lafayette
# 39 square
# 40 trump
# 41 would
# 42 have
# 43 issued
# 44 a
# 45 formal
# 46 proclamation
# 47 calling
# 48 on
# 49 the
# 50 insurgents
# 51 disperse
# 52 if
# 53 he
# 54 ’s
# 55 serious
# 56 about
# 57 the
# 58 application
# 59 of
# 60 the
# 3593
# 0 None
# 1 None
# 2 while
# 3 in
# 4 the
# 5 wake
# 6 of
# 7 the
# 8 el
# 9 paso
# 10 murders
# 11 the
# 12 media
# 13 most
# 14 of
# 15 our
# 16 politicians
# 17 are
# 18 acting
# 19 shocked
# 20 that
# 21 there
# 22 are
# 23 armed
# 24 racists
# 25 in
# 26 america
# 27 who
# 28 are
# 29 trying
# 30 terrify
# 31 people
# 32 of
# 33 color
# 34 the
# 35 reality
# 36 is
# 37 that
# 38 it
# 39 ’s
# 40 pretty
# 41 much
# 42 always
# 43 been
# 44 that
# 45 way
# 46 here
# 47 in
# 48 the
# 3594
# 0 None
# 1 None
# 2 while
# 3 in
# 4 the
# 5 wake
# 6 of
# 7 the
# 8 el
# 9 paso
# 10 murders
# 11 the
# 12 media
# 13 most
# 14 of
# 15 our
# 16 politicians
# 17 are
# 18 acting
# 19 shocked—“shocked
# 20 i
# 21 tell
# 22 you!”—that
# 23 there
# 24 are
# 25 armed
# 26 racists
# 27 in
# 28 america
# 29 who
# 30 are
# 31 trying
# 32 terrify
# 33 people
# 34 of
# 35 color
# 36 the
# 37 reality
# 38 is
# 39 that
# 40 it
# 41 ’s
# 42 pretty
# 43 much
# 44 always
# 45 been
# 46 that
# 47 way
# 48 here
# 49 in
# 50 the
# 3595
# 0 None
# 1 None
# 2 white
# 3 house
# 4 national
# 5 economic
# 6 council
# 7 director
# 8 larry
# 9 kudlow
# 10 said
# 11 on
# 12 friday
# 13 that
# 14 he
# 15 did
# 16 favor
# 17 a
# 18 higher
# 19 federal
# 20 tax
# 21 on
# 22 gasoline
# 23 fund
# 24 an
# 25 infrastructure
# 26 program
# 27 if
# 28 states
# 29 wanted
# 30 raise
# 31 their
# 32 own
# 33 gas
# 34 taxes
# 35 that
# 36 was
# 37 up
# 3596
# 0 None
# 1 None
# 2 white
# 3 house
# 4 press
# 5 secretary
# 6 kayleigh
# 7 mcenany
# 8 voiced
# 9 tepid
# 10 support
# 11 for
# 12 defense
# 13 secretary
# 14 mark
# 15 esper
# 16 after
# 17 he
# 18 stated
# 19 wednesday
# 20 that
# 21 he
# 22 did
# 23 support
# 24 invoking
# 25 the
# 26 insurrection
# 27 act
# 28 which
# 29 would
# 30 allow
# 31 active
# 32 duty
# 33 troops
# 34 act
# 35 in
# 36 domestic
# 37 law
# 3597
# 0 None
# 1 None
# 2 white
# 3 house
# 4 senior
# 5 adviser
# 6 jared
# 7 kushner
# 8 criticized
# 9 athletes
# 10 others
# 11 who
# 12 have
# 13 protested
# 14 against
# 15 u.s.
# 16 racism
# 17 on
# 18 social
# 19 media
# 20 basketball
# 21 courts
# 22 suggested
# 23 that
# 24 black
# 25 people
# 26 had
# 27 want
# 28 succeed
# 29 for
# 3598
# 0 None
# 1 None
# 2 white
# 3 mobs
# 4 have
# 5 once
# 6 again
# 7 moved
# 8 out
# 9 of
# 10 the
# 11 shadows
# 12 into
# 13 the
# 14 limelight
# 15 during
# 16 this
# 3599
# 0 None
# 1 None
# 2 white
# 3 nationalism
# 4 fueled
# 5 violence
# 6 is
# 7 on
# 8 the
# 9 rise
# 10 fbi
# 11 is
# 12 slow
# 13 call
# 14 it
# 3600
# 0 None
# 1 None
# 2 white
# 3 nationalist
# 4 arrested
# 5 for
# 6 alleged
# 7 threat
# 8 against
# 9 ohio
# 10 jewish
# 3601
# 0 None
# 1 None
# 2 white
# 3 nationalists
# 4 also
# 5 expressed
# 6 excitement
# 7 tuesday
# 8 about
# 9 trump
# 10 plan
# 11 use
# 12 an
# 13 executive
# 14 order
# 15 end
# 16 birthright
# 17 citizenship
# 18 the
# 19 automatic
# 20 grant
# 21 of
# 22 citizen
# 23 status
# 24 to
# 25 anyone
# 26 born
# 27 in
# 28 the
# 3602
# 0 None
# 1 None
# 2 white
# 3 people
# 4 are
# 5 being
# 6 asked
# 7 pushed
# 8 take
# 9 stock
# 10 of
# 11 their
# 12 whiteness
# 13 identify
# 14 with
# 15 it
# 16 more
# 17 this
# 18 is
# 19 a
# 20 remarkably
# 3603
# 0 None
# 1 None
# 2 white
# 3 supremacist
# 4 violent
# 5 extremists
# 6 can
# 7 generally
# 8 be
# 9 characterized
# 10 by
# 11 hatred
# 12 for
# 13 immigrants
# 14 ethnic
# 15 minorities
# 16 often
# 17 combining
# 18 these
# 19 prejudices
# 20 with
# 21 virulent
# 22 anti
# 23 -
# 24 semitism
# 25 anti
# 26 -
# 27 muslim
# 28 views
# 29 the
# 30 dhs
# 3604
# 0 None
# 1 None
# 2 whitmer
# 3 takes
# 4 on
# 5 trump
# 6 for
# 7 claiming
# 8 the
# 9 economy
# 10 is
# 11 booming
# 12 asking
# 13 for
# 14 whom
# 15 she
# 16 details
# 17 local
# 18 pieces
# 19 of
# 20 legislation
# 21 dem
# 22 governors
# 23 are
# 24 working
# 25 on
# 26 before
# 27 claiming
# 28 democrats
# 29 are
# 30 the
# 31 ones
# 32 who
# 33 actually
# 34 fight
# 35 for
# 3605
# 0 None
# 1 None
# 2 who
# 3 is
# 4 working
# 5 ensure
# 6 fair
# 7 vaccine
# 8 distribution
# 9 in
# 10 the
# 11 meantime
# 12 it
# 13 is
# 14 key
# 15 suppress
# 16 the
# 17 virus
# 18 spread
# 19 said
# 20 mike
# 21 ryan
# 22 head
# 23 of
# 24 who
# 25 emergencies
# 26 program
# 27 as
# 28 daily
# 29 new
# 30 cases
# 31 around
# 32 the
# 33 globe
# 34 are
# 35 at
# 36 near
# 3606
# 0 None
# 1 None
# 2 why
# 3 are
# 4 members
# 5 of
# 6 the
# 7 fairer
# 8 sex
# 9 on
# 10 the
# 11 frontlines
# 12 of
# 13 riotous
# 14 efforts
# 15 support
# 16 a
# 17 movement
# 18 that
# 19 insists
# 20 they
# 21 're
# 22 racist
# 23 capitalism
# 24 is
# 25 racist
# 26 the
# 27 whole
# 28 system
# 3607
# 0 None
# 1 None
# 2 why
# 3 did
# 4 democrats
# 5 vote
# 6 overwhelmingly
# 7 against
# 8 a
# 9 bill
# 10 that
# 11 would
# 12 require
# 13 infants
# 14 born
# 15 alive
# 16 after
# 17 abortion
# 18 be
# 19 treated
# 20 as
# 21 any
# 22 other
# 23 infant
# 24 born
# 25 at
# 26 that
# 27 gestational
# 28 age
# 29 because
# 30 abortion
# 31 is
# 32 the
# 33 right
# 34 destroy
# 35 own
# 36 child
# 37 if
# 38 a
# 39 woman
# 40 chose
# 41 kill
# 42 her
# 43 baby
# 44 to
# 45 the
# 46 left
# 47 it
# 48 would
# 49 seem
# 50 a
# 51 violation
# 52 of
# 53 her
# 54 so
# 55 called
# 56 right
# 57 choose
# 58 for
# 59 doctors
# 60 try
# 61 save
# 3608
# 0 None
# 1 None
# 2 why
# 3 did
# 4 trump
# 5 offer
# 6 up
# 7 this
# 8 cards
# 9 that
# 10 's
# 11 because
# 12 his
# 13 vaunted
# 14 skills
# 15 in
# 16 making
# 17 the
# 18 deal
# 19 absolutely
# 20 failed
# 21 budge
# 22 the
# 23 prices
# 24 from
# 25 pharmaceutical
# 26 companies
# 27 a
# 28 deal
# 29 that
# 30 had
# 31 been
# 32 in
# 33 the
# 34 works
# 35 for
# 36 months
# 3609
# 0 None
# 1 None
# 2 why
# 3 women
# 4 have
# 5 abortions
# 6 is
# 7 a
# 8 topic
# 9 much
# 10 discussed
# 11 by
# 12 those
# 13 who
# 14 argue
# 15 that
# 16 ending
# 17 a
# 18 life
# 19 in
# 20 the
# 21 womb
# 22 is
# 3610
# 0 None
# 1 None
# 2 wikipedia
# 3 coverage
# 4 of
# 5 other
# 6 contentious
# 7 political
# 8 topics
# 9 such
# 10 as
# 11 abortion
# 12 were
# 13 also
# 14 criticized
# 15 with
# 16 sanger
# 17 singling
# 18 out
# 19 wikipedia
# 20 claiming
# 21 abortion
# 22 is
# 23 of
# 24 the
# 25 safest
# 26 procedures
# 3611
# 0 None
# 1 None
# 2 wikipedia
# 3 own
# 4 articles
# 5 on
# 6 the
# 7 floyd
# 8 protests
# 9 similarly
# 10 reflect
# 11 the
# 12 foundation
# 13 abandonment
# 14 of
# 15 neutrality
# 16 by
# 17 being
# 18 unduly
# 19 skewed
# 20 towards
# 21 smearing
# 22 president
# 23 donald
# 24 trump
# 25 while
# 26 downplaying
# 27 protestor
# 28 violence
# 29 the
# 30 violent
# 31 antifa
# 3612
# 0 None
# 1 None
# 2 will
# 3 noted
# 4 gender
# 5 dysphoria
# 6 is
# 7 a
# 8 mental
# 9 health
# 10 issue
# 11 parents
# 12 have
# 13 the
# 14 right
# 15 make
# 16 healthcare
# 17 decisions
# 18 on
# 19 behalf
# 20 of
# 3613
# 0 None
# 1 None
# 2 will
# 3 the
# 4 american
# 5 people
# 6 follow
# 7 the
# 8 commands
# 9 of
# 10 donald
# 11 trump
# 12 coronavirus
# 3614
# 0 None
# 1 None
# 2 wilson
# 3 ali
# 4 have
# 5 received
# 6 death
# 7 threats
# 8 for
# 9 the
# 10 crime
# 11 of
# 12 poking
# 13 fun
# 14 at
# 15 donald
# 16 trump
# 17 the
# 18 members
# 19 of
# 20 his
# 3615
# 0 None
# 1 None
# 2 wilton
# 3 gregory
# 4 the
# 5 first
# 6 african
# 7 american
# 8 be
# 9 named
# 10 as
# 11 cardinal
# 12 known
# 13 as
# 14 a
# 15 refined
# 16 diplomat
# 17 made
# 18 headlines
# 19 when
# 20 he
# 21 blasted
# 22 president
# 23 donald
# 24 trump
# 25 photo
# 26 opportunity
# 27 hoisting
# 28 a
# 29 bible
# 30 at
# 31 a
# 32 washington
# 33 church
# 34 after
# 35 police
# 36 used
# 37 tear
# 38 gas
# 39 clear
# 40 demonstrators
# 3616
# 0 None
# 1 None
# 2 wimbledon
# 3 champion
# 4 navratilova
# 5 who
# 6 has
# 7 campaigned
# 8 for
# 9 gay
# 10 rights
# 11 suffered
# 12 abuse
# 13 when
# 14 she
# 15 came
# 16 out
# 17 in
# 18 the
# 19 1980s
# 20 argued
# 21 trans
# 22 women
# 23 have
# 24 unfair
# 3617
# 0 None
# 1 None
# 2 winston
# 3 churchill
# 4 was
# 5 a
# 6 racist
# 7 so
# 8 the
# 9 black
# 10 lives
# 11 matter
# 12 graffiti
# 13 says
# 14 on
# 15 the
# 16 plinth
# 17 of
# 18 his
# 19 statue
# 20 in
# 21 london
# 22 parliament
# 23 square
# 24 which
# 25 is
# 26 bound
# 27 be
# 28 pulled
# 29 down
# 30 by
# 31 hard
# 32 left
# 33 activists
# 34 sooner
# 35 later
# 36 because
# 37 the
# 38 police
# 39 do
# 40 seem
# 41 have
# 42 that
# 43 much
# 44 of
# 45 an
# 46 appetite
# 3618
# 0 None
# 1 None
# 2 with
# 3 democrats
# 4 fuming
# 5 over
# 6 trump
# 7 push
# 8 for
# 9 a
# 10 border
# 11 wall
# 12 amid
# 13 a
# 14 still
# 15 unresolved
# 16 funding
# 17 standoff
# 18 those
# 19 guest
# 20 lists
# 21 signal
# 22 the
# 23 president
# 24 could
# 25 face
# 26 a
# 3619
# 0 None
# 1 None
# 2 with
# 3 hundreds
# 4 of
# 5 potential
# 6 vaccines
# 7 in
# 8 various
# 9 stages
# 10 of
# 11 development
# 12 around
# 13 the
# 14 world
# 15 russia
# 16 was
# 17 the
# 18 first
# 19 country
# 20 license
# 21 its
# 22 vaccine
# 23 for
# 24 public
# 25 use
# 26 alongside
# 27 china
# 28 has
# 29 been
# 30 deploying
# 31 the
# 32 shots
# 33 before
# 34 full
# 35 efficacy
# 36 trials
# 3620
# 0 None
# 1 None
# 2 with
# 3 it
# 4 ’s
# 5 bothsidesism
# 6 pro
# 7 -
# 8 trump
# 9 onesiderism
# 10 the
# 11 new
# 12 york
# 13 times
# 3621
# 0 None
# 1 None
# 2 with
# 3 june
# 4 marking
# 5 the
# 6 start
# 7 of
# 8 the
# 9 annual
# 10 pride
# 11 month
# 12 when
# 13 many
# 14 gay
# 15 trans
# 16 people
# 17 commemorate
# 18 riots
# 19 against
# 20 police
# 21 brutality
# 22 in
# 23 in
# 24 new
# 25 york
# 26 city
# 27 brown
# 28 called
# 29 on
# 30 the
# 31 lgbt+
# 32 community
# 33 recall
# 34 the
# 35 protest
# 36 driven
# 37 roots
# 38 of
# 3622
# 0 None
# 1 None
# 2 with
# 3 just
# 4 over
# 5 a
# 6 year
# 7 left
# 8 in
# 9 president
# 10 donald
# 11 trump
# 12 first
# 13 term
# 14 another
# 15 late
# 16 breaking
# 17 news
# 18 item
# 19 barely
# 20 made
# 21 waves
# 22 the
# 23 interior
# 24 department
# 25 which
# 26 manages
# 27 the
# 28 majority
# 29 of
# 30 the
# 31 federal
# 32 government
# 33 public
# 34 lands
# 35 deleted
# 36 sexual
# 37 orientation
# 38 from
# 39 its
# 40 anti
# 41 -
# 3623
# 0 None
# 1 None
# 2 with
# 3 many
# 4 formal
# 5 juneteenth
# 6 events
# 7 canceled
# 8 due
# 9 to
# 10 coronavirus
# 11 concerns
# 12 activists
# 13 instead
# 14 organized
# 15 a
# 16 host
# 17 of
# 18 virtual
# 19 observances
# 20 online
# 21 as
# 22 well
# 23 as
# 24 street
# 25 marches
# 26 car
# 27 caravans
# 28 through
# 29 several
# 3624
# 0 None
# 1 None
# 2 with
# 3 more
# 4 than
# 5 people
# 6 killed
# 7 by
# 8 gun
# 9 violence
# 10 in
# 11 the
# 12 united
# 13 states
# 14 last
# 15 year
# 16 counting
# 17 suicides
# 18 democrats
# 19 running
# 20 for
# 21 their
# 22 party
# 23 presidential
# 24 nomination
# 25 are
# 26 pointing
# 27 to
# 28 inaction
# 29 in
# 30 washington
# 31 as
# 32 evidence
# 33 they
# 34 should
# 35 be
# 36 chosen
# 37 run
# 38 against
# 39 republican
# 40 president
# 3625
# 0 None
# 1 None
# 2 with
# 3 more
# 4 than
# 5 reported
# 6 cases
# 7 of
# 8 the
# 9 disease
# 10 the
# 11 viral
# 12 outbreak
# 13 continues
# 14 create
# 15 uncertainty
# 16 about
# 17 future
# 18 competitions
# 19 from
# 20 track
# 21 field
# 22 formula
# 23 to
# 24 the
# 25 ultimate
# 26 global
# 27 event
# 28 the
# 3626
# 0 None
# 1 None
# 2 with
# 3 our
# 4 climate
# 5 impacted
# 6 world
# 7 now
# 8 highly
# 9 prone
# 10 to
# 11 fires
# 12 extreme
# 13 storms
# 14 sea
# 15 level
# 16 rise
# 17 nuclear
# 18 energy
# 19 is
# 20 touted
# 21 as
# 22 a
# 23 possible
# 24 replacement
# 25 for
# 26 the
# 27 burning
# 28 of
# 29 fossil
# 30 fuels
# 31 for
# 32 energy
# 33 the
# 34 leading
# 35 cause
# 36 of
# 3627
# 0 None
# 1 None
# 2 with
# 3 protests
# 4 over
# 5 racial
# 6 injustice
# 7 continuing
# 8 roil
# 9 the
# 10 united
# 11 states
# 12 queer
# 13 eye
# 14 star
# 15 karamo
# 16 brown
# 17 has
# 18 called
# 19 on
# 20 lgbt+
# 21 people
# 22 recognize
# 23 the
# 24 racism
# 25 transphobia
# 26 in
# 27 the
# 28 community
# 29 remember
# 30 the
# 31 radical
# 32 roots
# 33 of
# 34 the
# 35 gay
# 3628
# 0 None
# 1 None
# 2 with
# 3 radical
# 4 feminists
# 5 extremist
# 6 trans
# 7 activists
# 8 seeking
# 9 have
# 10 her
# 11 publishers
# 12 film
# 13 associates
# 14 ban
# 15 her
# 16 from
# 17 earning
# 18 a
# 19 living
# 20 she
# 21 understands
# 22 how
# 23 the
# 24 radical
# 25 left
# 26 seeks
# 27 merely
# 28 disagree
# 29 with
# 30 their
# 31 opponents
# 32 destroy
# 33 them
# 34 utterly
# 35 as
# 3629
# 0 None
# 1 None
# 2 with
# 3 the
# 4 arrival
# 5 of
# 6 virus
# 7 our
# 8 legal
# 9 rights
# 10 seem
# 11 have
# 12 been
# 13 deemed
# 14 irrelevant
# 15 completely
# 16 subordinated
# 17 to
# 18 the
# 19 arbitrary
# 20 whims
# 21 of
# 22 politicians
# 23 all
# 24 in
# 25 the
# 26 name
# 3630
# 0 None
# 1 None
# 2 with
# 3 the
# 4 olympic
# 5 games
# 6 postponed
# 7 until
# 8 cinemas
# 9 closed
# 10 across
# 11 the
# 12 country
# 13 whole
# 14 segments
# 15 of
# 16 the
# 17 advertising
# 18 market
# 3631
# 0 None
# 1 None
# 2 with
# 3 this
# 4 in
# 5 mind
# 6 the
# 7 trump
# 8 administration
# 9 reportedly
# 10 hopes
# 11 reduce
# 12 poverty
# 13 in
# 14 the
# 15 united
# 16 states
# 17 by
# 18 making
# 19 a
# 20 material
# 21 difference
# 22 in
# 23 struggling
# 24 families
# 25 finances
# 26 by
# 27 tinkering
# 28 with
# 29 the
# 30 threshold
# 31 for
# 32 what
# 33 counts
# 3632
# 0 None
# 1 None
# 2 with
# 3 justices
# 4 appointed
# 5 in
# 6 recent
# 7 years
# 8 by
# 9 president
# 10 donald
# 11 trump
# 12 the
# 13 supreme
# 14 court
# 15 has
# 16 appeared
# 17 primed
# 18 ready
# 19 deliver
# 20 a
# 21 huge
# 22 victory
# 23 for
# 24 conservatives
# 25 looking
# 26 roll
# 27 back
# 28 abortion
# 29 rights
# 30 in
# 31 the
# 3633
# 0 None
# 1 None
# 2 with
# 3 u.s.
# 4 president
# 5 donald
# 6 trump
# 7 announcement
# 8 on
# 9 thursday
# 10 of
# 11 tariffs
# 12 on
# 13 another
# 14 of
# 15 chinese
# 16 imports
# 17 nearly
# 18 all
# 19 goods
# 20 from
# 21 china
# 22 will
# 23 be
# 24 subject
# 25 to
# 26 import
# 27 taxes
# 28 trump
# 29 says
# 30 they
# 31 generate
# 32 billions
# 33 of
# 34 dollars
# 35 in
# 36 revenues
# 37 for
# 38 the
# 39 u.s.
# 40 treasury
# 3634
# 0 None
# 1 None
# 2 with
# 3 president
# 4 donald
# 5 trump
# 6 signaling
# 7 that
# 8 he
# 9 's
# 10 eager
# 11 for
# 12 the
# 13 country
# 14 relax
# 15 stringent
# 16 measures
# 17 meant
# 18 stem
# 19 the
# 20 tide
# 21 of
# 22 the
# 23 covid-19
# 24 pandemic
# 25 it
# 26 's
# 27 important
# 28 realize
# 29 how
# 30 dangerous
# 31 this
# 3635
# 0 None
# 1 None
# 2 within
# 3 weeks
# 4 of
# 5 floyd
# 6 passing
# 7 in
# 8 minneapolis
# 9 police
# 10 custody
# 11 militant
# 12 social
# 13 justice
# 14 warriors
# 15 racked
# 16 up
# 17 an
# 18 estimated
# 19 in
# 20 damage
# 21 causing
# 22 the
# 23 costliest
# 24 outbreak
# 25 of
# 26 political
# 27 upheaval
# 28 in
# 29 u.s.
# 30 history
# 31 devastating
# 32 minority
# 33 businesses
# 34 while
# 35 kicking
# 36 off
# 37 an
# 38 entire
# 39 summer
# 40 of
# 41 chaos
# 42 engulfing
# 43 the
# 44 nation
# 45 major
# 46 cities
# 47 eventually
# 48 spreading
# 49 to
# 3636
# 0 None
# 1 None
# 2 witness
# 3 for
# 4 instance
# 5 the
# 6 wacky
# 7 nonsense
# 8 new
# 9 york
# 10 mayor
# 11 current
# 12 trump
# 13 flunky
# 14 rudy
# 15 giuliani
# 16 addressed
# 17 to
# 18 salon
# 19 roger
# 20 sollenberger
# 21 during
# 22 a
# 23 text
# 24 interview
# 3637
# 0 None
# 1 None
# 2 women
# 3 in
# 4 power
# 5 must
# 6 pay
# 7 a
# 8 significant
# 9 tax
# 10 on
# 11 their
# 12 limited
# 13 time
# 14 sit
# 15 for
# 16 manicures
# 17 blowouts
# 18 brow
# 19 waxes
# 20 braids
# 21 rather
# 22 than
# 23 meeting
# 24 with
# 25 constituents
# 26 reviewing
# 27 legislation
# 28 conducting
# 29 investigations
# 30 chasing
# 31 a
# 32 story
# 33 traveling
# 34 to
# 35 their
# 36 districts
# 37 reviewing
# 38 their
# 39 notes
# 40 spending
# 41 time
# 42 with
# 3638
# 0 None
# 1 None
# 2 women
# 3 were
# 4 allowed
# 5 into
# 6 saudi
# 7 sports
# 8 stadiums
# 9 a
# 10 year
# 11 ago
# 12 for
# 13 the
# 14 first
# 15 time
# 16 watch
# 17 soccer
# 18 matches
# 19 although
# 20 they
# 21 were
# 22 segregated
# 23 in
# 24 the
# 25 stands
# 26 sticking
# 27 to
# 28 the
# 29 family
# 30 section
# 31 away
# 32 from
# 33 all
# 34 male
# 3639
# 0 None
# 1 None
# 2 women
# 3 rights
# 4 advocates
# 5 were
# 6 relieved
# 7 late
# 8 monday
# 9 when
# 10 senate
# 11 democrats
# 12 blocked
# 13 an
# 14 extreme
# 15 anti
# 16 -
# 17 choice
# 18 bill
# 19 from
# 20 advancing
# 21 to
# 22 a
# 23 floor
# 24 debate
# 25 were
# 26 soon
# 27 outraged
# 28 by
# 29 president
# 30 donald
# 31 trump
# 32 lies
# 33 about
# 34 abortion
# 35 care
# 36 as
# 37 well
# 38 as
# 39 the
# 40 corporate
# 41 media
# 42 for
# 43 enabling
# 44 his
# 45 blatantly
# 46 false
# 47 characterization
# 48 of
# 49 the
# 3640
# 0 None
# 1 None
# 2 wo
# 3 it
# 4 be
# 5 absurdly
# 6 difficult
# 7 enforce
# 8 new
# 9 gun
# 10 control
# 11 laws
# 12 move
# 13 toward
# 14 the
# 15 outright
# 16 confiscation
# 17 that
# 18 is
# 19 always
# 20 forever
# 21 the
# 22 left
# 23 ultimate
# 24 goal
# 25 after
# 26 a
# 27 year
# 28 of
# 29 record
# 30 breaking
# 3641
# 0 None
# 1 None
# 2 working
# 3 class
# 4 americans
# 5 like
# 6 those
# 7 who
# 8 make
# 9 up
# 10 the
# 11 majority
# 12 of
# 13 south
# 14 bend
# 15 residents
# 16 have
# 17 secured
# 18 the
# 19 largest
# 20 wage
# 21 hikes
# 22 in
# 23 the
# 24 nation
# 25 compared
# 26 to
# 27 all
# 28 other
# 29 economic
# 30 demographic
# 31 groups
# 32 a
# 33 direct
# 34 result
# 35 of
# 36 trump
# 37 tightening
# 38 the
# 3642
# 0 None
# 1 None
# 2 workplace
# 3 bias
# 4 against
# 5 gay
# 6 transgender
# 7 employees
# 8 has
# 9 remained
# 10 legal
# 11 in
# 12 much
# 13 of
# 14 the
# 15 country
# 16 with
# 17 u.s.
# 18 states
# 19 lacking
# 20 comprehensive
# 21 measures
# 22 against
# 3643
# 0 None
# 1 None
# 2 world
# 3 leaders
# 4 organisations
# 5 pledged
# 6 fund
# 7 a
# 8 possible
# 9 vaccine
# 10 treatments
# 11 many
# 12 hoping
# 13 explicitly
# 14 ensure
# 15 that
# 16 no
# 17 country
# 18 on
# 19 earth
# 20 would
# 21 be
# 22 left
# 23 out
# 24 the
# 25 united
# 26 states
# 3644
# 0 None
# 1 None
# 2 worth
# 3 noting
# 4 however
# 5 is
# 6 that
# 7 democrats
# 8 have
# 9 also
# 10 been
# 11 notably
# 12 faced
# 13 on
# 3645
# 0 None
# 1 None
# 2 writing
# 3 in
# 4 today
# 5 wall
# 6 street
# 7 journal
# 8 pence
# 9 denies
# 10 that
# 11 there
# 12 is
# 13 such
# 14 a
# 15 thing
# 16 as
# 17 a
# 18 second
# 19 wave
# 20 to
# 21 the
# 22 pandemic
# 23 he
# 24 does
# 25 mean
# 26 because
# 27 we
# 28 have
# 29 exited
# 30 the
# 3646
# 0 None
# 1 None
# 2 yale
# 3 psychiatrist
# 4 explains
# 5 why
# 6 the
# 7 coronavirus
# 8 pandemic
# 9 donald
# 10 trump
# 11 irrational
# 12 cult
# 13 is
# 14 a
# 3647
# 0 None
# 1 None
# 2 yep
# 3 after
# 4 openly
# 5 committing
# 6 adultery
# 7 against
# 8 the
# 9 republican
# 10 party
# 11 these
# 12 shameless
# 13 cheats
# 14 honestly
# 15 believed
# 16 the
# 17 democrat
# 18 party
# 19 would
# 20 make
# 21 them
# 22 equal
# 23 trusted
# 24 partners
# 25 in
# 26 the
# 3648
# 0 None
# 1 None
# 2 yes
# 3 trump
# 4 the
# 5 right
# 6 are
# 7 embracing
# 8 celebrating
# 9 death
# 10 it
# 11 is
# 12 ghoulish
# 13 it
# 14 is
# 15 also
# 16 more
# 17 illustration
# 18 that
# 19 the
# 20 age
# 21 of
# 22 trump
# 23 is
# 24 an
# 25 american
# 26 dystopia
# 27 where
# 28 what
# 29 was
# 30 previously
# 31 unimaginable
# 32 for
# 33 most
# 34 decent
# 35 people
# 36 has
# 3649
# 0 None
# 1 None
# 2 yes
# 3 he
# 4 might
# 5 be
# 6 a
# 7 demented
# 8 stalinist
# 9 eager
# 10 flood
# 11 america
# 12 with
# 13 illegal
# 14 aliens
# 15 take
# 16 away
# 17 our
# 18 guns
# 19 health
# 20 insurance
# 21 he
# 22 sure
# 23 gave
# 24 those
# 25 venal
# 26 never
# 27 trumpers
# 28 a
# 29 sweet
# 30 face
# 31 job
# 32 saturday
# 33 night
# 34 in
# 35 nevada
# 36 now
# 37 i
# 38 ca
# 39 tell
# 40 if
# 41 my
# 42 tears
# 43 come
# 44 from
# 3650
# 0 None
# 1 None
# 2 yes
# 3 the
# 4 rich
# 5 are
# 6 rich
# 7 want
# 8 stay
# 9 that
# 10 way
# 11 yet
# 12 at
# 13 the
# 14 same
# 15 time
# 16 fat
# 17 cats
# 18 now
# 19 lean
# 20 left
# 21 even
# 22 far
# 23 left
# 24 on
# 25 cultural
# 26 issues
# 27 they
# 28 want
# 29 you
# 30 do
# 31 as
# 32 you
# 3651
# 0 None
# 1 None
# 2 yes
# 3 there
# 4 may
# 5 still
# 6 be
# 7 time
# 8 for
# 9 the
# 10 union
# 11 membership
# 12 change
# 13 its
# 14 thinking
# 15 if
# 16 the
# 17 players
# 18 reject
# 19 the
# 20 proposal
# 21 at
# 22 least
# 23 marketing
# 24 expert
# 25 said
# 26 a
# 27 no
# 28 vote
# 29 now
# 30 could
# 31 mean
# 32 short-
# 33 long
# 3652
# 0 None
# 1 None
# 2 biden
# 3 finds
# 4 himself
# 5 in
# 6 an
# 7 increasingly
# 8 competitive
# 9 race
# 10 with
# 11 sanders
# 12 the
# 13 u.s.
# 14 senator
# 15 who
# 16 came
# 17 close
# 18 to
# 19 winning
# 20 the
# 21 nevada
# 22 caucus
# 23 finds
# 24 support
# 25 with
# 26 some
# 27 of
# 28 the
# 3653
# 0 None
# 1 None
# 2 bizarrely
# 3 the
# 4 entirety
# 5 of
# 6 the
# 7 establishment
# 8 from
# 9 prime
# 10 minister
# 11 boris
# 12 johnson
# 13 downwards
# 14 the
# 15 bodies
# 16 representing
# 17 every
# 18 cultural
# 19 institution
# 20 from
# 21 the
# 22 church
# 23 of
# 24 england
# 25 to
# 26 the
# 27 football
# 28 association
# 29 have
# 30 been
# 31 grovelling
# 32 fawning
# 33 kowtowing
# 34 to
# 35 blm
# 36 as
# 37 if
# 38 its
# 39 name
# 40 were
# 41 be
# 42 taken
# 43 at
# 3654
# 0 None
# 1 None
# 2 yet
# 3 every
# 4 nation
# 5 except
# 6 mongolia
# 7 greenland
# 8 recorded
# 9 dozens
# 10 to
# 11 thousands
# 12 of
# 13 deaths
# 14 no
# 15 matter
# 16 what
# 17 they
# 18 tried
# 19 even
# 20 socialist
# 21 systems
# 22 with
# 23 draconian
# 24 lockdowns
# 25 like
# 26 italy
# 27 deaths
# 28 per
# 29 spain
# 30 the
# 3655
# 0 None
# 1 None
# 2 it
# 3 far
# 4 better
# 5 applies
# 6 to
# 7 unelected
# 8 career
# 9 bureaucrats
# 10 use
# 11 of
# 12 their
# 13 power
# 14 prosecute
# 15 their
# 16 political
# 17 enemies
# 18 which
# 19 comprises
# 20 the
# 21 heart
# 22 of
# 23 the
# 24 resistance
# 25 to
# 26 republican
# 27 rule
# 28 that
# 29 will
# 30 endure
# 31 so
# 32 long
# 33 as
# 34 bureaucracy
# 35 has
# 36 enough
# 37 power
# 38 challenged
# 39 elected
# 40 branches
# 41 of
# 42 government
# 43 this
# 44 bureacracy
# 45 weaponization
# 46 was
# 47 also
# 48 a
# 49 hallmark
# 50 of
# 51 the
# 52 obama
# 53 presidency
# 54 with
# 55 ironies
# 56 of
# 57 ironies
# 58 perhaps
# 59 the
# 60 biggest
# 61 evidences
# 62 again
# 63 coming
# 64 from
# 65 the
# 66 department
# 67 of
# 68 justice
# 69 under
# 70 attorneys
# 71 general
# 72 eric
# 73 holder
# 3656
# 0 None
# 1 None
# 2 it
# 3 's
# 4 merely
# 5 the
# 6 tip
# 7 of
# 8 the
# 9 iceberg
# 10 of
# 11 war
# 12 criminals
# 13 lurking
# 14 working
# 15 on
# 3657
# 0 None
# 1 None
# 2 merril
# 3 hoge
# 4 a
# 5 former
# 6 running
# 7 back
# 8 for
# 9 the
# 10 nfl
# 11 pittsburgh
# 12 steelers
# 13 chicago
# 14 bears
# 15 later
# 16 turned
# 17 espn
# 18 analyst
# 19 has
# 20 been
# 21 of
# 22 the
# 23 most
# 24 outspoken
# 25 critics
# 26 against
# 27 the
# 28 alarm
# 29 surrounding
# 30 cte
# 31 studies
# 32 putting
# 33 much
# 34 of
# 35 the
# 36 research
# 37 down
# 38 to
# 39 science
# 40 fiction
# 41 misleading
# 42 science
# 43 far
# 44 from
# 45 a
# 3658
# 0 None
# 1 None
# 2 mlb
# 3 with
# 4 an
# 5 exhaustive
# 6 page
# 7 health
# 8 safety
# 9 operations
# 10 manual
# 11 will
# 12 attempt
# 13 become
# 14 the
# 15 first
# 16 major
# 17 sport
# 18 return
# 19 on
# 20 july
# 21 with
# 22 nationally
# 23 televised
# 24 games
# 25 the
# 26 rest
# 27 of
# 28 the
# 29 teams
# 30 scheduled
# 3659
# 0 None
# 1 None
# 2 yet
# 3 no
# 4 one
# 5 denies
# 6 that
# 7 older
# 8 nuclear
# 9 plants
# 10 with
# 11 an
# 12 aged
# 13 infrastructure
# 14 often
# 15 surpassing
# 16 expected
# 17 lifetimes
# 18 are
# 19 extremely
# 20 inefficient
# 21 run
# 22 a
# 23 higher
# 24 risk
# 3660
# 0 None
# 1 None
# 2 omar
# 3 is
# 4 unashamed
# 5 about
# 6 being
# 7 linked
# 8 to
# 9 this
# 10 kind
# 11 of
# 12 hate
# 13 even
# 14 claiming
# 15 that
# 16 while
# 17 she
# 18 opposes
# 19 economic
# 20 sanctions
# 21 on
# 22 the
# 23 tyrannical
# 24 terrorist
# 25 supporting
# 26 iranian
# 27 regime
# 28 she
# 29 thinks
# 30 boycotts
# 31 of
# 32 israel
# 3661
# 0 None
# 1 None
# 2 yet
# 3 the
# 4 drumbeat
# 5 for
# 6 censorship
# 7 goes
# 8 on
# 9 as
# 10 the
# 11 politicians
# 12 whose
# 13 ideas
# 14 find
# 15 favor
# 16 with
# 17 the
# 18 mainstream
# 19 media
# 20 want
# 21 make
# 22 sure
# 23 theirs
# 24 are
# 25 the
# 26 only
# 27 ideas
# 28 you
# 29 ever
# 30 get
# 31 hear
# 32 today
# 33 it
# 34 will
# 35 be
# 36 about
# 37 money
# 38 only
# 39 because
# 40 money
# 41 is
# 42 the
# 43 means
# 3662
# 0 None
# 1 None
# 2 yet
# 3 the
# 4 gender
# 5 ideology
# 6 is
# 7 rapidly
# 8 gaining
# 9 power
# 10 aided
# 11 by
# 12 huge
# 13 donations
# 14 from
# 15 wealthy
# 16 individuals
# 3663
# 0 None
# 1 None
# 2 the
# 3 overwhelming
# 4 narrative
# 5 across
# 6 social
# 7 media
# 8 today
# 9 depressingly
# 10 across
# 11 much
# 12 of
# 13 the
# 14 mainstream
# 15 media
# 16 is
# 17 that
# 18 these
# 19 ugly
# 20 sinister
# 21 shows
# 22 of
# 23 force
# 24 by
# 25 the
# 26 triumphant
# 27 radical
# 28 left
# 29 are
# 30 something
# 31 almost
# 32 charming
# 33 admirable
# 34 rather
# 35 than
# 36 something
# 37 we
# 38 should
# 3664
# 0 None
# 1 None
# 2 yet
# 3 when
# 4 researchers
# 5 in
# 6 the
# 7 u.s.
# 8 have
# 9 been
# 10 so
# 11 corrupt
# 12 they
# 13 have
# 14 gone
# 15 to
# 16 jail
# 17 mainstream
# 18 scientists
# 19 still
# 20 accept
# 3665
# 0 None
# 1 None
# 2 the
# 3 trump
# 4 family
# 5 his
# 6 allies
# 7 are
# 8 evidently
# 9 using
# 10 this
# 11 national
# 12 emergency
# 3666
# 0 None
# 1 None
# 2 you
# 3 may
# 4 remember
# 5 that
# 6 hours
# 7 after
# 8 america
# 9 was
# 10 attacked
# 11 by
# 12 al
# 13 qaeda
# 14 on
# 15 thousands
# 16 of
# 17 muslims
# 18 regular
# 19 folks
# 20 celebrated
# 21 in
# 3667
# 0 None
# 1 None
# 2 you
# 3 may
# 4 remember
# 5 that
# 6 nbc
# 7 journalist
# 8 nancy
# 9 snyderman
# 10 broke
# 11 her
# 12 ebola
# 13 quarantine
# 14 to
# 15 the
# 16 outrage
# 17 of
# 3668
# 0 None
# 1 None
# 2 you
# 3 need
# 4 keep
# 5 a
# 6 close
# 7 eye
# 8 on
# 9 what
# 10 your
# 11 school
# 12 is
# 13 teaching
# 14 because
# 15 the
# 16 left
# 17 only
# 18 wants
# 19 teach
# 20 your
# 21 kids
# 22 engage
# 23 in
# 24 loveless
# 25 sex
# 26 the
# 27 sanctity
# 28 of
# 29 abortion
# 30 why
# 31 america
# 32 is
# 33 evil
# 34 that
# 35 men
# 36 are
# 37 women
# 38 women
# 39 are
# 40 men
# 41 that
# 42 global
# 43 warming
# 44 is
# 45 real
# 3669
# 0 None
# 1 None
# 2 you
# 3 ’ve
# 4 heard
# 5 of
# 6 jim
# 7 crow
# 8 southern
# 9 segregation
# 10 that
# 11 was
# 3670
# 0 None
# 1 None
# 2 young
# 3 female
# 4 athletes
# 5 dreams
# 6 accomplishments
# 7 have
# 8 been
# 9 dashed
# 10 across
# 11 the
# 12 country
# 13 when
# 14 competing
# 15 against
# 16 biological
# 17 males
# 18 who
# 19 identify
# 3671
# 0 None
# 1 None
# 2 young
# 3 white
# 4 men
# 5 reacting
# 6 to
# 7 social
# 8 educational
# 9 constructs
# 10 that
# 11 paint
# 12 them
# 13 as
# 14 the
# 15 embodiment
# 16 of
# 17 historical
# 18 evil
# 19 are
# 20 fertile
# 21 ground
# 22 for
# 3672
# 0 None
# 1 None
# 2 young
# 3 women
# 4 taking
# 5 part
# 6 in
# 7 high
# 8 school
# 9 college
# 10 athletics
# 11 across
# 12 the
# 13 country
# 14 have
# 15 had
# 16 their
# 17 dreams
# 18 of
# 19 winning
# 20 dashed
# 21 by
# 22 the
# 23 movement
# 24 allow
# 25 biological
# 26 male
# 27 who
# 28 identify
# 29 as
# 30 female
# 31 compete
# 3673
# 0 None
# 1 None
# 2 youtube
# 3 is
# 4 making
# 5 clear
# 6 there
# 7 will
# 8 be
# 9 no
# 10 birtherism
# 11 on
# 12 its
# 13 platform
# 14 during
# 15 this
# 16 year
# 17 u.s.
# 18 presidential
# 19 election
# 20 a
# 21 belated
# 22 response
# 23 to
# 24 a
# 25 type
# 26 of
# 27 conspiracy
# 28 theory
# 29 more
# 30 prevalent
# 31 in

# %%
# token in context -1 (c2)
for index, row in dt.iterrows():
    print(index)
    for i, token in enumerate(row.spacy_lg_dict):
        print(i, token['text_low_C2'])
        if token['text_low_C2'] == None:
            token['assertive_verbs_C2'] = 0
            token['factive_verbs_C2'] = 0
            token['report_verbs_C2'] = 0
            token['hedges_C2'] = 0
            token['boosters_C2'] = 0
            token['implicative_verbs_C2'] = 0
        else:
            if token['window_text'] != None and token['window_lemma'] != None:
                window_text = token['window_text']
                window_lemma = token['window_lemma']

              # 0 1 2 <3> 4 5 6 7 8
              # token['text_low_C2']
              # token['lemma_low_C2']
                # words
                c1, c2, c_m, c3, c4 = None, None, None, None, None
                if window_text[1] != None and window_text[2] != None:
                    c1 = window_text[1] + ' ' + window_text[2] + ' ' + token['text_low_C2']
                if window_text[2] != None:
                    c2 = window_text[2] + ' ' + token['text_low_C2']
                if window_text[2] != None and window_text[4] != None:
                    c_m = window_text[2] + ' ' + token['text_low_C2'] + ' ' + window_text[4]
                if window_text[4] != None:
                    c3 = token['text_low_C2'] + ' ' + window_text[4]
                if window_text[4] != None and window_text[5] != None:
                    c4 = token['text_low_C2'] + ' ' + window_text[4] + ' ' + window_text[5]

                # lemmas
                c1l, c2l, c_ml, c3l, c4l = None, None, None, None, None
                if window_lemma[1] != None and window_lemma[2] != None:
                    c1l = window_lemma[1] + ' ' + window_lemma[2] + ' ' + token['lemma_low_C2']
                if window_lemma[2] != None:
                    c2l = window_lemma[2] + ' ' + token['lemma_low_C2']
                if window_lemma[2] != None and window_lemma[4] != None:
                    c_ml = window_lemma[2] + ' ' + token['lemma_low_C2'] + ' ' + window_lemma[4]
                if window_lemma[4] != None:
                    c3l = token['lemma_low_C2'] + ' ' + window_lemma[4]
                if window_lemma[4] != None and window_text[5] != None:
                    c4l = token['lemma_low_C2'] + ' ' + window_lemma[4] + ' ' + window_lemma[5]

                # assertive verbs
                if token['text_low_C2'] in assertive_verbs or c1 in assertive_verbs or c2 in assertive_verbs or \
                c_m in assertive_verbs or c3 in assertive_verbs or c4 in assertive_verbs or \
                token['lemma_low_C2'] in assertive_verbs or c1l in assertive_verbs or c2l in assertive_verbs or \
                c_ml in assertive_verbs or c3l in assertive_verbs or c4l in assertive_verbs:
                    token['assertive_verbs_C2'] = 1
                else:
                    token['assertive_verbs_C2'] = 0   

                # factive verbs
                if token['text_low_C2'] in factive_verbs or c1 in factive_verbs or c2 in factive_verbs or \
                c_m in factive_verbs or c3 in factive_verbs or c4 in factive_verbs or \
                token['lemma_low_C2'] in factive_verbs or c1l in factive_verbs or c2l in factive_verbs or \
                c_ml in factive_verbs or c3l in factive_verbs or c4l in factive_verbs:
                    token['factive_verbs_C2'] = 1
                else:
                    token['factive_verbs_C2'] = 0   

                # report verbs
                if token['text_low_C2'] in report_verbs or c1 in report_verbs or c2 in report_verbs or \
                c_m in report_verbs or c3 in report_verbs or c4 in report_verbs or \
                token['lemma_low_C2'] in report_verbs or c1l in report_verbs or c2l in report_verbs or \
                c_ml in report_verbs or c3l in report_verbs or c4l in report_verbs:
                    token['report_verbs_C2'] = 1
                else:
                    token['report_verbs_C2'] = 0

                # hedges
                if token['text_low_C2'] in hedges or c1 in hedges or c2 in hedges or \
                c_m in hedges or c3 in hedges or c4 in hedges or \
                token['lemma_low_C2'] in hedges or c1l in hedges or c2l in hedges or \
                c_ml in hedges or c3l in hedges or c4l in hedges:
                    token['hedges_C2'] = 1
                else:
                    token['hedges_C2'] = 0

                # boosters
                if token['text_low_C2'] in boosters or c1 in boosters or c2 in boosters or \
                c_m in boosters or c3 in boosters or c4 in boosters or \
                token['lemma_low_C2'] in boosters or c1l in boosters or c2l in boosters or \
                c_ml in boosters or c3l in boosters or c4l in boosters:
                    token['boosters_C2'] = 1
                else:
                    token['boosters_C2'] = 0
                    
                # implicative verbs
                if token['text_low_C2'] in implicative_verbs or c1 in implicative_verbs or c2 in implicative_verbs or \
                c_m in implicative_verbs or c3 in implicative_verbs or c4 in implicative_verbs or \
                token['lemma_low_C2'] in implicative_verbs or c1l in implicative_verbs or c2l in implicative_verbs or \
                c_ml in implicative_verbs or c3l in implicative_verbs or c4l in implicative_verbs:
                    token['implicative_verbs_C2'] = 1
                else:
                    token['implicative_verbs_C2'] = 0

            else:
                # assertive verbs
                if token['text_low_C2'] in assertive_verbs or token['lemma_low_C2'] in assertive_verbs:
                    token['assertive_verbs_C2'] = 1
                else:
                    token['assertive_verbs_C2'] = 0 

                # factive verbs
                if token['text_low_C2'] in factive_verbs or token['lemma_low_C2'] in factive_verbs:
                    token['factive_verbs_C2'] = 1
                else:
                    token['factive_verbs_C2'] = 0   

                # report verbs
                if token['text_low_C2'] in report_verbs or token['lemma_low_C2'] in report_verbs:
                    token['report_verbs_C2'] = 1
                else:
                    token['report_verbs_C2'] = 0

                # hedges
                if token['text_low_C2'] in hedges or token['lemma_low_C2'] in hedges:
                    token['hedges_C2'] = 1
                else:
                    token['hedges_C2'] = 0

                # boosters
                if token['text_low_C2'] in boosters or token['lemma_low_C2'] in boosters:
                    token['boosters_C2'] = 1
                else:
                    token['boosters_C2'] = 0
                    
                # implicative verbs
                if token['text_low_C2'] in implicative_verbs or token['lemma_low_C2'] in implicative_verbs:
                    token['implicative_verbs_C2'] = 1
                else:
                    token['implicative_verbs_C2'] = 0
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 10 vaccines
# 11 cause
# 12 autism
# 13 as
# 14 he
# 15 did
# 16 during
# 17 the
# 18 presidential
# 19 debates
# 20 many
# 21 parents
# 22 may
# 23 choose
# 24 vaccinate
# 25 putting
# 26 children
# 27 at
# 28 unnecessary
# 3523
# 0 None
# 1 when
# 2 a
# 3 newly
# 4 organized
# 5 vaccine
# 6 research
# 7 group
# 8 at
# 9 the
# 10 u.s.
# 11 national
# 12 institutes
# 13 of
# 14 health
# 15 nih
# 16 met
# 17 for
# 18 the
# 19 first
# 20 time
# 21 this
# 22 week
# 23 its
# 24 members
# 25 had
# 26 expected
# 27 be
# 28 able
# 29 ease
# 30 into
# 31 their
# 32 work
# 33 their
# 34 mandate
# 35 is
# 36 conduct
# 37 human
# 38 trials
# 39 for
# 40 emerging
# 41 health
# 42 threats
# 43 their
# 44 first
# 45 assignment
# 46 came
# 47 at
# 48 shocking
# 3524
# 0 None
# 1 when
# 2 a
# 3 supporter
# 4 told
# 5 warren
# 6 public
# 7 schools
# 8 need
# 9 teach
# 10 more
# 11 about
# 12 lgbtq
# 13 history
# 14 sex
# 15 education
# 16 the
# 17 massachusetts
# 18 senator
# 19 replied
# 20 her
# 21 education
# 22 secretary
# 23 would
# 24 have
# 25 be
# 26 interviewed
# 27 by
# 28 a
# 29 transgender
# 3525
# 0 None
# 1 when
# 2 carrying
# 3 a
# 4 firearm
# 5 you
# 6 have
# 7 the
# 8 ultimate
# 9 power
# 10 of
# 11 force
# 12 in
# 13 your
# 3526
# 0 None
# 1 when
# 2 democrats
# 3 are
# 4 releasing
# 5 violent
# 6 criminals
# 7 encouraging
# 8 illegal
# 9 immigration
# 10 passing
# 11 laws
# 12 disarm
# 13 you
# 14 while
# 15 turning
# 16 the
# 17 police
# 18 into
# 19 eunuchs
# 20 it
# 21 ’s
# 3527
# 0 None
# 1 when
# 2 did
# 3 it
# 4 become
# 5 racist
# 6 like
# 7 the
# 8 national
# 9 anthem
# 10 mount
# 3528
# 0 None
# 1 when
# 2 did
# 3 vaccines
# 4 become
# 5 politicized
# 6 amid
# 7 a
# 8 measles
# 9 outbreak
# 10 suddenly
# 11 republicans
# 12 support
# 13 anti
# 14 -
# 3529
# 0 None
# 1 when
# 2 far
# 3 right
# 4 white
# 5 evangelicals
# 6 white
# 7 nationalists
# 8 coronavirus
# 9 truthers
# 10 rail
# 11 against
# 12 social
# 13 distancing
# 14 encourage
# 15 large
# 16 gatherings
# 17 they
# 18 are
# 19 encouraging
# 20 suicidal
# 21 behavior
# 22 there
# 23 have
# 24 been
# 25 many
# 3530
# 0 None
# 1 when
# 2 greed
# 3 power
# 4 are
# 5 exercised
# 6 by
# 7 giant
# 8 multinational
# 9 corporations
# 10 that
# 11 escape
# 12 the
# 13 discipline
# 14 of
# 15 the
# 16 nation
# 17 state
# 18 the
# 19 potential
# 20 for
# 21 evil
# 22 becomes
# 23 infinite
# 24 in
# 3531
# 0 None
# 1 when
# 2 he
# 3 finally
# 4 spoke
# 5 in
# 6 the
# 7 rose
# 8 garden
# 9 on
# 10 monday
# 11 trump
# 12 threatened
# 13 deploy
# 14 the
# 15 military
# 16 against
# 17 american
# 18 citizens
# 19 if
# 20 the
# 21 governors
# 22 did
# 23 take
# 24 his
# 25 advice
# 26 for
# 27 a
# 28 more
# 29 forceful
# 30 crackdown
# 31 this
# 32 threat
# 33 did
# 34 appear
# 35 cow
# 36 anyone
# 37 only
# 38 increased
# 39 the
# 3532
# 0 None
# 1 when
# 2 i
# 3 opened
# 4 britain
# 5 bestselling
# 6 tabloid
# 7 conservative
# 8 sunday
# 9 newspaper
# 10 i
# 11 was
# 12 greeted
# 13 by
# 14 a
# 15 double
# 16 page
# 17 spread
# 18 showing
# 19 a
# 20 vast
# 21 mob
# 22 of
# 23 black
# 24 lives
# 25 matter
# 26 activists
# 27 marching
# 28 on
# 29 downing
# 30 street
# 31 in
# 3533
# 0 None
# 1 when
# 2 it
# 3 comes
# 4 to
# 5 the
# 6 green
# 7 new
# 8 deal
# 9 blueprint
# 10 address
# 11 the
# 12 climate
# 13 crisis
# 14 republicans
# 15 generally
# 16 like
# 17 pretend
# 18 it
# 19 calls
# 20 for
# 21 the
# 22 elimination
# 23 of
# 3534
# 0 None
# 1 when
# 2 mexico
# 3 leader
# 4 enters
# 5 the
# 6 white
# 7 house
# 8 meet
# 9 president
# 10 donald
# 11 trump
# 12 on
# 13 wednesday
# 14 he
# 15 will
# 16 do
# 17 so
# 18 only
# 19 as
# 20 a
# 21 hostage
# 22 to
# 23 the
# 24 whims
# 25 of
# 26 his
# 27 u.s.
# 28 counterpart
# 29 also
# 30 as
# 31 partner
# 32 in
# 33 an
# 34 unlikely
# 35 alliance
# 36 that
# 37 has
# 38 benefited
# 39 both
# 3535
# 0 None
# 1 when
# 2 parents
# 3 borrow
# 4 the
# 5 debt
# 6 can
# 7 weigh
# 8 down
# 9 families
# 10 for
# 11 generations
# 12 the
# 13 burden
# 14 falls
# 15 particularly
# 16 hard
# 17 on
# 18 low
# 19 income
# 20 black
# 3536
# 0 None
# 1 when
# 2 president
# 3 trump
# 4 rolled
# 5 out
# 6 his
# 7 recent
# 8 budget
# 9 proposal
# 10 it
# 11 made
# 12 some
# 13 cuts
# 14 that
# 15 were
# 16 always
# 17 going
# 18 cause
# 19 controversy
# 20 for
# 21 thing
# 22 his
# 23 plan
# 24 would
# 25 slash
# 26 subsidized
# 27 student
# 28 loan
# 29 repayment
# 30 plans
# 31 let
# 32 the
# 33 government
# 34 crack
# 35 down
# 36 on
# 37 missed
# 3537
# 0 None
# 1 when
# 2 prioritizing
# 3 healthcare
# 4 workers
# 5 the
# 6 panel
# 7 noted
# 8 that
# 9 vaccines
# 10 should
# 11 go
# 12 first
# 13 to
# 14 people
# 15 who
# 16 have
# 17 the
# 18 most
# 19 contact
# 20 with
# 3538
# 0 None
# 1 when
# 2 republicans
# 3 warned
# 4 democrats
# 5 that
# 6 impeachment
# 7 was
# 8 a
# 9 waste
# 10 of
# 11 time
# 12 a
# 13 divisive
# 14 partisan
# 15 exercise
# 16 a
# 17 distraction
# 18 from
# 19 the
# 20 real
# 21 issues
# 22 facing
# 23 the
# 24 country
# 25 a
# 26 lesson
# 27 republicans
# 28 learned
# 29 the
# 30 hard
# 31 way
# 32 in
# 33 bill
# 34 clinton
# 35 impeachment
# 36 years
# 37 before
# 38 democrats
# 39 ignored
# 3539
# 0 None
# 1 when
# 2 the
# 3 left
# 4 is
# 5 emboldened
# 6 cities
# 7 burn
# 8 statues
# 9 topple
# 10 careers
# 11 people
# 12 are
# 13 disappeared
# 14 good
# 15 men
# 16 are
# 17 murdered
# 18 civil
# 19 liberties
# 20 are
# 21 trampled
# 22 the
# 23 dual
# 24 horrors
# 25 of
# 26 blacklisting
# 27 censorship
# 28 reign
# 3540
# 0 None
# 1 when
# 2 the
# 3 men
# 4 basketball
# 5 final
# 6 four
# 7 tips
# 8 off
# 9 saturday
# 10 in
# 11 minneapolis
# 12 the
# 13 ncaa
# 14 biggest
# 15 most
# 16 lucrative
# 17 event
# 18 will
# 19 proceed
# 20 as
# 21 it
# 22 normally
# 23 does
# 24 the
# 25 athletes
# 26 on
# 27 the
# 28 floor
# 29 for
# 30 virginia
# 31 auburn
# 32 michigan
# 33 state
# 34 texas
# 35 tech
# 36 will
# 37 play
# 38 games
# 39 that
# 40 generate
# 41 hundreds
# 42 of
# 43 millions
# 44 of
# 45 dollars
# 46 in
# 47 total
# 48 revenue
# 49 for
# 50 their
# 51 schools
# 52 the
# 53 ncaa
# 54 broadcast
# 55 companies
# 56 the
# 57 coaches
# 58 athletic
# 59 directors
# 60 tv
# 61 executives
# 62 ncaa
# 63 suits
# 64 will
# 65 share
# 66 in
# 67 the
# 68 riches
# 69 athletes
# 70 themselves
# 71 still
# 72 wo
# 73 receive
# 74 their
# 75 fair
# 76 share
# 77 thanks
# 78 to
# 79 a
# 80 recent
# 81 federal
# 82 court
# 83 decision
# 84 that
# 85 wo
# 86 change
# 87 in
# 88 the
# 89 immediate
# 3541
# 0 None
# 1 when
# 2 the
# 3 muslim
# 4 ban
# 5 was
# 6 first
# 7 enacted
# 8 it
# 9 triggered
# 10 chaos
# 11 at
# 12 airports
# 13 prompted
# 14 widespread
# 15 protest
# 16 legal
# 17 challenges
# 18 it
# 19 continues
# 20 impose
# 21 devastating
# 22 costs
# 23 on
# 24 families
# 25 people
# 26 who
# 27 wish
# 28 come
# 29 to
# 30 the
# 3542
# 0 None
# 1 when
# 2 the
# 3 nation
# 4 highest
# 5 civilian
# 6 honor
# 7 went
# 8 to
# 9 a
# 10 right
# 11 wing
# 12 media
# 13 personality
# 14 it
# 15 served
# 16 as
# 17 an
# 18 oddly
# 19 appropriate
# 20 capstone
# 21 to
# 22 trump
# 23 broader
# 3543
# 0 None
# 1 when
# 2 trump
# 3 entered
# 4 the
# 5 white
# 6 house
# 7 in
# 8 lopez
# 9 obrador
# 10 likened
# 11 the
# 12 american
# 13 to
# 14 adolf
# 15 hitler
# 16 for
# 17 his
# 18 attitude
# 19 toward
# 3544
# 0 None
# 1 when
# 2 sadists
# 3 in
# 4 uniform
# 5 shoved
# 6 an
# 7 elderly
# 8 man
# 9 to
# 10 the
# 11 ground
# 12 for
# 13 the
# 14 crime
# 15 of
# 16 approaching
# 17 them
# 18 causing
# 19 him
# 20 a
# 21 critical
# 22 head
# 23 injury
# 24 their
# 25 fellow
# 26 cops
# 27 made
# 28 no
# 29 attempt
# 30 help
# 31 the
# 3545
# 0 None
# 1 when
# 2 u.s.
# 3 schools
# 4 begin
# 5 the
# 6 next
# 7 academic
# 8 year
# 9 with
# 10 the
# 11 country
# 12 still
# 13 fighting
# 14 the
# 15 coronavirus
# 16 pandemic
# 17 students
# 18 should
# 19 spend
# 20 half
# 21 their
# 22 time
# 23 in
# 24 classrooms
# 25 half
# 26 doing
# 27 online
# 28 activities
# 29 that
# 30 pinpoint
# 31 their
# 32 individual
# 33 learning
# 34 style
# 35 such
# 36 as
# 37 videos
# 3546
# 0 None
# 1 whether
# 2 it
# 3 is
# 4 due
# 5 to
# 6 gaffes
# 7 his
# 8 inability
# 9 complete
# 10 some
# 11 sentences
# 12 lack
# 13 of
# 14 knowledge
# 15 on
# 16 a
# 17 subject
# 18 biden
# 19 has
# 20 proven
# 21 that
# 22 interviews
# 23 are
# 24 for
# 25 him
# 26 the
# 27 media
# 28 has
# 29 covered
# 3547
# 0 None
# 1 whether
# 2 you
# 3 find
# 4 trump
# 5 buffoonery
# 6 utterly
# 7 disgraceful
# 8 a
# 9 sign
# 10 of
# 11 authenticity
# 12 may
# 13 mark
# 14 our
# 15 central
# 16 political
# 17 divide
# 3548
# 0 None
# 1 which
# 2 is
# 3 why
# 4 republicans
# 5 like
# 6 mcconnell
# 7 complaining
# 8 about
# 9 federal
# 10 entitlements
# 11 is
# 12 so
# 3549
# 0 None
# 1 while
# 2 a
# 3 number
# 4 of
# 5 transgender
# 6 advocates
# 7 lgbtq
# 8 health
# 9 experts
# 10 applauded
# 11 p&g
# 12 decision
# 13 redesign
# 14 the
# 15 always
# 16 packaging
# 17 by
# 18 removing
# 19 the
# 20 female
# 21 signs
# 22 the
# 23 company
# 24 announcement
# 25 sparked
# 26 criticism
# 27 online
# 28 including
# 29 a
# 30 bounty
# 31 of
# 32 transphobic
# 3550
# 0 None
# 1 while
# 2 americans
# 3 still
# 4 cling
# 5 to
# 6 sexist
# 7 gender
# 8 roles
# 9 at
# 10 home
# 11 overwhelming
# 12 majorities
# 13 believe
# 14 that
# 15 sex
# 16 discrimination
# 17 in
# 18 public
# 19 spaces
# 20 should
# 21 be
# 3551
# 0 None
# 1 while
# 2 barr
# 3 republican
# 4 president
# 5 donald
# 6 trump
# 7 have
# 8 focused
# 9 blame
# 10 on
# 11 antifa
# 12 a
# 13 loosely
# 14 organized
# 15 anti
# 16 -
# 17 fascist
# 18 movement
# 19 federal
# 20 prosecutors
# 21 in
# 22 las
# 23 vegas
# 24 on
# 25 wednesday
# 26 charged
# 27 members
# 28 of
# 29 the
# 30 far
# 31 right
# 32 boogaloo
# 33 movement
# 34 with
# 35 planning
# 36 cause
# 37 violence
# 38 destruction
# 39 during
# 3552
# 0 None
# 1 while
# 2 brazil
# 3 has
# 4 taken
# 5 the
# 6 lead
# 7 in
# 8 a
# 9 direct
# 10 attack
# 11 on
# 12 the
# 13 amazon
# 14 with
# 15 bolsonaro
# 16 adding
# 17 a
# 18 racial
# 19 element
# 20 to
# 21 his
# 22 attack
# 23 on
# 24 indigenous
# 25 people
# 26 the
# 27 pressure
# 28 open
# 29 the
# 30 amazonian
# 31 forests
# 32 to
# 33 agriculture
# 34 logging
# 35 mining
# 36 is
# 37 just
# 38 limited
# 39 to
# 3553
# 0 None
# 1 while
# 2 conservatives
# 3 may
# 4 find
# 5 comfort
# 6 in
# 7 the
# 8 old
# 9 saw
# 10 that
# 11 those
# 12 who
# 13 are
# 14 liberal
# 15 at
# 16 have
# 17 no
# 18 heart
# 19 those
# 20 who
# 21 are
# 22 conservative
# 23 at
# 24 have
# 25 no
# 26 brain
# 27 the
# 28 truth
# 29 as
# 30 levin
# 31 knows
# 32 is
# 33 that
# 34 those
# 35 who
# 36 are
# 37 statists
# 38 at
# 39 usually
# 40 end
# 41 up
# 42 statists
# 43 at
# 44 he
# 45 ’s
# 46 content
# 47 allow
# 48 time
# 49 take
# 50 its
# 51 uncertain
# 52 political
# 3554
# 0 None
# 1 while
# 2 corporate
# 3 media
# 4 hypocritical
# 5 politicians
# 6 others
# 7 labeled
# 8 anyone
# 9 in
# 10 favor
# 11 of
# 12 reopening
# 13 the
# 14 economy
# 15 getting
# 16 kids
# 17 back
# 18 in
# 19 school
# 20 even
# 21 gathering
# 22 for
# 23 holidays
# 24 a
# 25 grandma
# 26 killer
# 27 expert
# 28 in
# 29 ethics
# 30 health
# 31 policy
# 32 in
# 33 the
# 34 new
# 35 york
# 36 times
# 37 says
# 38 that
# 39 vaccinating
# 40 elderly
# 41 people
# 42 first
# 43 is
# 3555
# 0 None
# 1 while
# 2 democrat
# 3 presidential
# 4 hopefuls
# 5 aim
# 6 weaponize
# 7 the
# 8 tax
# 9 cuts
# 10 elaine
# 11 parker
# 12 chief
# 13 communications
# 14 officer
# 15 of
# 16 job
# 17 creators
# 18 network
# 19 jcn
# 20 told
# 21 breitbart
# 22 news
# 23 in
# 24 an
# 25 exclusive
# 26 interview
# 27 in
# 28 january
# 29 that
# 30 it
# 31 is
# 32 precisely
# 33 what
# 34 will
# 35 assist
# 36 trump
# 37 in
# 38 making
# 39 his
# 40 case
# 41 to
# 42 the
# 43 american
# 3556
# 0 None
# 1 while
# 2 democrats
# 3 were
# 4 busy
# 5 diverting
# 6 the
# 7 attention
# 8 energy
# 9 of
# 10 the
# 11 entire
# 12 country
# 13 into
# 14 a
# 15 pointless
# 16 trial
# 17 that
# 18 could
# 19 possibly
# 20 have
# 21 ended
# 22 in
# 23 anything
# 24 other
# 25 than
# 26 president
# 27 donald
# 28 trump
# 3557
# 0 None
# 1 while
# 2 democrats
# 3 were
# 4 diverting
# 5 the
# 6 attention
# 7 energy
# 8 of
# 9 the
# 10 entire
# 11 country
# 12 into
# 13 a
# 14 pointless
# 15 trial
# 16 that
# 17 could
# 18 possibly
# 19 have
# 20 ended
# 21 in
# 22 anything
# 23 other
# 24 than
# 25 president
# 26 donald
# 27 trump
# 3558
# 0 None
# 1 while
# 2 democrats
# 3 were
# 4 persistent
# 5 in
# 6 their
# 7 questioning
# 8 the
# 9 hearing
# 10 retained
# 11 a
# 12 respectful
# 13 tone
# 14 barrett
# 15 remained
# 16 even
# 17 tempered
# 18 while
# 19 nimbly
# 20 sidestepping
# 21 questions
# 22 on
# 23 her
# 24 views
# 25 on
# 26 abortion
# 27 lgbt
# 28 rights
# 29 gun
# 30 control
# 31 voting
# 3559
# 0 None
# 1 while
# 2 each
# 3 sport
# 4 has
# 5 its
# 6 own
# 7 rules
# 8 with
# 9 regards
# 10 to
# 11 religious
# 12 headwear
# 13 muslim
# 14 women
# 15 who
# 16 compete
# 17 while
# 18 wearing
# 19 a
# 20 hijab
# 21 have
# 22 faced
# 23 a
# 24 litany
# 25 of
# 3560
# 0 None
# 1 while
# 2 emphasizing
# 3 he
# 4 ’s
# 5 singling
# 6 out
# 7 party
# 8 cohen
# 9 warned
# 10 about
# 11 the
# 12 danger
# 13 of
# 14 normalizing
# 15 white
# 16 supremacist
# 3561
# 0 None
# 1 while
# 2 falling
# 3 short
# 4 of
# 5 calling
# 6 half
# 7 the
# 8 nation
# 9 deplorable
# 10 as
# 11 former
# 12 secretary
# 13 of
# 14 state
# 15 hillary
# 16 clinton
# 17 did
# 18 in
# 19 the
# 20 comments
# 21 echo
# 22 a
# 23 deep
# 24 disdain
# 25 for
# 26 a
# 27 large
# 28 population
# 29 of
# 30 the
# 31 country
# 32 increasingly
# 33 perpetuated
# 34 by
# 35 left
# 36 wing
# 37 elites
# 38 in
# 39 the
# 40 wake
# 41 of
# 42 the
# 43 george
# 44 floyd
# 45 protests
# 46 characterizing
# 47 the
# 48 u.s.
# 49 as
# 50 irredeemably
# 3562
# 0 None
# 1 while
# 2 health
# 3 experts
# 4 say
# 5 a
# 6 vaccine
# 7 prevent
# 8 infection
# 9 is
# 10 needed
# 11 return
# 12 life
# 13 to
# 14 normal
# 15 the
# 16 survey
# 17 points
# 18 to
# 19 a
# 20 potential
# 21 trust
# 22 issue
# 23 for
# 24 the
# 25 trump
# 26 administration
# 27 already
# 28 under
# 29 fire
# 30 for
# 31 its
# 32 often
# 33 contradictory
# 34 safety
# 35 guidance
# 36 during
# 37 the
# 3563
# 0 None
# 1 while
# 2 his
# 3 supporters
# 4 have
# 5 included
# 6 many
# 7 strains
# 8 of
# 9 nationalism
# 10 populism
# 11 he
# 12 did
# 13 run
# 14 as
# 15 a
# 16 republican
# 17 this
# 18 will
# 19 hopefully
# 20 work
# 21 in
# 22 his
# 23 favor
# 24 many
# 25 americans
# 26 are
# 27 hopeful
# 28 excited
# 29 looking
# 30 forward
# 31 to
# 32 a
# 33 trump
# 34 presidency
# 35 here
# 36 are
# 37 some
# 38 of
# 39 the
# 40 reasons
# 3564
# 0 None
# 1 while
# 2 it
# 3 ’s
# 4 perfectly
# 5 evident
# 6 that
# 7 trump
# 8 does
# 9 have
# 10 racist
# 11 supporters
# 12 which
# 13 he
# 14 is
# 15 suspiciously
# 16 reluctant
# 17 condemn
# 18 many
# 19 contend
# 20 that
# 21 trumpism
# 22 is
# 23 itself
# 24 racist
# 25 merely
# 26 a
# 27 justified
# 28 reaction
# 29 to
# 30 the
# 31 left
# 32 racial
# 3565
# 0 None
# 1 while
# 2 lecturing
# 3 americans
# 4 on
# 5 racism
# 6 big
# 7 business
# 8 opposes
# 9 ban
# 10 on
# 11 using
# 12 foreign
# 13 slave
# 3566
# 0 None
# 1 while
# 2 low
# 3 unemployment
# 4 steadily
# 5 if
# 6 slowly
# 7 rising
# 8 wages
# 9 have
# 10 improved
# 11 the
# 12 fortunes
# 13 of
# 14 lower
# 15 income
# 16 americans
# 17 these
# 18 gains
# 19 pale
# 20 in
# 21 comparison
# 22 to
# 23 the
# 24 investment
# 25 gains
# 26 realized
# 27 by
# 28 the
# 29 wealthy
# 3567
# 0 None
# 1 while
# 2 many
# 3 things
# 4 were
# 5 certain
# 6 change
# 7 the
# 8 president
# 9 felt
# 10 sure
# 11 that
# 12 element
# 13 of
# 14 continuity
# 15 would
# 16 persist
# 17 the
# 18 united
# 19 states
# 20 would
# 21 determine
# 22 history
# 23 onward
# 3568
# 0 None
# 1 while
# 2 many
# 3 women
# 4 the
# 5 men
# 6 who
# 7 love
# 8 them
# 9 are
# 10 well
# 11 aware
# 12 that
# 13 spurred
# 14 on
# 15 by
# 16 the
# 17 vatican
# 18 united
# 19 states
# 20 conference
# 21 of
# 22 catholic
# 23 bishops
# 24 usccb
# 25 the
# 26 so
# 27 called
# 28 personhood
# 29 movement
# 30 republicans
# 31 are
# 32 working
# 33 feverishly
# 34 eradicate
# 35 women
# 36 reproductive
# 3569
# 0 None
# 1 while
# 2 most
# 3 national
# 4 attention
# 5 has
# 6 been
# 7 focused
# 8 on
# 9 massive
# 10 demonstrations
# 11 violent
# 12 clashes
# 13 with
# 14 police
# 15 in
# 16 the
# 17 united
# 18 states
# 19 biggest
# 20 cities
# 21 like
# 22 new
# 23 york
# 24 los
# 25 angeles
# 26 hundreds
# 27 of
# 28 spontaneous
# 29 demonstrations
# 30 have
# 31 popped
# 32 up
# 33 in
# 34 little
# 35 towns
# 36 rural
# 37 areas
# 38 across
# 39 the
# 40 nation
# 41 in
# 42 recent
# 3570
# 0 None
# 1 while
# 2 no
# 3 one
# 4 is
# 5 praising
# 6 trump
# 7 as
# 8 a
# 9 thought
# 10 leader
# 11 in
# 12 the
# 13 way
# 14 limbaugh
# 15 has
# 16 been
# 17 he
# 18 ’s
# 19 undeniably
# 20 made
# 21 conservative
# 22 ideas
# 23 tangible
# 24 for
# 25 average
# 3571
# 0 None
# 1 while
# 2 nyc
# 3 has
# 4 largely
# 5 tamed
# 6 the
# 7 lethal
# 8 highly
# 9 contagious
# 10 coronavirus
# 11 another
# 12 epidemic
# 13 is
# 14 starting
# 15 rear
# 16 its
# 17 ugly
# 18 head
# 19 in
# 20 the
# 21 city
# 22 once
# 23 again
# 24 violent
# 3572
# 0 None
# 1 while
# 2 omar
# 3 is
# 4 in
# 5 no
# 6 danger
# 7 of
# 8 being
# 9 held
# 10 accountable
# 11 for
# 12 her
# 13 extremism
# 14 her
# 15 ascent
# 16 to
# 17 rock
# 18 star
# 19 status
# 20 among
# 21 democrats
# 22 their
# 23 media
# 24 cheering
# 25 section
# 26 gives
# 27 the
# 28 lie
# 29 to
# 30 their
# 31 claims
# 32 be
# 33 standing
# 34 up
# 35 against
# 36 hate
# 3573
# 0 None
# 1 while
# 2 opportunity
# 3 zone
# 4 program
# 5 that
# 6 offers
# 7 tax
# 8 breaks
# 9 to
# 10 investors
# 11 who
# 12 put
# 13 money
# 14 into
# 15 specially
# 16 designated
# 17 areas
# 18 was
# 19 pitched
# 20 as
# 21 a
# 22 way
# 23 help
# 24 struggling
# 25 neighborhoods
# 26 propublica
# 27 others
# 28 have
# 29 documented
# 30 how
# 31 the
# 32 process
# 33 has
# 34 appeared
# 35 benefit
# 36 billionaires
# 37 with
# 38 investments
# 39 in
# 40 areas
# 41 that
# 42 should
# 43 have
# 3574
# 0 None
# 1 while
# 2 pace
# 3 receives
# 4 her
# 5 spiritual
# 6 grace
# 7 from
# 8 a
# 9 christian
# 10 god
# 11 science
# 12 has
# 13 shown
# 14 that
# 15 faith
# 16 in
# 17 a
# 18 supernatural
# 19 wonder
# 20 whatever
# 21 it
# 22 may
# 23 be
# 24 that
# 25 bears
# 26 powerful
# 27 benefits
# 28 on
# 29 an
# 30 individual
# 31 mental
# 32 even
# 33 physical
# 34 well
# 3575
# 0 None
# 1 while
# 2 pence
# 3 the
# 4 president
# 5 have
# 6 tried
# 7 paint
# 8 a
# 9 rosier
# 10 picture
# 11 of
# 12 the
# 13 virus
# 14 project
# 15 a
# 16 return
# 17 to
# 18 normalcy
# 19 some
# 20 members
# 21 of
# 22 the
# 23 task
# 24 force
# 25 are
# 26 eager
# 27 resume
# 28 appearances
# 29 from
# 30 white
# 31 house
# 3576
# 0 None
# 1 while
# 2 president
# 3 donald
# 4 trump
# 5 impeachment
# 6 trial
# 7 had
# 8 been
# 9 wrapping
# 10 up
# 11 he
# 12 expanded
# 13 of
# 14 his
# 15 most
# 16 controversial
# 17 inflammatory
# 18 policies
# 19 with
# 20 little
# 21 fanfare
# 22 minimal
# 23 opposition
# 24 the
# 25 travel
# 26 ban
# 27 on
# 28 people
# 29 from
# 30 multiple
# 31 muslim
# 32 majority
# 3577
# 0 None
# 1 while
# 2 president
# 3 trump
# 4 visited
# 5 the
# 6 southern
# 7 border
# 8 thursday
# 9 democratic
# 10 darling
# 11 beto
# 12 o’rourke
# 13 visited
# 14 the
# 15 dentist
# 16 posting
# 17 a
# 18 bizarre
# 19 video
# 20 showing
# 21 him
# 22 getting
# 23 a
# 24 mouth
# 25 wide
# 26 open
# 27 cleaning
# 28 in
# 29 order
# 30 highlight
# 31 the
# 32 story
# 33 of
# 34 his
# 35 dental
# 36 hygienist
# 37 ’s
# 38 upbringing
# 39 in
# 40 el
# 3578
# 0 None
# 1 while
# 2 riots
# 3 raged
# 4 across
# 5 the
# 6 united
# 7 states
# 8 over
# 9 floyd
# 10 death
# 11 editors
# 12 on
# 13 wikipedia
# 14 promptly
# 15 set
# 16 out
# 17 spin
# 18 the
# 19 narrative
# 20 of
# 21 the
# 22 unrest
# 23 against
# 3579
# 0 None
# 1 while
# 2 sexual
# 3 ambiguity
# 4 does
# 5 occasionally
# 6 occur
# 7 the
# 8 authors
# 9 note
# 10 intersex
# 11 individuals
# 12 are
# 13 extremely
# 14 rare
# 15 they
# 16 are
# 17 a
# 18 third
# 19 sex
# 20 proof
# 21 that
# 22 sex
# 23 is
# 24 a
# 25 spectrum
# 26 a
# 27 social
# 3580
# 0 None
# 1 while
# 2 snapchat
# 3 is
# 4 happy
# 5 blame
# 6 president
# 7 trump
# 8 who
# 9 is
# 10 working
# 11 restore
# 12 order
# 13 for
# 14 the
# 15 ongoing
# 16 violence
# 17 it
# 18 has
# 19 said
# 20 anything
# 21 about
# 22 support
# 23 for
# 24 the
# 25 domestic
# 26 terrorist
# 27 antifa
# 28 movement
# 29 on
# 30 its
# 3581
# 0 None
# 1 while
# 2 the
# 3 announcement
# 4 identifies
# 5 cases
# 6 of
# 7 alleged
# 8 police
# 9 misconduct
# 10 it
# 11 does
# 12 mention
# 13 violence
# 14 accompanying
# 15 the
# 16 protests
# 17 over
# 18 floyd
# 19 death
# 20 that
# 21 the
# 22 foundation
# 23 is
# 24 now
# 3582
# 0 None
# 1 while
# 2 the
# 3 major
# 4 baseball
# 5 leagues
# 6 wo
# 7 be
# 8 affected
# 9 much
# 10 by
# 11 tariffs
# 12 on
# 13 chinese
# 14 imports
# 15 everyone
# 16 from
# 17 double
# 18 a
# 19 players
# 20 down
# 21 through
# 22 the
# 23 office
# 24 softball
# 25 team
# 26 will
# 3583
# 0 None
# 1 while
# 2 the
# 3 majority
# 4 of
# 5 americans
# 6 seem
# 7 accept
# 8 scientific
# 9 information
# 10 about
# 11 the
# 12 deadly
# 13 coronavirus
# 14 are
# 15 wary
# 16 of
# 17 reopening
# 18 the
# 19 country
# 20 before
# 21 we
# 22 can
# 23 be
# 24 sure
# 25 it
# 26 ’s
# 27 safe
# 28 segment
# 29 of
# 30 the
# 31 population
# 32 is
# 33 driving
# 34 the
# 35 opposite
# 36 narrative
# 37 this
# 38 group
# 39 is
# 40 small
# 41 vocal
# 42 represents
# 43 a
# 44 predictable
# 45 if
# 46 threatening
# 47 merging
# 48 of
# 3584
# 0 None
# 1 while
# 2 the
# 3 mayor
# 4 has
# 5 severely
# 6 curtailed
# 7 religious
# 8 practice
# 9 in
# 10 the
# 11 city
# 12 he
# 13 has
# 14 defended
# 15 the
# 16 rights
# 17 of
# 18 citizens
# 19 form
# 20 huge
# 21 gatherings
# 22 protest
# 23 even
# 24 violently
# 25 obviously
# 26 without
# 27 social
# 28 distancing
# 29 masks
# 30 except
# 31 perhaps
# 32 antifa
# 3585
# 0 None
# 1 while
# 2 the
# 3 overwhelming
# 4 majority
# 5 of
# 6 americans
# 7 choose
# 8 have
# 9 their
# 10 children
# 11 vaccinated
# 12 the
# 13 number
# 14 of
# 15 children
# 16 who
# 17 go
# 18 completely
# 19 unvaccinated
# 20 is
# 3586
# 0 None
# 1 while
# 2 the
# 3 piece
# 4 fairly
# 5 analyzes
# 6 the
# 7 fracturing
# 8 of
# 9 the
# 10 white
# 11 nationalist
# 12 movement
# 13 it
# 14 makes
# 15 the
# 16 bizarre
# 17 claim
# 18 that
# 19 ideas
# 20 that
# 21 are
# 22 widely
# 23 popular
# 24 amongst
# 25 mainstream
# 26 conservatives
# 27 such
# 28 as
# 29 ending
# 30 affirmative
# 31 action
# 32 are
# 33 actually
# 34 white
# 35 nationalist
# 36 in
# 3587
# 0 None
# 1 while
# 2 the
# 3 press
# 4 had
# 5 no
# 6 problem
# 7 regurgitating
# 8 the
# 9 propaganda
# 10 ben
# 11 rhodes
# 12 created
# 13 in
# 14 the
# 15 d.c.
# 16 echo
# 17 chamber
# 18 sell
# 19 president
# 20 obama
# 21 disastrous
# 22 iran
# 23 deal
# 24 with
# 25 trump
# 26 corporate
# 27 media
# 28 has
# 29 opted
# 30 limit
# 31 coverage
# 32 of
# 33 iran
# 34 horrific
# 35 human
# 36 rights
# 3588
# 0 None
# 1 while
# 2 the
# 3 stupid
# 4 democrats
# 5 who
# 6 vote
# 7 for
# 8 democrats
# 9 stress
# 10 worry
# 11 about
# 12 another
# 13 round
# 14 of
# 15 looting
# 16 burning
# 17 this
# 18 weekend
# 19 in
# 20 their
# 21 democrat
# 22 run
# 23 cities
# 24 all
# 25 i
# 26 ’m
# 27 worried
# 28 about
# 29 is
# 30 the
# 3589
# 0 None
# 1 while
# 2 the
# 3 threat
# 4 of
# 5 anti
# 6 -
# 7 trans
# 8 bills
# 9 being
# 10 passed
# 11 into
# 12 law
# 13 is
# 14 real
# 15 present
# 16 all
# 17 such
# 18 legislation
# 19 will
# 20 almost
# 21 certainly
# 22 be
# 23 challenged
# 24 in
# 25 the
# 26 courts
# 27 immediately
# 28 upon
# 29 passing
# 30 before
# 31 it
# 32 can
# 33 be
# 34 fully
# 3590
# 0 None
# 1 while
# 2 the
# 3 workaday
# 4 majority
# 5 of
# 6 americans
# 7 continue
# 8 be
# 9 mired
# 10 in
# 11 our
# 12 low
# 13 wage
# 14 economy
# 15 the
# 16 precious
# 17 few
# 18 at
# 19 the
# 20 tippy
# 21 top
# 22 soared
# 23 out
# 24 of
# 25 sight
# 3591
# 0 None
# 1 while
# 2 these
# 3 many
# 4 similarities
# 5 between
# 6 green
# 7 new
# 8 deal
# 9 the
# 10 constitution
# 11 ushered
# 12 in
# 13 by
# 14 venezuelan
# 15 leftist
# 16 dictator
# 17 hugo
# 18 chavez
# 19 in
# 20 may
# 21 be
# 22 just
# 23 happenstance
# 24 the
# 25 important
# 26 thing
# 27 remember
# 28 is
# 29 that
# 30 venezuela
# 31 under
# 32 its
# 33 new
# 34 constitution
# 35 has
# 36 become
# 37 a
# 38 disaster
# 3592
# 0 None
# 1 while
# 2 trump
# 3 has
# 4 stopped
# 5 short
# 6 of
# 7 invoking
# 8 the
# 9 act
# 10 use
# 11 the
# 12 military
# 13 enforce
# 14 laws
# 15 domestically
# 16 he
# 17 ’s
# 18 kept
# 19 the
# 20 option
# 21 open
# 22 fomenting
# 23 further
# 24 unrest
# 25 division
# 26 rather
# 27 than
# 28 staging
# 29 photo
# 30 opportunities
# 31 while
# 32 awkwardly
# 33 holding
# 34 a
# 35 bible
# 36 in
# 37 lafayette
# 38 square
# 39 trump
# 40 would
# 41 have
# 42 issued
# 43 a
# 44 formal
# 45 proclamation
# 46 calling
# 47 on
# 48 the
# 49 insurgents
# 50 disperse
# 51 if
# 52 he
# 53 ’s
# 54 serious
# 55 about
# 56 the
# 57 application
# 58 of
# 59 the
# 60 insurrection
# 3593
# 0 None
# 1 while
# 2 in
# 3 the
# 4 wake
# 5 of
# 6 the
# 7 el
# 8 paso
# 9 murders
# 10 the
# 11 media
# 12 most
# 13 of
# 14 our
# 15 politicians
# 16 are
# 17 acting
# 18 shocked
# 19 that
# 20 there
# 21 are
# 22 armed
# 23 racists
# 24 in
# 25 america
# 26 who
# 27 are
# 28 trying
# 29 terrify
# 30 people
# 31 of
# 32 color
# 33 the
# 34 reality
# 35 is
# 36 that
# 37 it
# 38 ’s
# 39 pretty
# 40 much
# 41 always
# 42 been
# 43 that
# 44 way
# 45 here
# 46 in
# 47 the
# 48 united
# 3594
# 0 None
# 1 while
# 2 in
# 3 the
# 4 wake
# 5 of
# 6 the
# 7 el
# 8 paso
# 9 murders
# 10 the
# 11 media
# 12 most
# 13 of
# 14 our
# 15 politicians
# 16 are
# 17 acting
# 18 shocked—“shocked
# 19 i
# 20 tell
# 21 you!”—that
# 22 there
# 23 are
# 24 armed
# 25 racists
# 26 in
# 27 america
# 28 who
# 29 are
# 30 trying
# 31 terrify
# 32 people
# 33 of
# 34 color
# 35 the
# 36 reality
# 37 is
# 38 that
# 39 it
# 40 ’s
# 41 pretty
# 42 much
# 43 always
# 44 been
# 45 that
# 46 way
# 47 here
# 48 in
# 49 the
# 50 united
# 3595
# 0 None
# 1 white
# 2 house
# 3 national
# 4 economic
# 5 council
# 6 director
# 7 larry
# 8 kudlow
# 9 said
# 10 on
# 11 friday
# 12 that
# 13 he
# 14 did
# 15 favor
# 16 a
# 17 higher
# 18 federal
# 19 tax
# 20 on
# 21 gasoline
# 22 fund
# 23 an
# 24 infrastructure
# 25 program
# 26 if
# 27 states
# 28 wanted
# 29 raise
# 30 their
# 31 own
# 32 gas
# 33 taxes
# 34 that
# 35 was
# 36 up
# 37 to
# 3596
# 0 None
# 1 white
# 2 house
# 3 press
# 4 secretary
# 5 kayleigh
# 6 mcenany
# 7 voiced
# 8 tepid
# 9 support
# 10 for
# 11 defense
# 12 secretary
# 13 mark
# 14 esper
# 15 after
# 16 he
# 17 stated
# 18 wednesday
# 19 that
# 20 he
# 21 did
# 22 support
# 23 invoking
# 24 the
# 25 insurrection
# 26 act
# 27 which
# 28 would
# 29 allow
# 30 active
# 31 duty
# 32 troops
# 33 act
# 34 in
# 35 domestic
# 36 law
# 37 enforcement
# 3597
# 0 None
# 1 white
# 2 house
# 3 senior
# 4 adviser
# 5 jared
# 6 kushner
# 7 criticized
# 8 athletes
# 9 others
# 10 who
# 11 have
# 12 protested
# 13 against
# 14 u.s.
# 15 racism
# 16 on
# 17 social
# 18 media
# 19 basketball
# 20 courts
# 21 suggested
# 22 that
# 23 black
# 24 people
# 25 had
# 26 want
# 27 succeed
# 28 for
# 29 policies
# 3598
# 0 None
# 1 white
# 2 mobs
# 3 have
# 4 once
# 5 again
# 6 moved
# 7 out
# 8 of
# 9 the
# 10 shadows
# 11 into
# 12 the
# 13 limelight
# 14 during
# 15 this
# 16 trump
# 3599
# 0 None
# 1 white
# 2 nationalism
# 3 fueled
# 4 violence
# 5 is
# 6 on
# 7 the
# 8 rise
# 9 fbi
# 10 is
# 11 slow
# 12 call
# 13 it
# 14 domestic
# 3600
# 0 None
# 1 white
# 2 nationalist
# 3 arrested
# 4 for
# 5 alleged
# 6 threat
# 7 against
# 8 ohio
# 9 jewish
# 10 community
# 3601
# 0 None
# 1 white
# 2 nationalists
# 3 also
# 4 expressed
# 5 excitement
# 6 tuesday
# 7 about
# 8 trump
# 9 plan
# 10 use
# 11 an
# 12 executive
# 13 order
# 14 end
# 15 birthright
# 16 citizenship
# 17 the
# 18 automatic
# 19 grant
# 20 of
# 21 citizen
# 22 status
# 23 to
# 24 anyone
# 25 born
# 26 in
# 27 the
# 28 united
# 3602
# 0 None
# 1 white
# 2 people
# 3 are
# 4 being
# 5 asked
# 6 pushed
# 7 take
# 8 stock
# 9 of
# 10 their
# 11 whiteness
# 12 identify
# 13 with
# 14 it
# 15 more
# 16 this
# 17 is
# 18 a
# 19 remarkably
# 20 bad
# 3603
# 0 None
# 1 white
# 2 supremacist
# 3 violent
# 4 extremists
# 5 can
# 6 generally
# 7 be
# 8 characterized
# 9 by
# 10 hatred
# 11 for
# 12 immigrants
# 13 ethnic
# 14 minorities
# 15 often
# 16 combining
# 17 these
# 18 prejudices
# 19 with
# 20 virulent
# 21 anti
# 22 -
# 23 semitism
# 24 anti
# 25 -
# 26 muslim
# 27 views
# 28 the
# 29 dhs
# 30 report
# 3604
# 0 None
# 1 whitmer
# 2 takes
# 3 on
# 4 trump
# 5 for
# 6 claiming
# 7 the
# 8 economy
# 9 is
# 10 booming
# 11 asking
# 12 for
# 13 whom
# 14 she
# 15 details
# 16 local
# 17 pieces
# 18 of
# 19 legislation
# 20 dem
# 21 governors
# 22 are
# 23 working
# 24 on
# 25 before
# 26 claiming
# 27 democrats
# 28 are
# 29 the
# 30 ones
# 31 who
# 32 actually
# 33 fight
# 34 for
# 35 hardworking
# 3605
# 0 None
# 1 who
# 2 is
# 3 working
# 4 ensure
# 5 fair
# 6 vaccine
# 7 distribution
# 8 in
# 9 the
# 10 meantime
# 11 it
# 12 is
# 13 key
# 14 suppress
# 15 the
# 16 virus
# 17 spread
# 18 said
# 19 mike
# 20 ryan
# 21 head
# 22 of
# 23 who
# 24 emergencies
# 25 program
# 26 as
# 27 daily
# 28 new
# 29 cases
# 30 around
# 31 the
# 32 globe
# 33 are
# 34 at
# 35 near
# 36 record
# 3606
# 0 None
# 1 why
# 2 are
# 3 members
# 4 of
# 5 the
# 6 fairer
# 7 sex
# 8 on
# 9 the
# 10 frontlines
# 11 of
# 12 riotous
# 13 efforts
# 14 support
# 15 a
# 16 movement
# 17 that
# 18 insists
# 19 they
# 20 're
# 21 racist
# 22 capitalism
# 23 is
# 24 racist
# 25 the
# 26 whole
# 27 system
# 28 is
# 3607
# 0 None
# 1 why
# 2 did
# 3 democrats
# 4 vote
# 5 overwhelmingly
# 6 against
# 7 a
# 8 bill
# 9 that
# 10 would
# 11 require
# 12 infants
# 13 born
# 14 alive
# 15 after
# 16 abortion
# 17 be
# 18 treated
# 19 as
# 20 any
# 21 other
# 22 infant
# 23 born
# 24 at
# 25 that
# 26 gestational
# 27 age
# 28 because
# 29 abortion
# 30 is
# 31 the
# 32 right
# 33 destroy
# 34 own
# 35 child
# 36 if
# 37 a
# 38 woman
# 39 chose
# 40 kill
# 41 her
# 42 baby
# 43 to
# 44 the
# 45 left
# 46 it
# 47 would
# 48 seem
# 49 a
# 50 violation
# 51 of
# 52 her
# 53 so
# 54 called
# 55 right
# 56 choose
# 57 for
# 58 doctors
# 59 try
# 60 save
# 61 that
# 3608
# 0 None
# 1 why
# 2 did
# 3 trump
# 4 offer
# 5 up
# 6 this
# 7 cards
# 8 that
# 9 's
# 10 because
# 11 his
# 12 vaunted
# 13 skills
# 14 in
# 15 making
# 16 the
# 17 deal
# 18 absolutely
# 19 failed
# 20 budge
# 21 the
# 22 prices
# 23 from
# 24 pharmaceutical
# 25 companies
# 26 a
# 27 deal
# 28 that
# 29 had
# 30 been
# 31 in
# 32 the
# 33 works
# 34 for
# 35 months
# 36 absolutely
# 3609
# 0 None
# 1 why
# 2 women
# 3 have
# 4 abortions
# 5 is
# 6 a
# 7 topic
# 8 much
# 9 discussed
# 10 by
# 11 those
# 12 who
# 13 argue
# 14 that
# 15 ending
# 16 a
# 17 life
# 18 in
# 19 the
# 20 womb
# 21 is
# 22 sometimes
# 3610
# 0 None
# 1 wikipedia
# 2 coverage
# 3 of
# 4 other
# 5 contentious
# 6 political
# 7 topics
# 8 such
# 9 as
# 10 abortion
# 11 were
# 12 also
# 13 criticized
# 14 with
# 15 sanger
# 16 singling
# 17 out
# 18 wikipedia
# 19 claiming
# 20 abortion
# 21 is
# 22 of
# 23 the
# 24 safest
# 25 procedures
# 26 in
# 3611
# 0 None
# 1 wikipedia
# 2 own
# 3 articles
# 4 on
# 5 the
# 6 floyd
# 7 protests
# 8 similarly
# 9 reflect
# 10 the
# 11 foundation
# 12 abandonment
# 13 of
# 14 neutrality
# 15 by
# 16 being
# 17 unduly
# 18 skewed
# 19 towards
# 20 smearing
# 21 president
# 22 donald
# 23 trump
# 24 while
# 25 downplaying
# 26 protestor
# 27 violence
# 28 the
# 29 violent
# 30 antifa
# 31 group
# 3612
# 0 None
# 1 will
# 2 noted
# 3 gender
# 4 dysphoria
# 5 is
# 6 a
# 7 mental
# 8 health
# 9 issue
# 10 parents
# 11 have
# 12 the
# 13 right
# 14 make
# 15 healthcare
# 16 decisions
# 17 on
# 18 behalf
# 19 of
# 20 their
# 3613
# 0 None
# 1 will
# 2 the
# 3 american
# 4 people
# 5 follow
# 6 the
# 7 commands
# 8 of
# 9 donald
# 10 trump
# 11 coronavirus
# 12 death
# 3614
# 0 None
# 1 wilson
# 2 ali
# 3 have
# 4 received
# 5 death
# 6 threats
# 7 for
# 8 the
# 9 crime
# 10 of
# 11 poking
# 12 fun
# 13 at
# 14 donald
# 15 trump
# 16 the
# 17 members
# 18 of
# 19 his
# 20 political
# 3615
# 0 None
# 1 wilton
# 2 gregory
# 3 the
# 4 first
# 5 african
# 6 american
# 7 be
# 8 named
# 9 as
# 10 cardinal
# 11 known
# 12 as
# 13 a
# 14 refined
# 15 diplomat
# 16 made
# 17 headlines
# 18 when
# 19 he
# 20 blasted
# 21 president
# 22 donald
# 23 trump
# 24 photo
# 25 opportunity
# 26 hoisting
# 27 a
# 28 bible
# 29 at
# 30 a
# 31 washington
# 32 church
# 33 after
# 34 police
# 35 used
# 36 tear
# 37 gas
# 38 clear
# 39 demonstrators
# 40 in
# 3616
# 0 None
# 1 wimbledon
# 2 champion
# 3 navratilova
# 4 who
# 5 has
# 6 campaigned
# 7 for
# 8 gay
# 9 rights
# 10 suffered
# 11 abuse
# 12 when
# 13 she
# 14 came
# 15 out
# 16 in
# 17 the
# 18 1980s
# 19 argued
# 20 trans
# 21 women
# 22 have
# 23 unfair
# 24 physical
# 3617
# 0 None
# 1 winston
# 2 churchill
# 3 was
# 4 a
# 5 racist
# 6 so
# 7 the
# 8 black
# 9 lives
# 10 matter
# 11 graffiti
# 12 says
# 13 on
# 14 the
# 15 plinth
# 16 of
# 17 his
# 18 statue
# 19 in
# 20 london
# 21 parliament
# 22 square
# 23 which
# 24 is
# 25 bound
# 26 be
# 27 pulled
# 28 down
# 29 by
# 30 hard
# 31 left
# 32 activists
# 33 sooner
# 34 later
# 35 because
# 36 the
# 37 police
# 38 do
# 39 seem
# 40 have
# 41 that
# 42 much
# 43 of
# 44 an
# 45 appetite
# 46 save
# 3618
# 0 None
# 1 with
# 2 democrats
# 3 fuming
# 4 over
# 5 trump
# 6 push
# 7 for
# 8 a
# 9 border
# 10 wall
# 11 amid
# 12 a
# 13 still
# 14 unresolved
# 15 funding
# 16 standoff
# 17 those
# 18 guest
# 19 lists
# 20 signal
# 21 the
# 22 president
# 23 could
# 24 face
# 25 a
# 26 tough
# 3619
# 0 None
# 1 with
# 2 hundreds
# 3 of
# 4 potential
# 5 vaccines
# 6 in
# 7 various
# 8 stages
# 9 of
# 10 development
# 11 around
# 12 the
# 13 world
# 14 russia
# 15 was
# 16 the
# 17 first
# 18 country
# 19 license
# 20 its
# 21 vaccine
# 22 for
# 23 public
# 24 use
# 25 alongside
# 26 china
# 27 has
# 28 been
# 29 deploying
# 30 the
# 31 shots
# 32 before
# 33 full
# 34 efficacy
# 35 trials
# 36 are
# 3620
# 0 None
# 1 with
# 2 it
# 3 ’s
# 4 bothsidesism
# 5 pro
# 6 -
# 7 trump
# 8 onesiderism
# 9 the
# 10 new
# 11 york
# 12 times
# 13 is
# 3621
# 0 None
# 1 with
# 2 june
# 3 marking
# 4 the
# 5 start
# 6 of
# 7 the
# 8 annual
# 9 pride
# 10 month
# 11 when
# 12 many
# 13 gay
# 14 trans
# 15 people
# 16 commemorate
# 17 riots
# 18 against
# 19 police
# 20 brutality
# 21 in
# 22 in
# 23 new
# 24 york
# 25 city
# 26 brown
# 27 called
# 28 on
# 29 the
# 30 lgbt+
# 31 community
# 32 recall
# 33 the
# 34 protest
# 35 driven
# 36 roots
# 37 of
# 38 the
# 3622
# 0 None
# 1 with
# 2 just
# 3 over
# 4 a
# 5 year
# 6 left
# 7 in
# 8 president
# 9 donald
# 10 trump
# 11 first
# 12 term
# 13 another
# 14 late
# 15 breaking
# 16 news
# 17 item
# 18 barely
# 19 made
# 20 waves
# 21 the
# 22 interior
# 23 department
# 24 which
# 25 manages
# 26 the
# 27 majority
# 28 of
# 29 the
# 30 federal
# 31 government
# 32 public
# 33 lands
# 34 deleted
# 35 sexual
# 36 orientation
# 37 from
# 38 its
# 39 anti
# 40 -
# 41 discrimination
# 3623
# 0 None
# 1 with
# 2 many
# 3 formal
# 4 juneteenth
# 5 events
# 6 canceled
# 7 due
# 8 to
# 9 coronavirus
# 10 concerns
# 11 activists
# 12 instead
# 13 organized
# 14 a
# 15 host
# 16 of
# 17 virtual
# 18 observances
# 19 online
# 20 as
# 21 well
# 22 as
# 23 street
# 24 marches
# 25 car
# 26 caravans
# 27 through
# 28 several
# 29 major
# 3624
# 0 None
# 1 with
# 2 more
# 3 than
# 4 people
# 5 killed
# 6 by
# 7 gun
# 8 violence
# 9 in
# 10 the
# 11 united
# 12 states
# 13 last
# 14 year
# 15 counting
# 16 suicides
# 17 democrats
# 18 running
# 19 for
# 20 their
# 21 party
# 22 presidential
# 23 nomination
# 24 are
# 25 pointing
# 26 to
# 27 inaction
# 28 in
# 29 washington
# 30 as
# 31 evidence
# 32 they
# 33 should
# 34 be
# 35 chosen
# 36 run
# 37 against
# 38 republican
# 39 president
# 40 donald
# 3625
# 0 None
# 1 with
# 2 more
# 3 than
# 4 reported
# 5 cases
# 6 of
# 7 the
# 8 disease
# 9 the
# 10 viral
# 11 outbreak
# 12 continues
# 13 create
# 14 uncertainty
# 15 about
# 16 future
# 17 competitions
# 18 from
# 19 track
# 20 field
# 21 formula
# 22 to
# 23 the
# 24 ultimate
# 25 global
# 26 event
# 27 the
# 28 tokyo
# 3626
# 0 None
# 1 with
# 2 our
# 3 climate
# 4 impacted
# 5 world
# 6 now
# 7 highly
# 8 prone
# 9 to
# 10 fires
# 11 extreme
# 12 storms
# 13 sea
# 14 level
# 15 rise
# 16 nuclear
# 17 energy
# 18 is
# 19 touted
# 20 as
# 21 a
# 22 possible
# 23 replacement
# 24 for
# 25 the
# 26 burning
# 27 of
# 28 fossil
# 29 fuels
# 30 for
# 31 energy
# 32 the
# 33 leading
# 34 cause
# 35 of
# 36 climate
# 3627
# 0 None
# 1 with
# 2 protests
# 3 over
# 4 racial
# 5 injustice
# 6 continuing
# 7 roil
# 8 the
# 9 united
# 10 states
# 11 queer
# 12 eye
# 13 star
# 14 karamo
# 15 brown
# 16 has
# 17 called
# 18 on
# 19 lgbt+
# 20 people
# 21 recognize
# 22 the
# 23 racism
# 24 transphobia
# 25 in
# 26 the
# 27 community
# 28 remember
# 29 the
# 30 radical
# 31 roots
# 32 of
# 33 the
# 34 gay
# 35 rights
# 3628
# 0 None
# 1 with
# 2 radical
# 3 feminists
# 4 extremist
# 5 trans
# 6 activists
# 7 seeking
# 8 have
# 9 her
# 10 publishers
# 11 film
# 12 associates
# 13 ban
# 14 her
# 15 from
# 16 earning
# 17 a
# 18 living
# 19 she
# 20 understands
# 21 how
# 22 the
# 23 radical
# 24 left
# 25 seeks
# 26 merely
# 27 disagree
# 28 with
# 29 their
# 30 opponents
# 31 destroy
# 32 them
# 33 utterly
# 34 as
# 35 human
# 3629
# 0 None
# 1 with
# 2 the
# 3 arrival
# 4 of
# 5 virus
# 6 our
# 7 legal
# 8 rights
# 9 seem
# 10 have
# 11 been
# 12 deemed
# 13 irrelevant
# 14 completely
# 15 subordinated
# 16 to
# 17 the
# 18 arbitrary
# 19 whims
# 20 of
# 21 politicians
# 22 all
# 23 in
# 24 the
# 25 name
# 26 of
# 3630
# 0 None
# 1 with
# 2 the
# 3 olympic
# 4 games
# 5 postponed
# 6 until
# 7 cinemas
# 8 closed
# 9 across
# 10 the
# 11 country
# 12 whole
# 13 segments
# 14 of
# 15 the
# 16 advertising
# 17 market
# 18 have
# 3631
# 0 None
# 1 with
# 2 this
# 3 in
# 4 mind
# 5 the
# 6 trump
# 7 administration
# 8 reportedly
# 9 hopes
# 10 reduce
# 11 poverty
# 12 in
# 13 the
# 14 united
# 15 states
# 16 by
# 17 making
# 18 a
# 19 material
# 20 difference
# 21 in
# 22 struggling
# 23 families
# 24 finances
# 25 by
# 26 tinkering
# 27 with
# 28 the
# 29 threshold
# 30 for
# 31 what
# 32 counts
# 33 as
# 3632
# 0 None
# 1 with
# 2 justices
# 3 appointed
# 4 in
# 5 recent
# 6 years
# 7 by
# 8 president
# 9 donald
# 10 trump
# 11 the
# 12 supreme
# 13 court
# 14 has
# 15 appeared
# 16 primed
# 17 ready
# 18 deliver
# 19 a
# 20 huge
# 21 victory
# 22 for
# 23 conservatives
# 24 looking
# 25 roll
# 26 back
# 27 abortion
# 28 rights
# 29 in
# 30 the
# 31 united
# 3633
# 0 None
# 1 with
# 2 u.s.
# 3 president
# 4 donald
# 5 trump
# 6 announcement
# 7 on
# 8 thursday
# 9 of
# 10 tariffs
# 11 on
# 12 another
# 13 of
# 14 chinese
# 15 imports
# 16 nearly
# 17 all
# 18 goods
# 19 from
# 20 china
# 21 will
# 22 be
# 23 subject
# 24 to
# 25 import
# 26 taxes
# 27 trump
# 28 says
# 29 they
# 30 generate
# 31 billions
# 32 of
# 33 dollars
# 34 in
# 35 revenues
# 36 for
# 37 the
# 38 u.s.
# 39 treasury
# 40 from
# 3634
# 0 None
# 1 with
# 2 president
# 3 donald
# 4 trump
# 5 signaling
# 6 that
# 7 he
# 8 's
# 9 eager
# 10 for
# 11 the
# 12 country
# 13 relax
# 14 stringent
# 15 measures
# 16 meant
# 17 stem
# 18 the
# 19 tide
# 20 of
# 21 the
# 22 covid-19
# 23 pandemic
# 24 it
# 25 's
# 26 important
# 27 realize
# 28 how
# 29 dangerous
# 30 this
# 31 idea
# 3635
# 0 None
# 1 within
# 2 weeks
# 3 of
# 4 floyd
# 5 passing
# 6 in
# 7 minneapolis
# 8 police
# 9 custody
# 10 militant
# 11 social
# 12 justice
# 13 warriors
# 14 racked
# 15 up
# 16 an
# 17 estimated
# 18 in
# 19 damage
# 20 causing
# 21 the
# 22 costliest
# 23 outbreak
# 24 of
# 25 political
# 26 upheaval
# 27 in
# 28 u.s.
# 29 history
# 30 devastating
# 31 minority
# 32 businesses
# 33 while
# 34 kicking
# 35 off
# 36 an
# 37 entire
# 38 summer
# 39 of
# 40 chaos
# 41 engulfing
# 42 the
# 43 nation
# 44 major
# 45 cities
# 46 eventually
# 47 spreading
# 48 to
# 49 the
# 3636
# 0 None
# 1 witness
# 2 for
# 3 instance
# 4 the
# 5 wacky
# 6 nonsense
# 7 new
# 8 york
# 9 mayor
# 10 current
# 11 trump
# 12 flunky
# 13 rudy
# 14 giuliani
# 15 addressed
# 16 to
# 17 salon
# 18 roger
# 19 sollenberger
# 20 during
# 21 a
# 22 text
# 23 interview
# 24 this
# 3637
# 0 None
# 1 women
# 2 in
# 3 power
# 4 must
# 5 pay
# 6 a
# 7 significant
# 8 tax
# 9 on
# 10 their
# 11 limited
# 12 time
# 13 sit
# 14 for
# 15 manicures
# 16 blowouts
# 17 brow
# 18 waxes
# 19 braids
# 20 rather
# 21 than
# 22 meeting
# 23 with
# 24 constituents
# 25 reviewing
# 26 legislation
# 27 conducting
# 28 investigations
# 29 chasing
# 30 a
# 31 story
# 32 traveling
# 33 to
# 34 their
# 35 districts
# 36 reviewing
# 37 their
# 38 notes
# 39 spending
# 40 time
# 41 with
# 42 their
# 3638
# 0 None
# 1 women
# 2 were
# 3 allowed
# 4 into
# 5 saudi
# 6 sports
# 7 stadiums
# 8 a
# 9 year
# 10 ago
# 11 for
# 12 the
# 13 first
# 14 time
# 15 watch
# 16 soccer
# 17 matches
# 18 although
# 19 they
# 20 were
# 21 segregated
# 22 in
# 23 the
# 24 stands
# 25 sticking
# 26 to
# 27 the
# 28 family
# 29 section
# 30 away
# 31 from
# 32 all
# 33 male
# 34 crowds
# 3639
# 0 None
# 1 women
# 2 rights
# 3 advocates
# 4 were
# 5 relieved
# 6 late
# 7 monday
# 8 when
# 9 senate
# 10 democrats
# 11 blocked
# 12 an
# 13 extreme
# 14 anti
# 15 -
# 16 choice
# 17 bill
# 18 from
# 19 advancing
# 20 to
# 21 a
# 22 floor
# 23 debate
# 24 were
# 25 soon
# 26 outraged
# 27 by
# 28 president
# 29 donald
# 30 trump
# 31 lies
# 32 about
# 33 abortion
# 34 care
# 35 as
# 36 well
# 37 as
# 38 the
# 39 corporate
# 40 media
# 41 for
# 42 enabling
# 43 his
# 44 blatantly
# 45 false
# 46 characterization
# 47 of
# 48 the
# 49 bill
# 3640
# 0 None
# 1 wo
# 2 it
# 3 be
# 4 absurdly
# 5 difficult
# 6 enforce
# 7 new
# 8 gun
# 9 control
# 10 laws
# 11 move
# 12 toward
# 13 the
# 14 outright
# 15 confiscation
# 16 that
# 17 is
# 18 always
# 19 forever
# 20 the
# 21 left
# 22 ultimate
# 23 goal
# 24 after
# 25 a
# 26 year
# 27 of
# 28 record
# 29 breaking
# 30 gun
# 3641
# 0 None
# 1 working
# 2 class
# 3 americans
# 4 like
# 5 those
# 6 who
# 7 make
# 8 up
# 9 the
# 10 majority
# 11 of
# 12 south
# 13 bend
# 14 residents
# 15 have
# 16 secured
# 17 the
# 18 largest
# 19 wage
# 20 hikes
# 21 in
# 22 the
# 23 nation
# 24 compared
# 25 to
# 26 all
# 27 other
# 28 economic
# 29 demographic
# 30 groups
# 31 a
# 32 direct
# 33 result
# 34 of
# 35 trump
# 36 tightening
# 37 the
# 38 labor
# 3642
# 0 None
# 1 workplace
# 2 bias
# 3 against
# 4 gay
# 5 transgender
# 6 employees
# 7 has
# 8 remained
# 9 legal
# 10 in
# 11 much
# 12 of
# 13 the
# 14 country
# 15 with
# 16 u.s.
# 17 states
# 18 lacking
# 19 comprehensive
# 20 measures
# 21 against
# 22 employment
# 3643
# 0 None
# 1 world
# 2 leaders
# 3 organisations
# 4 pledged
# 5 fund
# 6 a
# 7 possible
# 8 vaccine
# 9 treatments
# 10 many
# 11 hoping
# 12 explicitly
# 13 ensure
# 14 that
# 15 no
# 16 country
# 17 on
# 18 earth
# 19 would
# 20 be
# 21 left
# 22 out
# 23 the
# 24 united
# 25 states
# 26 did
# 3644
# 0 None
# 1 worth
# 2 noting
# 3 however
# 4 is
# 5 that
# 6 democrats
# 7 have
# 8 also
# 9 been
# 10 notably
# 11 faced
# 12 on
# 13 gun
# 3645
# 0 None
# 1 writing
# 2 in
# 3 today
# 4 wall
# 5 street
# 6 journal
# 7 pence
# 8 denies
# 9 that
# 10 there
# 11 is
# 12 such
# 13 a
# 14 thing
# 15 as
# 16 a
# 17 second
# 18 wave
# 19 to
# 20 the
# 21 pandemic
# 22 he
# 23 does
# 24 mean
# 25 because
# 26 we
# 27 have
# 28 exited
# 29 the
# 30 first
# 3646
# 0 None
# 1 yale
# 2 psychiatrist
# 3 explains
# 4 why
# 5 the
# 6 coronavirus
# 7 pandemic
# 8 donald
# 9 trump
# 10 irrational
# 11 cult
# 12 is
# 13 a
# 14 deadly
# 3647
# 0 None
# 1 yep
# 2 after
# 3 openly
# 4 committing
# 5 adultery
# 6 against
# 7 the
# 8 republican
# 9 party
# 10 these
# 11 shameless
# 12 cheats
# 13 honestly
# 14 believed
# 15 the
# 16 democrat
# 17 party
# 18 would
# 19 make
# 20 them
# 21 equal
# 22 trusted
# 23 partners
# 24 in
# 25 the
# 26 family
# 3648
# 0 None
# 1 yes
# 2 trump
# 3 the
# 4 right
# 5 are
# 6 embracing
# 7 celebrating
# 8 death
# 9 it
# 10 is
# 11 ghoulish
# 12 it
# 13 is
# 14 also
# 15 more
# 16 illustration
# 17 that
# 18 the
# 19 age
# 20 of
# 21 trump
# 22 is
# 23 an
# 24 american
# 25 dystopia
# 26 where
# 27 what
# 28 was
# 29 previously
# 30 unimaginable
# 31 for
# 32 most
# 33 decent
# 34 people
# 35 has
# 36 become
# 3649
# 0 None
# 1 yes
# 2 he
# 3 might
# 4 be
# 5 a
# 6 demented
# 7 stalinist
# 8 eager
# 9 flood
# 10 america
# 11 with
# 12 illegal
# 13 aliens
# 14 take
# 15 away
# 16 our
# 17 guns
# 18 health
# 19 insurance
# 20 he
# 21 sure
# 22 gave
# 23 those
# 24 venal
# 25 never
# 26 trumpers
# 27 a
# 28 sweet
# 29 face
# 30 job
# 31 saturday
# 32 night
# 33 in
# 34 nevada
# 35 now
# 36 i
# 37 ca
# 38 tell
# 39 if
# 40 my
# 41 tears
# 42 come
# 43 from
# 44 joy
# 3650
# 0 None
# 1 yes
# 2 the
# 3 rich
# 4 are
# 5 rich
# 6 want
# 7 stay
# 8 that
# 9 way
# 10 yet
# 11 at
# 12 the
# 13 same
# 14 time
# 15 fat
# 16 cats
# 17 now
# 18 lean
# 19 left
# 20 even
# 21 far
# 22 left
# 23 on
# 24 cultural
# 25 issues
# 26 they
# 27 want
# 28 you
# 29 do
# 30 as
# 31 you
# 32 ’re
# 3651
# 0 None
# 1 yes
# 2 there
# 3 may
# 4 still
# 5 be
# 6 time
# 7 for
# 8 the
# 9 union
# 10 membership
# 11 change
# 12 its
# 13 thinking
# 14 if
# 15 the
# 16 players
# 17 reject
# 18 the
# 19 proposal
# 20 at
# 21 least
# 22 marketing
# 23 expert
# 24 said
# 25 a
# 26 no
# 27 vote
# 28 now
# 29 could
# 30 mean
# 31 short-
# 32 long
# 33 term
# 3652
# 0 None
# 1 biden
# 2 finds
# 3 himself
# 4 in
# 5 an
# 6 increasingly
# 7 competitive
# 8 race
# 9 with
# 10 sanders
# 11 the
# 12 u.s.
# 13 senator
# 14 who
# 15 came
# 16 close
# 17 to
# 18 winning
# 19 the
# 20 nevada
# 21 caucus
# 22 finds
# 23 support
# 24 with
# 25 some
# 26 of
# 27 the
# 28 same
# 3653
# 0 None
# 1 bizarrely
# 2 the
# 3 entirety
# 4 of
# 5 the
# 6 establishment
# 7 from
# 8 prime
# 9 minister
# 10 boris
# 11 johnson
# 12 downwards
# 13 the
# 14 bodies
# 15 representing
# 16 every
# 17 cultural
# 18 institution
# 19 from
# 20 the
# 21 church
# 22 of
# 23 england
# 24 to
# 25 the
# 26 football
# 27 association
# 28 have
# 29 been
# 30 grovelling
# 31 fawning
# 32 kowtowing
# 33 to
# 34 blm
# 35 as
# 36 if
# 37 its
# 38 name
# 39 were
# 40 be
# 41 taken
# 42 at
# 43 face
# 3654
# 0 None
# 1 yet
# 2 every
# 3 nation
# 4 except
# 5 mongolia
# 6 greenland
# 7 recorded
# 8 dozens
# 9 to
# 10 thousands
# 11 of
# 12 deaths
# 13 no
# 14 matter
# 15 what
# 16 they
# 17 tried
# 18 even
# 19 socialist
# 20 systems
# 21 with
# 22 draconian
# 23 lockdowns
# 24 like
# 25 italy
# 26 deaths
# 27 per
# 28 spain
# 29 the
# 30 united
# 3655
# 0 None
# 1 it
# 2 far
# 3 better
# 4 applies
# 5 to
# 6 unelected
# 7 career
# 8 bureaucrats
# 9 use
# 10 of
# 11 their
# 12 power
# 13 prosecute
# 14 their
# 15 political
# 16 enemies
# 17 which
# 18 comprises
# 19 the
# 20 heart
# 21 of
# 22 the
# 23 resistance
# 24 to
# 25 republican
# 26 rule
# 27 that
# 28 will
# 29 endure
# 30 so
# 31 long
# 32 as
# 33 bureaucracy
# 34 has
# 35 enough
# 36 power
# 37 challenged
# 38 elected
# 39 branches
# 40 of
# 41 government
# 42 this
# 43 bureacracy
# 44 weaponization
# 45 was
# 46 also
# 47 a
# 48 hallmark
# 49 of
# 50 the
# 51 obama
# 52 presidency
# 53 with
# 54 ironies
# 55 of
# 56 ironies
# 57 perhaps
# 58 the
# 59 biggest
# 60 evidences
# 61 again
# 62 coming
# 63 from
# 64 the
# 65 department
# 66 of
# 67 justice
# 68 under
# 69 attorneys
# 70 general
# 71 eric
# 72 holder
# 73 loretta
# 3656
# 0 None
# 1 it
# 2 's
# 3 merely
# 4 the
# 5 tip
# 6 of
# 7 the
# 8 iceberg
# 9 of
# 10 war
# 11 criminals
# 12 lurking
# 13 working
# 14 on
# 15 u.s.
# 3657
# 0 None
# 1 merril
# 2 hoge
# 3 a
# 4 former
# 5 running
# 6 back
# 7 for
# 8 the
# 9 nfl
# 10 pittsburgh
# 11 steelers
# 12 chicago
# 13 bears
# 14 later
# 15 turned
# 16 espn
# 17 analyst
# 18 has
# 19 been
# 20 of
# 21 the
# 22 most
# 23 outspoken
# 24 critics
# 25 against
# 26 the
# 27 alarm
# 28 surrounding
# 29 cte
# 30 studies
# 31 putting
# 32 much
# 33 of
# 34 the
# 35 research
# 36 down
# 37 to
# 38 science
# 39 fiction
# 40 misleading
# 41 science
# 42 far
# 43 from
# 44 a
# 45 factual
# 3658
# 0 None
# 1 mlb
# 2 with
# 3 an
# 4 exhaustive
# 5 page
# 6 health
# 7 safety
# 8 operations
# 9 manual
# 10 will
# 11 attempt
# 12 become
# 13 the
# 14 first
# 15 major
# 16 sport
# 17 return
# 18 on
# 19 july
# 20 with
# 21 nationally
# 22 televised
# 23 games
# 24 the
# 25 rest
# 26 of
# 27 the
# 28 teams
# 29 scheduled
# 30 start
# 3659
# 0 None
# 1 yet
# 2 no
# 3 one
# 4 denies
# 5 that
# 6 older
# 7 nuclear
# 8 plants
# 9 with
# 10 an
# 11 aged
# 12 infrastructure
# 13 often
# 14 surpassing
# 15 expected
# 16 lifetimes
# 17 are
# 18 extremely
# 19 inefficient
# 20 run
# 21 a
# 22 higher
# 23 risk
# 24 of
# 3660
# 0 None
# 1 omar
# 2 is
# 3 unashamed
# 4 about
# 5 being
# 6 linked
# 7 to
# 8 this
# 9 kind
# 10 of
# 11 hate
# 12 even
# 13 claiming
# 14 that
# 15 while
# 16 she
# 17 opposes
# 18 economic
# 19 sanctions
# 20 on
# 21 the
# 22 tyrannical
# 23 terrorist
# 24 supporting
# 25 iranian
# 26 regime
# 27 she
# 28 thinks
# 29 boycotts
# 30 of
# 31 israel
# 32 are
# 3661
# 0 None
# 1 yet
# 2 the
# 3 drumbeat
# 4 for
# 5 censorship
# 6 goes
# 7 on
# 8 as
# 9 the
# 10 politicians
# 11 whose
# 12 ideas
# 13 find
# 14 favor
# 15 with
# 16 the
# 17 mainstream
# 18 media
# 19 want
# 20 make
# 21 sure
# 22 theirs
# 23 are
# 24 the
# 25 only
# 26 ideas
# 27 you
# 28 ever
# 29 get
# 30 hear
# 31 today
# 32 it
# 33 will
# 34 be
# 35 about
# 36 money
# 37 only
# 38 because
# 39 money
# 40 is
# 41 the
# 42 means
# 43 spread
# 3662
# 0 None
# 1 yet
# 2 the
# 3 gender
# 4 ideology
# 5 is
# 6 rapidly
# 7 gaining
# 8 power
# 9 aided
# 10 by
# 11 huge
# 12 donations
# 13 from
# 14 wealthy
# 15 individuals
# 16 medical
# 3663
# 0 None
# 1 the
# 2 overwhelming
# 3 narrative
# 4 across
# 5 social
# 6 media
# 7 today
# 8 depressingly
# 9 across
# 10 much
# 11 of
# 12 the
# 13 mainstream
# 14 media
# 15 is
# 16 that
# 17 these
# 18 ugly
# 19 sinister
# 20 shows
# 21 of
# 22 force
# 23 by
# 24 the
# 25 triumphant
# 26 radical
# 27 left
# 28 are
# 29 something
# 30 almost
# 31 charming
# 32 admirable
# 33 rather
# 34 than
# 35 something
# 36 we
# 37 should
# 38 all
# 3664
# 0 None
# 1 yet
# 2 when
# 3 researchers
# 4 in
# 5 the
# 6 u.s.
# 7 have
# 8 been
# 9 so
# 10 corrupt
# 11 they
# 12 have
# 13 gone
# 14 to
# 15 jail
# 16 mainstream
# 17 scientists
# 18 still
# 19 accept
# 20 their
# 3665
# 0 None
# 1 the
# 2 trump
# 3 family
# 4 his
# 5 allies
# 6 are
# 7 evidently
# 8 using
# 9 this
# 10 national
# 11 emergency
# 12 enrich
# 3666
# 0 None
# 1 you
# 2 may
# 3 remember
# 4 that
# 5 hours
# 6 after
# 7 america
# 8 was
# 9 attacked
# 10 by
# 11 al
# 12 qaeda
# 13 on
# 14 thousands
# 15 of
# 16 muslims
# 17 regular
# 18 folks
# 19 celebrated
# 20 in
# 21 the
# 3667
# 0 None
# 1 you
# 2 may
# 3 remember
# 4 that
# 5 nbc
# 6 journalist
# 7 nancy
# 8 snyderman
# 9 broke
# 10 her
# 11 ebola
# 12 quarantine
# 13 to
# 14 the
# 15 outrage
# 16 of
# 17 her
# 3668
# 0 None
# 1 you
# 2 need
# 3 keep
# 4 a
# 5 close
# 6 eye
# 7 on
# 8 what
# 9 your
# 10 school
# 11 is
# 12 teaching
# 13 because
# 14 the
# 15 left
# 16 only
# 17 wants
# 18 teach
# 19 your
# 20 kids
# 21 engage
# 22 in
# 23 loveless
# 24 sex
# 25 the
# 26 sanctity
# 27 of
# 28 abortion
# 29 why
# 30 america
# 31 is
# 32 evil
# 33 that
# 34 men
# 35 are
# 36 women
# 37 women
# 38 are
# 39 men
# 40 that
# 41 global
# 42 warming
# 43 is
# 44 real
# 45 it
# 3669
# 0 None
# 1 you
# 2 ’ve
# 3 heard
# 4 of
# 5 jim
# 6 crow
# 7 southern
# 8 segregation
# 9 that
# 10 was
# 11 all
# 3670
# 0 None
# 1 young
# 2 female
# 3 athletes
# 4 dreams
# 5 accomplishments
# 6 have
# 7 been
# 8 dashed
# 9 across
# 10 the
# 11 country
# 12 when
# 13 competing
# 14 against
# 15 biological
# 16 males
# 17 who
# 18 identify
# 19 as
# 3671
# 0 None
# 1 young
# 2 white
# 3 men
# 4 reacting
# 5 to
# 6 social
# 7 educational
# 8 constructs
# 9 that
# 10 paint
# 11 them
# 12 as
# 13 the
# 14 embodiment
# 15 of
# 16 historical
# 17 evil
# 18 are
# 19 fertile
# 20 ground
# 21 for
# 22 white
# 3672
# 0 None
# 1 young
# 2 women
# 3 taking
# 4 part
# 5 in
# 6 high
# 7 school
# 8 college
# 9 athletics
# 10 across
# 11 the
# 12 country
# 13 have
# 14 had
# 15 their
# 16 dreams
# 17 of
# 18 winning
# 19 dashed
# 20 by
# 21 the
# 22 movement
# 23 allow
# 24 biological
# 25 male
# 26 who
# 27 identify
# 28 as
# 29 female
# 30 compete
# 31 against
# 3673
# 0 None
# 1 youtube
# 2 is
# 3 making
# 4 clear
# 5 there
# 6 will
# 7 be
# 8 no
# 9 birtherism
# 10 on
# 11 its
# 12 platform
# 13 during
# 14 this
# 15 year
# 16 u.s.
# 17 presidential
# 18 election
# 19 a
# 20 belated
# 21 response
# 22 to
# 23 a
# 24 type
# 25 of
# 26 conspiracy
# 27 theory
# 28 more
# 29 prevalent
# 30 in
# 31 the

# %%
# token in context +1 (c3)
for index, row in dt.iterrows():
    print(index)
    for i, token in enumerate(row.spacy_lg_dict):
        print(i, token['text_low_C3'])
        if token['text_low_C3'] == None:
            token['assertive_verbs_C3'] = 0
            token['factive_verbs_C3'] = 0
            token['report_verbs_C3'] = 0
            token['hedges_C3'] = 0
            token['boosters_C3'] = 0
            token['implicative_verbs_C3'] = 0
        else:
            if token['window_text'] != None and token['window_lemma'] != None:
                window_text = token['window_text']
                window_lemma = token['window_lemma']

              # 0 1 2 3 4 <5> 6 7 8
              # token['text_low_C3']
              # token['lemma_low_C3']
                # words
                c1, c2, c_m, c3, c4 = None, None, None, None, None
                if window_text[3] != None and window_text[4] != None:
                    c1 = window_text[3] + ' ' + window_text[4] + ' ' + token['text_low_C3']
                if window_text[4] != None:
                    c2 = window_text[4] + ' ' + token['text_low_C3']
                if window_text[4] != None and window_text[6] != None:
                    c_m = window_text[4] + ' ' + token['text_low_C3'] + ' ' + window_text[6]
                if window_text[6] != None:
                    c3 = token['text_low_C3'] + ' ' + window_text[6]
                if window_text[6] != None and window_text[7] != None:
                    c4 = token['text_low_C3'] + ' ' + window_text[6] + ' ' + window_text[7]

                # lemmas
                c1l, c2l, c_ml, c3l, c4l = None, None, None, None, None
                if window_lemma[3] != None and window_lemma[4] != None:
                    c1l = window_lemma[3] + ' ' + window_lemma[4] + ' ' + token['lemma_low_C3']
                if window_lemma[4] != None:
                    c2l = window_lemma[4] + ' ' + token['lemma_low_C3']
                if window_lemma[4] != None and window_lemma[6] != None:
                    c_ml = window_lemma[4] + ' ' + token['lemma_low_C3'] + ' ' + window_lemma[6]
                if window_lemma[6] != None:
                    c3l = token['lemma_low_C3'] + ' ' + window_lemma[6]
                if window_lemma[6] != None and window_text[7] != None:
                    c4l = token['lemma_low_C3'] + ' ' + window_lemma[6] + ' ' + window_lemma[7]

                # assertive verbs
                if token['text_low_C3'] in assertive_verbs or c1 in assertive_verbs or c2 in assertive_verbs or \
                c_m in assertive_verbs or c3 in assertive_verbs or c4 in assertive_verbs or \
                token['lemma_low_C3'] in assertive_verbs or c1l in assertive_verbs or c2l in assertive_verbs or \
                c_ml in assertive_verbs or c3l in assertive_verbs or c4l in assertive_verbs:
                    token['assertive_verbs_C3'] = 1
                else:
                    token['assertive_verbs_C3'] = 0   

                # factive verbs
                if token['text_low_C3'] in factive_verbs or c1 in factive_verbs or c2 in factive_verbs or \
                c_m in factive_verbs or c3 in factive_verbs or c4 in factive_verbs or \
                token['lemma_low_C3'] in factive_verbs or c1l in factive_verbs or c2l in factive_verbs or \
                c_ml in factive_verbs or c3l in factive_verbs or c4l in factive_verbs:
                    token['factive_verbs_C3'] = 1
                else:
                    token['factive_verbs_C3'] = 0   

                # report verbs
                if token['text_low_C3'] in report_verbs or c1 in report_verbs or c2 in report_verbs or \
                c_m in report_verbs or c3 in report_verbs or c4 in report_verbs or \
                token['lemma_low_C3'] in report_verbs or c1l in report_verbs or c2l in report_verbs or \
                c_ml in report_verbs or c3l in report_verbs or c4l in report_verbs:
                    token['report_verbs_C3'] = 1
                else:
                    token['report_verbs_C3'] = 0

                # hedges
                if token['text_low_C3'] in hedges or c1 in hedges or c2 in hedges or \
                c_m in hedges or c3 in hedges or c4 in hedges or \
                token['lemma_low_C3'] in hedges or c1l in hedges or c2l in hedges or \
                c_ml in hedges or c3l in hedges or c4l in hedges:
                    token['hedges_C3'] = 1
                else:
                    token['hedges_C3'] = 0

                # boosters
                if token['text_low_C3'] in boosters or c1 in boosters or c2 in boosters or \
                c_m in boosters or c3 in boosters or c4 in boosters or \
                token['lemma_low_C3'] in boosters or c1l in boosters or c2l in boosters or \
                c_ml in boosters or c3l in boosters or c4l in boosters:
                    token['boosters_C3'] = 1
                else:
                    token['boosters_C3'] = 0
                    
                # implicative verbs
                if token['text_low_C3'] in implicative_verbs or c1 in implicative_verbs or c2 in implicative_verbs or \
                c_m in implicative_verbs or c3 in implicative_verbs or c4 in implicative_verbs or \
                token['lemma_low_C3'] in implicative_verbs or c1l in implicative_verbs or c2l in implicative_verbs or \
                c_ml in implicative_verbs or c3l in implicative_verbs or c4l in implicative_verbs:
                    token['implicative_verbs_C3'] = 1
                else:
                    token['implicative_verbs_C3'] = 0

            else:
                # assertive verbs
                if token['text_low_C3'] in assertive_verbs or token['lemma_low_C3'] in assertive_verbs:
                    token['assertive_verbs_C3'] = 1
                else:
                    token['assertive_verbs_C3'] = 0 

                # factive verbs
                if token['text_low_C3'] in factive_verbs or token['lemma_low_C3'] in factive_verbs:
                    token['factive_verbs_C3'] = 1
                else:
                    token['factive_verbs_C3'] = 0   

                # report verbs
                if token['text_low_C3'] in report_verbs or token['lemma_low_C3'] in report_verbs:
                    token['report_verbs_C3'] = 1
                else:
                    token['report_verbs_C3'] = 0

                # hedges
                if token['text_low_C3'] in hedges or token['lemma_low_C3'] in hedges:
                    token['hedges_C3'] = 1
                else:
                    token['hedges_C3'] = 0

                # boosters
                if token['text_low_C3'] in boosters or token['lemma_low_C3'] in boosters:
                    token['boosters_C3'] = 1
                else:
                    token['boosters_C3'] = 0
                    
                # implicative verbs
                if token['text_low_C3'] in implicative_verbs or token['lemma_low_C3'] in implicative_verbs:
                    token['implicative_verbs_C3'] = 1
                else:
                    token['implicative_verbs_C3'] = 0
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 10 autism
# 11 as
# 12 he
# 13 did
# 14 during
# 15 the
# 16 presidential
# 17 debates
# 18 many
# 19 parents
# 20 may
# 21 choose
# 22 vaccinate
# 23 putting
# 24 children
# 25 at
# 26 unnecessary
# 27 risk
# 28 None
# 3523
# 0 a
# 1 newly
# 2 organized
# 3 vaccine
# 4 research
# 5 group
# 6 at
# 7 the
# 8 u.s.
# 9 national
# 10 institutes
# 11 of
# 12 health
# 13 nih
# 14 met
# 15 for
# 16 the
# 17 first
# 18 time
# 19 this
# 20 week
# 21 its
# 22 members
# 23 had
# 24 expected
# 25 be
# 26 able
# 27 ease
# 28 into
# 29 their
# 30 work
# 31 their
# 32 mandate
# 33 is
# 34 conduct
# 35 human
# 36 trials
# 37 for
# 38 emerging
# 39 health
# 40 threats
# 41 their
# 42 first
# 43 assignment
# 44 came
# 45 at
# 46 shocking
# 47 speed
# 48 None
# 3524
# 0 a
# 1 supporter
# 2 told
# 3 warren
# 4 public
# 5 schools
# 6 need
# 7 teach
# 8 more
# 9 about
# 10 lgbtq
# 11 history
# 12 sex
# 13 education
# 14 the
# 15 massachusetts
# 16 senator
# 17 replied
# 18 her
# 19 education
# 20 secretary
# 21 would
# 22 have
# 23 be
# 24 interviewed
# 25 by
# 26 a
# 27 transgender
# 28 child
# 29 None
# 3525
# 0 carrying
# 1 a
# 2 firearm
# 3 you
# 4 have
# 5 the
# 6 ultimate
# 7 power
# 8 of
# 9 force
# 10 in
# 11 your
# 12 control
# 13 None
# 3526
# 0 democrats
# 1 are
# 2 releasing
# 3 violent
# 4 criminals
# 5 encouraging
# 6 illegal
# 7 immigration
# 8 passing
# 9 laws
# 10 disarm
# 11 you
# 12 while
# 13 turning
# 14 the
# 15 police
# 16 into
# 17 eunuchs
# 18 it
# 19 ’s
# 20 over
# 21 None
# 3527
# 0 did
# 1 it
# 2 become
# 3 racist
# 4 like
# 5 the
# 6 national
# 7 anthem
# 8 mount
# 9 rushmore
# 10 None
# 3528
# 0 did
# 1 vaccines
# 2 become
# 3 politicized
# 4 amid
# 5 a
# 6 measles
# 7 outbreak
# 8 suddenly
# 9 republicans
# 10 support
# 11 anti
# 12 -
# 13 vaxxers
# 14 None
# 3529
# 0 far
# 1 right
# 2 white
# 3 evangelicals
# 4 white
# 5 nationalists
# 6 coronavirus
# 7 truthers
# 8 rail
# 9 against
# 10 social
# 11 distancing
# 12 encourage
# 13 large
# 14 gatherings
# 15 they
# 16 are
# 17 encouraging
# 18 suicidal
# 19 behavior
# 20 there
# 21 have
# 22 been
# 23 many
# 24 examples
# 25 None
# 3530
# 0 greed
# 1 power
# 2 are
# 3 exercised
# 4 by
# 5 giant
# 6 multinational
# 7 corporations
# 8 that
# 9 escape
# 10 the
# 11 discipline
# 12 of
# 13 the
# 14 nation
# 15 state
# 16 the
# 17 potential
# 18 for
# 19 evil
# 20 becomes
# 21 infinite
# 22 in
# 23 nature
# 24 None
# 3531
# 0 he
# 1 finally
# 2 spoke
# 3 in
# 4 the
# 5 rose
# 6 garden
# 7 on
# 8 monday
# 9 trump
# 10 threatened
# 11 deploy
# 12 the
# 13 military
# 14 against
# 15 american
# 16 citizens
# 17 if
# 18 the
# 19 governors
# 20 did
# 21 take
# 22 his
# 23 advice
# 24 for
# 25 a
# 26 more
# 27 forceful
# 28 crackdown
# 29 this
# 30 threat
# 31 did
# 32 appear
# 33 cow
# 34 anyone
# 35 only
# 36 increased
# 37 the
# 38 anger
# 39 None
# 3532
# 0 i
# 1 opened
# 2 britain
# 3 bestselling
# 4 tabloid
# 5 conservative
# 6 sunday
# 7 newspaper
# 8 i
# 9 was
# 10 greeted
# 11 by
# 12 a
# 13 double
# 14 page
# 15 spread
# 16 showing
# 17 a
# 18 vast
# 19 mob
# 20 of
# 21 black
# 22 lives
# 23 matter
# 24 activists
# 25 marching
# 26 on
# 27 downing
# 28 street
# 29 in
# 30 london
# 31 None
# 3533
# 0 it
# 1 comes
# 2 to
# 3 the
# 4 green
# 5 new
# 6 deal
# 7 blueprint
# 8 address
# 9 the
# 10 climate
# 11 crisis
# 12 republicans
# 13 generally
# 14 like
# 15 pretend
# 16 it
# 17 calls
# 18 for
# 19 the
# 20 elimination
# 21 of
# 22 hamburgers
# 23 None
# 3534
# 0 mexico
# 1 leader
# 2 enters
# 3 the
# 4 white
# 5 house
# 6 meet
# 7 president
# 8 donald
# 9 trump
# 10 on
# 11 wednesday
# 12 he
# 13 will
# 14 do
# 15 so
# 16 only
# 17 as
# 18 a
# 19 hostage
# 20 to
# 21 the
# 22 whims
# 23 of
# 24 his
# 25 u.s.
# 26 counterpart
# 27 also
# 28 as
# 29 partner
# 30 in
# 31 an
# 32 unlikely
# 33 alliance
# 34 that
# 35 has
# 36 benefited
# 37 both
# 38 men
# 39 None
# 3535
# 0 parents
# 1 borrow
# 2 the
# 3 debt
# 4 can
# 5 weigh
# 6 down
# 7 families
# 8 for
# 9 generations
# 10 the
# 11 burden
# 12 falls
# 13 particularly
# 14 hard
# 15 on
# 16 low
# 17 income
# 18 black
# 19 families
# 20 None
# 3536
# 0 president
# 1 trump
# 2 rolled
# 3 out
# 4 his
# 5 recent
# 6 budget
# 7 proposal
# 8 it
# 9 made
# 10 some
# 11 cuts
# 12 that
# 13 were
# 14 always
# 15 going
# 16 cause
# 17 controversy
# 18 for
# 19 thing
# 20 his
# 21 plan
# 22 would
# 23 slash
# 24 subsidized
# 25 student
# 26 loan
# 27 repayment
# 28 plans
# 29 let
# 30 the
# 31 government
# 32 crack
# 33 down
# 34 on
# 35 missed
# 36 payments
# 37 None
# 3537
# 0 prioritizing
# 1 healthcare
# 2 workers
# 3 the
# 4 panel
# 5 noted
# 6 that
# 7 vaccines
# 8 should
# 9 go
# 10 first
# 11 to
# 12 people
# 13 who
# 14 have
# 15 the
# 16 most
# 17 contact
# 18 with
# 19 patients
# 20 None
# 3538
# 0 republicans
# 1 warned
# 2 democrats
# 3 that
# 4 impeachment
# 5 was
# 6 a
# 7 waste
# 8 of
# 9 time
# 10 a
# 11 divisive
# 12 partisan
# 13 exercise
# 14 a
# 15 distraction
# 16 from
# 17 the
# 18 real
# 19 issues
# 20 facing
# 21 the
# 22 country
# 23 a
# 24 lesson
# 25 republicans
# 26 learned
# 27 the
# 28 hard
# 29 way
# 30 in
# 31 bill
# 32 clinton
# 33 impeachment
# 34 years
# 35 before
# 36 democrats
# 37 ignored
# 38 them
# 39 None
# 3539
# 0 the
# 1 left
# 2 is
# 3 emboldened
# 4 cities
# 5 burn
# 6 statues
# 7 topple
# 8 careers
# 9 people
# 10 are
# 11 disappeared
# 12 good
# 13 men
# 14 are
# 15 murdered
# 16 civil
# 17 liberties
# 18 are
# 19 trampled
# 20 the
# 21 dual
# 22 horrors
# 23 of
# 24 blacklisting
# 25 censorship
# 26 reign
# 27 supreme
# 28 None
# 3540
# 0 the
# 1 men
# 2 basketball
# 3 final
# 4 four
# 5 tips
# 6 off
# 7 saturday
# 8 in
# 9 minneapolis
# 10 the
# 11 ncaa
# 12 biggest
# 13 most
# 14 lucrative
# 15 event
# 16 will
# 17 proceed
# 18 as
# 19 it
# 20 normally
# 21 does
# 22 the
# 23 athletes
# 24 on
# 25 the
# 26 floor
# 27 for
# 28 virginia
# 29 auburn
# 30 michigan
# 31 state
# 32 texas
# 33 tech
# 34 will
# 35 play
# 36 games
# 37 that
# 38 generate
# 39 hundreds
# 40 of
# 41 millions
# 42 of
# 43 dollars
# 44 in
# 45 total
# 46 revenue
# 47 for
# 48 their
# 49 schools
# 50 the
# 51 ncaa
# 52 broadcast
# 53 companies
# 54 the
# 55 coaches
# 56 athletic
# 57 directors
# 58 tv
# 59 executives
# 60 ncaa
# 61 suits
# 62 will
# 63 share
# 64 in
# 65 the
# 66 riches
# 67 athletes
# 68 themselves
# 69 still
# 70 wo
# 71 receive
# 72 their
# 73 fair
# 74 share
# 75 thanks
# 76 to
# 77 a
# 78 recent
# 79 federal
# 80 court
# 81 decision
# 82 that
# 83 wo
# 84 change
# 85 in
# 86 the
# 87 immediate
# 88 future
# 89 None
# 3541
# 0 the
# 1 muslim
# 2 ban
# 3 was
# 4 first
# 5 enacted
# 6 it
# 7 triggered
# 8 chaos
# 9 at
# 10 airports
# 11 prompted
# 12 widespread
# 13 protest
# 14 legal
# 15 challenges
# 16 it
# 17 continues
# 18 impose
# 19 devastating
# 20 costs
# 21 on
# 22 families
# 23 people
# 24 who
# 25 wish
# 26 come
# 27 to
# 28 the
# 29 u.s.
# 30 None
# 3542
# 0 the
# 1 nation
# 2 highest
# 3 civilian
# 4 honor
# 5 went
# 6 to
# 7 a
# 8 right
# 9 wing
# 10 media
# 11 personality
# 12 it
# 13 served
# 14 as
# 15 an
# 16 oddly
# 17 appropriate
# 18 capstone
# 19 to
# 20 trump
# 21 broader
# 22 goals
# 23 None
# 3543
# 0 trump
# 1 entered
# 2 the
# 3 white
# 4 house
# 5 in
# 6 lopez
# 7 obrador
# 8 likened
# 9 the
# 10 american
# 11 to
# 12 adolf
# 13 hitler
# 14 for
# 15 his
# 16 attitude
# 17 toward
# 18 migrants
# 19 None
# 3544
# 0 sadists
# 1 in
# 2 uniform
# 3 shoved
# 4 an
# 5 elderly
# 6 man
# 7 to
# 8 the
# 9 ground
# 10 for
# 11 the
# 12 crime
# 13 of
# 14 approaching
# 15 them
# 16 causing
# 17 him
# 18 a
# 19 critical
# 20 head
# 21 injury
# 22 their
# 23 fellow
# 24 cops
# 25 made
# 26 no
# 27 attempt
# 28 help
# 29 the
# 30 victim
# 31 None
# 3545
# 0 u.s.
# 1 schools
# 2 begin
# 3 the
# 4 next
# 5 academic
# 6 year
# 7 with
# 8 the
# 9 country
# 10 still
# 11 fighting
# 12 the
# 13 coronavirus
# 14 pandemic
# 15 students
# 16 should
# 17 spend
# 18 half
# 19 their
# 20 time
# 21 in
# 22 classrooms
# 23 half
# 24 doing
# 25 online
# 26 activities
# 27 that
# 28 pinpoint
# 29 their
# 30 individual
# 31 learning
# 32 style
# 33 such
# 34 as
# 35 videos
# 36 reading
# 37 None
# 3546
# 0 it
# 1 is
# 2 due
# 3 to
# 4 gaffes
# 5 his
# 6 inability
# 7 complete
# 8 some
# 9 sentences
# 10 lack
# 11 of
# 12 knowledge
# 13 on
# 14 a
# 15 subject
# 16 biden
# 17 has
# 18 proven
# 19 that
# 20 interviews
# 21 are
# 22 for
# 23 him
# 24 the
# 25 media
# 26 has
# 27 covered
# 28 accordingly
# 29 None
# 3547
# 0 you
# 1 find
# 2 trump
# 3 buffoonery
# 4 utterly
# 5 disgraceful
# 6 a
# 7 sign
# 8 of
# 9 authenticity
# 10 may
# 11 mark
# 12 our
# 13 central
# 14 political
# 15 divide
# 16 today
# 17 None
# 3548
# 0 is
# 1 why
# 2 republicans
# 3 like
# 4 mcconnell
# 5 complaining
# 6 about
# 7 federal
# 8 entitlements
# 9 is
# 10 so
# 11 laughable
# 12 None
# 3549
# 0 a
# 1 number
# 2 of
# 3 transgender
# 4 advocates
# 5 lgbtq
# 6 health
# 7 experts
# 8 applauded
# 9 p&g
# 10 decision
# 11 redesign
# 12 the
# 13 always
# 14 packaging
# 15 by
# 16 removing
# 17 the
# 18 female
# 19 signs
# 20 the
# 21 company
# 22 announcement
# 23 sparked
# 24 criticism
# 25 online
# 26 including
# 27 a
# 28 bounty
# 29 of
# 30 transphobic
# 31 commentary
# 32 None
# 3550
# 0 americans
# 1 still
# 2 cling
# 3 to
# 4 sexist
# 5 gender
# 6 roles
# 7 at
# 8 home
# 9 overwhelming
# 10 majorities
# 11 believe
# 12 that
# 13 sex
# 14 discrimination
# 15 in
# 16 public
# 17 spaces
# 18 should
# 19 be
# 20 illegal
# 21 None
# 3551
# 0 barr
# 1 republican
# 2 president
# 3 donald
# 4 trump
# 5 have
# 6 focused
# 7 blame
# 8 on
# 9 antifa
# 10 a
# 11 loosely
# 12 organized
# 13 anti
# 14 -
# 15 fascist
# 16 movement
# 17 federal
# 18 prosecutors
# 19 in
# 20 las
# 21 vegas
# 22 on
# 23 wednesday
# 24 charged
# 25 members
# 26 of
# 27 the
# 28 far
# 29 right
# 30 boogaloo
# 31 movement
# 32 with
# 33 planning
# 34 cause
# 35 violence
# 36 destruction
# 37 during
# 38 protests
# 39 None
# 3552
# 0 brazil
# 1 has
# 2 taken
# 3 the
# 4 lead
# 5 in
# 6 a
# 7 direct
# 8 attack
# 9 on
# 10 the
# 11 amazon
# 12 with
# 13 bolsonaro
# 14 adding
# 15 a
# 16 racial
# 17 element
# 18 to
# 19 his
# 20 attack
# 21 on
# 22 indigenous
# 23 people
# 24 the
# 25 pressure
# 26 open
# 27 the
# 28 amazonian
# 29 forests
# 30 to
# 31 agriculture
# 32 logging
# 33 mining
# 34 is
# 35 just
# 36 limited
# 37 to
# 38 brazil
# 39 None
# 3553
# 0 conservatives
# 1 may
# 2 find
# 3 comfort
# 4 in
# 5 the
# 6 old
# 7 saw
# 8 that
# 9 those
# 10 who
# 11 are
# 12 liberal
# 13 at
# 14 have
# 15 no
# 16 heart
# 17 those
# 18 who
# 19 are
# 20 conservative
# 21 at
# 22 have
# 23 no
# 24 brain
# 25 the
# 26 truth
# 27 as
# 28 levin
# 29 knows
# 30 is
# 31 that
# 32 those
# 33 who
# 34 are
# 35 statists
# 36 at
# 37 usually
# 38 end
# 39 up
# 40 statists
# 41 at
# 42 he
# 43 ’s
# 44 content
# 45 allow
# 46 time
# 47 take
# 48 its
# 49 uncertain
# 50 political
# 51 toll
# 52 None
# 3554
# 0 corporate
# 1 media
# 2 hypocritical
# 3 politicians
# 4 others
# 5 labeled
# 6 anyone
# 7 in
# 8 favor
# 9 of
# 10 reopening
# 11 the
# 12 economy
# 13 getting
# 14 kids
# 15 back
# 16 in
# 17 school
# 18 even
# 19 gathering
# 20 for
# 21 holidays
# 22 a
# 23 grandma
# 24 killer
# 25 expert
# 26 in
# 27 ethics
# 28 health
# 29 policy
# 30 in
# 31 the
# 32 new
# 33 york
# 34 times
# 35 says
# 36 that
# 37 vaccinating
# 38 elderly
# 39 people
# 40 first
# 41 is
# 42 racist
# 43 None
# 3555
# 0 democrat
# 1 presidential
# 2 hopefuls
# 3 aim
# 4 weaponize
# 5 the
# 6 tax
# 7 cuts
# 8 elaine
# 9 parker
# 10 chief
# 11 communications
# 12 officer
# 13 of
# 14 job
# 15 creators
# 16 network
# 17 jcn
# 18 told
# 19 breitbart
# 20 news
# 21 in
# 22 an
# 23 exclusive
# 24 interview
# 25 in
# 26 january
# 27 that
# 28 it
# 29 is
# 30 precisely
# 31 what
# 32 will
# 33 assist
# 34 trump
# 35 in
# 36 making
# 37 his
# 38 case
# 39 to
# 40 the
# 41 american
# 42 people
# 43 None
# 3556
# 0 democrats
# 1 were
# 2 busy
# 3 diverting
# 4 the
# 5 attention
# 6 energy
# 7 of
# 8 the
# 9 entire
# 10 country
# 11 into
# 12 a
# 13 pointless
# 14 trial
# 15 that
# 16 could
# 17 possibly
# 18 have
# 19 ended
# 20 in
# 21 anything
# 22 other
# 23 than
# 24 president
# 25 donald
# 26 trump
# 27 acquittal
# 28 None
# 3557
# 0 democrats
# 1 were
# 2 diverting
# 3 the
# 4 attention
# 5 energy
# 6 of
# 7 the
# 8 entire
# 9 country
# 10 into
# 11 a
# 12 pointless
# 13 trial
# 14 that
# 15 could
# 16 possibly
# 17 have
# 18 ended
# 19 in
# 20 anything
# 21 other
# 22 than
# 23 president
# 24 donald
# 25 trump
# 26 acquittal
# 27 None
# 3558
# 0 democrats
# 1 were
# 2 persistent
# 3 in
# 4 their
# 5 questioning
# 6 the
# 7 hearing
# 8 retained
# 9 a
# 10 respectful
# 11 tone
# 12 barrett
# 13 remained
# 14 even
# 15 tempered
# 16 while
# 17 nimbly
# 18 sidestepping
# 19 questions
# 20 on
# 21 her
# 22 views
# 23 on
# 24 abortion
# 25 lgbt
# 26 rights
# 27 gun
# 28 control
# 29 voting
# 30 rights
# 31 None
# 3559
# 0 each
# 1 sport
# 2 has
# 3 its
# 4 own
# 5 rules
# 6 with
# 7 regards
# 8 to
# 9 religious
# 10 headwear
# 11 muslim
# 12 women
# 13 who
# 14 compete
# 15 while
# 16 wearing
# 17 a
# 18 hijab
# 19 have
# 20 faced
# 21 a
# 22 litany
# 23 of
# 24 obstacles
# 25 None
# 3560
# 0 emphasizing
# 1 he
# 2 ’s
# 3 singling
# 4 out
# 5 party
# 6 cohen
# 7 warned
# 8 about
# 9 the
# 10 danger
# 11 of
# 12 normalizing
# 13 white
# 14 supremacist
# 15 ideology
# 16 None
# 3561
# 0 falling
# 1 short
# 2 of
# 3 calling
# 4 half
# 5 the
# 6 nation
# 7 deplorable
# 8 as
# 9 former
# 10 secretary
# 11 of
# 12 state
# 13 hillary
# 14 clinton
# 15 did
# 16 in
# 17 the
# 18 comments
# 19 echo
# 20 a
# 21 deep
# 22 disdain
# 23 for
# 24 a
# 25 large
# 26 population
# 27 of
# 28 the
# 29 country
# 30 increasingly
# 31 perpetuated
# 32 by
# 33 left
# 34 wing
# 35 elites
# 36 in
# 37 the
# 38 wake
# 39 of
# 40 the
# 41 george
# 42 floyd
# 43 protests
# 44 characterizing
# 45 the
# 46 u.s.
# 47 as
# 48 irredeemably
# 49 racist
# 50 None
# 3562
# 0 health
# 1 experts
# 2 say
# 3 a
# 4 vaccine
# 5 prevent
# 6 infection
# 7 is
# 8 needed
# 9 return
# 10 life
# 11 to
# 12 normal
# 13 the
# 14 survey
# 15 points
# 16 to
# 17 a
# 18 potential
# 19 trust
# 20 issue
# 21 for
# 22 the
# 23 trump
# 24 administration
# 25 already
# 26 under
# 27 fire
# 28 for
# 29 its
# 30 often
# 31 contradictory
# 32 safety
# 33 guidance
# 34 during
# 35 the
# 36 pandemic
# 37 None
# 3563
# 0 his
# 1 supporters
# 2 have
# 3 included
# 4 many
# 5 strains
# 6 of
# 7 nationalism
# 8 populism
# 9 he
# 10 did
# 11 run
# 12 as
# 13 a
# 14 republican
# 15 this
# 16 will
# 17 hopefully
# 18 work
# 19 in
# 20 his
# 21 favor
# 22 many
# 23 americans
# 24 are
# 25 hopeful
# 26 excited
# 27 looking
# 28 forward
# 29 to
# 30 a
# 31 trump
# 32 presidency
# 33 here
# 34 are
# 35 some
# 36 of
# 37 the
# 38 reasons
# 39 why
# 40 None
# 3564
# 0 it
# 1 ’s
# 2 perfectly
# 3 evident
# 4 that
# 5 trump
# 6 does
# 7 have
# 8 racist
# 9 supporters
# 10 which
# 11 he
# 12 is
# 13 suspiciously
# 14 reluctant
# 15 condemn
# 16 many
# 17 contend
# 18 that
# 19 trumpism
# 20 is
# 21 itself
# 22 racist
# 23 merely
# 24 a
# 25 justified
# 26 reaction
# 27 to
# 28 the
# 29 left
# 30 racial
# 31 patronage
# 32 None
# 3565
# 0 lecturing
# 1 americans
# 2 on
# 3 racism
# 4 big
# 5 business
# 6 opposes
# 7 ban
# 8 on
# 9 using
# 10 foreign
# 11 slave
# 12 labor
# 13 None
# 3566
# 0 low
# 1 unemployment
# 2 steadily
# 3 if
# 4 slowly
# 5 rising
# 6 wages
# 7 have
# 8 improved
# 9 the
# 10 fortunes
# 11 of
# 12 lower
# 13 income
# 14 americans
# 15 these
# 16 gains
# 17 pale
# 18 in
# 19 comparison
# 20 to
# 21 the
# 22 investment
# 23 gains
# 24 realized
# 25 by
# 26 the
# 27 wealthy
# 28 few
# 29 None
# 3567
# 0 many
# 1 things
# 2 were
# 3 certain
# 4 change
# 5 the
# 6 president
# 7 felt
# 8 sure
# 9 that
# 10 element
# 11 of
# 12 continuity
# 13 would
# 14 persist
# 15 the
# 16 united
# 17 states
# 18 would
# 19 determine
# 20 history
# 21 onward
# 22 course
# 23 None
# 3568
# 0 many
# 1 women
# 2 the
# 3 men
# 4 who
# 5 love
# 6 them
# 7 are
# 8 well
# 9 aware
# 10 that
# 11 spurred
# 12 on
# 13 by
# 14 the
# 15 vatican
# 16 united
# 17 states
# 18 conference
# 19 of
# 20 catholic
# 21 bishops
# 22 usccb
# 23 the
# 24 so
# 25 called
# 26 personhood
# 27 movement
# 28 republicans
# 29 are
# 30 working
# 31 feverishly
# 32 eradicate
# 33 women
# 34 reproductive
# 35 rights
# 36 None
# 3569
# 0 most
# 1 national
# 2 attention
# 3 has
# 4 been
# 5 focused
# 6 on
# 7 massive
# 8 demonstrations
# 9 violent
# 10 clashes
# 11 with
# 12 police
# 13 in
# 14 the
# 15 united
# 16 states
# 17 biggest
# 18 cities
# 19 like
# 20 new
# 21 york
# 22 los
# 23 angeles
# 24 hundreds
# 25 of
# 26 spontaneous
# 27 demonstrations
# 28 have
# 29 popped
# 30 up
# 31 in
# 32 little
# 33 towns
# 34 rural
# 35 areas
# 36 across
# 37 the
# 38 nation
# 39 in
# 40 recent
# 41 days
# 42 None
# 3570
# 0 no
# 1 one
# 2 is
# 3 praising
# 4 trump
# 5 as
# 6 a
# 7 thought
# 8 leader
# 9 in
# 10 the
# 11 way
# 12 limbaugh
# 13 has
# 14 been
# 15 he
# 16 ’s
# 17 undeniably
# 18 made
# 19 conservative
# 20 ideas
# 21 tangible
# 22 for
# 23 average
# 24 americans
# 25 None
# 3571
# 0 nyc
# 1 has
# 2 largely
# 3 tamed
# 4 the
# 5 lethal
# 6 highly
# 7 contagious
# 8 coronavirus
# 9 another
# 10 epidemic
# 11 is
# 12 starting
# 13 rear
# 14 its
# 15 ugly
# 16 head
# 17 in
# 18 the
# 19 city
# 20 once
# 21 again
# 22 violent
# 23 crimes
# 24 None
# 3572
# 0 omar
# 1 is
# 2 in
# 3 no
# 4 danger
# 5 of
# 6 being
# 7 held
# 8 accountable
# 9 for
# 10 her
# 11 extremism
# 12 her
# 13 ascent
# 14 to
# 15 rock
# 16 star
# 17 status
# 18 among
# 19 democrats
# 20 their
# 21 media
# 22 cheering
# 23 section
# 24 gives
# 25 the
# 26 lie
# 27 to
# 28 their
# 29 claims
# 30 be
# 31 standing
# 32 up
# 33 against
# 34 hate
# 35 antisemitism
# 36 None
# 3573
# 0 opportunity
# 1 zone
# 2 program
# 3 that
# 4 offers
# 5 tax
# 6 breaks
# 7 to
# 8 investors
# 9 who
# 10 put
# 11 money
# 12 into
# 13 specially
# 14 designated
# 15 areas
# 16 was
# 17 pitched
# 18 as
# 19 a
# 20 way
# 21 help
# 22 struggling
# 23 neighborhoods
# 24 propublica
# 25 others
# 26 have
# 27 documented
# 28 how
# 29 the
# 30 process
# 31 has
# 32 appeared
# 33 benefit
# 34 billionaires
# 35 with
# 36 investments
# 37 in
# 38 areas
# 39 that
# 40 should
# 41 have
# 42 qualified
# 43 None
# 3574
# 0 pace
# 1 receives
# 2 her
# 3 spiritual
# 4 grace
# 5 from
# 6 a
# 7 christian
# 8 god
# 9 science
# 10 has
# 11 shown
# 12 that
# 13 faith
# 14 in
# 15 a
# 16 supernatural
# 17 wonder
# 18 whatever
# 19 it
# 20 may
# 21 be
# 22 that
# 23 bears
# 24 powerful
# 25 benefits
# 26 on
# 27 an
# 28 individual
# 29 mental
# 30 even
# 31 physical
# 32 well
# 33 being
# 34 None
# 3575
# 0 pence
# 1 the
# 2 president
# 3 have
# 4 tried
# 5 paint
# 6 a
# 7 rosier
# 8 picture
# 9 of
# 10 the
# 11 virus
# 12 project
# 13 a
# 14 return
# 15 to
# 16 normalcy
# 17 some
# 18 members
# 19 of
# 20 the
# 21 task
# 22 force
# 23 are
# 24 eager
# 25 resume
# 26 appearances
# 27 from
# 28 white
# 29 house
# 30 grounds
# 31 None
# 3576
# 0 president
# 1 donald
# 2 trump
# 3 impeachment
# 4 trial
# 5 had
# 6 been
# 7 wrapping
# 8 up
# 9 he
# 10 expanded
# 11 of
# 12 his
# 13 most
# 14 controversial
# 15 inflammatory
# 16 policies
# 17 with
# 18 little
# 19 fanfare
# 20 minimal
# 21 opposition
# 22 the
# 23 travel
# 24 ban
# 25 on
# 26 people
# 27 from
# 28 multiple
# 29 muslim
# 30 majority
# 31 countries
# 32 None
# 3577
# 0 president
# 1 trump
# 2 visited
# 3 the
# 4 southern
# 5 border
# 6 thursday
# 7 democratic
# 8 darling
# 9 beto
# 10 o’rourke
# 11 visited
# 12 the
# 13 dentist
# 14 posting
# 15 a
# 16 bizarre
# 17 video
# 18 showing
# 19 him
# 20 getting
# 21 a
# 22 mouth
# 23 wide
# 24 open
# 25 cleaning
# 26 in
# 27 order
# 28 highlight
# 29 the
# 30 story
# 31 of
# 32 his
# 33 dental
# 34 hygienist
# 35 ’s
# 36 upbringing
# 37 in
# 38 el
# 39 paso
# 40 None
# 3578
# 0 riots
# 1 raged
# 2 across
# 3 the
# 4 united
# 5 states
# 6 over
# 7 floyd
# 8 death
# 9 editors
# 10 on
# 11 wikipedia
# 12 promptly
# 13 set
# 14 out
# 15 spin
# 16 the
# 17 narrative
# 18 of
# 19 the
# 20 unrest
# 21 against
# 22 trump
# 23 None
# 3579
# 0 sexual
# 1 ambiguity
# 2 does
# 3 occasionally
# 4 occur
# 5 the
# 6 authors
# 7 note
# 8 intersex
# 9 individuals
# 10 are
# 11 extremely
# 12 rare
# 13 they
# 14 are
# 15 a
# 16 third
# 17 sex
# 18 proof
# 19 that
# 20 sex
# 21 is
# 22 a
# 23 spectrum
# 24 a
# 25 social
# 26 construct
# 27 None
# 3580
# 0 snapchat
# 1 is
# 2 happy
# 3 blame
# 4 president
# 5 trump
# 6 who
# 7 is
# 8 working
# 9 restore
# 10 order
# 11 for
# 12 the
# 13 ongoing
# 14 violence
# 15 it
# 16 has
# 17 said
# 18 anything
# 19 about
# 20 support
# 21 for
# 22 the
# 23 domestic
# 24 terrorist
# 25 antifa
# 26 movement
# 27 on
# 28 its
# 29 platform
# 30 None
# 3581
# 0 the
# 1 announcement
# 2 identifies
# 3 cases
# 4 of
# 5 alleged
# 6 police
# 7 misconduct
# 8 it
# 9 does
# 10 mention
# 11 violence
# 12 accompanying
# 13 the
# 14 protests
# 15 over
# 16 floyd
# 17 death
# 18 that
# 19 the
# 20 foundation
# 21 is
# 22 now
# 23 backing
# 24 None
# 3582
# 0 the
# 1 major
# 2 baseball
# 3 leagues
# 4 wo
# 5 be
# 6 affected
# 7 much
# 8 by
# 9 tariffs
# 10 on
# 11 chinese
# 12 imports
# 13 everyone
# 14 from
# 15 double
# 16 a
# 17 players
# 18 down
# 19 through
# 20 the
# 21 office
# 22 softball
# 23 team
# 24 will
# 25 be
# 26 None
# 3583
# 0 the
# 1 majority
# 2 of
# 3 americans
# 4 seem
# 5 accept
# 6 scientific
# 7 information
# 8 about
# 9 the
# 10 deadly
# 11 coronavirus
# 12 are
# 13 wary
# 14 of
# 15 reopening
# 16 the
# 17 country
# 18 before
# 19 we
# 20 can
# 21 be
# 22 sure
# 23 it
# 24 ’s
# 25 safe
# 26 segment
# 27 of
# 28 the
# 29 population
# 30 is
# 31 driving
# 32 the
# 33 opposite
# 34 narrative
# 35 this
# 36 group
# 37 is
# 38 small
# 39 vocal
# 40 represents
# 41 a
# 42 predictable
# 43 if
# 44 threatening
# 45 merging
# 46 of
# 47 forces
# 48 None
# 3584
# 0 the
# 1 mayor
# 2 has
# 3 severely
# 4 curtailed
# 5 religious
# 6 practice
# 7 in
# 8 the
# 9 city
# 10 he
# 11 has
# 12 defended
# 13 the
# 14 rights
# 15 of
# 16 citizens
# 17 form
# 18 huge
# 19 gatherings
# 20 protest
# 21 even
# 22 violently
# 23 obviously
# 24 without
# 25 social
# 26 distancing
# 27 masks
# 28 except
# 29 perhaps
# 30 antifa
# 31 masks
# 32 None
# 3585
# 0 the
# 1 overwhelming
# 2 majority
# 3 of
# 4 americans
# 5 choose
# 6 have
# 7 their
# 8 children
# 9 vaccinated
# 10 the
# 11 number
# 12 of
# 13 children
# 14 who
# 15 go
# 16 completely
# 17 unvaccinated
# 18 is
# 19 rising
# 20 None
# 3586
# 0 the
# 1 piece
# 2 fairly
# 3 analyzes
# 4 the
# 5 fracturing
# 6 of
# 7 the
# 8 white
# 9 nationalist
# 10 movement
# 11 it
# 12 makes
# 13 the
# 14 bizarre
# 15 claim
# 16 that
# 17 ideas
# 18 that
# 19 are
# 20 widely
# 21 popular
# 22 amongst
# 23 mainstream
# 24 conservatives
# 25 such
# 26 as
# 27 ending
# 28 affirmative
# 29 action
# 30 are
# 31 actually
# 32 white
# 33 nationalist
# 34 in
# 35 origin
# 36 None
# 3587
# 0 the
# 1 press
# 2 had
# 3 no
# 4 problem
# 5 regurgitating
# 6 the
# 7 propaganda
# 8 ben
# 9 rhodes
# 10 created
# 11 in
# 12 the
# 13 d.c.
# 14 echo
# 15 chamber
# 16 sell
# 17 president
# 18 obama
# 19 disastrous
# 20 iran
# 21 deal
# 22 with
# 23 trump
# 24 corporate
# 25 media
# 26 has
# 27 opted
# 28 limit
# 29 coverage
# 30 of
# 31 iran
# 32 horrific
# 33 human
# 34 rights
# 35 abuses
# 36 None
# 3588
# 0 the
# 1 stupid
# 2 democrats
# 3 who
# 4 vote
# 5 for
# 6 democrats
# 7 stress
# 8 worry
# 9 about
# 10 another
# 11 round
# 12 of
# 13 looting
# 14 burning
# 15 this
# 16 weekend
# 17 in
# 18 their
# 19 democrat
# 20 run
# 21 cities
# 22 all
# 23 i
# 24 ’m
# 25 worried
# 26 about
# 27 is
# 28 the
# 29 weather
# 30 None
# 3589
# 0 the
# 1 threat
# 2 of
# 3 anti
# 4 -
# 5 trans
# 6 bills
# 7 being
# 8 passed
# 9 into
# 10 law
# 11 is
# 12 real
# 13 present
# 14 all
# 15 such
# 16 legislation
# 17 will
# 18 almost
# 19 certainly
# 20 be
# 21 challenged
# 22 in
# 23 the
# 24 courts
# 25 immediately
# 26 upon
# 27 passing
# 28 before
# 29 it
# 30 can
# 31 be
# 32 fully
# 33 implemented
# 34 None
# 3590
# 0 the
# 1 workaday
# 2 majority
# 3 of
# 4 americans
# 5 continue
# 6 be
# 7 mired
# 8 in
# 9 our
# 10 low
# 11 wage
# 12 economy
# 13 the
# 14 precious
# 15 few
# 16 at
# 17 the
# 18 tippy
# 19 top
# 20 soared
# 21 out
# 22 of
# 23 sight
# 24 in
# 25 None
# 3591
# 0 these
# 1 many
# 2 similarities
# 3 between
# 4 green
# 5 new
# 6 deal
# 7 the
# 8 constitution
# 9 ushered
# 10 in
# 11 by
# 12 venezuelan
# 13 leftist
# 14 dictator
# 15 hugo
# 16 chavez
# 17 in
# 18 may
# 19 be
# 20 just
# 21 happenstance
# 22 the
# 23 important
# 24 thing
# 25 remember
# 26 is
# 27 that
# 28 venezuela
# 29 under
# 30 its
# 31 new
# 32 constitution
# 33 has
# 34 become
# 35 a
# 36 disaster
# 37 zone
# 38 None
# 3592
# 0 trump
# 1 has
# 2 stopped
# 3 short
# 4 of
# 5 invoking
# 6 the
# 7 act
# 8 use
# 9 the
# 10 military
# 11 enforce
# 12 laws
# 13 domestically
# 14 he
# 15 ’s
# 16 kept
# 17 the
# 18 option
# 19 open
# 20 fomenting
# 21 further
# 22 unrest
# 23 division
# 24 rather
# 25 than
# 26 staging
# 27 photo
# 28 opportunities
# 29 while
# 30 awkwardly
# 31 holding
# 32 a
# 33 bible
# 34 in
# 35 lafayette
# 36 square
# 37 trump
# 38 would
# 39 have
# 40 issued
# 41 a
# 42 formal
# 43 proclamation
# 44 calling
# 45 on
# 46 the
# 47 insurgents
# 48 disperse
# 49 if
# 50 he
# 51 ’s
# 52 serious
# 53 about
# 54 the
# 55 application
# 56 of
# 57 the
# 58 insurrection
# 59 act
# 60 None
# 3593
# 0 in
# 1 the
# 2 wake
# 3 of
# 4 the
# 5 el
# 6 paso
# 7 murders
# 8 the
# 9 media
# 10 most
# 11 of
# 12 our
# 13 politicians
# 14 are
# 15 acting
# 16 shocked
# 17 that
# 18 there
# 19 are
# 20 armed
# 21 racists
# 22 in
# 23 america
# 24 who
# 25 are
# 26 trying
# 27 terrify
# 28 people
# 29 of
# 30 color
# 31 the
# 32 reality
# 33 is
# 34 that
# 35 it
# 36 ’s
# 37 pretty
# 38 much
# 39 always
# 40 been
# 41 that
# 42 way
# 43 here
# 44 in
# 45 the
# 46 united
# 47 states
# 48 None
# 3594
# 0 in
# 1 the
# 2 wake
# 3 of
# 4 the
# 5 el
# 6 paso
# 7 murders
# 8 the
# 9 media
# 10 most
# 11 of
# 12 our
# 13 politicians
# 14 are
# 15 acting
# 16 shocked—“shocked
# 17 i
# 18 tell
# 19 you!”—that
# 20 there
# 21 are
# 22 armed
# 23 racists
# 24 in
# 25 america
# 26 who
# 27 are
# 28 trying
# 29 terrify
# 30 people
# 31 of
# 32 color
# 33 the
# 34 reality
# 35 is
# 36 that
# 37 it
# 38 ’s
# 39 pretty
# 40 much
# 41 always
# 42 been
# 43 that
# 44 way
# 45 here
# 46 in
# 47 the
# 48 united
# 49 states
# 50 None
# 3595
# 0 house
# 1 national
# 2 economic
# 3 council
# 4 director
# 5 larry
# 6 kudlow
# 7 said
# 8 on
# 9 friday
# 10 that
# 11 he
# 12 did
# 13 favor
# 14 a
# 15 higher
# 16 federal
# 17 tax
# 18 on
# 19 gasoline
# 20 fund
# 21 an
# 22 infrastructure
# 23 program
# 24 if
# 25 states
# 26 wanted
# 27 raise
# 28 their
# 29 own
# 30 gas
# 31 taxes
# 32 that
# 33 was
# 34 up
# 35 to
# 36 them
# 37 None
# 3596
# 0 house
# 1 press
# 2 secretary
# 3 kayleigh
# 4 mcenany
# 5 voiced
# 6 tepid
# 7 support
# 8 for
# 9 defense
# 10 secretary
# 11 mark
# 12 esper
# 13 after
# 14 he
# 15 stated
# 16 wednesday
# 17 that
# 18 he
# 19 did
# 20 support
# 21 invoking
# 22 the
# 23 insurrection
# 24 act
# 25 which
# 26 would
# 27 allow
# 28 active
# 29 duty
# 30 troops
# 31 act
# 32 in
# 33 domestic
# 34 law
# 35 enforcement
# 36 roles
# 37 None
# 3597
# 0 house
# 1 senior
# 2 adviser
# 3 jared
# 4 kushner
# 5 criticized
# 6 athletes
# 7 others
# 8 who
# 9 have
# 10 protested
# 11 against
# 12 u.s.
# 13 racism
# 14 on
# 15 social
# 16 media
# 17 basketball
# 18 courts
# 19 suggested
# 20 that
# 21 black
# 22 people
# 23 had
# 24 want
# 25 succeed
# 26 for
# 27 policies
# 28 change
# 29 None
# 3598
# 0 mobs
# 1 have
# 2 once
# 3 again
# 4 moved
# 5 out
# 6 of
# 7 the
# 8 shadows
# 9 into
# 10 the
# 11 limelight
# 12 during
# 13 this
# 14 trump
# 15 moment
# 16 None
# 3599
# 0 nationalism
# 1 fueled
# 2 violence
# 3 is
# 4 on
# 5 the
# 6 rise
# 7 fbi
# 8 is
# 9 slow
# 10 call
# 11 it
# 12 domestic
# 13 terrorism
# 14 None
# 3600
# 0 nationalist
# 1 arrested
# 2 for
# 3 alleged
# 4 threat
# 5 against
# 6 ohio
# 7 jewish
# 8 community
# 9 center
# 10 None
# 3601
# 0 nationalists
# 1 also
# 2 expressed
# 3 excitement
# 4 tuesday
# 5 about
# 6 trump
# 7 plan
# 8 use
# 9 an
# 10 executive
# 11 order
# 12 end
# 13 birthright
# 14 citizenship
# 15 the
# 16 automatic
# 17 grant
# 18 of
# 19 citizen
# 20 status
# 21 to
# 22 anyone
# 23 born
# 24 in
# 25 the
# 26 united
# 27 states
# 28 None
# 3602
# 0 people
# 1 are
# 2 being
# 3 asked
# 4 pushed
# 5 take
# 6 stock
# 7 of
# 8 their
# 9 whiteness
# 10 identify
# 11 with
# 12 it
# 13 more
# 14 this
# 15 is
# 16 a
# 17 remarkably
# 18 bad
# 19 idea
# 20 None
# 3603
# 0 supremacist
# 1 violent
# 2 extremists
# 3 can
# 4 generally
# 5 be
# 6 characterized
# 7 by
# 8 hatred
# 9 for
# 10 immigrants
# 11 ethnic
# 12 minorities
# 13 often
# 14 combining
# 15 these
# 16 prejudices
# 17 with
# 18 virulent
# 19 anti
# 20 -
# 21 semitism
# 22 anti
# 23 -
# 24 muslim
# 25 views
# 26 the
# 27 dhs
# 28 report
# 29 states
# 30 None
# 3604
# 0 takes
# 1 on
# 2 trump
# 3 for
# 4 claiming
# 5 the
# 6 economy
# 7 is
# 8 booming
# 9 asking
# 10 for
# 11 whom
# 12 she
# 13 details
# 14 local
# 15 pieces
# 16 of
# 17 legislation
# 18 dem
# 19 governors
# 20 are
# 21 working
# 22 on
# 23 before
# 24 claiming
# 25 democrats
# 26 are
# 27 the
# 28 ones
# 29 who
# 30 actually
# 31 fight
# 32 for
# 33 hardworking
# 34 americans
# 35 None
# 3605
# 0 is
# 1 working
# 2 ensure
# 3 fair
# 4 vaccine
# 5 distribution
# 6 in
# 7 the
# 8 meantime
# 9 it
# 10 is
# 11 key
# 12 suppress
# 13 the
# 14 virus
# 15 spread
# 16 said
# 17 mike
# 18 ryan
# 19 head
# 20 of
# 21 who
# 22 emergencies
# 23 program
# 24 as
# 25 daily
# 26 new
# 27 cases
# 28 around
# 29 the
# 30 globe
# 31 are
# 32 at
# 33 near
# 34 record
# 35 levels
# 36 None
# 3606
# 0 are
# 1 members
# 2 of
# 3 the
# 4 fairer
# 5 sex
# 6 on
# 7 the
# 8 frontlines
# 9 of
# 10 riotous
# 11 efforts
# 12 support
# 13 a
# 14 movement
# 15 that
# 16 insists
# 17 they
# 18 're
# 19 racist
# 20 capitalism
# 21 is
# 22 racist
# 23 the
# 24 whole
# 25 system
# 26 is
# 27 racist
# 28 None
# 3607
# 0 did
# 1 democrats
# 2 vote
# 3 overwhelmingly
# 4 against
# 5 a
# 6 bill
# 7 that
# 8 would
# 9 require
# 10 infants
# 11 born
# 12 alive
# 13 after
# 14 abortion
# 15 be
# 16 treated
# 17 as
# 18 any
# 19 other
# 20 infant
# 21 born
# 22 at
# 23 that
# 24 gestational
# 25 age
# 26 because
# 27 abortion
# 28 is
# 29 the
# 30 right
# 31 destroy
# 32 own
# 33 child
# 34 if
# 35 a
# 36 woman
# 37 chose
# 38 kill
# 39 her
# 40 baby
# 41 to
# 42 the
# 43 left
# 44 it
# 45 would
# 46 seem
# 47 a
# 48 violation
# 49 of
# 50 her
# 51 so
# 52 called
# 53 right
# 54 choose
# 55 for
# 56 doctors
# 57 try
# 58 save
# 59 that
# 60 baby
# 61 None
# 3608
# 0 did
# 1 trump
# 2 offer
# 3 up
# 4 this
# 5 cards
# 6 that
# 7 's
# 8 because
# 9 his
# 10 vaunted
# 11 skills
# 12 in
# 13 making
# 14 the
# 15 deal
# 16 absolutely
# 17 failed
# 18 budge
# 19 the
# 20 prices
# 21 from
# 22 pharmaceutical
# 23 companies
# 24 a
# 25 deal
# 26 that
# 27 had
# 28 been
# 29 in
# 30 the
# 31 works
# 32 for
# 33 months
# 34 absolutely
# 35 collapsed
# 36 None
# 3609
# 0 women
# 1 have
# 2 abortions
# 3 is
# 4 a
# 5 topic
# 6 much
# 7 discussed
# 8 by
# 9 those
# 10 who
# 11 argue
# 12 that
# 13 ending
# 14 a
# 15 life
# 16 in
# 17 the
# 18 womb
# 19 is
# 20 sometimes
# 21 necessary
# 22 None
# 3610
# 0 coverage
# 1 of
# 2 other
# 3 contentious
# 4 political
# 5 topics
# 6 such
# 7 as
# 8 abortion
# 9 were
# 10 also
# 11 criticized
# 12 with
# 13 sanger
# 14 singling
# 15 out
# 16 wikipedia
# 17 claiming
# 18 abortion
# 19 is
# 20 of
# 21 the
# 22 safest
# 23 procedures
# 24 in
# 25 medicine
# 26 None
# 3611
# 0 own
# 1 articles
# 2 on
# 3 the
# 4 floyd
# 5 protests
# 6 similarly
# 7 reflect
# 8 the
# 9 foundation
# 10 abandonment
# 11 of
# 12 neutrality
# 13 by
# 14 being
# 15 unduly
# 16 skewed
# 17 towards
# 18 smearing
# 19 president
# 20 donald
# 21 trump
# 22 while
# 23 downplaying
# 24 protestor
# 25 violence
# 26 the
# 27 violent
# 28 antifa
# 29 group
# 30 involvement
# 31 None
# 3612
# 0 noted
# 1 gender
# 2 dysphoria
# 3 is
# 4 a
# 5 mental
# 6 health
# 7 issue
# 8 parents
# 9 have
# 10 the
# 11 right
# 12 make
# 13 healthcare
# 14 decisions
# 15 on
# 16 behalf
# 17 of
# 18 their
# 19 children
# 20 None
# 3613
# 0 the
# 1 american
# 2 people
# 3 follow
# 4 the
# 5 commands
# 6 of
# 7 donald
# 8 trump
# 9 coronavirus
# 10 death
# 11 cult
# 12 None
# 3614
# 0 ali
# 1 have
# 2 received
# 3 death
# 4 threats
# 5 for
# 6 the
# 7 crime
# 8 of
# 9 poking
# 10 fun
# 11 at
# 12 donald
# 13 trump
# 14 the
# 15 members
# 16 of
# 17 his
# 18 political
# 19 cult
# 20 None
# 3615
# 0 gregory
# 1 the
# 2 first
# 3 african
# 4 american
# 5 be
# 6 named
# 7 as
# 8 cardinal
# 9 known
# 10 as
# 11 a
# 12 refined
# 13 diplomat
# 14 made
# 15 headlines
# 16 when
# 17 he
# 18 blasted
# 19 president
# 20 donald
# 21 trump
# 22 photo
# 23 opportunity
# 24 hoisting
# 25 a
# 26 bible
# 27 at
# 28 a
# 29 washington
# 30 church
# 31 after
# 32 police
# 33 used
# 34 tear
# 35 gas
# 36 clear
# 37 demonstrators
# 38 in
# 39 june
# 40 None
# 3616
# 0 champion
# 1 navratilova
# 2 who
# 3 has
# 4 campaigned
# 5 for
# 6 gay
# 7 rights
# 8 suffered
# 9 abuse
# 10 when
# 11 she
# 12 came
# 13 out
# 14 in
# 15 the
# 16 1980s
# 17 argued
# 18 trans
# 19 women
# 20 have
# 21 unfair
# 22 physical
# 23 advantages
# 24 None
# 3617
# 0 churchill
# 1 was
# 2 a
# 3 racist
# 4 so
# 5 the
# 6 black
# 7 lives
# 8 matter
# 9 graffiti
# 10 says
# 11 on
# 12 the
# 13 plinth
# 14 of
# 15 his
# 16 statue
# 17 in
# 18 london
# 19 parliament
# 20 square
# 21 which
# 22 is
# 23 bound
# 24 be
# 25 pulled
# 26 down
# 27 by
# 28 hard
# 29 left
# 30 activists
# 31 sooner
# 32 later
# 33 because
# 34 the
# 35 police
# 36 do
# 37 seem
# 38 have
# 39 that
# 40 much
# 41 of
# 42 an
# 43 appetite
# 44 save
# 45 it
# 46 None
# 3618
# 0 democrats
# 1 fuming
# 2 over
# 3 trump
# 4 push
# 5 for
# 6 a
# 7 border
# 8 wall
# 9 amid
# 10 a
# 11 still
# 12 unresolved
# 13 funding
# 14 standoff
# 15 those
# 16 guest
# 17 lists
# 18 signal
# 19 the
# 20 president
# 21 could
# 22 face
# 23 a
# 24 tough
# 25 crowd
# 26 None
# 3619
# 0 hundreds
# 1 of
# 2 potential
# 3 vaccines
# 4 in
# 5 various
# 6 stages
# 7 of
# 8 development
# 9 around
# 10 the
# 11 world
# 12 russia
# 13 was
# 14 the
# 15 first
# 16 country
# 17 license
# 18 its
# 19 vaccine
# 20 for
# 21 public
# 22 use
# 23 alongside
# 24 china
# 25 has
# 26 been
# 27 deploying
# 28 the
# 29 shots
# 30 before
# 31 full
# 32 efficacy
# 33 trials
# 34 are
# 35 complete
# 36 None
# 3620
# 0 it
# 1 ’s
# 2 bothsidesism
# 3 pro
# 4 -
# 5 trump
# 6 onesiderism
# 7 the
# 8 new
# 9 york
# 10 times
# 11 is
# 12 flailing
# 13 None
# 3621
# 0 june
# 1 marking
# 2 the
# 3 start
# 4 of
# 5 the
# 6 annual
# 7 pride
# 8 month
# 9 when
# 10 many
# 11 gay
# 12 trans
# 13 people
# 14 commemorate
# 15 riots
# 16 against
# 17 police
# 18 brutality
# 19 in
# 20 in
# 21 new
# 22 york
# 23 city
# 24 brown
# 25 called
# 26 on
# 27 the
# 28 lgbt+
# 29 community
# 30 recall
# 31 the
# 32 protest
# 33 driven
# 34 roots
# 35 of
# 36 the
# 37 celebration
# 38 None
# 3622
# 0 just
# 1 over
# 2 a
# 3 year
# 4 left
# 5 in
# 6 president
# 7 donald
# 8 trump
# 9 first
# 10 term
# 11 another
# 12 late
# 13 breaking
# 14 news
# 15 item
# 16 barely
# 17 made
# 18 waves
# 19 the
# 20 interior
# 21 department
# 22 which
# 23 manages
# 24 the
# 25 majority
# 26 of
# 27 the
# 28 federal
# 29 government
# 30 public
# 31 lands
# 32 deleted
# 33 sexual
# 34 orientation
# 35 from
# 36 its
# 37 anti
# 38 -
# 39 discrimination
# 40 guidelines
# 41 None
# 3623
# 0 many
# 1 formal
# 2 juneteenth
# 3 events
# 4 canceled
# 5 due
# 6 to
# 7 coronavirus
# 8 concerns
# 9 activists
# 10 instead
# 11 organized
# 12 a
# 13 host
# 14 of
# 15 virtual
# 16 observances
# 17 online
# 18 as
# 19 well
# 20 as
# 21 street
# 22 marches
# 23 car
# 24 caravans
# 25 through
# 26 several
# 27 major
# 28 cities
# 29 None
# 3624
# 0 more
# 1 than
# 2 people
# 3 killed
# 4 by
# 5 gun
# 6 violence
# 7 in
# 8 the
# 9 united
# 10 states
# 11 last
# 12 year
# 13 counting
# 14 suicides
# 15 democrats
# 16 running
# 17 for
# 18 their
# 19 party
# 20 presidential
# 21 nomination
# 22 are
# 23 pointing
# 24 to
# 25 inaction
# 26 in
# 27 washington
# 28 as
# 29 evidence
# 30 they
# 31 should
# 32 be
# 33 chosen
# 34 run
# 35 against
# 36 republican
# 37 president
# 38 donald
# 39 trump
# 40 None
# 3625
# 0 more
# 1 than
# 2 reported
# 3 cases
# 4 of
# 5 the
# 6 disease
# 7 the
# 8 viral
# 9 outbreak
# 10 continues
# 11 create
# 12 uncertainty
# 13 about
# 14 future
# 15 competitions
# 16 from
# 17 track
# 18 field
# 19 formula
# 20 to
# 21 the
# 22 ultimate
# 23 global
# 24 event
# 25 the
# 26 tokyo
# 27 olympics
# 28 None
# 3626
# 0 our
# 1 climate
# 2 impacted
# 3 world
# 4 now
# 5 highly
# 6 prone
# 7 to
# 8 fires
# 9 extreme
# 10 storms
# 11 sea
# 12 level
# 13 rise
# 14 nuclear
# 15 energy
# 16 is
# 17 touted
# 18 as
# 19 a
# 20 possible
# 21 replacement
# 22 for
# 23 the
# 24 burning
# 25 of
# 26 fossil
# 27 fuels
# 28 for
# 29 energy
# 30 the
# 31 leading
# 32 cause
# 33 of
# 34 climate
# 35 change
# 36 None
# 3627
# 0 protests
# 1 over
# 2 racial
# 3 injustice
# 4 continuing
# 5 roil
# 6 the
# 7 united
# 8 states
# 9 queer
# 10 eye
# 11 star
# 12 karamo
# 13 brown
# 14 has
# 15 called
# 16 on
# 17 lgbt+
# 18 people
# 19 recognize
# 20 the
# 21 racism
# 22 transphobia
# 23 in
# 24 the
# 25 community
# 26 remember
# 27 the
# 28 radical
# 29 roots
# 30 of
# 31 the
# 32 gay
# 33 rights
# 34 movement
# 35 None
# 3628
# 0 radical
# 1 feminists
# 2 extremist
# 3 trans
# 4 activists
# 5 seeking
# 6 have
# 7 her
# 8 publishers
# 9 film
# 10 associates
# 11 ban
# 12 her
# 13 from
# 14 earning
# 15 a
# 16 living
# 17 she
# 18 understands
# 19 how
# 20 the
# 21 radical
# 22 left
# 23 seeks
# 24 merely
# 25 disagree
# 26 with
# 27 their
# 28 opponents
# 29 destroy
# 30 them
# 31 utterly
# 32 as
# 33 human
# 34 beings
# 35 None
# 3629
# 0 the
# 1 arrival
# 2 of
# 3 virus
# 4 our
# 5 legal
# 6 rights
# 7 seem
# 8 have
# 9 been
# 10 deemed
# 11 irrelevant
# 12 completely
# 13 subordinated
# 14 to
# 15 the
# 16 arbitrary
# 17 whims
# 18 of
# 19 politicians
# 20 all
# 21 in
# 22 the
# 23 name
# 24 of
# 25 safety
# 26 None
# 3630
# 0 the
# 1 olympic
# 2 games
# 3 postponed
# 4 until
# 5 cinemas
# 6 closed
# 7 across
# 8 the
# 9 country
# 10 whole
# 11 segments
# 12 of
# 13 the
# 14 advertising
# 15 market
# 16 have
# 17 evaporated
# 18 None
# 3631
# 0 this
# 1 in
# 2 mind
# 3 the
# 4 trump
# 5 administration
# 6 reportedly
# 7 hopes
# 8 reduce
# 9 poverty
# 10 in
# 11 the
# 12 united
# 13 states
# 14 by
# 15 making
# 16 a
# 17 material
# 18 difference
# 19 in
# 20 struggling
# 21 families
# 22 finances
# 23 by
# 24 tinkering
# 25 with
# 26 the
# 27 threshold
# 28 for
# 29 what
# 30 counts
# 31 as
# 32 poverty
# 33 None
# 3632
# 0 justices
# 1 appointed
# 2 in
# 3 recent
# 4 years
# 5 by
# 6 president
# 7 donald
# 8 trump
# 9 the
# 10 supreme
# 11 court
# 12 has
# 13 appeared
# 14 primed
# 15 ready
# 16 deliver
# 17 a
# 18 huge
# 19 victory
# 20 for
# 21 conservatives
# 22 looking
# 23 roll
# 24 back
# 25 abortion
# 26 rights
# 27 in
# 28 the
# 29 united
# 30 states
# 31 None
# 3633
# 0 u.s.
# 1 president
# 2 donald
# 3 trump
# 4 announcement
# 5 on
# 6 thursday
# 7 of
# 8 tariffs
# 9 on
# 10 another
# 11 of
# 12 chinese
# 13 imports
# 14 nearly
# 15 all
# 16 goods
# 17 from
# 18 china
# 19 will
# 20 be
# 21 subject
# 22 to
# 23 import
# 24 taxes
# 25 trump
# 26 says
# 27 they
# 28 generate
# 29 billions
# 30 of
# 31 dollars
# 32 in
# 33 revenues
# 34 for
# 35 the
# 36 u.s.
# 37 treasury
# 38 from
# 39 china
# 40 None
# 3634
# 0 president
# 1 donald
# 2 trump
# 3 signaling
# 4 that
# 5 he
# 6 's
# 7 eager
# 8 for
# 9 the
# 10 country
# 11 relax
# 12 stringent
# 13 measures
# 14 meant
# 15 stem
# 16 the
# 17 tide
# 18 of
# 19 the
# 20 covid-19
# 21 pandemic
# 22 it
# 23 's
# 24 important
# 25 realize
# 26 how
# 27 dangerous
# 28 this
# 29 idea
# 30 is
# 31 None
# 3635
# 0 weeks
# 1 of
# 2 floyd
# 3 passing
# 4 in
# 5 minneapolis
# 6 police
# 7 custody
# 8 militant
# 9 social
# 10 justice
# 11 warriors
# 12 racked
# 13 up
# 14 an
# 15 estimated
# 16 in
# 17 damage
# 18 causing
# 19 the
# 20 costliest
# 21 outbreak
# 22 of
# 23 political
# 24 upheaval
# 25 in
# 26 u.s.
# 27 history
# 28 devastating
# 29 minority
# 30 businesses
# 31 while
# 32 kicking
# 33 off
# 34 an
# 35 entire
# 36 summer
# 37 of
# 38 chaos
# 39 engulfing
# 40 the
# 41 nation
# 42 major
# 43 cities
# 44 eventually
# 45 spreading
# 46 to
# 47 the
# 48 suburbs
# 49 None
# 3636
# 0 for
# 1 instance
# 2 the
# 3 wacky
# 4 nonsense
# 5 new
# 6 york
# 7 mayor
# 8 current
# 9 trump
# 10 flunky
# 11 rudy
# 12 giuliani
# 13 addressed
# 14 to
# 15 salon
# 16 roger
# 17 sollenberger
# 18 during
# 19 a
# 20 text
# 21 interview
# 22 this
# 23 week
# 24 None
# 3637
# 0 in
# 1 power
# 2 must
# 3 pay
# 4 a
# 5 significant
# 6 tax
# 7 on
# 8 their
# 9 limited
# 10 time
# 11 sit
# 12 for
# 13 manicures
# 14 blowouts
# 15 brow
# 16 waxes
# 17 braids
# 18 rather
# 19 than
# 20 meeting
# 21 with
# 22 constituents
# 23 reviewing
# 24 legislation
# 25 conducting
# 26 investigations
# 27 chasing
# 28 a
# 29 story
# 30 traveling
# 31 to
# 32 their
# 33 districts
# 34 reviewing
# 35 their
# 36 notes
# 37 spending
# 38 time
# 39 with
# 40 their
# 41 families
# 42 None
# 3638
# 0 were
# 1 allowed
# 2 into
# 3 saudi
# 4 sports
# 5 stadiums
# 6 a
# 7 year
# 8 ago
# 9 for
# 10 the
# 11 first
# 12 time
# 13 watch
# 14 soccer
# 15 matches
# 16 although
# 17 they
# 18 were
# 19 segregated
# 20 in
# 21 the
# 22 stands
# 23 sticking
# 24 to
# 25 the
# 26 family
# 27 section
# 28 away
# 29 from
# 30 all
# 31 male
# 32 crowds
# 33 elsewhere
# 34 None
# 3639
# 0 rights
# 1 advocates
# 2 were
# 3 relieved
# 4 late
# 5 monday
# 6 when
# 7 senate
# 8 democrats
# 9 blocked
# 10 an
# 11 extreme
# 12 anti
# 13 -
# 14 choice
# 15 bill
# 16 from
# 17 advancing
# 18 to
# 19 a
# 20 floor
# 21 debate
# 22 were
# 23 soon
# 24 outraged
# 25 by
# 26 president
# 27 donald
# 28 trump
# 29 lies
# 30 about
# 31 abortion
# 32 care
# 33 as
# 34 well
# 35 as
# 36 the
# 37 corporate
# 38 media
# 39 for
# 40 enabling
# 41 his
# 42 blatantly
# 43 false
# 44 characterization
# 45 of
# 46 the
# 47 bill
# 48 stand
# 49 None
# 3640
# 0 it
# 1 be
# 2 absurdly
# 3 difficult
# 4 enforce
# 5 new
# 6 gun
# 7 control
# 8 laws
# 9 move
# 10 toward
# 11 the
# 12 outright
# 13 confiscation
# 14 that
# 15 is
# 16 always
# 17 forever
# 18 the
# 19 left
# 20 ultimate
# 21 goal
# 22 after
# 23 a
# 24 year
# 25 of
# 26 record
# 27 breaking
# 28 gun
# 29 sales
# 30 None
# 3641
# 0 class
# 1 americans
# 2 like
# 3 those
# 4 who
# 5 make
# 6 up
# 7 the
# 8 majority
# 9 of
# 10 south
# 11 bend
# 12 residents
# 13 have
# 14 secured
# 15 the
# 16 largest
# 17 wage
# 18 hikes
# 19 in
# 20 the
# 21 nation
# 22 compared
# 23 to
# 24 all
# 25 other
# 26 economic
# 27 demographic
# 28 groups
# 29 a
# 30 direct
# 31 result
# 32 of
# 33 trump
# 34 tightening
# 35 the
# 36 labor
# 37 market
# 38 None
# 3642
# 0 bias
# 1 against
# 2 gay
# 3 transgender
# 4 employees
# 5 has
# 6 remained
# 7 legal
# 8 in
# 9 much
# 10 of
# 11 the
# 12 country
# 13 with
# 14 u.s.
# 15 states
# 16 lacking
# 17 comprehensive
# 18 measures
# 19 against
# 20 employment
# 21 discrimination
# 22 None
# 3643
# 0 leaders
# 1 organisations
# 2 pledged
# 3 fund
# 4 a
# 5 possible
# 6 vaccine
# 7 treatments
# 8 many
# 9 hoping
# 10 explicitly
# 11 ensure
# 12 that
# 13 no
# 14 country
# 15 on
# 16 earth
# 17 would
# 18 be
# 19 left
# 20 out
# 21 the
# 22 united
# 23 states
# 24 did
# 25 contribute
# 26 None
# 3644
# 0 noting
# 1 however
# 2 is
# 3 that
# 4 democrats
# 5 have
# 6 also
# 7 been
# 8 notably
# 9 faced
# 10 on
# 11 gun
# 12 control
# 13 None
# 3645
# 0 in
# 1 today
# 2 wall
# 3 street
# 4 journal
# 5 pence
# 6 denies
# 7 that
# 8 there
# 9 is
# 10 such
# 11 a
# 12 thing
# 13 as
# 14 a
# 15 second
# 16 wave
# 17 to
# 18 the
# 19 pandemic
# 20 he
# 21 does
# 22 mean
# 23 because
# 24 we
# 25 have
# 26 exited
# 27 the
# 28 first
# 29 wave
# 30 None
# 3646
# 0 psychiatrist
# 1 explains
# 2 why
# 3 the
# 4 coronavirus
# 5 pandemic
# 6 donald
# 7 trump
# 8 irrational
# 9 cult
# 10 is
# 11 a
# 12 deadly
# 13 combination
# 14 None
# 3647
# 0 after
# 1 openly
# 2 committing
# 3 adultery
# 4 against
# 5 the
# 6 republican
# 7 party
# 8 these
# 9 shameless
# 10 cheats
# 11 honestly
# 12 believed
# 13 the
# 14 democrat
# 15 party
# 16 would
# 17 make
# 18 them
# 19 equal
# 20 trusted
# 21 partners
# 22 in
# 23 the
# 24 family
# 25 business
# 26 None
# 3648
# 0 trump
# 1 the
# 2 right
# 3 are
# 4 embracing
# 5 celebrating
# 6 death
# 7 it
# 8 is
# 9 ghoulish
# 10 it
# 11 is
# 12 also
# 13 more
# 14 illustration
# 15 that
# 16 the
# 17 age
# 18 of
# 19 trump
# 20 is
# 21 an
# 22 american
# 23 dystopia
# 24 where
# 25 what
# 26 was
# 27 previously
# 28 unimaginable
# 29 for
# 30 most
# 31 decent
# 32 people
# 33 has
# 34 become
# 35 normal
# 36 None
# 3649
# 0 he
# 1 might
# 2 be
# 3 a
# 4 demented
# 5 stalinist
# 6 eager
# 7 flood
# 8 america
# 9 with
# 10 illegal
# 11 aliens
# 12 take
# 13 away
# 14 our
# 15 guns
# 16 health
# 17 insurance
# 18 he
# 19 sure
# 20 gave
# 21 those
# 22 venal
# 23 never
# 24 trumpers
# 25 a
# 26 sweet
# 27 face
# 28 job
# 29 saturday
# 30 night
# 31 in
# 32 nevada
# 33 now
# 34 i
# 35 ca
# 36 tell
# 37 if
# 38 my
# 39 tears
# 40 come
# 41 from
# 42 joy
# 43 laughter
# 44 None
# 3650
# 0 the
# 1 rich
# 2 are
# 3 rich
# 4 want
# 5 stay
# 6 that
# 7 way
# 8 yet
# 9 at
# 10 the
# 11 same
# 12 time
# 13 fat
# 14 cats
# 15 now
# 16 lean
# 17 left
# 18 even
# 19 far
# 20 left
# 21 on
# 22 cultural
# 23 issues
# 24 they
# 25 want
# 26 you
# 27 do
# 28 as
# 29 you
# 30 ’re
# 31 told
# 32 None
# 3651
# 0 there
# 1 may
# 2 still
# 3 be
# 4 time
# 5 for
# 6 the
# 7 union
# 8 membership
# 9 change
# 10 its
# 11 thinking
# 12 if
# 13 the
# 14 players
# 15 reject
# 16 the
# 17 proposal
# 18 at
# 19 least
# 20 marketing
# 21 expert
# 22 said
# 23 a
# 24 no
# 25 vote
# 26 now
# 27 could
# 28 mean
# 29 short-
# 30 long
# 31 term
# 32 disaster
# 33 None
# 3652
# 0 finds
# 1 himself
# 2 in
# 3 an
# 4 increasingly
# 5 competitive
# 6 race
# 7 with
# 8 sanders
# 9 the
# 10 u.s.
# 11 senator
# 12 who
# 13 came
# 14 close
# 15 to
# 16 winning
# 17 the
# 18 nevada
# 19 caucus
# 20 finds
# 21 support
# 22 with
# 23 some
# 24 of
# 25 the
# 26 same
# 27 voters
# 28 None
# 3653
# 0 the
# 1 entirety
# 2 of
# 3 the
# 4 establishment
# 5 from
# 6 prime
# 7 minister
# 8 boris
# 9 johnson
# 10 downwards
# 11 the
# 12 bodies
# 13 representing
# 14 every
# 15 cultural
# 16 institution
# 17 from
# 18 the
# 19 church
# 20 of
# 21 england
# 22 to
# 23 the
# 24 football
# 25 association
# 26 have
# 27 been
# 28 grovelling
# 29 fawning
# 30 kowtowing
# 31 to
# 32 blm
# 33 as
# 34 if
# 35 its
# 36 name
# 37 were
# 38 be
# 39 taken
# 40 at
# 41 face
# 42 value
# 43 None
# 3654
# 0 every
# 1 nation
# 2 except
# 3 mongolia
# 4 greenland
# 5 recorded
# 6 dozens
# 7 to
# 8 thousands
# 9 of
# 10 deaths
# 11 no
# 12 matter
# 13 what
# 14 they
# 15 tried
# 16 even
# 17 socialist
# 18 systems
# 19 with
# 20 draconian
# 21 lockdowns
# 22 like
# 23 italy
# 24 deaths
# 25 per
# 26 spain
# 27 the
# 28 united
# 29 kingdom
# 30 None
# 3655
# 0 far
# 1 better
# 2 applies
# 3 to
# 4 unelected
# 5 career
# 6 bureaucrats
# 7 use
# 8 of
# 9 their
# 10 power
# 11 prosecute
# 12 their
# 13 political
# 14 enemies
# 15 which
# 16 comprises
# 17 the
# 18 heart
# 19 of
# 20 the
# 21 resistance
# 22 to
# 23 republican
# 24 rule
# 25 that
# 26 will
# 27 endure
# 28 so
# 29 long
# 30 as
# 31 bureaucracy
# 32 has
# 33 enough
# 34 power
# 35 challenged
# 36 elected
# 37 branches
# 38 of
# 39 government
# 40 this
# 41 bureacracy
# 42 weaponization
# 43 was
# 44 also
# 45 a
# 46 hallmark
# 47 of
# 48 the
# 49 obama
# 50 presidency
# 51 with
# 52 ironies
# 53 of
# 54 ironies
# 55 perhaps
# 56 the
# 57 biggest
# 58 evidences
# 59 again
# 60 coming
# 61 from
# 62 the
# 63 department
# 64 of
# 65 justice
# 66 under
# 67 attorneys
# 68 general
# 69 eric
# 70 holder
# 71 loretta
# 72 lynch
# 73 None
# 3656
# 0 's
# 1 merely
# 2 the
# 3 tip
# 4 of
# 5 the
# 6 iceberg
# 7 of
# 8 war
# 9 criminals
# 10 lurking
# 11 working
# 12 on
# 13 u.s.
# 14 turf
# 15 None
# 3657
# 0 hoge
# 1 a
# 2 former
# 3 running
# 4 back
# 5 for
# 6 the
# 7 nfl
# 8 pittsburgh
# 9 steelers
# 10 chicago
# 11 bears
# 12 later
# 13 turned
# 14 espn
# 15 analyst
# 16 has
# 17 been
# 18 of
# 19 the
# 20 most
# 21 outspoken
# 22 critics
# 23 against
# 24 the
# 25 alarm
# 26 surrounding
# 27 cte
# 28 studies
# 29 putting
# 30 much
# 31 of
# 32 the
# 33 research
# 34 down
# 35 to
# 36 science
# 37 fiction
# 38 misleading
# 39 science
# 40 far
# 41 from
# 42 a
# 43 factual
# 44 realm
# 45 None
# 3658
# 0 with
# 1 an
# 2 exhaustive
# 3 page
# 4 health
# 5 safety
# 6 operations
# 7 manual
# 8 will
# 9 attempt
# 10 become
# 11 the
# 12 first
# 13 major
# 14 sport
# 15 return
# 16 on
# 17 july
# 18 with
# 19 nationally
# 20 televised
# 21 games
# 22 the
# 23 rest
# 24 of
# 25 the
# 26 teams
# 27 scheduled
# 28 start
# 29 july
# 30 None
# 3659
# 0 no
# 1 one
# 2 denies
# 3 that
# 4 older
# 5 nuclear
# 6 plants
# 7 with
# 8 an
# 9 aged
# 10 infrastructure
# 11 often
# 12 surpassing
# 13 expected
# 14 lifetimes
# 15 are
# 16 extremely
# 17 inefficient
# 18 run
# 19 a
# 20 higher
# 21 risk
# 22 of
# 23 disaster
# 24 None
# 3660
# 0 is
# 1 unashamed
# 2 about
# 3 being
# 4 linked
# 5 to
# 6 this
# 7 kind
# 8 of
# 9 hate
# 10 even
# 11 claiming
# 12 that
# 13 while
# 14 she
# 15 opposes
# 16 economic
# 17 sanctions
# 18 on
# 19 the
# 20 tyrannical
# 21 terrorist
# 22 supporting
# 23 iranian
# 24 regime
# 25 she
# 26 thinks
# 27 boycotts
# 28 of
# 29 israel
# 30 are
# 31 justified
# 32 None
# 3661
# 0 the
# 1 drumbeat
# 2 for
# 3 censorship
# 4 goes
# 5 on
# 6 as
# 7 the
# 8 politicians
# 9 whose
# 10 ideas
# 11 find
# 12 favor
# 13 with
# 14 the
# 15 mainstream
# 16 media
# 17 want
# 18 make
# 19 sure
# 20 theirs
# 21 are
# 22 the
# 23 only
# 24 ideas
# 25 you
# 26 ever
# 27 get
# 28 hear
# 29 today
# 30 it
# 31 will
# 32 be
# 33 about
# 34 money
# 35 only
# 36 because
# 37 money
# 38 is
# 39 the
# 40 means
# 41 spread
# 42 ideas
# 43 None
# 3662
# 0 the
# 1 gender
# 2 ideology
# 3 is
# 4 rapidly
# 5 gaining
# 6 power
# 7 aided
# 8 by
# 9 huge
# 10 donations
# 11 from
# 12 wealthy
# 13 individuals
# 14 medical
# 15 companies
# 16 None
# 3663
# 0 overwhelming
# 1 narrative
# 2 across
# 3 social
# 4 media
# 5 today
# 6 depressingly
# 7 across
# 8 much
# 9 of
# 10 the
# 11 mainstream
# 12 media
# 13 is
# 14 that
# 15 these
# 16 ugly
# 17 sinister
# 18 shows
# 19 of
# 20 force
# 21 by
# 22 the
# 23 triumphant
# 24 radical
# 25 left
# 26 are
# 27 something
# 28 almost
# 29 charming
# 30 admirable
# 31 rather
# 32 than
# 33 something
# 34 we
# 35 should
# 36 all
# 37 fear
# 38 None
# 3664
# 0 when
# 1 researchers
# 2 in
# 3 the
# 4 u.s.
# 5 have
# 6 been
# 7 so
# 8 corrupt
# 9 they
# 10 have
# 11 gone
# 12 to
# 13 jail
# 14 mainstream
# 15 scientists
# 16 still
# 17 accept
# 18 their
# 19 research
# 20 None
# 3665
# 0 trump
# 1 family
# 2 his
# 3 allies
# 4 are
# 5 evidently
# 6 using
# 7 this
# 8 national
# 9 emergency
# 10 enrich
# 11 themselves
# 12 None
# 3666
# 0 may
# 1 remember
# 2 that
# 3 hours
# 4 after
# 5 america
# 6 was
# 7 attacked
# 8 by
# 9 al
# 10 qaeda
# 11 on
# 12 thousands
# 13 of
# 14 muslims
# 15 regular
# 16 folks
# 17 celebrated
# 18 in
# 19 the
# 20 streets
# 21 None
# 3667
# 0 may
# 1 remember
# 2 that
# 3 nbc
# 4 journalist
# 5 nancy
# 6 snyderman
# 7 broke
# 8 her
# 9 ebola
# 10 quarantine
# 11 to
# 12 the
# 13 outrage
# 14 of
# 15 her
# 16 neighbors
# 17 None
# 3668
# 0 need
# 1 keep
# 2 a
# 3 close
# 4 eye
# 5 on
# 6 what
# 7 your
# 8 school
# 9 is
# 10 teaching
# 11 because
# 12 the
# 13 left
# 14 only
# 15 wants
# 16 teach
# 17 your
# 18 kids
# 19 engage
# 20 in
# 21 loveless
# 22 sex
# 23 the
# 24 sanctity
# 25 of
# 26 abortion
# 27 why
# 28 america
# 29 is
# 30 evil
# 31 that
# 32 men
# 33 are
# 34 women
# 35 women
# 36 are
# 37 men
# 38 that
# 39 global
# 40 warming
# 41 is
# 42 real
# 43 it
# 44 ’s
# 45 None
# 3669
# 0 ’ve
# 1 heard
# 2 of
# 3 jim
# 4 crow
# 5 southern
# 6 segregation
# 7 that
# 8 was
# 9 all
# 10 democrats
# 11 None
# 3670
# 0 female
# 1 athletes
# 2 dreams
# 3 accomplishments
# 4 have
# 5 been
# 6 dashed
# 7 across
# 8 the
# 9 country
# 10 when
# 11 competing
# 12 against
# 13 biological
# 14 males
# 15 who
# 16 identify
# 17 as
# 18 females
# 19 None
# 3671
# 0 white
# 1 men
# 2 reacting
# 3 to
# 4 social
# 5 educational
# 6 constructs
# 7 that
# 8 paint
# 9 them
# 10 as
# 11 the
# 12 embodiment
# 13 of
# 14 historical
# 15 evil
# 16 are
# 17 fertile
# 18 ground
# 19 for
# 20 white
# 21 supremacists
# 22 None
# 3672
# 0 women
# 1 taking
# 2 part
# 3 in
# 4 high
# 5 school
# 6 college
# 7 athletics
# 8 across
# 9 the
# 10 country
# 11 have
# 12 had
# 13 their
# 14 dreams
# 15 of
# 16 winning
# 17 dashed
# 18 by
# 19 the
# 20 movement
# 21 allow
# 22 biological
# 23 male
# 24 who
# 25 identify
# 26 as
# 27 female
# 28 compete
# 29 against
# 30 them
# 31 None
# 3673
# 0 is
# 1 making
# 2 clear
# 3 there
# 4 will
# 5 be
# 6 no
# 7 birtherism
# 8 on
# 9 its
# 10 platform
# 11 during
# 12 this
# 13 year
# 14 u.s.
# 15 presidential
# 16 election
# 17 a
# 18 belated
# 19 response
# 20 to
# 21 a
# 22 type
# 23 of
# 24 conspiracy
# 25 theory
# 26 more
# 27 prevalent
# 28 in
# 29 the
# 30 race
# 31 None

# %%
# token in context +2 (c4)
for index, row in dt.iterrows():
    print(index)
    for i, token in enumerate(row.spacy_lg_dict):
        print(i, token['text_low_C4'])
        if token['text_low_C4'] == None:
            token['assertive_verbs_C4'] = 0
            token['factive_verbs_C4'] = 0
            token['report_verbs_C4'] = 0
            token['hedges_C4'] = 0
            token['boosters_C4'] = 0
            token['implicative_verbs_C4'] = 0
        else:
            if token['window_text'] != None and token['window_lemma'] != None:
                window_text = token['window_text']
                window_lemma = token['window_lemma']

              # 0 1 2 3 4 5 <6> 7 8
              # token['text_low_C4']
              # token['lemma_low_C4']
                # words
                c1, c2, c_m, c3, c4 = None, None, None, None, None
                if window_text[4] != None and window_text[5] != None:
                    c1 = window_text[4] + ' ' + window_text[5] + ' ' + token['text_low_C4']
                if window_text[5] != None:
                    c2 = window_text[5] + ' ' + token['text_low_C4']
                if window_text[5] != None and window_text[7] != None:
                    c_m = window_text[5] + ' ' + token['text_low_C4'] + ' ' + window_text[7]
                if window_text[7] != None:
                    c3 = token['text_low_C4'] + ' ' + window_text[7]
                if window_text[7] != None and window_text[8] != None:
                    c4 = token['text_low_C4'] + ' ' + window_text[7] + ' ' + window_text[8]

                # lemmas
                c1l, c2l, c_ml, c3l, c4l = None, None, None, None, None
                if window_lemma[4] != None and window_lemma[5] != None:
                    c1l = window_lemma[4] + ' ' + window_lemma[5] + ' ' + token['lemma_low_C4']
                if window_lemma[5] != None:
                    c2l = window_lemma[5] + ' ' + token['lemma_low_C4']
                if window_lemma[5] != None and window_lemma[7] != None:
                    c_ml = window_lemma[5] + ' ' + token['lemma_low_C4'] + ' ' + window_lemma[7]
                if window_lemma[7] != None:
                    c3l = token['lemma_low_C4'] + ' ' + window_lemma[7]
                if window_lemma[7] != None and window_text[8] != None:
                    c4l = token['lemma_low_C4'] + ' ' + window_lemma[7] + ' ' + window_lemma[8]

                # assertive verbs
                if token['text_low_C4'] in assertive_verbs or c1 in assertive_verbs or c2 in assertive_verbs or \
                c_m in assertive_verbs or c3 in assertive_verbs or c4 in assertive_verbs or \
                token['lemma_low_C4'] in assertive_verbs or c1l in assertive_verbs or c2l in assertive_verbs or \
                c_ml in assertive_verbs or c3l in assertive_verbs or c4l in assertive_verbs:
                    token['assertive_verbs_C4'] = 1
                else:
                    token['assertive_verbs_C4'] = 0   

                # factive verbs
                if token['text_low_C4'] in factive_verbs or c1 in factive_verbs or c2 in factive_verbs or \
                c_m in factive_verbs or c3 in factive_verbs or c4 in factive_verbs or \
                token['lemma_low_C4'] in factive_verbs or c1l in factive_verbs or c2l in factive_verbs or \
                c_ml in factive_verbs or c3l in factive_verbs or c4l in factive_verbs:
                    token['factive_verbs_C4'] = 1
                else:
                    token['factive_verbs_C4'] = 0   

                # report verbs
                if token['text_low_C4'] in report_verbs or c1 in report_verbs or c2 in report_verbs or \
                c_m in report_verbs or c3 in report_verbs or c4 in report_verbs or \
                token['lemma_low_C4'] in report_verbs or c1l in report_verbs or c2l in report_verbs or \
                c_ml in report_verbs or c3l in report_verbs or c4l in report_verbs:
                    token['report_verbs_C4'] = 1
                else:
                    token['report_verbs_C4'] = 0

                # hedges
                if token['text_low_C4'] in hedges or c1 in hedges or c2 in hedges or \
                c_m in hedges or c3 in hedges or c4 in hedges or \
                token['lemma_low_C4'] in hedges or c1l in hedges or c2l in hedges or \
                c_ml in hedges or c3l in hedges or c4l in hedges:
                    token['hedges_C4'] = 1
                else:
                    token['hedges_C4'] = 0

                # boosters
                if token['text_low_C4'] in boosters or c1 in boosters or c2 in boosters or \
                c_m in boosters or c3 in boosters or c4 in boosters or \
                token['lemma_low_C4'] in boosters or c1l in boosters or c2l in boosters or \
                c_ml in boosters or c3l in boosters or c4l in boosters:
                    token['boosters_C4'] = 1
                else:
                    token['boosters_C4'] = 0
                    
                # implicative verbs
                if token['text_low_C4'] in implicative_verbs or c1 in implicative_verbs or c2 in implicative_verbs or \
                c_m in implicative_verbs or c3 in implicative_verbs or c4 in implicative_verbs or \
                token['lemma_low_C4'] in implicative_verbs or c1l in implicative_verbs or c2l in implicative_verbs or \
                c_ml in implicative_verbs or c3l in implicative_verbs or c4l in implicative_verbs:
                    token['implicative_verbs_C4'] = 1
                else:
                    token['implicative_verbs_C4'] = 0

            else:
                # assertive verbs
                if token['text_low_C4'] in assertive_verbs or token['lemma_low_C4'] in assertive_verbs:
                    token['assertive_verbs_C4'] = 1
                else:
                    token['assertive_verbs_C4'] = 0 

                # factive verbs
                if token['text_low_C4'] in factive_verbs or token['lemma_low_C4'] in factive_verbs:
                    token['factive_verbs_C4'] = 1
                else:
                    token['factive_verbs_C4'] = 0   

                # report verbs
                if token['text_low_C4'] in report_verbs or token['lemma_low_C4'] in report_verbs:
                    token['report_verbs_C4'] = 1
                else:
                    token['report_verbs_C4'] = 0

                # hedges
                if token['text_low_C4'] in hedges or token['lemma_low_C4'] in hedges:
                    token['hedges_C4'] = 1
                else:
                    token['hedges_C4'] = 0

                # boosters
                if token['text_low_C4'] in boosters or token['lemma_low_C4'] in boosters:
                    token['boosters_C4'] = 1
                else:
                    token['boosters_C4'] = 0
                    
                # implicative verbs
                if token['text_low_C4'] in implicative_verbs or token['lemma_low_C4'] in implicative_verbs:
                    token['implicative_verbs_C4'] = 1
                else:
                    token['implicative_verbs_C4'] = 0
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 10 as
# 11 he
# 12 did
# 13 during
# 14 the
# 15 presidential
# 16 debates
# 17 many
# 18 parents
# 19 may
# 20 choose
# 21 vaccinate
# 22 putting
# 23 children
# 24 at
# 25 unnecessary
# 26 risk
# 27 None
# 28 None
# 3523
# 0 newly
# 1 organized
# 2 vaccine
# 3 research
# 4 group
# 5 at
# 6 the
# 7 u.s.
# 8 national
# 9 institutes
# 10 of
# 11 health
# 12 nih
# 13 met
# 14 for
# 15 the
# 16 first
# 17 time
# 18 this
# 19 week
# 20 its
# 21 members
# 22 had
# 23 expected
# 24 be
# 25 able
# 26 ease
# 27 into
# 28 their
# 29 work
# 30 their
# 31 mandate
# 32 is
# 33 conduct
# 34 human
# 35 trials
# 36 for
# 37 emerging
# 38 health
# 39 threats
# 40 their
# 41 first
# 42 assignment
# 43 came
# 44 at
# 45 shocking
# 46 speed
# 47 None
# 48 None
# 3524
# 0 supporter
# 1 told
# 2 warren
# 3 public
# 4 schools
# 5 need
# 6 teach
# 7 more
# 8 about
# 9 lgbtq
# 10 history
# 11 sex
# 12 education
# 13 the
# 14 massachusetts
# 15 senator
# 16 replied
# 17 her
# 18 education
# 19 secretary
# 20 would
# 21 have
# 22 be
# 23 interviewed
# 24 by
# 25 a
# 26 transgender
# 27 child
# 28 None
# 29 None
# 3525
# 0 a
# 1 firearm
# 2 you
# 3 have
# 4 the
# 5 ultimate
# 6 power
# 7 of
# 8 force
# 9 in
# 10 your
# 11 control
# 12 None
# 13 None
# 3526
# 0 are
# 1 releasing
# 2 violent
# 3 criminals
# 4 encouraging
# 5 illegal
# 6 immigration
# 7 passing
# 8 laws
# 9 disarm
# 10 you
# 11 while
# 12 turning
# 13 the
# 14 police
# 15 into
# 16 eunuchs
# 17 it
# 18 ’s
# 19 over
# 20 None
# 21 None
# 3527
# 0 it
# 1 become
# 2 racist
# 3 like
# 4 the
# 5 national
# 6 anthem
# 7 mount
# 8 rushmore
# 9 None
# 10 None
# 3528
# 0 vaccines
# 1 become
# 2 politicized
# 3 amid
# 4 a
# 5 measles
# 6 outbreak
# 7 suddenly
# 8 republicans
# 9 support
# 10 anti
# 11 -
# 12 vaxxers
# 13 None
# 14 None
# 3529
# 0 right
# 1 white
# 2 evangelicals
# 3 white
# 4 nationalists
# 5 coronavirus
# 6 truthers
# 7 rail
# 8 against
# 9 social
# 10 distancing
# 11 encourage
# 12 large
# 13 gatherings
# 14 they
# 15 are
# 16 encouraging
# 17 suicidal
# 18 behavior
# 19 there
# 20 have
# 21 been
# 22 many
# 23 examples
# 24 None
# 25 None
# 3530
# 0 power
# 1 are
# 2 exercised
# 3 by
# 4 giant
# 5 multinational
# 6 corporations
# 7 that
# 8 escape
# 9 the
# 10 discipline
# 11 of
# 12 the
# 13 nation
# 14 state
# 15 the
# 16 potential
# 17 for
# 18 evil
# 19 becomes
# 20 infinite
# 21 in
# 22 nature
# 23 None
# 24 None
# 3531
# 0 finally
# 1 spoke
# 2 in
# 3 the
# 4 rose
# 5 garden
# 6 on
# 7 monday
# 8 trump
# 9 threatened
# 10 deploy
# 11 the
# 12 military
# 13 against
# 14 american
# 15 citizens
# 16 if
# 17 the
# 18 governors
# 19 did
# 20 take
# 21 his
# 22 advice
# 23 for
# 24 a
# 25 more
# 26 forceful
# 27 crackdown
# 28 this
# 29 threat
# 30 did
# 31 appear
# 32 cow
# 33 anyone
# 34 only
# 35 increased
# 36 the
# 37 anger
# 38 None
# 39 None
# 3532
# 0 opened
# 1 britain
# 2 bestselling
# 3 tabloid
# 4 conservative
# 5 sunday
# 6 newspaper
# 7 i
# 8 was
# 9 greeted
# 10 by
# 11 a
# 12 double
# 13 page
# 14 spread
# 15 showing
# 16 a
# 17 vast
# 18 mob
# 19 of
# 20 black
# 21 lives
# 22 matter
# 23 activists
# 24 marching
# 25 on
# 26 downing
# 27 street
# 28 in
# 29 london
# 30 None
# 31 None
# 3533
# 0 comes
# 1 to
# 2 the
# 3 green
# 4 new
# 5 deal
# 6 blueprint
# 7 address
# 8 the
# 9 climate
# 10 crisis
# 11 republicans
# 12 generally
# 13 like
# 14 pretend
# 15 it
# 16 calls
# 17 for
# 18 the
# 19 elimination
# 20 of
# 21 hamburgers
# 22 None
# 23 None
# 3534
# 0 leader
# 1 enters
# 2 the
# 3 white
# 4 house
# 5 meet
# 6 president
# 7 donald
# 8 trump
# 9 on
# 10 wednesday
# 11 he
# 12 will
# 13 do
# 14 so
# 15 only
# 16 as
# 17 a
# 18 hostage
# 19 to
# 20 the
# 21 whims
# 22 of
# 23 his
# 24 u.s.
# 25 counterpart
# 26 also
# 27 as
# 28 partner
# 29 in
# 30 an
# 31 unlikely
# 32 alliance
# 33 that
# 34 has
# 35 benefited
# 36 both
# 37 men
# 38 None
# 39 None
# 3535
# 0 borrow
# 1 the
# 2 debt
# 3 can
# 4 weigh
# 5 down
# 6 families
# 7 for
# 8 generations
# 9 the
# 10 burden
# 11 falls
# 12 particularly
# 13 hard
# 14 on
# 15 low
# 16 income
# 17 black
# 18 families
# 19 None
# 20 None
# 3536
# 0 trump
# 1 rolled
# 2 out
# 3 his
# 4 recent
# 5 budget
# 6 proposal
# 7 it
# 8 made
# 9 some
# 10 cuts
# 11 that
# 12 were
# 13 always
# 14 going
# 15 cause
# 16 controversy
# 17 for
# 18 thing
# 19 his
# 20 plan
# 21 would
# 22 slash
# 23 subsidized
# 24 student
# 25 loan
# 26 repayment
# 27 plans
# 28 let
# 29 the
# 30 government
# 31 crack
# 32 down
# 33 on
# 34 missed
# 35 payments
# 36 None
# 37 None
# 3537
# 0 healthcare
# 1 workers
# 2 the
# 3 panel
# 4 noted
# 5 that
# 6 vaccines
# 7 should
# 8 go
# 9 first
# 10 to
# 11 people
# 12 who
# 13 have
# 14 the
# 15 most
# 16 contact
# 17 with
# 18 patients
# 19 None
# 20 None
# 3538
# 0 warned
# 1 democrats
# 2 that
# 3 impeachment
# 4 was
# 5 a
# 6 waste
# 7 of
# 8 time
# 9 a
# 10 divisive
# 11 partisan
# 12 exercise
# 13 a
# 14 distraction
# 15 from
# 16 the
# 17 real
# 18 issues
# 19 facing
# 20 the
# 21 country
# 22 a
# 23 lesson
# 24 republicans
# 25 learned
# 26 the
# 27 hard
# 28 way
# 29 in
# 30 bill
# 31 clinton
# 32 impeachment
# 33 years
# 34 before
# 35 democrats
# 36 ignored
# 37 them
# 38 None
# 39 None
# 3539
# 0 left
# 1 is
# 2 emboldened
# 3 cities
# 4 burn
# 5 statues
# 6 topple
# 7 careers
# 8 people
# 9 are
# 10 disappeared
# 11 good
# 12 men
# 13 are
# 14 murdered
# 15 civil
# 16 liberties
# 17 are
# 18 trampled
# 19 the
# 20 dual
# 21 horrors
# 22 of
# 23 blacklisting
# 24 censorship
# 25 reign
# 26 supreme
# 27 None
# 28 None
# 3540
# 0 men
# 1 basketball
# 2 final
# 3 four
# 4 tips
# 5 off
# 6 saturday
# 7 in
# 8 minneapolis
# 9 the
# 10 ncaa
# 11 biggest
# 12 most
# 13 lucrative
# 14 event
# 15 will
# 16 proceed
# 17 as
# 18 it
# 19 normally
# 20 does
# 21 the
# 22 athletes
# 23 on
# 24 the
# 25 floor
# 26 for
# 27 virginia
# 28 auburn
# 29 michigan
# 30 state
# 31 texas
# 32 tech
# 33 will
# 34 play
# 35 games
# 36 that
# 37 generate
# 38 hundreds
# 39 of
# 40 millions
# 41 of
# 42 dollars
# 43 in
# 44 total
# 45 revenue
# 46 for
# 47 their
# 48 schools
# 49 the
# 50 ncaa
# 51 broadcast
# 52 companies
# 53 the
# 54 coaches
# 55 athletic
# 56 directors
# 57 tv
# 58 executives
# 59 ncaa
# 60 suits
# 61 will
# 62 share
# 63 in
# 64 the
# 65 riches
# 66 athletes
# 67 themselves
# 68 still
# 69 wo
# 70 receive
# 71 their
# 72 fair
# 73 share
# 74 thanks
# 75 to
# 76 a
# 77 recent
# 78 federal
# 79 court
# 80 decision
# 81 that
# 82 wo
# 83 change
# 84 in
# 85 the
# 86 immediate
# 87 future
# 88 None
# 89 None
# 3541
# 0 muslim
# 1 ban
# 2 was
# 3 first
# 4 enacted
# 5 it
# 6 triggered
# 7 chaos
# 8 at
# 9 airports
# 10 prompted
# 11 widespread
# 12 protest
# 13 legal
# 14 challenges
# 15 it
# 16 continues
# 17 impose
# 18 devastating
# 19 costs
# 20 on
# 21 families
# 22 people
# 23 who
# 24 wish
# 25 come
# 26 to
# 27 the
# 28 u.s.
# 29 None
# 30 None
# 3542
# 0 nation
# 1 highest
# 2 civilian
# 3 honor
# 4 went
# 5 to
# 6 a
# 7 right
# 8 wing
# 9 media
# 10 personality
# 11 it
# 12 served
# 13 as
# 14 an
# 15 oddly
# 16 appropriate
# 17 capstone
# 18 to
# 19 trump
# 20 broader
# 21 goals
# 22 None
# 23 None
# 3543
# 0 entered
# 1 the
# 2 white
# 3 house
# 4 in
# 5 lopez
# 6 obrador
# 7 likened
# 8 the
# 9 american
# 10 to
# 11 adolf
# 12 hitler
# 13 for
# 14 his
# 15 attitude
# 16 toward
# 17 migrants
# 18 None
# 19 None
# 3544
# 0 in
# 1 uniform
# 2 shoved
# 3 an
# 4 elderly
# 5 man
# 6 to
# 7 the
# 8 ground
# 9 for
# 10 the
# 11 crime
# 12 of
# 13 approaching
# 14 them
# 15 causing
# 16 him
# 17 a
# 18 critical
# 19 head
# 20 injury
# 21 their
# 22 fellow
# 23 cops
# 24 made
# 25 no
# 26 attempt
# 27 help
# 28 the
# 29 victim
# 30 None
# 31 None
# 3545
# 0 schools
# 1 begin
# 2 the
# 3 next
# 4 academic
# 5 year
# 6 with
# 7 the
# 8 country
# 9 still
# 10 fighting
# 11 the
# 12 coronavirus
# 13 pandemic
# 14 students
# 15 should
# 16 spend
# 17 half
# 18 their
# 19 time
# 20 in
# 21 classrooms
# 22 half
# 23 doing
# 24 online
# 25 activities
# 26 that
# 27 pinpoint
# 28 their
# 29 individual
# 30 learning
# 31 style
# 32 such
# 33 as
# 34 videos
# 35 reading
# 36 None
# 37 None
# 3546
# 0 is
# 1 due
# 2 to
# 3 gaffes
# 4 his
# 5 inability
# 6 complete
# 7 some
# 8 sentences
# 9 lack
# 10 of
# 11 knowledge
# 12 on
# 13 a
# 14 subject
# 15 biden
# 16 has
# 17 proven
# 18 that
# 19 interviews
# 20 are
# 21 for
# 22 him
# 23 the
# 24 media
# 25 has
# 26 covered
# 27 accordingly
# 28 None
# 29 None
# 3547
# 0 find
# 1 trump
# 2 buffoonery
# 3 utterly
# 4 disgraceful
# 5 a
# 6 sign
# 7 of
# 8 authenticity
# 9 may
# 10 mark
# 11 our
# 12 central
# 13 political
# 14 divide
# 15 today
# 16 None
# 17 None
# 3548
# 0 why
# 1 republicans
# 2 like
# 3 mcconnell
# 4 complaining
# 5 about
# 6 federal
# 7 entitlements
# 8 is
# 9 so
# 10 laughable
# 11 None
# 12 None
# 3549
# 0 number
# 1 of
# 2 transgender
# 3 advocates
# 4 lgbtq
# 5 health
# 6 experts
# 7 applauded
# 8 p&g
# 9 decision
# 10 redesign
# 11 the
# 12 always
# 13 packaging
# 14 by
# 15 removing
# 16 the
# 17 female
# 18 signs
# 19 the
# 20 company
# 21 announcement
# 22 sparked
# 23 criticism
# 24 online
# 25 including
# 26 a
# 27 bounty
# 28 of
# 29 transphobic
# 30 commentary
# 31 None
# 32 None
# 3550
# 0 still
# 1 cling
# 2 to
# 3 sexist
# 4 gender
# 5 roles
# 6 at
# 7 home
# 8 overwhelming
# 9 majorities
# 10 believe
# 11 that
# 12 sex
# 13 discrimination
# 14 in
# 15 public
# 16 spaces
# 17 should
# 18 be
# 19 illegal
# 20 None
# 21 None
# 3551
# 0 republican
# 1 president
# 2 donald
# 3 trump
# 4 have
# 5 focused
# 6 blame
# 7 on
# 8 antifa
# 9 a
# 10 loosely
# 11 organized
# 12 anti
# 13 -
# 14 fascist
# 15 movement
# 16 federal
# 17 prosecutors
# 18 in
# 19 las
# 20 vegas
# 21 on
# 22 wednesday
# 23 charged
# 24 members
# 25 of
# 26 the
# 27 far
# 28 right
# 29 boogaloo
# 30 movement
# 31 with
# 32 planning
# 33 cause
# 34 violence
# 35 destruction
# 36 during
# 37 protests
# 38 None
# 39 None
# 3552
# 0 has
# 1 taken
# 2 the
# 3 lead
# 4 in
# 5 a
# 6 direct
# 7 attack
# 8 on
# 9 the
# 10 amazon
# 11 with
# 12 bolsonaro
# 13 adding
# 14 a
# 15 racial
# 16 element
# 17 to
# 18 his
# 19 attack
# 20 on
# 21 indigenous
# 22 people
# 23 the
# 24 pressure
# 25 open
# 26 the
# 27 amazonian
# 28 forests
# 29 to
# 30 agriculture
# 31 logging
# 32 mining
# 33 is
# 34 just
# 35 limited
# 36 to
# 37 brazil
# 38 None
# 39 None
# 3553
# 0 may
# 1 find
# 2 comfort
# 3 in
# 4 the
# 5 old
# 6 saw
# 7 that
# 8 those
# 9 who
# 10 are
# 11 liberal
# 12 at
# 13 have
# 14 no
# 15 heart
# 16 those
# 17 who
# 18 are
# 19 conservative
# 20 at
# 21 have
# 22 no
# 23 brain
# 24 the
# 25 truth
# 26 as
# 27 levin
# 28 knows
# 29 is
# 30 that
# 31 those
# 32 who
# 33 are
# 34 statists
# 35 at
# 36 usually
# 37 end
# 38 up
# 39 statists
# 40 at
# 41 he
# 42 ’s
# 43 content
# 44 allow
# 45 time
# 46 take
# 47 its
# 48 uncertain
# 49 political
# 50 toll
# 51 None
# 52 None
# 3554
# 0 media
# 1 hypocritical
# 2 politicians
# 3 others
# 4 labeled
# 5 anyone
# 6 in
# 7 favor
# 8 of
# 9 reopening
# 10 the
# 11 economy
# 12 getting
# 13 kids
# 14 back
# 15 in
# 16 school
# 17 even
# 18 gathering
# 19 for
# 20 holidays
# 21 a
# 22 grandma
# 23 killer
# 24 expert
# 25 in
# 26 ethics
# 27 health
# 28 policy
# 29 in
# 30 the
# 31 new
# 32 york
# 33 times
# 34 says
# 35 that
# 36 vaccinating
# 37 elderly
# 38 people
# 39 first
# 40 is
# 41 racist
# 42 None
# 43 None
# 3555
# 0 presidential
# 1 hopefuls
# 2 aim
# 3 weaponize
# 4 the
# 5 tax
# 6 cuts
# 7 elaine
# 8 parker
# 9 chief
# 10 communications
# 11 officer
# 12 of
# 13 job
# 14 creators
# 15 network
# 16 jcn
# 17 told
# 18 breitbart
# 19 news
# 20 in
# 21 an
# 22 exclusive
# 23 interview
# 24 in
# 25 january
# 26 that
# 27 it
# 28 is
# 29 precisely
# 30 what
# 31 will
# 32 assist
# 33 trump
# 34 in
# 35 making
# 36 his
# 37 case
# 38 to
# 39 the
# 40 american
# 41 people
# 42 None
# 43 None
# 3556
# 0 were
# 1 busy
# 2 diverting
# 3 the
# 4 attention
# 5 energy
# 6 of
# 7 the
# 8 entire
# 9 country
# 10 into
# 11 a
# 12 pointless
# 13 trial
# 14 that
# 15 could
# 16 possibly
# 17 have
# 18 ended
# 19 in
# 20 anything
# 21 other
# 22 than
# 23 president
# 24 donald
# 25 trump
# 26 acquittal
# 27 None
# 28 None
# 3557
# 0 were
# 1 diverting
# 2 the
# 3 attention
# 4 energy
# 5 of
# 6 the
# 7 entire
# 8 country
# 9 into
# 10 a
# 11 pointless
# 12 trial
# 13 that
# 14 could
# 15 possibly
# 16 have
# 17 ended
# 18 in
# 19 anything
# 20 other
# 21 than
# 22 president
# 23 donald
# 24 trump
# 25 acquittal
# 26 None
# 27 None
# 3558
# 0 were
# 1 persistent
# 2 in
# 3 their
# 4 questioning
# 5 the
# 6 hearing
# 7 retained
# 8 a
# 9 respectful
# 10 tone
# 11 barrett
# 12 remained
# 13 even
# 14 tempered
# 15 while
# 16 nimbly
# 17 sidestepping
# 18 questions
# 19 on
# 20 her
# 21 views
# 22 on
# 23 abortion
# 24 lgbt
# 25 rights
# 26 gun
# 27 control
# 28 voting
# 29 rights
# 30 None
# 31 None
# 3559
# 0 sport
# 1 has
# 2 its
# 3 own
# 4 rules
# 5 with
# 6 regards
# 7 to
# 8 religious
# 9 headwear
# 10 muslim
# 11 women
# 12 who
# 13 compete
# 14 while
# 15 wearing
# 16 a
# 17 hijab
# 18 have
# 19 faced
# 20 a
# 21 litany
# 22 of
# 23 obstacles
# 24 None
# 25 None
# 3560
# 0 he
# 1 ’s
# 2 singling
# 3 out
# 4 party
# 5 cohen
# 6 warned
# 7 about
# 8 the
# 9 danger
# 10 of
# 11 normalizing
# 12 white
# 13 supremacist
# 14 ideology
# 15 None
# 16 None
# 3561
# 0 short
# 1 of
# 2 calling
# 3 half
# 4 the
# 5 nation
# 6 deplorable
# 7 as
# 8 former
# 9 secretary
# 10 of
# 11 state
# 12 hillary
# 13 clinton
# 14 did
# 15 in
# 16 the
# 17 comments
# 18 echo
# 19 a
# 20 deep
# 21 disdain
# 22 for
# 23 a
# 24 large
# 25 population
# 26 of
# 27 the
# 28 country
# 29 increasingly
# 30 perpetuated
# 31 by
# 32 left
# 33 wing
# 34 elites
# 35 in
# 36 the
# 37 wake
# 38 of
# 39 the
# 40 george
# 41 floyd
# 42 protests
# 43 characterizing
# 44 the
# 45 u.s.
# 46 as
# 47 irredeemably
# 48 racist
# 49 None
# 50 None
# 3562
# 0 experts
# 1 say
# 2 a
# 3 vaccine
# 4 prevent
# 5 infection
# 6 is
# 7 needed
# 8 return
# 9 life
# 10 to
# 11 normal
# 12 the
# 13 survey
# 14 points
# 15 to
# 16 a
# 17 potential
# 18 trust
# 19 issue
# 20 for
# 21 the
# 22 trump
# 23 administration
# 24 already
# 25 under
# 26 fire
# 27 for
# 28 its
# 29 often
# 30 contradictory
# 31 safety
# 32 guidance
# 33 during
# 34 the
# 35 pandemic
# 36 None
# 37 None
# 3563
# 0 supporters
# 1 have
# 2 included
# 3 many
# 4 strains
# 5 of
# 6 nationalism
# 7 populism
# 8 he
# 9 did
# 10 run
# 11 as
# 12 a
# 13 republican
# 14 this
# 15 will
# 16 hopefully
# 17 work
# 18 in
# 19 his
# 20 favor
# 21 many
# 22 americans
# 23 are
# 24 hopeful
# 25 excited
# 26 looking
# 27 forward
# 28 to
# 29 a
# 30 trump
# 31 presidency
# 32 here
# 33 are
# 34 some
# 35 of
# 36 the
# 37 reasons
# 38 why
# 39 None
# 40 None
# 3564
# 0 ’s
# 1 perfectly
# 2 evident
# 3 that
# 4 trump
# 5 does
# 6 have
# 7 racist
# 8 supporters
# 9 which
# 10 he
# 11 is
# 12 suspiciously
# 13 reluctant
# 14 condemn
# 15 many
# 16 contend
# 17 that
# 18 trumpism
# 19 is
# 20 itself
# 21 racist
# 22 merely
# 23 a
# 24 justified
# 25 reaction
# 26 to
# 27 the
# 28 left
# 29 racial
# 30 patronage
# 31 None
# 32 None
# 3565
# 0 americans
# 1 on
# 2 racism
# 3 big
# 4 business
# 5 opposes
# 6 ban
# 7 on
# 8 using
# 9 foreign
# 10 slave
# 11 labor
# 12 None
# 13 None
# 3566
# 0 unemployment
# 1 steadily
# 2 if
# 3 slowly
# 4 rising
# 5 wages
# 6 have
# 7 improved
# 8 the
# 9 fortunes
# 10 of
# 11 lower
# 12 income
# 13 americans
# 14 these
# 15 gains
# 16 pale
# 17 in
# 18 comparison
# 19 to
# 20 the
# 21 investment
# 22 gains
# 23 realized
# 24 by
# 25 the
# 26 wealthy
# 27 few
# 28 None
# 29 None
# 3567
# 0 things
# 1 were
# 2 certain
# 3 change
# 4 the
# 5 president
# 6 felt
# 7 sure
# 8 that
# 9 element
# 10 of
# 11 continuity
# 12 would
# 13 persist
# 14 the
# 15 united
# 16 states
# 17 would
# 18 determine
# 19 history
# 20 onward
# 21 course
# 22 None
# 23 None
# 3568
# 0 women
# 1 the
# 2 men
# 3 who
# 4 love
# 5 them
# 6 are
# 7 well
# 8 aware
# 9 that
# 10 spurred
# 11 on
# 12 by
# 13 the
# 14 vatican
# 15 united
# 16 states
# 17 conference
# 18 of
# 19 catholic
# 20 bishops
# 21 usccb
# 22 the
# 23 so
# 24 called
# 25 personhood
# 26 movement
# 27 republicans
# 28 are
# 29 working
# 30 feverishly
# 31 eradicate
# 32 women
# 33 reproductive
# 34 rights
# 35 None
# 36 None
# 3569
# 0 national
# 1 attention
# 2 has
# 3 been
# 4 focused
# 5 on
# 6 massive
# 7 demonstrations
# 8 violent
# 9 clashes
# 10 with
# 11 police
# 12 in
# 13 the
# 14 united
# 15 states
# 16 biggest
# 17 cities
# 18 like
# 19 new
# 20 york
# 21 los
# 22 angeles
# 23 hundreds
# 24 of
# 25 spontaneous
# 26 demonstrations
# 27 have
# 28 popped
# 29 up
# 30 in
# 31 little
# 32 towns
# 33 rural
# 34 areas
# 35 across
# 36 the
# 37 nation
# 38 in
# 39 recent
# 40 days
# 41 None
# 42 None
# 3570
# 0 one
# 1 is
# 2 praising
# 3 trump
# 4 as
# 5 a
# 6 thought
# 7 leader
# 8 in
# 9 the
# 10 way
# 11 limbaugh
# 12 has
# 13 been
# 14 he
# 15 ’s
# 16 undeniably
# 17 made
# 18 conservative
# 19 ideas
# 20 tangible
# 21 for
# 22 average
# 23 americans
# 24 None
# 25 None
# 3571
# 0 has
# 1 largely
# 2 tamed
# 3 the
# 4 lethal
# 5 highly
# 6 contagious
# 7 coronavirus
# 8 another
# 9 epidemic
# 10 is
# 11 starting
# 12 rear
# 13 its
# 14 ugly
# 15 head
# 16 in
# 17 the
# 18 city
# 19 once
# 20 again
# 21 violent
# 22 crimes
# 23 None
# 24 None
# 3572
# 0 is
# 1 in
# 2 no
# 3 danger
# 4 of
# 5 being
# 6 held
# 7 accountable
# 8 for
# 9 her
# 10 extremism
# 11 her
# 12 ascent
# 13 to
# 14 rock
# 15 star
# 16 status
# 17 among
# 18 democrats
# 19 their
# 20 media
# 21 cheering
# 22 section
# 23 gives
# 24 the
# 25 lie
# 26 to
# 27 their
# 28 claims
# 29 be
# 30 standing
# 31 up
# 32 against
# 33 hate
# 34 antisemitism
# 35 None
# 36 None
# 3573
# 0 zone
# 1 program
# 2 that
# 3 offers
# 4 tax
# 5 breaks
# 6 to
# 7 investors
# 8 who
# 9 put
# 10 money
# 11 into
# 12 specially
# 13 designated
# 14 areas
# 15 was
# 16 pitched
# 17 as
# 18 a
# 19 way
# 20 help
# 21 struggling
# 22 neighborhoods
# 23 propublica
# 24 others
# 25 have
# 26 documented
# 27 how
# 28 the
# 29 process
# 30 has
# 31 appeared
# 32 benefit
# 33 billionaires
# 34 with
# 35 investments
# 36 in
# 37 areas
# 38 that
# 39 should
# 40 have
# 41 qualified
# 42 None
# 43 None
# 3574
# 0 receives
# 1 her
# 2 spiritual
# 3 grace
# 4 from
# 5 a
# 6 christian
# 7 god
# 8 science
# 9 has
# 10 shown
# 11 that
# 12 faith
# 13 in
# 14 a
# 15 supernatural
# 16 wonder
# 17 whatever
# 18 it
# 19 may
# 20 be
# 21 that
# 22 bears
# 23 powerful
# 24 benefits
# 25 on
# 26 an
# 27 individual
# 28 mental
# 29 even
# 30 physical
# 31 well
# 32 being
# 33 None
# 34 None
# 3575
# 0 the
# 1 president
# 2 have
# 3 tried
# 4 paint
# 5 a
# 6 rosier
# 7 picture
# 8 of
# 9 the
# 10 virus
# 11 project
# 12 a
# 13 return
# 14 to
# 15 normalcy
# 16 some
# 17 members
# 18 of
# 19 the
# 20 task
# 21 force
# 22 are
# 23 eager
# 24 resume
# 25 appearances
# 26 from
# 27 white
# 28 house
# 29 grounds
# 30 None
# 31 None
# 3576
# 0 donald
# 1 trump
# 2 impeachment
# 3 trial
# 4 had
# 5 been
# 6 wrapping
# 7 up
# 8 he
# 9 expanded
# 10 of
# 11 his
# 12 most
# 13 controversial
# 14 inflammatory
# 15 policies
# 16 with
# 17 little
# 18 fanfare
# 19 minimal
# 20 opposition
# 21 the
# 22 travel
# 23 ban
# 24 on
# 25 people
# 26 from
# 27 multiple
# 28 muslim
# 29 majority
# 30 countries
# 31 None
# 32 None
# 3577
# 0 trump
# 1 visited
# 2 the
# 3 southern
# 4 border
# 5 thursday
# 6 democratic
# 7 darling
# 8 beto
# 9 o’rourke
# 10 visited
# 11 the
# 12 dentist
# 13 posting
# 14 a
# 15 bizarre
# 16 video
# 17 showing
# 18 him
# 19 getting
# 20 a
# 21 mouth
# 22 wide
# 23 open
# 24 cleaning
# 25 in
# 26 order
# 27 highlight
# 28 the
# 29 story
# 30 of
# 31 his
# 32 dental
# 33 hygienist
# 34 ’s
# 35 upbringing
# 36 in
# 37 el
# 38 paso
# 39 None
# 40 None
# 3578
# 0 raged
# 1 across
# 2 the
# 3 united
# 4 states
# 5 over
# 6 floyd
# 7 death
# 8 editors
# 9 on
# 10 wikipedia
# 11 promptly
# 12 set
# 13 out
# 14 spin
# 15 the
# 16 narrative
# 17 of
# 18 the
# 19 unrest
# 20 against
# 21 trump
# 22 None
# 23 None
# 3579
# 0 ambiguity
# 1 does
# 2 occasionally
# 3 occur
# 4 the
# 5 authors
# 6 note
# 7 intersex
# 8 individuals
# 9 are
# 10 extremely
# 11 rare
# 12 they
# 13 are
# 14 a
# 15 third
# 16 sex
# 17 proof
# 18 that
# 19 sex
# 20 is
# 21 a
# 22 spectrum
# 23 a
# 24 social
# 25 construct
# 26 None
# 27 None
# 3580
# 0 is
# 1 happy
# 2 blame
# 3 president
# 4 trump
# 5 who
# 6 is
# 7 working
# 8 restore
# 9 order
# 10 for
# 11 the
# 12 ongoing
# 13 violence
# 14 it
# 15 has
# 16 said
# 17 anything
# 18 about
# 19 support
# 20 for
# 21 the
# 22 domestic
# 23 terrorist
# 24 antifa
# 25 movement
# 26 on
# 27 its
# 28 platform
# 29 None
# 30 None
# 3581
# 0 announcement
# 1 identifies
# 2 cases
# 3 of
# 4 alleged
# 5 police
# 6 misconduct
# 7 it
# 8 does
# 9 mention
# 10 violence
# 11 accompanying
# 12 the
# 13 protests
# 14 over
# 15 floyd
# 16 death
# 17 that
# 18 the
# 19 foundation
# 20 is
# 21 now
# 22 backing
# 23 None
# 24 None
# 3582
# 0 major
# 1 baseball
# 2 leagues
# 3 wo
# 4 be
# 5 affected
# 6 much
# 7 by
# 8 tariffs
# 9 on
# 10 chinese
# 11 imports
# 12 everyone
# 13 from
# 14 double
# 15 a
# 16 players
# 17 down
# 18 through
# 19 the
# 20 office
# 21 softball
# 22 team
# 23 will
# 24 be
# 25 None
# 26 None
# 3583
# 0 majority
# 1 of
# 2 americans
# 3 seem
# 4 accept
# 5 scientific
# 6 information
# 7 about
# 8 the
# 9 deadly
# 10 coronavirus
# 11 are
# 12 wary
# 13 of
# 14 reopening
# 15 the
# 16 country
# 17 before
# 18 we
# 19 can
# 20 be
# 21 sure
# 22 it
# 23 ’s
# 24 safe
# 25 segment
# 26 of
# 27 the
# 28 population
# 29 is
# 30 driving
# 31 the
# 32 opposite
# 33 narrative
# 34 this
# 35 group
# 36 is
# 37 small
# 38 vocal
# 39 represents
# 40 a
# 41 predictable
# 42 if
# 43 threatening
# 44 merging
# 45 of
# 46 forces
# 47 None
# 48 None
# 3584
# 0 mayor
# 1 has
# 2 severely
# 3 curtailed
# 4 religious
# 5 practice
# 6 in
# 7 the
# 8 city
# 9 he
# 10 has
# 11 defended
# 12 the
# 13 rights
# 14 of
# 15 citizens
# 16 form
# 17 huge
# 18 gatherings
# 19 protest
# 20 even
# 21 violently
# 22 obviously
# 23 without
# 24 social
# 25 distancing
# 26 masks
# 27 except
# 28 perhaps
# 29 antifa
# 30 masks
# 31 None
# 32 None
# 3585
# 0 overwhelming
# 1 majority
# 2 of
# 3 americans
# 4 choose
# 5 have
# 6 their
# 7 children
# 8 vaccinated
# 9 the
# 10 number
# 11 of
# 12 children
# 13 who
# 14 go
# 15 completely
# 16 unvaccinated
# 17 is
# 18 rising
# 19 None
# 20 None
# 3586
# 0 piece
# 1 fairly
# 2 analyzes
# 3 the
# 4 fracturing
# 5 of
# 6 the
# 7 white
# 8 nationalist
# 9 movement
# 10 it
# 11 makes
# 12 the
# 13 bizarre
# 14 claim
# 15 that
# 16 ideas
# 17 that
# 18 are
# 19 widely
# 20 popular
# 21 amongst
# 22 mainstream
# 23 conservatives
# 24 such
# 25 as
# 26 ending
# 27 affirmative
# 28 action
# 29 are
# 30 actually
# 31 white
# 32 nationalist
# 33 in
# 34 origin
# 35 None
# 36 None
# 3587
# 0 press
# 1 had
# 2 no
# 3 problem
# 4 regurgitating
# 5 the
# 6 propaganda
# 7 ben
# 8 rhodes
# 9 created
# 10 in
# 11 the
# 12 d.c.
# 13 echo
# 14 chamber
# 15 sell
# 16 president
# 17 obama
# 18 disastrous
# 19 iran
# 20 deal
# 21 with
# 22 trump
# 23 corporate
# 24 media
# 25 has
# 26 opted
# 27 limit
# 28 coverage
# 29 of
# 30 iran
# 31 horrific
# 32 human
# 33 rights
# 34 abuses
# 35 None
# 36 None
# 3588
# 0 stupid
# 1 democrats
# 2 who
# 3 vote
# 4 for
# 5 democrats
# 6 stress
# 7 worry
# 8 about
# 9 another
# 10 round
# 11 of
# 12 looting
# 13 burning
# 14 this
# 15 weekend
# 16 in
# 17 their
# 18 democrat
# 19 run
# 20 cities
# 21 all
# 22 i
# 23 ’m
# 24 worried
# 25 about
# 26 is
# 27 the
# 28 weather
# 29 None
# 30 None
# 3589
# 0 threat
# 1 of
# 2 anti
# 3 -
# 4 trans
# 5 bills
# 6 being
# 7 passed
# 8 into
# 9 law
# 10 is
# 11 real
# 12 present
# 13 all
# 14 such
# 15 legislation
# 16 will
# 17 almost
# 18 certainly
# 19 be
# 20 challenged
# 21 in
# 22 the
# 23 courts
# 24 immediately
# 25 upon
# 26 passing
# 27 before
# 28 it
# 29 can
# 30 be
# 31 fully
# 32 implemented
# 33 None
# 34 None
# 3590
# 0 workaday
# 1 majority
# 2 of
# 3 americans
# 4 continue
# 5 be
# 6 mired
# 7 in
# 8 our
# 9 low
# 10 wage
# 11 economy
# 12 the
# 13 precious
# 14 few
# 15 at
# 16 the
# 17 tippy
# 18 top
# 19 soared
# 20 out
# 21 of
# 22 sight
# 23 in
# 24 None
# 25 None
# 3591
# 0 many
# 1 similarities
# 2 between
# 3 green
# 4 new
# 5 deal
# 6 the
# 7 constitution
# 8 ushered
# 9 in
# 10 by
# 11 venezuelan
# 12 leftist
# 13 dictator
# 14 hugo
# 15 chavez
# 16 in
# 17 may
# 18 be
# 19 just
# 20 happenstance
# 21 the
# 22 important
# 23 thing
# 24 remember
# 25 is
# 26 that
# 27 venezuela
# 28 under
# 29 its
# 30 new
# 31 constitution
# 32 has
# 33 become
# 34 a
# 35 disaster
# 36 zone
# 37 None
# 38 None
# 3592
# 0 has
# 1 stopped
# 2 short
# 3 of
# 4 invoking
# 5 the
# 6 act
# 7 use
# 8 the
# 9 military
# 10 enforce
# 11 laws
# 12 domestically
# 13 he
# 14 ’s
# 15 kept
# 16 the
# 17 option
# 18 open
# 19 fomenting
# 20 further
# 21 unrest
# 22 division
# 23 rather
# 24 than
# 25 staging
# 26 photo
# 27 opportunities
# 28 while
# 29 awkwardly
# 30 holding
# 31 a
# 32 bible
# 33 in
# 34 lafayette
# 35 square
# 36 trump
# 37 would
# 38 have
# 39 issued
# 40 a
# 41 formal
# 42 proclamation
# 43 calling
# 44 on
# 45 the
# 46 insurgents
# 47 disperse
# 48 if
# 49 he
# 50 ’s
# 51 serious
# 52 about
# 53 the
# 54 application
# 55 of
# 56 the
# 57 insurrection
# 58 act
# 59 None
# 60 None
# 3593
# 0 the
# 1 wake
# 2 of
# 3 the
# 4 el
# 5 paso
# 6 murders
# 7 the
# 8 media
# 9 most
# 10 of
# 11 our
# 12 politicians
# 13 are
# 14 acting
# 15 shocked
# 16 that
# 17 there
# 18 are
# 19 armed
# 20 racists
# 21 in
# 22 america
# 23 who
# 24 are
# 25 trying
# 26 terrify
# 27 people
# 28 of
# 29 color
# 30 the
# 31 reality
# 32 is
# 33 that
# 34 it
# 35 ’s
# 36 pretty
# 37 much
# 38 always
# 39 been
# 40 that
# 41 way
# 42 here
# 43 in
# 44 the
# 45 united
# 46 states
# 47 None
# 48 None
# 3594
# 0 the
# 1 wake
# 2 of
# 3 the
# 4 el
# 5 paso
# 6 murders
# 7 the
# 8 media
# 9 most
# 10 of
# 11 our
# 12 politicians
# 13 are
# 14 acting
# 15 shocked—“shocked
# 16 i
# 17 tell
# 18 you!”—that
# 19 there
# 20 are
# 21 armed
# 22 racists
# 23 in
# 24 america
# 25 who
# 26 are
# 27 trying
# 28 terrify
# 29 people
# 30 of
# 31 color
# 32 the
# 33 reality
# 34 is
# 35 that
# 36 it
# 37 ’s
# 38 pretty
# 39 much
# 40 always
# 41 been
# 42 that
# 43 way
# 44 here
# 45 in
# 46 the
# 47 united
# 48 states
# 49 None
# 50 None
# 3595
# 0 national
# 1 economic
# 2 council
# 3 director
# 4 larry
# 5 kudlow
# 6 said
# 7 on
# 8 friday
# 9 that
# 10 he
# 11 did
# 12 favor
# 13 a
# 14 higher
# 15 federal
# 16 tax
# 17 on
# 18 gasoline
# 19 fund
# 20 an
# 21 infrastructure
# 22 program
# 23 if
# 24 states
# 25 wanted
# 26 raise
# 27 their
# 28 own
# 29 gas
# 30 taxes
# 31 that
# 32 was
# 33 up
# 34 to
# 35 them
# 36 None
# 37 None
# 3596
# 0 press
# 1 secretary
# 2 kayleigh
# 3 mcenany
# 4 voiced
# 5 tepid
# 6 support
# 7 for
# 8 defense
# 9 secretary
# 10 mark
# 11 esper
# 12 after
# 13 he
# 14 stated
# 15 wednesday
# 16 that
# 17 he
# 18 did
# 19 support
# 20 invoking
# 21 the
# 22 insurrection
# 23 act
# 24 which
# 25 would
# 26 allow
# 27 active
# 28 duty
# 29 troops
# 30 act
# 31 in
# 32 domestic
# 33 law
# 34 enforcement
# 35 roles
# 36 None
# 37 None
# 3597
# 0 senior
# 1 adviser
# 2 jared
# 3 kushner
# 4 criticized
# 5 athletes
# 6 others
# 7 who
# 8 have
# 9 protested
# 10 against
# 11 u.s.
# 12 racism
# 13 on
# 14 social
# 15 media
# 16 basketball
# 17 courts
# 18 suggested
# 19 that
# 20 black
# 21 people
# 22 had
# 23 want
# 24 succeed
# 25 for
# 26 policies
# 27 change
# 28 None
# 29 None
# 3598
# 0 have
# 1 once
# 2 again
# 3 moved
# 4 out
# 5 of
# 6 the
# 7 shadows
# 8 into
# 9 the
# 10 limelight
# 11 during
# 12 this
# 13 trump
# 14 moment
# 15 None
# 16 None
# 3599
# 0 fueled
# 1 violence
# 2 is
# 3 on
# 4 the
# 5 rise
# 6 fbi
# 7 is
# 8 slow
# 9 call
# 10 it
# 11 domestic
# 12 terrorism
# 13 None
# 14 None
# 3600
# 0 arrested
# 1 for
# 2 alleged
# 3 threat
# 4 against
# 5 ohio
# 6 jewish
# 7 community
# 8 center
# 9 None
# 10 None
# 3601
# 0 also
# 1 expressed
# 2 excitement
# 3 tuesday
# 4 about
# 5 trump
# 6 plan
# 7 use
# 8 an
# 9 executive
# 10 order
# 11 end
# 12 birthright
# 13 citizenship
# 14 the
# 15 automatic
# 16 grant
# 17 of
# 18 citizen
# 19 status
# 20 to
# 21 anyone
# 22 born
# 23 in
# 24 the
# 25 united
# 26 states
# 27 None
# 28 None
# 3602
# 0 are
# 1 being
# 2 asked
# 3 pushed
# 4 take
# 5 stock
# 6 of
# 7 their
# 8 whiteness
# 9 identify
# 10 with
# 11 it
# 12 more
# 13 this
# 14 is
# 15 a
# 16 remarkably
# 17 bad
# 18 idea
# 19 None
# 20 None
# 3603
# 0 violent
# 1 extremists
# 2 can
# 3 generally
# 4 be
# 5 characterized
# 6 by
# 7 hatred
# 8 for
# 9 immigrants
# 10 ethnic
# 11 minorities
# 12 often
# 13 combining
# 14 these
# 15 prejudices
# 16 with
# 17 virulent
# 18 anti
# 19 -
# 20 semitism
# 21 anti
# 22 -
# 23 muslim
# 24 views
# 25 the
# 26 dhs
# 27 report
# 28 states
# 29 None
# 30 None
# 3604
# 0 on
# 1 trump
# 2 for
# 3 claiming
# 4 the
# 5 economy
# 6 is
# 7 booming
# 8 asking
# 9 for
# 10 whom
# 11 she
# 12 details
# 13 local
# 14 pieces
# 15 of
# 16 legislation
# 17 dem
# 18 governors
# 19 are
# 20 working
# 21 on
# 22 before
# 23 claiming
# 24 democrats
# 25 are
# 26 the
# 27 ones
# 28 who
# 29 actually
# 30 fight
# 31 for
# 32 hardworking
# 33 americans
# 34 None
# 35 None
# 3605
# 0 working
# 1 ensure
# 2 fair
# 3 vaccine
# 4 distribution
# 5 in
# 6 the
# 7 meantime
# 8 it
# 9 is
# 10 key
# 11 suppress
# 12 the
# 13 virus
# 14 spread
# 15 said
# 16 mike
# 17 ryan
# 18 head
# 19 of
# 20 who
# 21 emergencies
# 22 program
# 23 as
# 24 daily
# 25 new
# 26 cases
# 27 around
# 28 the
# 29 globe
# 30 are
# 31 at
# 32 near
# 33 record
# 34 levels
# 35 None
# 36 None
# 3606
# 0 members
# 1 of
# 2 the
# 3 fairer
# 4 sex
# 5 on
# 6 the
# 7 frontlines
# 8 of
# 9 riotous
# 10 efforts
# 11 support
# 12 a
# 13 movement
# 14 that
# 15 insists
# 16 they
# 17 're
# 18 racist
# 19 capitalism
# 20 is
# 21 racist
# 22 the
# 23 whole
# 24 system
# 25 is
# 26 racist
# 27 None
# 28 None
# 3607
# 0 democrats
# 1 vote
# 2 overwhelmingly
# 3 against
# 4 a
# 5 bill
# 6 that
# 7 would
# 8 require
# 9 infants
# 10 born
# 11 alive
# 12 after
# 13 abortion
# 14 be
# 15 treated
# 16 as
# 17 any
# 18 other
# 19 infant
# 20 born
# 21 at
# 22 that
# 23 gestational
# 24 age
# 25 because
# 26 abortion
# 27 is
# 28 the
# 29 right
# 30 destroy
# 31 own
# 32 child
# 33 if
# 34 a
# 35 woman
# 36 chose
# 37 kill
# 38 her
# 39 baby
# 40 to
# 41 the
# 42 left
# 43 it
# 44 would
# 45 seem
# 46 a
# 47 violation
# 48 of
# 49 her
# 50 so
# 51 called
# 52 right
# 53 choose
# 54 for
# 55 doctors
# 56 try
# 57 save
# 58 that
# 59 baby
# 60 None
# 61 None
# 3608
# 0 trump
# 1 offer
# 2 up
# 3 this
# 4 cards
# 5 that
# 6 's
# 7 because
# 8 his
# 9 vaunted
# 10 skills
# 11 in
# 12 making
# 13 the
# 14 deal
# 15 absolutely
# 16 failed
# 17 budge
# 18 the
# 19 prices
# 20 from
# 21 pharmaceutical
# 22 companies
# 23 a
# 24 deal
# 25 that
# 26 had
# 27 been
# 28 in
# 29 the
# 30 works
# 31 for
# 32 months
# 33 absolutely
# 34 collapsed
# 35 None
# 36 None
# 3609
# 0 have
# 1 abortions
# 2 is
# 3 a
# 4 topic
# 5 much
# 6 discussed
# 7 by
# 8 those
# 9 who
# 10 argue
# 11 that
# 12 ending
# 13 a
# 14 life
# 15 in
# 16 the
# 17 womb
# 18 is
# 19 sometimes
# 20 necessary
# 21 None
# 22 None
# 3610
# 0 of
# 1 other
# 2 contentious
# 3 political
# 4 topics
# 5 such
# 6 as
# 7 abortion
# 8 were
# 9 also
# 10 criticized
# 11 with
# 12 sanger
# 13 singling
# 14 out
# 15 wikipedia
# 16 claiming
# 17 abortion
# 18 is
# 19 of
# 20 the
# 21 safest
# 22 procedures
# 23 in
# 24 medicine
# 25 None
# 26 None
# 3611
# 0 articles
# 1 on
# 2 the
# 3 floyd
# 4 protests
# 5 similarly
# 6 reflect
# 7 the
# 8 foundation
# 9 abandonment
# 10 of
# 11 neutrality
# 12 by
# 13 being
# 14 unduly
# 15 skewed
# 16 towards
# 17 smearing
# 18 president
# 19 donald
# 20 trump
# 21 while
# 22 downplaying
# 23 protestor
# 24 violence
# 25 the
# 26 violent
# 27 antifa
# 28 group
# 29 involvement
# 30 None
# 31 None
# 3612
# 0 gender
# 1 dysphoria
# 2 is
# 3 a
# 4 mental
# 5 health
# 6 issue
# 7 parents
# 8 have
# 9 the
# 10 right
# 11 make
# 12 healthcare
# 13 decisions
# 14 on
# 15 behalf
# 16 of
# 17 their
# 18 children
# 19 None
# 20 None
# 3613
# 0 american
# 1 people
# 2 follow
# 3 the
# 4 commands
# 5 of
# 6 donald
# 7 trump
# 8 coronavirus
# 9 death
# 10 cult
# 11 None
# 12 None
# 3614
# 0 have
# 1 received
# 2 death
# 3 threats
# 4 for
# 5 the
# 6 crime
# 7 of
# 8 poking
# 9 fun
# 10 at
# 11 donald
# 12 trump
# 13 the
# 14 members
# 15 of
# 16 his
# 17 political
# 18 cult
# 19 None
# 20 None
# 3615
# 0 the
# 1 first
# 2 african
# 3 american
# 4 be
# 5 named
# 6 as
# 7 cardinal
# 8 known
# 9 as
# 10 a
# 11 refined
# 12 diplomat
# 13 made
# 14 headlines
# 15 when
# 16 he
# 17 blasted
# 18 president
# 19 donald
# 20 trump
# 21 photo
# 22 opportunity
# 23 hoisting
# 24 a
# 25 bible
# 26 at
# 27 a
# 28 washington
# 29 church
# 30 after
# 31 police
# 32 used
# 33 tear
# 34 gas
# 35 clear
# 36 demonstrators
# 37 in
# 38 june
# 39 None
# 40 None
# 3616
# 0 navratilova
# 1 who
# 2 has
# 3 campaigned
# 4 for
# 5 gay
# 6 rights
# 7 suffered
# 8 abuse
# 9 when
# 10 she
# 11 came
# 12 out
# 13 in
# 14 the
# 15 1980s
# 16 argued
# 17 trans
# 18 women
# 19 have
# 20 unfair
# 21 physical
# 22 advantages
# 23 None
# 24 None
# 3617
# 0 was
# 1 a
# 2 racist
# 3 so
# 4 the
# 5 black
# 6 lives
# 7 matter
# 8 graffiti
# 9 says
# 10 on
# 11 the
# 12 plinth
# 13 of
# 14 his
# 15 statue
# 16 in
# 17 london
# 18 parliament
# 19 square
# 20 which
# 21 is
# 22 bound
# 23 be
# 24 pulled
# 25 down
# 26 by
# 27 hard
# 28 left
# 29 activists
# 30 sooner
# 31 later
# 32 because
# 33 the
# 34 police
# 35 do
# 36 seem
# 37 have
# 38 that
# 39 much
# 40 of
# 41 an
# 42 appetite
# 43 save
# 44 it
# 45 None
# 46 None
# 3618
# 0 fuming
# 1 over
# 2 trump
# 3 push
# 4 for
# 5 a
# 6 border
# 7 wall
# 8 amid
# 9 a
# 10 still
# 11 unresolved
# 12 funding
# 13 standoff
# 14 those
# 15 guest
# 16 lists
# 17 signal
# 18 the
# 19 president
# 20 could
# 21 face
# 22 a
# 23 tough
# 24 crowd
# 25 None
# 26 None
# 3619
# 0 of
# 1 potential
# 2 vaccines
# 3 in
# 4 various
# 5 stages
# 6 of
# 7 development
# 8 around
# 9 the
# 10 world
# 11 russia
# 12 was
# 13 the
# 14 first
# 15 country
# 16 license
# 17 its
# 18 vaccine
# 19 for
# 20 public
# 21 use
# 22 alongside
# 23 china
# 24 has
# 25 been
# 26 deploying
# 27 the
# 28 shots
# 29 before
# 30 full
# 31 efficacy
# 32 trials
# 33 are
# 34 complete
# 35 None
# 36 None
# 3620
# 0 ’s
# 1 bothsidesism
# 2 pro
# 3 -
# 4 trump
# 5 onesiderism
# 6 the
# 7 new
# 8 york
# 9 times
# 10 is
# 11 flailing
# 12 None
# 13 None
# 3621
# 0 marking
# 1 the
# 2 start
# 3 of
# 4 the
# 5 annual
# 6 pride
# 7 month
# 8 when
# 9 many
# 10 gay
# 11 trans
# 12 people
# 13 commemorate
# 14 riots
# 15 against
# 16 police
# 17 brutality
# 18 in
# 19 in
# 20 new
# 21 york
# 22 city
# 23 brown
# 24 called
# 25 on
# 26 the
# 27 lgbt+
# 28 community
# 29 recall
# 30 the
# 31 protest
# 32 driven
# 33 roots
# 34 of
# 35 the
# 36 celebration
# 37 None
# 38 None
# 3622
# 0 over
# 1 a
# 2 year
# 3 left
# 4 in
# 5 president
# 6 donald
# 7 trump
# 8 first
# 9 term
# 10 another
# 11 late
# 12 breaking
# 13 news
# 14 item
# 15 barely
# 16 made
# 17 waves
# 18 the
# 19 interior
# 20 department
# 21 which
# 22 manages
# 23 the
# 24 majority
# 25 of
# 26 the
# 27 federal
# 28 government
# 29 public
# 30 lands
# 31 deleted
# 32 sexual
# 33 orientation
# 34 from
# 35 its
# 36 anti
# 37 -
# 38 discrimination
# 39 guidelines
# 40 None
# 41 None
# 3623
# 0 formal
# 1 juneteenth
# 2 events
# 3 canceled
# 4 due
# 5 to
# 6 coronavirus
# 7 concerns
# 8 activists
# 9 instead
# 10 organized
# 11 a
# 12 host
# 13 of
# 14 virtual
# 15 observances
# 16 online
# 17 as
# 18 well
# 19 as
# 20 street
# 21 marches
# 22 car
# 23 caravans
# 24 through
# 25 several
# 26 major
# 27 cities
# 28 None
# 29 None
# 3624
# 0 than
# 1 people
# 2 killed
# 3 by
# 4 gun
# 5 violence
# 6 in
# 7 the
# 8 united
# 9 states
# 10 last
# 11 year
# 12 counting
# 13 suicides
# 14 democrats
# 15 running
# 16 for
# 17 their
# 18 party
# 19 presidential
# 20 nomination
# 21 are
# 22 pointing
# 23 to
# 24 inaction
# 25 in
# 26 washington
# 27 as
# 28 evidence
# 29 they
# 30 should
# 31 be
# 32 chosen
# 33 run
# 34 against
# 35 republican
# 36 president
# 37 donald
# 38 trump
# 39 None
# 40 None
# 3625
# 0 than
# 1 reported
# 2 cases
# 3 of
# 4 the
# 5 disease
# 6 the
# 7 viral
# 8 outbreak
# 9 continues
# 10 create
# 11 uncertainty
# 12 about
# 13 future
# 14 competitions
# 15 from
# 16 track
# 17 field
# 18 formula
# 19 to
# 20 the
# 21 ultimate
# 22 global
# 23 event
# 24 the
# 25 tokyo
# 26 olympics
# 27 None
# 28 None
# 3626
# 0 climate
# 1 impacted
# 2 world
# 3 now
# 4 highly
# 5 prone
# 6 to
# 7 fires
# 8 extreme
# 9 storms
# 10 sea
# 11 level
# 12 rise
# 13 nuclear
# 14 energy
# 15 is
# 16 touted
# 17 as
# 18 a
# 19 possible
# 20 replacement
# 21 for
# 22 the
# 23 burning
# 24 of
# 25 fossil
# 26 fuels
# 27 for
# 28 energy
# 29 the
# 30 leading
# 31 cause
# 32 of
# 33 climate
# 34 change
# 35 None
# 36 None
# 3627
# 0 over
# 1 racial
# 2 injustice
# 3 continuing
# 4 roil
# 5 the
# 6 united
# 7 states
# 8 queer
# 9 eye
# 10 star
# 11 karamo
# 12 brown
# 13 has
# 14 called
# 15 on
# 16 lgbt+
# 17 people
# 18 recognize
# 19 the
# 20 racism
# 21 transphobia
# 22 in
# 23 the
# 24 community
# 25 remember
# 26 the
# 27 radical
# 28 roots
# 29 of
# 30 the
# 31 gay
# 32 rights
# 33 movement
# 34 None
# 35 None
# 3628
# 0 feminists
# 1 extremist
# 2 trans
# 3 activists
# 4 seeking
# 5 have
# 6 her
# 7 publishers
# 8 film
# 9 associates
# 10 ban
# 11 her
# 12 from
# 13 earning
# 14 a
# 15 living
# 16 she
# 17 understands
# 18 how
# 19 the
# 20 radical
# 21 left
# 22 seeks
# 23 merely
# 24 disagree
# 25 with
# 26 their
# 27 opponents
# 28 destroy
# 29 them
# 30 utterly
# 31 as
# 32 human
# 33 beings
# 34 None
# 35 None
# 3629
# 0 arrival
# 1 of
# 2 virus
# 3 our
# 4 legal
# 5 rights
# 6 seem
# 7 have
# 8 been
# 9 deemed
# 10 irrelevant
# 11 completely
# 12 subordinated
# 13 to
# 14 the
# 15 arbitrary
# 16 whims
# 17 of
# 18 politicians
# 19 all
# 20 in
# 21 the
# 22 name
# 23 of
# 24 safety
# 25 None
# 26 None
# 3630
# 0 olympic
# 1 games
# 2 postponed
# 3 until
# 4 cinemas
# 5 closed
# 6 across
# 7 the
# 8 country
# 9 whole
# 10 segments
# 11 of
# 12 the
# 13 advertising
# 14 market
# 15 have
# 16 evaporated
# 17 None
# 18 None
# 3631
# 0 in
# 1 mind
# 2 the
# 3 trump
# 4 administration
# 5 reportedly
# 6 hopes
# 7 reduce
# 8 poverty
# 9 in
# 10 the
# 11 united
# 12 states
# 13 by
# 14 making
# 15 a
# 16 material
# 17 difference
# 18 in
# 19 struggling
# 20 families
# 21 finances
# 22 by
# 23 tinkering
# 24 with
# 25 the
# 26 threshold
# 27 for
# 28 what
# 29 counts
# 30 as
# 31 poverty
# 32 None
# 33 None
# 3632
# 0 appointed
# 1 in
# 2 recent
# 3 years
# 4 by
# 5 president
# 6 donald
# 7 trump
# 8 the
# 9 supreme
# 10 court
# 11 has
# 12 appeared
# 13 primed
# 14 ready
# 15 deliver
# 16 a
# 17 huge
# 18 victory
# 19 for
# 20 conservatives
# 21 looking
# 22 roll
# 23 back
# 24 abortion
# 25 rights
# 26 in
# 27 the
# 28 united
# 29 states
# 30 None
# 31 None
# 3633
# 0 president
# 1 donald
# 2 trump
# 3 announcement
# 4 on
# 5 thursday
# 6 of
# 7 tariffs
# 8 on
# 9 another
# 10 of
# 11 chinese
# 12 imports
# 13 nearly
# 14 all
# 15 goods
# 16 from
# 17 china
# 18 will
# 19 be
# 20 subject
# 21 to
# 22 import
# 23 taxes
# 24 trump
# 25 says
# 26 they
# 27 generate
# 28 billions
# 29 of
# 30 dollars
# 31 in
# 32 revenues
# 33 for
# 34 the
# 35 u.s.
# 36 treasury
# 37 from
# 38 china
# 39 None
# 40 None
# 3634
# 0 donald
# 1 trump
# 2 signaling
# 3 that
# 4 he
# 5 's
# 6 eager
# 7 for
# 8 the
# 9 country
# 10 relax
# 11 stringent
# 12 measures
# 13 meant
# 14 stem
# 15 the
# 16 tide
# 17 of
# 18 the
# 19 covid-19
# 20 pandemic
# 21 it
# 22 's
# 23 important
# 24 realize
# 25 how
# 26 dangerous
# 27 this
# 28 idea
# 29 is
# 30 None
# 31 None
# 3635
# 0 of
# 1 floyd
# 2 passing
# 3 in
# 4 minneapolis
# 5 police
# 6 custody
# 7 militant
# 8 social
# 9 justice
# 10 warriors
# 11 racked
# 12 up
# 13 an
# 14 estimated
# 15 in
# 16 damage
# 17 causing
# 18 the
# 19 costliest
# 20 outbreak
# 21 of
# 22 political
# 23 upheaval
# 24 in
# 25 u.s.
# 26 history
# 27 devastating
# 28 minority
# 29 businesses
# 30 while
# 31 kicking
# 32 off
# 33 an
# 34 entire
# 35 summer
# 36 of
# 37 chaos
# 38 engulfing
# 39 the
# 40 nation
# 41 major
# 42 cities
# 43 eventually
# 44 spreading
# 45 to
# 46 the
# 47 suburbs
# 48 None
# 49 None
# 3636
# 0 instance
# 1 the
# 2 wacky
# 3 nonsense
# 4 new
# 5 york
# 6 mayor
# 7 current
# 8 trump
# 9 flunky
# 10 rudy
# 11 giuliani
# 12 addressed
# 13 to
# 14 salon
# 15 roger
# 16 sollenberger
# 17 during
# 18 a
# 19 text
# 20 interview
# 21 this
# 22 week
# 23 None
# 24 None
# 3637
# 0 power
# 1 must
# 2 pay
# 3 a
# 4 significant
# 5 tax
# 6 on
# 7 their
# 8 limited
# 9 time
# 10 sit
# 11 for
# 12 manicures
# 13 blowouts
# 14 brow
# 15 waxes
# 16 braids
# 17 rather
# 18 than
# 19 meeting
# 20 with
# 21 constituents
# 22 reviewing
# 23 legislation
# 24 conducting
# 25 investigations
# 26 chasing
# 27 a
# 28 story
# 29 traveling
# 30 to
# 31 their
# 32 districts
# 33 reviewing
# 34 their
# 35 notes
# 36 spending
# 37 time
# 38 with
# 39 their
# 40 families
# 41 None
# 42 None
# 3638
# 0 allowed
# 1 into
# 2 saudi
# 3 sports
# 4 stadiums
# 5 a
# 6 year
# 7 ago
# 8 for
# 9 the
# 10 first
# 11 time
# 12 watch
# 13 soccer
# 14 matches
# 15 although
# 16 they
# 17 were
# 18 segregated
# 19 in
# 20 the
# 21 stands
# 22 sticking
# 23 to
# 24 the
# 25 family
# 26 section
# 27 away
# 28 from
# 29 all
# 30 male
# 31 crowds
# 32 elsewhere
# 33 None
# 34 None
# 3639
# 0 advocates
# 1 were
# 2 relieved
# 3 late
# 4 monday
# 5 when
# 6 senate
# 7 democrats
# 8 blocked
# 9 an
# 10 extreme
# 11 anti
# 12 -
# 13 choice
# 14 bill
# 15 from
# 16 advancing
# 17 to
# 18 a
# 19 floor
# 20 debate
# 21 were
# 22 soon
# 23 outraged
# 24 by
# 25 president
# 26 donald
# 27 trump
# 28 lies
# 29 about
# 30 abortion
# 31 care
# 32 as
# 33 well
# 34 as
# 35 the
# 36 corporate
# 37 media
# 38 for
# 39 enabling
# 40 his
# 41 blatantly
# 42 false
# 43 characterization
# 44 of
# 45 the
# 46 bill
# 47 stand
# 48 None
# 49 None
# 3640
# 0 be
# 1 absurdly
# 2 difficult
# 3 enforce
# 4 new
# 5 gun
# 6 control
# 7 laws
# 8 move
# 9 toward
# 10 the
# 11 outright
# 12 confiscation
# 13 that
# 14 is
# 15 always
# 16 forever
# 17 the
# 18 left
# 19 ultimate
# 20 goal
# 21 after
# 22 a
# 23 year
# 24 of
# 25 record
# 26 breaking
# 27 gun
# 28 sales
# 29 None
# 30 None
# 3641
# 0 americans
# 1 like
# 2 those
# 3 who
# 4 make
# 5 up
# 6 the
# 7 majority
# 8 of
# 9 south
# 10 bend
# 11 residents
# 12 have
# 13 secured
# 14 the
# 15 largest
# 16 wage
# 17 hikes
# 18 in
# 19 the
# 20 nation
# 21 compared
# 22 to
# 23 all
# 24 other
# 25 economic
# 26 demographic
# 27 groups
# 28 a
# 29 direct
# 30 result
# 31 of
# 32 trump
# 33 tightening
# 34 the
# 35 labor
# 36 market
# 37 None
# 38 None
# 3642
# 0 against
# 1 gay
# 2 transgender
# 3 employees
# 4 has
# 5 remained
# 6 legal
# 7 in
# 8 much
# 9 of
# 10 the
# 11 country
# 12 with
# 13 u.s.
# 14 states
# 15 lacking
# 16 comprehensive
# 17 measures
# 18 against
# 19 employment
# 20 discrimination
# 21 None
# 22 None
# 3643
# 0 organisations
# 1 pledged
# 2 fund
# 3 a
# 4 possible
# 5 vaccine
# 6 treatments
# 7 many
# 8 hoping
# 9 explicitly
# 10 ensure
# 11 that
# 12 no
# 13 country
# 14 on
# 15 earth
# 16 would
# 17 be
# 18 left
# 19 out
# 20 the
# 21 united
# 22 states
# 23 did
# 24 contribute
# 25 None
# 26 None
# 3644
# 0 however
# 1 is
# 2 that
# 3 democrats
# 4 have
# 5 also
# 6 been
# 7 notably
# 8 faced
# 9 on
# 10 gun
# 11 control
# 12 None
# 13 None
# 3645
# 0 today
# 1 wall
# 2 street
# 3 journal
# 4 pence
# 5 denies
# 6 that
# 7 there
# 8 is
# 9 such
# 10 a
# 11 thing
# 12 as
# 13 a
# 14 second
# 15 wave
# 16 to
# 17 the
# 18 pandemic
# 19 he
# 20 does
# 21 mean
# 22 because
# 23 we
# 24 have
# 25 exited
# 26 the
# 27 first
# 28 wave
# 29 None
# 30 None
# 3646
# 0 explains
# 1 why
# 2 the
# 3 coronavirus
# 4 pandemic
# 5 donald
# 6 trump
# 7 irrational
# 8 cult
# 9 is
# 10 a
# 11 deadly
# 12 combination
# 13 None
# 14 None
# 3647
# 0 openly
# 1 committing
# 2 adultery
# 3 against
# 4 the
# 5 republican
# 6 party
# 7 these
# 8 shameless
# 9 cheats
# 10 honestly
# 11 believed
# 12 the
# 13 democrat
# 14 party
# 15 would
# 16 make
# 17 them
# 18 equal
# 19 trusted
# 20 partners
# 21 in
# 22 the
# 23 family
# 24 business
# 25 None
# 26 None
# 3648
# 0 the
# 1 right
# 2 are
# 3 embracing
# 4 celebrating
# 5 death
# 6 it
# 7 is
# 8 ghoulish
# 9 it
# 10 is
# 11 also
# 12 more
# 13 illustration
# 14 that
# 15 the
# 16 age
# 17 of
# 18 trump
# 19 is
# 20 an
# 21 american
# 22 dystopia
# 23 where
# 24 what
# 25 was
# 26 previously
# 27 unimaginable
# 28 for
# 29 most
# 30 decent
# 31 people
# 32 has
# 33 become
# 34 normal
# 35 None
# 36 None
# 3649
# 0 might
# 1 be
# 2 a
# 3 demented
# 4 stalinist
# 5 eager
# 6 flood
# 7 america
# 8 with
# 9 illegal
# 10 aliens
# 11 take
# 12 away
# 13 our
# 14 guns
# 15 health
# 16 insurance
# 17 he
# 18 sure
# 19 gave
# 20 those
# 21 venal
# 22 never
# 23 trumpers
# 24 a
# 25 sweet
# 26 face
# 27 job
# 28 saturday
# 29 night
# 30 in
# 31 nevada
# 32 now
# 33 i
# 34 ca
# 35 tell
# 36 if
# 37 my
# 38 tears
# 39 come
# 40 from
# 41 joy
# 42 laughter
# 43 None
# 44 None
# 3650
# 0 rich
# 1 are
# 2 rich
# 3 want
# 4 stay
# 5 that
# 6 way
# 7 yet
# 8 at
# 9 the
# 10 same
# 11 time
# 12 fat
# 13 cats
# 14 now
# 15 lean
# 16 left
# 17 even
# 18 far
# 19 left
# 20 on
# 21 cultural
# 22 issues
# 23 they
# 24 want
# 25 you
# 26 do
# 27 as
# 28 you
# 29 ’re
# 30 told
# 31 None
# 32 None
# 3651
# 0 may
# 1 still
# 2 be
# 3 time
# 4 for
# 5 the
# 6 union
# 7 membership
# 8 change
# 9 its
# 10 thinking
# 11 if
# 12 the
# 13 players
# 14 reject
# 15 the
# 16 proposal
# 17 at
# 18 least
# 19 marketing
# 20 expert
# 21 said
# 22 a
# 23 no
# 24 vote
# 25 now
# 26 could
# 27 mean
# 28 short-
# 29 long
# 30 term
# 31 disaster
# 32 None
# 33 None
# 3652
# 0 himself
# 1 in
# 2 an
# 3 increasingly
# 4 competitive
# 5 race
# 6 with
# 7 sanders
# 8 the
# 9 u.s.
# 10 senator
# 11 who
# 12 came
# 13 close
# 14 to
# 15 winning
# 16 the
# 17 nevada
# 18 caucus
# 19 finds
# 20 support
# 21 with
# 22 some
# 23 of
# 24 the
# 25 same
# 26 voters
# 27 None
# 28 None
# 3653
# 0 entirety
# 1 of
# 2 the
# 3 establishment
# 4 from
# 5 prime
# 6 minister
# 7 boris
# 8 johnson
# 9 downwards
# 10 the
# 11 bodies
# 12 representing
# 13 every
# 14 cultural
# 15 institution
# 16 from
# 17 the
# 18 church
# 19 of
# 20 england
# 21 to
# 22 the
# 23 football
# 24 association
# 25 have
# 26 been
# 27 grovelling
# 28 fawning
# 29 kowtowing
# 30 to
# 31 blm
# 32 as
# 33 if
# 34 its
# 35 name
# 36 were
# 37 be
# 38 taken
# 39 at
# 40 face
# 41 value
# 42 None
# 43 None
# 3654
# 0 nation
# 1 except
# 2 mongolia
# 3 greenland
# 4 recorded
# 5 dozens
# 6 to
# 7 thousands
# 8 of
# 9 deaths
# 10 no
# 11 matter
# 12 what
# 13 they
# 14 tried
# 15 even
# 16 socialist
# 17 systems
# 18 with
# 19 draconian
# 20 lockdowns
# 21 like
# 22 italy
# 23 deaths
# 24 per
# 25 spain
# 26 the
# 27 united
# 28 kingdom
# 29 None
# 30 None
# 3655
# 0 better
# 1 applies
# 2 to
# 3 unelected
# 4 career
# 5 bureaucrats
# 6 use
# 7 of
# 8 their
# 9 power
# 10 prosecute
# 11 their
# 12 political
# 13 enemies
# 14 which
# 15 comprises
# 16 the
# 17 heart
# 18 of
# 19 the
# 20 resistance
# 21 to
# 22 republican
# 23 rule
# 24 that
# 25 will
# 26 endure
# 27 so
# 28 long
# 29 as
# 30 bureaucracy
# 31 has
# 32 enough
# 33 power
# 34 challenged
# 35 elected
# 36 branches
# 37 of
# 38 government
# 39 this
# 40 bureacracy
# 41 weaponization
# 42 was
# 43 also
# 44 a
# 45 hallmark
# 46 of
# 47 the
# 48 obama
# 49 presidency
# 50 with
# 51 ironies
# 52 of
# 53 ironies
# 54 perhaps
# 55 the
# 56 biggest
# 57 evidences
# 58 again
# 59 coming
# 60 from
# 61 the
# 62 department
# 63 of
# 64 justice
# 65 under
# 66 attorneys
# 67 general
# 68 eric
# 69 holder
# 70 loretta
# 71 lynch
# 72 None
# 73 None
# 3656
# 0 merely
# 1 the
# 2 tip
# 3 of
# 4 the
# 5 iceberg
# 6 of
# 7 war
# 8 criminals
# 9 lurking
# 10 working
# 11 on
# 12 u.s.
# 13 turf
# 14 None
# 15 None
# 3657
# 0 a
# 1 former
# 2 running
# 3 back
# 4 for
# 5 the
# 6 nfl
# 7 pittsburgh
# 8 steelers
# 9 chicago
# 10 bears
# 11 later
# 12 turned
# 13 espn
# 14 analyst
# 15 has
# 16 been
# 17 of
# 18 the
# 19 most
# 20 outspoken
# 21 critics
# 22 against
# 23 the
# 24 alarm
# 25 surrounding
# 26 cte
# 27 studies
# 28 putting
# 29 much
# 30 of
# 31 the
# 32 research
# 33 down
# 34 to
# 35 science
# 36 fiction
# 37 misleading
# 38 science
# 39 far
# 40 from
# 41 a
# 42 factual
# 43 realm
# 44 None
# 45 None
# 3658
# 0 an
# 1 exhaustive
# 2 page
# 3 health
# 4 safety
# 5 operations
# 6 manual
# 7 will
# 8 attempt
# 9 become
# 10 the
# 11 first
# 12 major
# 13 sport
# 14 return
# 15 on
# 16 july
# 17 with
# 18 nationally
# 19 televised
# 20 games
# 21 the
# 22 rest
# 23 of
# 24 the
# 25 teams
# 26 scheduled
# 27 start
# 28 july
# 29 None
# 30 None
# 3659
# 0 one
# 1 denies
# 2 that
# 3 older
# 4 nuclear
# 5 plants
# 6 with
# 7 an
# 8 aged
# 9 infrastructure
# 10 often
# 11 surpassing
# 12 expected
# 13 lifetimes
# 14 are
# 15 extremely
# 16 inefficient
# 17 run
# 18 a
# 19 higher
# 20 risk
# 21 of
# 22 disaster
# 23 None
# 24 None
# 3660
# 0 unashamed
# 1 about
# 2 being
# 3 linked
# 4 to
# 5 this
# 6 kind
# 7 of
# 8 hate
# 9 even
# 10 claiming
# 11 that
# 12 while
# 13 she
# 14 opposes
# 15 economic
# 16 sanctions
# 17 on
# 18 the
# 19 tyrannical
# 20 terrorist
# 21 supporting
# 22 iranian
# 23 regime
# 24 she
# 25 thinks
# 26 boycotts
# 27 of
# 28 israel
# 29 are
# 30 justified
# 31 None
# 32 None
# 3661
# 0 drumbeat
# 1 for
# 2 censorship
# 3 goes
# 4 on
# 5 as
# 6 the
# 7 politicians
# 8 whose
# 9 ideas
# 10 find
# 11 favor
# 12 with
# 13 the
# 14 mainstream
# 15 media
# 16 want
# 17 make
# 18 sure
# 19 theirs
# 20 are
# 21 the
# 22 only
# 23 ideas
# 24 you
# 25 ever
# 26 get
# 27 hear
# 28 today
# 29 it
# 30 will
# 31 be
# 32 about
# 33 money
# 34 only
# 35 because
# 36 money
# 37 is
# 38 the
# 39 means
# 40 spread
# 41 ideas
# 42 None
# 43 None
# 3662
# 0 gender
# 1 ideology
# 2 is
# 3 rapidly
# 4 gaining
# 5 power
# 6 aided
# 7 by
# 8 huge
# 9 donations
# 10 from
# 11 wealthy
# 12 individuals
# 13 medical
# 14 companies
# 15 None
# 16 None
# 3663
# 0 narrative
# 1 across
# 2 social
# 3 media
# 4 today
# 5 depressingly
# 6 across
# 7 much
# 8 of
# 9 the
# 10 mainstream
# 11 media
# 12 is
# 13 that
# 14 these
# 15 ugly
# 16 sinister
# 17 shows
# 18 of
# 19 force
# 20 by
# 21 the
# 22 triumphant
# 23 radical
# 24 left
# 25 are
# 26 something
# 27 almost
# 28 charming
# 29 admirable
# 30 rather
# 31 than
# 32 something
# 33 we
# 34 should
# 35 all
# 36 fear
# 37 None
# 38 None
# 3664
# 0 researchers
# 1 in
# 2 the
# 3 u.s.
# 4 have
# 5 been
# 6 so
# 7 corrupt
# 8 they
# 9 have
# 10 gone
# 11 to
# 12 jail
# 13 mainstream
# 14 scientists
# 15 still
# 16 accept
# 17 their
# 18 research
# 19 None
# 20 None
# 3665
# 0 family
# 1 his
# 2 allies
# 3 are
# 4 evidently
# 5 using
# 6 this
# 7 national
# 8 emergency
# 9 enrich
# 10 themselves
# 11 None
# 12 None
# 3666
# 0 remember
# 1 that
# 2 hours
# 3 after
# 4 america
# 5 was
# 6 attacked
# 7 by
# 8 al
# 9 qaeda
# 10 on
# 11 thousands
# 12 of
# 13 muslims
# 14 regular
# 15 folks
# 16 celebrated
# 17 in
# 18 the
# 19 streets
# 20 None
# 21 None
# 3667
# 0 remember
# 1 that
# 2 nbc
# 3 journalist
# 4 nancy
# 5 snyderman
# 6 broke
# 7 her
# 8 ebola
# 9 quarantine
# 10 to
# 11 the
# 12 outrage
# 13 of
# 14 her
# 15 neighbors
# 16 None
# 17 None
# 3668
# 0 keep
# 1 a
# 2 close
# 3 eye
# 4 on
# 5 what
# 6 your
# 7 school
# 8 is
# 9 teaching
# 10 because
# 11 the
# 12 left
# 13 only
# 14 wants
# 15 teach
# 16 your
# 17 kids
# 18 engage
# 19 in
# 20 loveless
# 21 sex
# 22 the
# 23 sanctity
# 24 of
# 25 abortion
# 26 why
# 27 america
# 28 is
# 29 evil
# 30 that
# 31 men
# 32 are
# 33 women
# 34 women
# 35 are
# 36 men
# 37 that
# 38 global
# 39 warming
# 40 is
# 41 real
# 42 it
# 43 ’s
# 44 None
# 45 None
# 3669
# 0 heard
# 1 of
# 2 jim
# 3 crow
# 4 southern
# 5 segregation
# 6 that
# 7 was
# 8 all
# 9 democrats
# 10 None
# 11 None
# 3670
# 0 athletes
# 1 dreams
# 2 accomplishments
# 3 have
# 4 been
# 5 dashed
# 6 across
# 7 the
# 8 country
# 9 when
# 10 competing
# 11 against
# 12 biological
# 13 males
# 14 who
# 15 identify
# 16 as
# 17 females
# 18 None
# 19 None
# 3671
# 0 men
# 1 reacting
# 2 to
# 3 social
# 4 educational
# 5 constructs
# 6 that
# 7 paint
# 8 them
# 9 as
# 10 the
# 11 embodiment
# 12 of
# 13 historical
# 14 evil
# 15 are
# 16 fertile
# 17 ground
# 18 for
# 19 white
# 20 supremacists
# 21 None
# 22 None
# 3672
# 0 taking
# 1 part
# 2 in
# 3 high
# 4 school
# 5 college
# 6 athletics
# 7 across
# 8 the
# 9 country
# 10 have
# 11 had
# 12 their
# 13 dreams
# 14 of
# 15 winning
# 16 dashed
# 17 by
# 18 the
# 19 movement
# 20 allow
# 21 biological
# 22 male
# 23 who
# 24 identify
# 25 as
# 26 female
# 27 compete
# 28 against
# 29 them
# 30 None
# 31 None
# 3673
# 0 making
# 1 clear
# 2 there
# 3 will
# 4 be
# 5 no
# 6 birtherism
# 7 on
# 8 its
# 9 platform
# 10 during
# 11 this
# 12 year
# 13 u.s.
# 14 presidential
# 15 election
# 16 a
# 17 belated
# 18 response
# 19 to
# 20 a
# 21 type
# 22 of
# 23 conspiracy
# 24 theory
# 25 more
# 26 prevalent
# 27 in
# 28 the
# 29 race
# 30 None
# 31 None

# %% [markdown]
# ## 3 Create a feature vector for each word

# %% [markdown]
# ### 3.1 Ungroup sentences (one obseravtion = one word)

# %%
dt
# Out:
#                                                sentence  ...                                            article
# 0     "Orange Is the New Black" star Yael Stone is r...  ...  "Orange Is the New Black" star Yael Stone is r...
# 1     "We have one beautiful law," Trump recently sa...  ...  "We have one beautiful law," Trump recently sa...
# 2     ...immigrants as criminals and eugenics, all o...  ...  ...immigrants as criminals and eugenics, all o...
# 3     ...we sounded the alarm in the early months of...  ...  ...we sounded the alarm in the early months of...
# 4     [Black Lives Matter] is essentially a non-fals...  ...  [Black Lives Matter] is essentially a non-fals...
# ...                                                 ...  ...                                                ...
# 3669  You’ve heard of Jim Crow and Southern Segregat...  ...  You’ve heard of Jim Crow and Southern Segregat...
# 3670  Young female athletes’ dreams and accomplishme...  ...  Young female athletes’ dreams and accomplishme...
# 3671  Young white men, reacting to social and educat...  ...  Young white men, reacting to social and educat...
# 3672  Young women taking part in high school and col...  ...  Young women taking part in high school and col...
# 3673  YouTube is making clear there will be no “birt...  ...  YouTube is making clear there will be no “birt...
#
# [3673 rows x 8 columns]

# %%
for feat in dt.loc[1,'spacy_lg_dict']:
  print(feat)
# Out:
# {'text': 'We', 'text_low': 'we', 'pos': 'PRON', 'lemma': '-PRON-', 'lemma_low': '-pron-', 'tag': 'PRP', 'dep': 'nsubj', 'shape': 'Xx', 'is_alpha': True, 'is_stop': True, 'has_vec': True, 'glove_vec300': array([-0.31676668,  4.087597  , -0.1161238 , -2.0217166 , -0.45238057,
#         0.35491768,  1.4899944 ,  3.952473  ,  3.8075526 ,  1.7800549 ,
#        -2.2092876 ,  3.6313457 ,  0.17599165,  1.5715055 ,  1.0988023 ,
#        -1.1550162 , -2.6193419 ,  0.01218152, -2.9498038 ,  0.79302603,
#         0.9338388 , -3.291411  , -1.6779103 , -3.2861583 , -3.2453792 ,
#        -1.7613271 , -0.96935546, -0.98925966, -1.137018  ,  0.32698405,
#         2.601997  , -3.179267  , -2.429421  , -0.9683772 ,  6.714281  ,
#         0.01271152, -2.3952408 ,  4.1934476 , -0.15137061, -2.463461  ,
#         1.3733284 , -0.6784345 , -0.99732786, -0.490483  , -0.7643031 ,
#         2.7650192 ,  0.18923801, -1.2285393 , -2.5842826 ,  1.0963786 ,
#        -1.2242095 ,  2.2945304 , -2.0236936 ,  1.5776336 ,  0.6756185 ,
#         1.1470528 ,  3.7207491 , -0.47422975,  0.26994932,  0.6917758 ,
#         2.917066  , -1.4396255 , -2.2485206 ,  6.6722736 ,  0.16118631,
#        -2.1646004 , -0.11449516, -3.7134838 , -2.6509256 ,  4.900377  ,
#        -4.1298018 ,  1.1869987 ,  4.2641597 , -2.0480428 ,  3.8858504 ,
#        -0.48263288,  0.8421749 , -3.6566827 , -3.2567496 , -2.4142268 ,
#         0.34031224,  3.8284647 , -3.6771474 ,  3.2501862 ,  4.4540715 ,
#        -0.52616906,  4.3338947 , -0.29253495,  0.91554433, -0.6850389 ,
#         1.0369359 , -2.883226  ,  0.93385124, -2.179288  , -0.5201297 ,
#        -0.5960307 ], dtype=float32), 'glove_vec300_norm': 24.056175, 'is_oov': True, 'order': 0, 'tfidf_art': 0.1605299124101392, 'label3': 0, 'label4': 0, 'label5': 0, 'is_ne': False, 'ne_label': None, 'liwc2015': [1, 2, 3, 5, 40, 80, 81], 'negative_conc': 0, 'positive_conc': 0, 'weak_subj': 0, 'strong_subj': 0, 'MRCP_concretness_ratings': 270, 'MRCP_Imagability_ratings': 389, 'hyperbolic_terms': 0, 'attitude_markers': 0, 'kill_verbs': 0, 'bias_lexicon': 0, 'text_C1': None, 'text_low_C1': None, 'pos_C1': None, 'lemma_C1': None, 'lemma_low_C1': None, 'tag_C1': None, 'dep_C1': None, 'shape_C1': None, 'is_alpha_C1': None, 'is_stop_C1': None, 'has_vec_C1': None, 'glove_vec300_C1': None, 'glove_vec300_norm_C1': None, 'is_oov_C1': None, 'order_C1': None, 'is_ne_C1': None, 'ne_label_C1': None, 'tfidf_art_C1': None, 'liwc2015_C1': None, 'negative_conc_C1': None, 'positive_conc_C1': None, 'weak_subj_C1': None, 'strong_subj_C1': None, 'MRCP_concretness_ratings_C1': None, 'MRCP_Imagability_ratings_C1': None, 'hyperbolic_terms_C1': None, 'attitude_markers_C1': None, 'kill_verbs_C1': None, 'bias_lexicon_C1': None, 'text_C2': None, 'text_low_C2': None, 'pos_C2': None, 'lemma_C2': None, 'lemma_low_C2': None, 'tag_C2': None, 'dep_C2': None, 'shape_C2': None, 'is_alpha_C2': None, 'is_stop_C2': None, 'has_vec_C2': None, 'glove_vec300_C2': None, 'glove_vec300_norm_C2': None, 'is_oov_C2': None, 'order_C2': None, 'is_ne_C2': None, 'ne_label_C2': None, 'tfidf_art_C2': None, 'liwc2015_C2': None, 'negative_conc_C2': None, 'positive_conc_C2': None, 'weak_subj_C2': None, 'strong_subj_C2': None, 'MRCP_concretness_ratings_C2': None, 'MRCP_Imagability_ratings_C2': None, 'hyperbolic_terms_C2': None, 'attitude_markers_C2': None, 'kill_verbs_C2': None, 'bias_lexicon_C2': None, 'text_C3': 'have', 'text_low_C3': 'have', 'pos_C3': 'AUX', 'lemma_C3': 'have', 'lemma_low_C3': 'have', 'tag_C3': 'VBP', 'dep_C3': 'ccomp', 'shape_C3': 'xxxx', 'is_alpha_C3': True, 'is_stop_C3': True, 'has_vec_C3': True, 'glove_vec300_C3': array([-0.7213155 ,  3.6601207 ,  0.1219139 , -2.8546267 , -1.6260936 ,
#         0.7542187 , -1.6724557 ,  1.1218082 ,  1.6834638 , -0.5129777 ,
#        -5.07646   , -2.7883441 , -4.5636215 ,  0.32953244, -1.3135604 ,
#         2.2146423 , -0.7577101 , -3.3878486 ,  3.7318592 ,  0.38368842,
#         5.2768984 ,  2.4950745 , -2.6944914 ,  1.3810098 ,  0.53450716,
#        -2.2463698 ,  1.223988  , -3.6009285 , -1.5314493 ,  0.4668301 ,
#         2.6985629 , -0.1332308 ,  1.229918  , -2.719051  , -1.332753  ,
#        -1.336633  ,  0.00754869, -2.1205497 , -0.5595583 ,  1.6552678 ,
#        -0.80639243,  0.23420328,  1.5979211 , -2.7545152 ,  2.5082233 ,
#        -1.2026258 ,  0.8675622 ,  3.5132718 , -1.0352685 , -2.772653  ,
#         0.8430741 , -1.1458037 ,  4.804392  , -2.6640275 , -2.2228732 ,
#        -2.0851455 ,  1.8123571 ,  0.88473475,  1.4531286 ,  1.6001296 ,
#         6.508646  , -3.6590223 , -2.010408  , -1.8154957 ,  0.32603776,
#         1.2426485 ,  1.595177  ,  2.848076  ,  3.260756  , -2.1086698 ,
#        -0.18522155,  4.6400237 ,  2.2688003 ,  1.0339924 ,  1.086308  ,
#        -0.03257135,  0.2157588 ,  0.9183563 ,  1.7917401 ,  0.5685625 ,
#         0.9769081 , -2.4917321 , -2.138284  ,  0.73112077,  0.8799888 ,
#        -1.0759863 ,  3.4777255 , -1.7152269 , -1.3512974 ,  0.2977367 ,
#         1.121925  ,  0.89665127, -3.7105746 ,  1.9052389 , -2.141551  ,
#         2.3576035 ], dtype=float32), 'glove_vec300_norm_C3': 22.088182, 'is_oov_C3': True, 'order_C3': 1, 'is_ne_C3': False, 'ne_label_C3': None, 'tfidf_art_C3': 0.10554970619696329, 'liwc2015_C3': [1, 12, 20, 91], 'negative_conc_C3': 0, 'positive_conc_C3': 0, 'weak_subj_C3': 0, 'strong_subj_C3': 0, 'MRCP_concretness_ratings_C3': 251, 'MRCP_Imagability_ratings_C3': 271, 'hyperbolic_terms_C3': 0, 'attitude_markers_C3': 0, 'kill_verbs_C3': 0, 'bias_lexicon_C3': 0, 'text_C4': 'beautiful', 'text_low_C4': 'beautiful', 'pos_C4': 'ADJ', 'lemma_C4': 'beautiful', 'lemma_low_C4': 'beautiful', 'tag_C4': 'JJ', 'dep_C4': 'amod', 'shape_C4': 'xxxx', 'is_alpha_C4': True, 'is_stop_C4': False, 'has_vec_C4': True, 'glove_vec300_C4': array([ 1.04209149e+00, -2.17558932e+00,  2.94323444e-01,  3.04307985e+00,
#        -2.62667298e+00,  1.52154946e+00, -1.45757461e+00,  1.15834236e+00,
#         2.75327969e+00,  1.69927657e-01,  2.11420894e+00,  5.67618787e-01,
#        -7.29837000e-01, -3.46303797e+00, -3.71549368e-01,  1.78159881e+00,
#        -4.86358225e-01,  2.41373062e-01, -9.76020098e-01, -1.99699879e+00,
#         7.37772465e-01, -9.60470676e-01, -2.45286560e+00,  3.52509832e+00,
#         2.24856424e+00, -2.05712104e+00, -1.43415308e+00,  3.47142053e+00,
#         5.47310889e-01, -1.61996675e+00, -7.93453574e-01,  7.19007850e-01,
#         2.46076536e+00, -2.49649465e-01, -1.12812662e+00, -5.49496055e-01,
#         3.42656112e+00, -1.56731606e+00, -3.22637939e+00,  7.37800062e-01,
#        -5.59149623e-01,  2.50340414e+00, -2.62753630e+00, -1.61706376e+00,
#         4.66870129e-01, -6.83374584e-01, -2.68598318e+00, -9.84853089e-01,
#        -1.95788419e+00,  9.39807892e-01,  3.87146622e-01,  2.10551596e+00,
#         2.22005844e+00, -2.12531710e+00, -2.21331310e+00, -4.41923022e-01,
#         6.05265617e+00,  1.65894949e+00, -7.25416064e-01, -1.10649514e+00,
#         6.15745783e-03, -1.42015171e+00,  2.45333362e+00, -2.48504519e-01,
#         2.61109161e+00, -2.31210399e+00,  6.75478029e+00, -1.54075718e+00,
#        -3.51919031e+00,  3.17375183e+00, -5.92801094e-01, -4.14915562e+00,
#        -9.52237606e-01,  1.13658404e+00,  2.05301240e-01, -2.24639869e+00,
#         1.61625552e+00, -1.25904191e+00,  8.08365464e-01,  3.82820177e+00,
#         1.18315327e+00, -1.80433226e+00,  2.44297886e+00, -6.95991337e-01,
#        -4.10978913e-01, -2.91799879e+00,  7.19997764e-01,  1.41642523e+00,
#        -6.45504653e-01, -9.00105357e-01, -1.95513892e+00, -3.32588720e+00,
#         9.94870901e-01, -1.62688643e-01,  1.19637445e-01,  4.08287001e+00],
#       dtype=float32), 'glove_vec300_norm_C4': 20.559483, 'is_oov_C4': True, 'order_C4': 2, 'is_ne_C4': False, 'ne_label_C4': None, 'tfidf_art_C4': 0.6027134447479771, 'liwc2015_C4': [21, 30, 31, 60, 61], 'negative_conc_C4': 0, 'positive_conc_C4': 1, 'weak_subj_C4': 0, 'strong_subj_C4': 1, 'MRCP_concretness_ratings_C4': 393, 'MRCP_Imagability_ratings_C4': 532, 'hyperbolic_terms_C4': 0, 'attitude_markers_C4': 0, 'kill_verbs_C4': 0, 'bias_lexicon_C4': 0, 'window_text': [None, None, None, None, 'we', 'have', 'beautiful', 'law', 'trump'], 'window_lemma': [None, None, None, None, '-pron-', 'have', 'beautiful', 'law', 'trump'], 'assertive_verbs': 0, 'factive_verbs': 0, 'report_verbs': 0, 'hedges': 0, 'boosters': 0, 'implicative_verbs': 0, 'assertive_verbs_C1': 0, 'factive_verbs_C1': 0, 'report_verbs_C1': 0, 'hedges_C1': 0, 'boosters_C1': 0, 'implicative_verbs_C1': 0, 'assertive_verbs_C2': 0, 'factive_verbs_C2': 0, 'report_verbs_C2': 0, 'hedges_C2': 0, 'boosters_C2': 0, 'implicative_verbs_C2': 0, 'assertive_verbs_C3': 0, 'factive_verbs_C3': 0, 'report_verbs_C3': 0, 'hedges_C3': 0, 'boosters_C3': 0, 'implicative_verbs_C3': 0, 'assertive_verbs_C4': 0, 'factive_verbs_C4': 0, 'report_verbs_C4': 0, 'hedges_C4': 0, 'boosters_C4': 0, 'implicative_verbs_C4': 0}
# {'text': 'have', 'text_low': 'have', 'pos': 'AUX', 'lemma': 'have', 'lemma_low': 'have', 'tag': 'VBP', 'dep': 'ccomp', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': True, 'has_vec': True, 'glove_vec300': array([-0.7213155 ,  3.6601207 ,  0.1219139 , -2.8546267 , -1.6260936 ,
#         0.7542187 , -1.6724557 ,  1.1218082 ,  1.6834638 , -0.5129777 ,
#        -5.07646   , -2.7883441 , -4.5636215 ,  0.32953244, -1.3135604 ,
#         2.2146423 , -0.7577101 , -3.3878486 ,  3.7318592 ,  0.38368842,
#         5.2768984 ,  2.4950745 , -2.6944914 ,  1.3810098 ,  0.53450716,
#        -2.2463698 ,  1.223988  , -3.6009285 , -1.5314493 ,  0.4668301 ,
#         2.6985629 , -0.1332308 ,  1.229918  , -2.719051  , -1.332753  ,
#        -1.336633  ,  0.00754869, -2.1205497 , -0.5595583 ,  1.6552678 ,
#        -0.80639243,  0.23420328,  1.5979211 , -2.7545152 ,  2.5082233 ,
#        -1.2026258 ,  0.8675622 ,  3.5132718 , -1.0352685 , -2.772653  ,
#         0.8430741 , -1.1458037 ,  4.804392  , -2.6640275 , -2.2228732 ,
#        -2.0851455 ,  1.8123571 ,  0.88473475,  1.4531286 ,  1.6001296 ,
#         6.508646  , -3.6590223 , -2.010408  , -1.8154957 ,  0.32603776,
#         1.2426485 ,  1.595177  ,  2.848076  ,  3.260756  , -2.1086698 ,
#        -0.18522155,  4.6400237 ,  2.2688003 ,  1.0339924 ,  1.086308  ,
#        -0.03257135,  0.2157588 ,  0.9183563 ,  1.7917401 ,  0.5685625 ,
#         0.9769081 , -2.4917321 , -2.138284  ,  0.73112077,  0.8799888 ,
#        -1.0759863 ,  3.4777255 , -1.7152269 , -1.3512974 ,  0.2977367 ,
#         1.121925  ,  0.89665127, -3.7105746 ,  1.9052389 , -2.141551  ,
#         2.3576035 ], dtype=float32), 'glove_vec300_norm': 22.088182, 'is_oov': True, 'order': 1, 'tfidf_art': 0.10554970619696329, 'label3': 0, 'label4': 0, 'label5': 0, 'is_ne': False, 'ne_label': None, 'liwc2015': [1, 12, 20, 91], 'negative_conc': 0, 'positive_conc': 0, 'weak_subj': 0, 'strong_subj': 0, 'MRCP_concretness_ratings': 251, 'MRCP_Imagability_ratings': 271, 'hyperbolic_terms': 0, 'attitude_markers': 0, 'kill_verbs': 0, 'bias_lexicon': 0, 'text_C1': None, 'text_low_C1': None, 'pos_C1': None, 'lemma_C1': None, 'lemma_low_C1': None, 'tag_C1': None, 'dep_C1': None, 'shape_C1': None, 'is_alpha_C1': None, 'is_stop_C1': None, 'has_vec_C1': None, 'glove_vec300_C1': None, 'glove_vec300_norm_C1': None, 'is_oov_C1': None, 'order_C1': None, 'is_ne_C1': None, 'ne_label_C1': None, 'tfidf_art_C1': None, 'liwc2015_C1': None, 'negative_conc_C1': None, 'positive_conc_C1': None, 'weak_subj_C1': None, 'strong_subj_C1': None, 'MRCP_concretness_ratings_C1': None, 'MRCP_Imagability_ratings_C1': None, 'hyperbolic_terms_C1': None, 'attitude_markers_C1': None, 'kill_verbs_C1': None, 'bias_lexicon_C1': None, 'text_C2': 'We', 'text_low_C2': 'we', 'pos_C2': 'PRON', 'lemma_C2': '-PRON-', 'lemma_low_C2': '-pron-', 'tag_C2': 'PRP', 'dep_C2': 'nsubj', 'shape_C2': 'Xx', 'is_alpha_C2': True, 'is_stop_C2': True, 'has_vec_C2': True, 'glove_vec300_C2': array([-0.31676668,  4.087597  , -0.1161238 , -2.0217166 , -0.45238057,
#         0.35491768,  1.4899944 ,  3.952473  ,  3.8075526 ,  1.7800549 ,
#        -2.2092876 ,  3.6313457 ,  0.17599165,  1.5715055 ,  1.0988023 ,
#        -1.1550162 , -2.6193419 ,  0.01218152, -2.9498038 ,  0.79302603,
#         0.9338388 , -3.291411  , -1.6779103 , -3.2861583 , -3.2453792 ,
#        -1.7613271 , -0.96935546, -0.98925966, -1.137018  ,  0.32698405,
#         2.601997  , -3.179267  , -2.429421  , -0.9683772 ,  6.714281  ,
#         0.01271152, -2.3952408 ,  4.1934476 , -0.15137061, -2.463461  ,
#         1.3733284 , -0.6784345 , -0.99732786, -0.490483  , -0.7643031 ,
#         2.7650192 ,  0.18923801, -1.2285393 , -2.5842826 ,  1.0963786 ,
#        -1.2242095 ,  2.2945304 , -2.0236936 ,  1.5776336 ,  0.6756185 ,
#         1.1470528 ,  3.7207491 , -0.47422975,  0.26994932,  0.6917758 ,
#         2.917066  , -1.4396255 , -2.2485206 ,  6.6722736 ,  0.16118631,
#        -2.1646004 , -0.11449516, -3.7134838 , -2.6509256 ,  4.900377  ,
#        -4.1298018 ,  1.1869987 ,  4.2641597 , -2.0480428 ,  3.8858504 ,
#        -0.48263288,  0.8421749 , -3.6566827 , -3.2567496 , -2.4142268 ,
#         0.34031224,  3.8284647 , -3.6771474 ,  3.2501862 ,  4.4540715 ,
#        -0.52616906,  4.3338947 , -0.29253495,  0.91554433, -0.6850389 ,
#         1.0369359 , -2.883226  ,  0.93385124, -2.179288  , -0.5201297 ,
#        -0.5960307 ], dtype=float32), 'glove_vec300_norm_C2': 24.056175, 'is_oov_C2': True, 'order_C2': 0, 'is_ne_C2': False, 'ne_label_C2': None, 'tfidf_art_C2': 0.1605299124101392, 'liwc2015_C2': [1, 2, 3, 5, 40, 80, 81], 'negative_conc_C2': 0, 'positive_conc_C2': 0, 'weak_subj_C2': 0, 'strong_subj_C2': 0, 'MRCP_concretness_ratings_C2': 270, 'MRCP_Imagability_ratings_C2': 389, 'hyperbolic_terms_C2': 0, 'attitude_markers_C2': 0, 'kill_verbs_C2': 0, 'bias_lexicon_C2': 0, 'text_C3': 'beautiful', 'text_low_C3': 'beautiful', 'pos_C3': 'ADJ', 'lemma_C3': 'beautiful', 'lemma_low_C3': 'beautiful', 'tag_C3': 'JJ', 'dep_C3': 'amod', 'shape_C3': 'xxxx', 'is_alpha_C3': True, 'is_stop_C3': False, 'has_vec_C3': True, 'glove_vec300_C3': array([ 1.04209149e+00, -2.17558932e+00,  2.94323444e-01,  3.04307985e+00,
#        -2.62667298e+00,  1.52154946e+00, -1.45757461e+00,  1.15834236e+00,
#         2.75327969e+00,  1.69927657e-01,  2.11420894e+00,  5.67618787e-01,
#        -7.29837000e-01, -3.46303797e+00, -3.71549368e-01,  1.78159881e+00,
#        -4.86358225e-01,  2.41373062e-01, -9.76020098e-01, -1.99699879e+00,
#         7.37772465e-01, -9.60470676e-01, -2.45286560e+00,  3.52509832e+00,
#         2.24856424e+00, -2.05712104e+00, -1.43415308e+00,  3.47142053e+00,
#         5.47310889e-01, -1.61996675e+00, -7.93453574e-01,  7.19007850e-01,
#         2.46076536e+00, -2.49649465e-01, -1.12812662e+00, -5.49496055e-01,
#         3.42656112e+00, -1.56731606e+00, -3.22637939e+00,  7.37800062e-01,
#        -5.59149623e-01,  2.50340414e+00, -2.62753630e+00, -1.61706376e+00,
#         4.66870129e-01, -6.83374584e-01, -2.68598318e+00, -9.84853089e-01,
#        -1.95788419e+00,  9.39807892e-01,  3.87146622e-01,  2.10551596e+00,
#         2.22005844e+00, -2.12531710e+00, -2.21331310e+00, -4.41923022e-01,
#         6.05265617e+00,  1.65894949e+00, -7.25416064e-01, -1.10649514e+00,
#         6.15745783e-03, -1.42015171e+00,  2.45333362e+00, -2.48504519e-01,
#         2.61109161e+00, -2.31210399e+00,  6.75478029e+00, -1.54075718e+00,
#        -3.51919031e+00,  3.17375183e+00, -5.92801094e-01, -4.14915562e+00,
#        -9.52237606e-01,  1.13658404e+00,  2.05301240e-01, -2.24639869e+00,
#         1.61625552e+00, -1.25904191e+00,  8.08365464e-01,  3.82820177e+00,
#         1.18315327e+00, -1.80433226e+00,  2.44297886e+00, -6.95991337e-01,
#        -4.10978913e-01, -2.91799879e+00,  7.19997764e-01,  1.41642523e+00,
#        -6.45504653e-01, -9.00105357e-01, -1.95513892e+00, -3.32588720e+00,
#         9.94870901e-01, -1.62688643e-01,  1.19637445e-01,  4.08287001e+00],
#       dtype=float32), 'glove_vec300_norm_C3': 20.559483, 'is_oov_C3': True, 'order_C3': 2, 'is_ne_C3': False, 'ne_label_C3': None, 'tfidf_art_C3': 0.6027134447479771, 'liwc2015_C3': [21, 30, 31, 60, 61], 'negative_conc_C3': 0, 'positive_conc_C3': 1, 'weak_subj_C3': 0, 'strong_subj_C3': 1, 'MRCP_concretness_ratings_C3': 393, 'MRCP_Imagability_ratings_C3': 532, 'hyperbolic_terms_C3': 0, 'attitude_markers_C3': 0, 'kill_verbs_C3': 0, 'bias_lexicon_C3': 0, 'text_C4': 'law', 'text_low_C4': 'law', 'pos_C4': 'NOUN', 'lemma_C4': 'law', 'lemma_low_C4': 'law', 'tag_C4': 'NN', 'dep_C4': 'dobj', 'shape_C4': 'xxx', 'is_alpha_C4': True, 'is_stop_C4': False, 'has_vec_C4': True, 'glove_vec300_C4': array([ 2.5127182 ,  1.0801048 ,  0.55141866, -1.0467696 ,  1.4058485 ,
#         1.893547  ,  1.4644513 , -0.38699186,  0.5582211 ,  2.2739348 ,
#        -0.6482614 ,  1.1916167 ,  2.6871152 , -1.4116424 , -0.00630745,
#        -2.0520222 ,  0.13316554, -0.9806278 , -0.70416397,  0.5440371 ,
#         2.9542725 ,  1.4204788 ,  2.8996089 ,  0.44668955, -2.963249  ,
#         2.7618935 , -2.9747844 , -0.9640903 ,  3.7109625 , -0.429999  ,
#         0.10766715, -0.324152  , -0.06549639, -2.1600335 ,  0.3804598 ,
#        -1.9936872 ,  0.950349  , -1.4694576 , -4.0618324 , -2.6660106 ,
#         3.5937643 , -0.9165827 , -2.472858  , -1.6270965 , -0.3674165 ,
#        -0.32352   , -1.2343179 , -1.745507  ,  0.08969823,  1.908558  ,
#         0.08551818, -2.0132713 , -3.1785307 , -0.98710597, -3.0032306 ,
#         0.07831207,  2.4955766 ,  3.0445752 , -1.3814574 ,  2.920233  ,
#         0.72864485, -2.2533162 ,  0.13788372,  1.0061135 ,  0.39507318,
#        -1.5263107 ,  1.4342663 , -0.3147173 ,  0.26480955,  4.166658  ,
#        -0.4282336 , -1.5266174 ,  1.7268038 ,  4.1373615 , -3.609137  ,
#         0.18474917,  2.7125258 , -1.9827187 ,  0.5843681 , -1.0632677 ,
#         2.49159   , -0.07329136, -3.933137  ,  1.3745403 , -1.0768496 ,
#        -0.5762987 ,  0.33623853,  0.78273374, -0.22827572, -2.9165163 ,
#        -0.8236386 , -0.61828196,  0.63191634, -0.30388442,  3.4109025 ,
#        -0.15561664], dtype=float32), 'glove_vec300_norm_C4': 18.441996, 'is_oov_C4': True, 'order_C4': 3, 'is_ne_C4': False, 'ne_label_C4': None, 'tfidf_art_C4': 0.15736830639226557, 'liwc2015_C4': [80, 83, 110], 'negative_conc_C4': 0, 'positive_conc_C4': 0, 'weak_subj_C4': 0, 'strong_subj_C4': 0, 'MRCP_concretness_ratings_C4': 349, 'MRCP_Imagability_ratings_C4': 409, 'hyperbolic_terms_C4': 0, 'attitude_markers_C4': 0, 'kill_verbs_C4': 0, 'bias_lexicon_C4': 0, 'window_text': [None, None, None, 'we', 'have', 'beautiful', 'law', 'trump', 'recently'], 'window_lemma': [None, None, None, '-pron-', 'have', 'beautiful', 'law', 'trump', 'recently'], 'assertive_verbs': 0, 'factive_verbs': 0, 'report_verbs': 0, 'hedges': 0, 'boosters': 0, 'implicative_verbs': 0, 'assertive_verbs_C1': 0, 'factive_verbs_C1': 0, 'report_verbs_C1': 0, 'hedges_C1': 0, 'boosters_C1': 0, 'implicative_verbs_C1': 0, 'assertive_verbs_C2': 0, 'factive_verbs_C2': 0, 'report_verbs_C2': 0, 'hedges_C2': 0, 'boosters_C2': 0, 'implicative_verbs_C2': 0, 'assertive_verbs_C3': 0, 'factive_verbs_C3': 0, 'report_verbs_C3': 0, 'hedges_C3': 0, 'boosters_C3': 0, 'implicative_verbs_C3': 0, 'assertive_verbs_C4': 0, 'factive_verbs_C4': 0, 'report_verbs_C4': 0, 'hedges_C4': 0, 'boosters_C4': 0, 'implicative_verbs_C4': 0}
# {'text': 'beautiful', 'text_low': 'beautiful', 'pos': 'ADJ', 'lemma': 'beautiful', 'lemma_low': 'beautiful', 'tag': 'JJ', 'dep': 'amod', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False, 'has_vec': True, 'glove_vec300': array([ 1.04209149e+00, -2.17558932e+00,  2.94323444e-01,  3.04307985e+00,
#        -2.62667298e+00,  1.52154946e+00, -1.45757461e+00,  1.15834236e+00,
#         2.75327969e+00,  1.69927657e-01,  2.11420894e+00,  5.67618787e-01,
#        -7.29837000e-01, -3.46303797e+00, -3.71549368e-01,  1.78159881e+00,
#        -4.86358225e-01,  2.41373062e-01, -9.76020098e-01, -1.99699879e+00,
#         7.37772465e-01, -9.60470676e-01, -2.45286560e+00,  3.52509832e+00,
#         2.24856424e+00, -2.05712104e+00, -1.43415308e+00,  3.47142053e+00,
#         5.47310889e-01, -1.61996675e+00, -7.93453574e-01,  7.19007850e-01,
#         2.46076536e+00, -2.49649465e-01, -1.12812662e+00, -5.49496055e-01,
#         3.42656112e+00, -1.56731606e+00, -3.22637939e+00,  7.37800062e-01,
#        -5.59149623e-01,  2.50340414e+00, -2.62753630e+00, -1.61706376e+00,
#         4.66870129e-01, -6.83374584e-01, -2.68598318e+00, -9.84853089e-01,
#        -1.95788419e+00,  9.39807892e-01,  3.87146622e-01,  2.10551596e+00,
#         2.22005844e+00, -2.12531710e+00, -2.21331310e+00, -4.41923022e-01,
#         6.05265617e+00,  1.65894949e+00, -7.25416064e-01, -1.10649514e+00,
#         6.15745783e-03, -1.42015171e+00,  2.45333362e+00, -2.48504519e-01,
#         2.61109161e+00, -2.31210399e+00,  6.75478029e+00, -1.54075718e+00,
#        -3.51919031e+00,  3.17375183e+00, -5.92801094e-01, -4.14915562e+00,
#        -9.52237606e-01,  1.13658404e+00,  2.05301240e-01, -2.24639869e+00,
#         1.61625552e+00, -1.25904191e+00,  8.08365464e-01,  3.82820177e+00,
#         1.18315327e+00, -1.80433226e+00,  2.44297886e+00, -6.95991337e-01,
#        -4.10978913e-01, -2.91799879e+00,  7.19997764e-01,  1.41642523e+00,
#        -6.45504653e-01, -9.00105357e-01, -1.95513892e+00, -3.32588720e+00,
#         9.94870901e-01, -1.62688643e-01,  1.19637445e-01,  4.08287001e+00],
#       dtype=float32), 'glove_vec300_norm': 20.559483, 'is_oov': True, 'order': 2, 'tfidf_art': 0.6027134447479771, 'label3': 0, 'label4': 0, 'label5': 0, 'is_ne': False, 'ne_label': None, 'liwc2015': [21, 30, 31, 60, 61], 'negative_conc': 0, 'positive_conc': 1, 'weak_subj': 0, 'strong_subj': 1, 'MRCP_concretness_ratings': 393, 'MRCP_Imagability_ratings': 532, 'hyperbolic_terms': 0, 'attitude_markers': 0, 'kill_verbs': 0, 'bias_lexicon': 0, 'text_C1': 'We', 'text_low_C1': 'we', 'pos_C1': 'PRON', 'lemma_C1': '-PRON-', 'lemma_low_C1': '-pron-', 'tag_C1': 'PRP', 'dep_C1': 'nsubj', 'shape_C1': 'Xx', 'is_alpha_C1': True, 'is_stop_C1': True, 'has_vec_C1': True, 'glove_vec300_C1': array([-0.31676668,  4.087597  , -0.1161238 , -2.0217166 , -0.45238057,
#         0.35491768,  1.4899944 ,  3.952473  ,  3.8075526 ,  1.7800549 ,
#        -2.2092876 ,  3.6313457 ,  0.17599165,  1.5715055 ,  1.0988023 ,
#        -1.1550162 , -2.6193419 ,  0.01218152, -2.9498038 ,  0.79302603,
#         0.9338388 , -3.291411  , -1.6779103 , -3.2861583 , -3.2453792 ,
#        -1.7613271 , -0.96935546, -0.98925966, -1.137018  ,  0.32698405,
#         2.601997  , -3.179267  , -2.429421  , -0.9683772 ,  6.714281  ,
#         0.01271152, -2.3952408 ,  4.1934476 , -0.15137061, -2.463461  ,
#         1.3733284 , -0.6784345 , -0.99732786, -0.490483  , -0.7643031 ,
#         2.7650192 ,  0.18923801, -1.2285393 , -2.5842826 ,  1.0963786 ,
#        -1.2242095 ,  2.2945304 , -2.0236936 ,  1.5776336 ,  0.6756185 ,
#         1.1470528 ,  3.7207491 , -0.47422975,  0.26994932,  0.6917758 ,
#         2.917066  , -1.4396255 , -2.2485206 ,  6.6722736 ,  0.16118631,
#        -2.1646004 , -0.11449516, -3.7134838 , -2.6509256 ,  4.900377  ,
#        -4.1298018 ,  1.1869987 ,  4.2641597 , -2.0480428 ,  3.8858504 ,
#        -0.48263288,  0.8421749 , -3.6566827 , -3.2567496 , -2.4142268 ,
#         0.34031224,  3.8284647 , -3.6771474 ,  3.2501862 ,  4.4540715 ,
#        -0.52616906,  4.3338947 , -0.29253495,  0.91554433, -0.6850389 ,
#         1.0369359 , -2.883226  ,  0.93385124, -2.179288  , -0.5201297 ,
#        -0.5960307 ], dtype=float32), 'glove_vec300_norm_C1': 24.056175, 'is_oov_C1': True, 'order_C1': 0, 'is_ne_C1': False, 'ne_label_C1': None, 'tfidf_art_C1': 0.1605299124101392, 'liwc2015_C1': [1, 2, 3, 5, 40, 80, 81], 'negative_conc_C1': 0, 'positive_conc_C1': 0, 'weak_subj_C1': 0, 'strong_subj_C1': 0, 'MRCP_concretness_ratings_C1': 270, 'MRCP_Imagability_ratings_C1': 389, 'hyperbolic_terms_C1': 0, 'attitude_markers_C1': 0, 'kill_verbs_C1': 0, 'bias_lexicon_C1': 0, 'text_C2': 'have', 'text_low_C2': 'have', 'pos_C2': 'AUX', 'lemma_C2': 'have', 'lemma_low_C2': 'have', 'tag_C2': 'VBP', 'dep_C2': 'ccomp', 'shape_C2': 'xxxx', 'is_alpha_C2': True, 'is_stop_C2': True, 'has_vec_C2': True, 'glove_vec300_C2': array([-0.7213155 ,  3.6601207 ,  0.1219139 , -2.8546267 , -1.6260936 ,
#         0.7542187 , -1.6724557 ,  1.1218082 ,  1.6834638 , -0.5129777 ,
#        -5.07646   , -2.7883441 , -4.5636215 ,  0.32953244, -1.3135604 ,
#         2.2146423 , -0.7577101 , -3.3878486 ,  3.7318592 ,  0.38368842,
#         5.2768984 ,  2.4950745 , -2.6944914 ,  1.3810098 ,  0.53450716,
#        -2.2463698 ,  1.223988  , -3.6009285 , -1.5314493 ,  0.4668301 ,
#         2.6985629 , -0.1332308 ,  1.229918  , -2.719051  , -1.332753  ,
#        -1.336633  ,  0.00754869, -2.1205497 , -0.5595583 ,  1.6552678 ,
#        -0.80639243,  0.23420328,  1.5979211 , -2.7545152 ,  2.5082233 ,
#        -1.2026258 ,  0.8675622 ,  3.5132718 , -1.0352685 , -2.772653  ,
#         0.8430741 , -1.1458037 ,  4.804392  , -2.6640275 , -2.2228732 ,
#        -2.0851455 ,  1.8123571 ,  0.88473475,  1.4531286 ,  1.6001296 ,
#         6.508646  , -3.6590223 , -2.010408  , -1.8154957 ,  0.32603776,
#         1.2426485 ,  1.595177  ,  2.848076  ,  3.260756  , -2.1086698 ,
#        -0.18522155,  4.6400237 ,  2.2688003 ,  1.0339924 ,  1.086308  ,
#        -0.03257135,  0.2157588 ,  0.9183563 ,  1.7917401 ,  0.5685625 ,
#         0.9769081 , -2.4917321 , -2.138284  ,  0.73112077,  0.8799888 ,
#        -1.0759863 ,  3.4777255 , -1.7152269 , -1.3512974 ,  0.2977367 ,
#         1.121925  ,  0.89665127, -3.7105746 ,  1.9052389 , -2.141551  ,
#         2.3576035 ], dtype=float32), 'glove_vec300_norm_C2': 22.088182, 'is_oov_C2': True, 'order_C2': 1, 'is_ne_C2': False, 'ne_label_C2': None, 'tfidf_art_C2': 0.10554970619696329, 'liwc2015_C2': [1, 12, 20, 91], 'negative_conc_C2': 0, 'positive_conc_C2': 0, 'weak_subj_C2': 0, 'strong_subj_C2': 0, 'MRCP_concretness_ratings_C2': 251, 'MRCP_Imagability_ratings_C2': 271, 'hyperbolic_terms_C2': 0, 'attitude_markers_C2': 0, 'kill_verbs_C2': 0, 'bias_lexicon_C2': 0, 'text_C3': 'law', 'text_low_C3': 'law', 'pos_C3': 'NOUN', 'lemma_C3': 'law', 'lemma_low_C3': 'law', 'tag_C3': 'NN', 'dep_C3': 'dobj', 'shape_C3': 'xxx', 'is_alpha_C3': True, 'is_stop_C3': False, 'has_vec_C3': True, 'glove_vec300_C3': array([ 2.5127182 ,  1.0801048 ,  0.55141866, -1.0467696 ,  1.4058485 ,
#         1.893547  ,  1.4644513 , -0.38699186,  0.5582211 ,  2.2739348 ,
#        -0.6482614 ,  1.1916167 ,  2.6871152 , -1.4116424 , -0.00630745,
#        -2.0520222 ,  0.13316554, -0.9806278 , -0.70416397,  0.5440371 ,
#         2.9542725 ,  1.4204788 ,  2.8996089 ,  0.44668955, -2.963249  ,
#         2.7618935 , -2.9747844 , -0.9640903 ,  3.7109625 , -0.429999  ,
#         0.10766715, -0.324152  , -0.06549639, -2.1600335 ,  0.3804598 ,
#        -1.9936872 ,  0.950349  , -1.4694576 , -4.0618324 , -2.6660106 ,
#         3.5937643 , -0.9165827 , -2.472858  , -1.6270965 , -0.3674165 ,
#        -0.32352   , -1.2343179 , -1.745507  ,  0.08969823,  1.908558  ,
#         0.08551818, -2.0132713 , -3.1785307 , -0.98710597, -3.0032306 ,
#         0.07831207,  2.4955766 ,  3.0445752 , -1.3814574 ,  2.920233  ,
#         0.72864485, -2.2533162 ,  0.13788372,  1.0061135 ,  0.39507318,
#        -1.5263107 ,  1.4342663 , -0.3147173 ,  0.26480955,  4.166658  ,
#        -0.4282336 , -1.5266174 ,  1.7268038 ,  4.1373615 , -3.609137  ,
#         0.18474917,  2.7125258 , -1.9827187 ,  0.5843681 , -1.0632677 ,
#         2.49159   , -0.07329136, -3.933137  ,  1.3745403 , -1.0768496 ,
#        -0.5762987 ,  0.33623853,  0.78273374, -0.22827572, -2.9165163 ,
#        -0.8236386 , -0.61828196,  0.63191634, -0.30388442,  3.4109025 ,
#        -0.15561664], dtype=float32), 'glove_vec300_norm_C3': 18.441996, 'is_oov_C3': True, 'order_C3': 3, 'is_ne_C3': False, 'ne_label_C3': None, 'tfidf_art_C3': 0.15736830639226557, 'liwc2015_C3': [80, 83, 110], 'negative_conc_C3': 0, 'positive_conc_C3': 0, 'weak_subj_C3': 0, 'strong_subj_C3': 0, 'MRCP_concretness_ratings_C3': 349, 'MRCP_Imagability_ratings_C3': 409, 'hyperbolic_terms_C3': 0, 'attitude_markers_C3': 0, 'kill_verbs_C3': 0, 'bias_lexicon_C3': 0, 'text_C4': 'Trump', 'text_low_C4': 'trump', 'pos_C4': 'PROPN', 'lemma_C4': 'Trump', 'lemma_low_C4': 'trump', 'tag_C4': 'NNP', 'dep_C4': 'nsubj', 'shape_C4': 'Xxxxx', 'is_alpha_C4': True, 'is_stop_C4': False, 'has_vec_C4': True, 'glove_vec300_C4': array([ 0.60732174, -0.45728394, -3.5649567 , -2.1744874 ,  1.3643047 ,
#        -1.1683029 , -0.81667846,  2.245509  , -1.7708302 ,  1.2036362 ,
#        -1.0819273 ,  1.8035645 ,  2.191144  , -3.4232817 , -4.5615845 ,
#         0.13325495,  0.7494449 , -1.8905632 , -0.13519168,  1.0753474 ,
#        -1.8177965 , -1.7737341 ,  1.9752417 , -2.5609624 , -2.1561115 ,
#         0.0629099 ,  1.0171343 ,  0.27236593, -0.1670343 , -4.4643564 ,
#         1.98068   , -2.7435334 ,  1.4847885 , -3.2501779 ,  2.5541608 ,
#        -3.290646  ,  1.5346978 , -1.6107153 , -1.024206  ,  3.5252826 ,
#        -1.2259681 ,  1.5499495 ,  1.3005277 , -3.0936418 ,  0.66602933,
#         4.8807645 , -2.886193  ,  1.187335  ,  0.7055118 ,  2.0495782 ,
#         1.6000254 ,  1.9992073 ,  0.00870097, -0.45050347, -3.039001  ,
#         1.313643  , -2.0468855 ,  4.9615507 ,  5.9556313 ,  0.30394483,
#         1.8115586 , -1.0292323 ,  0.6816999 ,  1.2509885 , -0.899361  ,
#         0.2511499 , -3.9400318 ,  3.2095208 ,  1.4688033 , -1.5865185 ,
#        -0.87137914, -1.224659  , -0.23414683, -1.946579  , -1.055157  ,
#         0.59367913,  3.7539284 , -2.1586318 , -1.9011242 , -1.7756962 ,
#         0.64730716,  1.1605623 ,  1.2610135 ,  1.4792057 , -1.3529465 ,
#         1.1468966 ,  1.0767351 , -0.8972961 ,  0.45825535,  1.337317  ,
#         1.7868032 , -0.5349264 ,  2.547089  ,  3.305139  , -0.47338557,
#         1.9667777 ], dtype=float32), 'glove_vec300_norm_C4': 20.631742, 'is_oov_C4': True, 'order_C4': 4, 'is_ne_C4': True, 'ne_label_C4': 'PERSON', 'tfidf_art_C4': 0.08352059251909213, 'liwc2015_C4': [], 'negative_conc_C4': 0, 'positive_conc_C4': 1, 'weak_subj_C4': 0, 'strong_subj_C4': 1, 'MRCP_concretness_ratings_C4': None, 'MRCP_Imagability_ratings_C4': None, 'hyperbolic_terms_C4': 0, 'attitude_markers_C4': 0, 'kill_verbs_C4': 0, 'bias_lexicon_C4': 0, 'window_text': [None, None, 'we', 'have', 'beautiful', 'law', 'trump', 'recently', 'said'], 'window_lemma': [None, None, '-pron-', 'have', 'beautiful', 'law', 'trump', 'recently', 'say'], 'assertive_verbs': 0, 'factive_verbs': 0, 'report_verbs': 0, 'hedges': 0, 'boosters': 0, 'implicative_verbs': 0, 'assertive_verbs_C1': 0, 'factive_verbs_C1': 0, 'report_verbs_C1': 0, 'hedges_C1': 0, 'boosters_C1': 0, 'implicative_verbs_C1': 0, 'assertive_verbs_C2': 0, 'factive_verbs_C2': 0, 'report_verbs_C2': 0, 'hedges_C2': 0, 'boosters_C2': 0, 'implicative_verbs_C2': 0, 'assertive_verbs_C3': 0, 'factive_verbs_C3': 0, 'report_verbs_C3': 0, 'hedges_C3': 0, 'boosters_C3': 0, 'implicative_verbs_C3': 0, 'assertive_verbs_C4': 0, 'factive_verbs_C4': 0, 'report_verbs_C4': 0, 'hedges_C4': 0, 'boosters_C4': 0, 'implicative_verbs_C4': 0}
# {'text': 'law', 'text_low': 'law', 'pos': 'NOUN', 'lemma': 'law', 'lemma_low': 'law', 'tag': 'NN', 'dep': 'dobj', 'shape': 'xxx', 'is_alpha': True, 'is_stop': False, 'has_vec': True, 'glove_vec300': array([ 2.5127182 ,  1.0801048 ,  0.55141866, -1.0467696 ,  1.4058485 ,
#         1.893547  ,  1.4644513 , -0.38699186,  0.5582211 ,  2.2739348 ,
#        -0.6482614 ,  1.1916167 ,  2.6871152 , -1.4116424 , -0.00630745,
#        -2.0520222 ,  0.13316554, -0.9806278 , -0.70416397,  0.5440371 ,
#         2.9542725 ,  1.4204788 ,  2.8996089 ,  0.44668955, -2.963249  ,
#         2.7618935 , -2.9747844 , -0.9640903 ,  3.7109625 , -0.429999  ,
#         0.10766715, -0.324152  , -0.06549639, -2.1600335 ,  0.3804598 ,
#        -1.9936872 ,  0.950349  , -1.4694576 , -4.0618324 , -2.6660106 ,
#         3.5937643 , -0.9165827 , -2.472858  , -1.6270965 , -0.3674165 ,
#        -0.32352   , -1.2343179 , -1.745507  ,  0.08969823,  1.908558  ,
#         0.08551818, -2.0132713 , -3.1785307 , -0.98710597, -3.0032306 ,
#         0.07831207,  2.4955766 ,  3.0445752 , -1.3814574 ,  2.920233  ,
#         0.72864485, -2.2533162 ,  0.13788372,  1.0061135 ,  0.39507318,
#        -1.5263107 ,  1.4342663 , -0.3147173 ,  0.26480955,  4.166658  ,
#        -0.4282336 , -1.5266174 ,  1.7268038 ,  4.1373615 , -3.609137  ,
#         0.18474917,  2.7125258 , -1.9827187 ,  0.5843681 , -1.0632677 ,
#         2.49159   , -0.07329136, -3.933137  ,  1.3745403 , -1.0768496 ,
#        -0.5762987 ,  0.33623853,  0.78273374, -0.22827572, -2.9165163 ,
#        -0.8236386 , -0.61828196,  0.63191634, -0.30388442,  3.4109025 ,
#        -0.15561664], dtype=float32), 'glove_vec300_norm': 18.441996, 'is_oov': True, 'order': 3, 'tfidf_art': 0.15736830639226557, 'label3': 0, 'label4': 0, 'label5': 0, 'is_ne': False, 'ne_label': None, 'liwc2015': [80, 83, 110], 'negative_conc': 0, 'positive_conc': 0, 'weak_subj': 0, 'strong_subj': 0, 'MRCP_concretness_ratings': 349, 'MRCP_Imagability_ratings': 409, 'hyperbolic_terms': 0, 'attitude_markers': 0, 'kill_verbs': 0, 'bias_lexicon': 0, 'text_C1': 'have', 'text_low_C1': 'have', 'pos_C1': 'AUX', 'lemma_C1': 'have', 'lemma_low_C1': 'have', 'tag_C1': 'VBP', 'dep_C1': 'ccomp', 'shape_C1': 'xxxx', 'is_alpha_C1': True, 'is_stop_C1': True, 'has_vec_C1': True, 'glove_vec300_C1': array([-0.7213155 ,  3.6601207 ,  0.1219139 , -2.8546267 , -1.6260936 ,
#         0.7542187 , -1.6724557 ,  1.1218082 ,  1.6834638 , -0.5129777 ,
#        -5.07646   , -2.7883441 , -4.5636215 ,  0.32953244, -1.3135604 ,
#         2.2146423 , -0.7577101 , -3.3878486 ,  3.7318592 ,  0.38368842,
#         5.2768984 ,  2.4950745 , -2.6944914 ,  1.3810098 ,  0.53450716,
#        -2.2463698 ,  1.223988  , -3.6009285 , -1.5314493 ,  0.4668301 ,
#         2.6985629 , -0.1332308 ,  1.229918  , -2.719051  , -1.332753  ,
#        -1.336633  ,  0.00754869, -2.1205497 , -0.5595583 ,  1.6552678 ,
#        -0.80639243,  0.23420328,  1.5979211 , -2.7545152 ,  2.5082233 ,
#        -1.2026258 ,  0.8675622 ,  3.5132718 , -1.0352685 , -2.772653  ,
#         0.8430741 , -1.1458037 ,  4.804392  , -2.6640275 , -2.2228732 ,
#        -2.0851455 ,  1.8123571 ,  0.88473475,  1.4531286 ,  1.6001296 ,
#         6.508646  , -3.6590223 , -2.010408  , -1.8154957 ,  0.32603776,
#         1.2426485 ,  1.595177  ,  2.848076  ,  3.260756  , -2.1086698 ,
#        -0.18522155,  4.6400237 ,  2.2688003 ,  1.0339924 ,  1.086308  ,
#        -0.03257135,  0.2157588 ,  0.9183563 ,  1.7917401 ,  0.5685625 ,
#         0.9769081 , -2.4917321 , -2.138284  ,  0.73112077,  0.8799888 ,
#        -1.0759863 ,  3.4777255 , -1.7152269 , -1.3512974 ,  0.2977367 ,
#         1.121925  ,  0.89665127, -3.7105746 ,  1.9052389 , -2.141551  ,
#         2.3576035 ], dtype=float32), 'glove_vec300_norm_C1': 22.088182, 'is_oov_C1': True, 'order_C1': 1, 'is_ne_C1': False, 'ne_label_C1': None, 'tfidf_art_C1': 0.10554970619696329, 'liwc2015_C1': [1, 12, 20, 91], 'negative_conc_C1': 0, 'positive_conc_C1': 0, 'weak_subj_C1': 0, 'strong_subj_C1': 0, 'MRCP_concretness_ratings_C1': 251, 'MRCP_Imagability_ratings_C1': 271, 'hyperbolic_terms_C1': 0, 'attitude_markers_C1': 0, 'kill_verbs_C1': 0, 'bias_lexicon_C1': 0, 'text_C2': 'beautiful', 'text_low_C2': 'beautiful', 'pos_C2': 'ADJ', 'lemma_C2': 'beautiful', 'lemma_low_C2': 'beautiful', 'tag_C2': 'JJ', 'dep_C2': 'amod', 'shape_C2': 'xxxx', 'is_alpha_C2': True, 'is_stop_C2': False, 'has_vec_C2': True, 'glove_vec300_C2': array([ 1.04209149e+00, -2.17558932e+00,  2.94323444e-01,  3.04307985e+00,
#        -2.62667298e+00,  1.52154946e+00, -1.45757461e+00,  1.15834236e+00,
#         2.75327969e+00,  1.69927657e-01,  2.11420894e+00,  5.67618787e-01,
#        -7.29837000e-01, -3.46303797e+00, -3.71549368e-01,  1.78159881e+00,
#        -4.86358225e-01,  2.41373062e-01, -9.76020098e-01, -1.99699879e+00,
#         7.37772465e-01, -9.60470676e-01, -2.45286560e+00,  3.52509832e+00,
#         2.24856424e+00, -2.05712104e+00, -1.43415308e+00,  3.47142053e+00,
#         5.47310889e-01, -1.61996675e+00, -7.93453574e-01,  7.19007850e-01,
#         2.46076536e+00, -2.49649465e-01, -1.12812662e+00, -5.49496055e-01,
#         3.42656112e+00, -1.56731606e+00, -3.22637939e+00,  7.37800062e-01,
#        -5.59149623e-01,  2.50340414e+00, -2.62753630e+00, -1.61706376e+00,
#         4.66870129e-01, -6.83374584e-01, -2.68598318e+00, -9.84853089e-01,
#        -1.95788419e+00,  9.39807892e-01,  3.87146622e-01,  2.10551596e+00,
#         2.22005844e+00, -2.12531710e+00, -2.21331310e+00, -4.41923022e-01,
#         6.05265617e+00,  1.65894949e+00, -7.25416064e-01, -1.10649514e+00,
#         6.15745783e-03, -1.42015171e+00,  2.45333362e+00, -2.48504519e-01,
#         2.61109161e+00, -2.31210399e+00,  6.75478029e+00, -1.54075718e+00,
#        -3.51919031e+00,  3.17375183e+00, -5.92801094e-01, -4.14915562e+00,
#        -9.52237606e-01,  1.13658404e+00,  2.05301240e-01, -2.24639869e+00,
#         1.61625552e+00, -1.25904191e+00,  8.08365464e-01,  3.82820177e+00,
#         1.18315327e+00, -1.80433226e+00,  2.44297886e+00, -6.95991337e-01,
#        -4.10978913e-01, -2.91799879e+00,  7.19997764e-01,  1.41642523e+00,
#        -6.45504653e-01, -9.00105357e-01, -1.95513892e+00, -3.32588720e+00,
#         9.94870901e-01, -1.62688643e-01,  1.19637445e-01,  4.08287001e+00],
#       dtype=float32), 'glove_vec300_norm_C2': 20.559483, 'is_oov_C2': True, 'order_C2': 2, 'is_ne_C2': False, 'ne_label_C2': None, 'tfidf_art_C2': 0.6027134447479771, 'liwc2015_C2': [21, 30, 31, 60, 61], 'negative_conc_C2': 0, 'positive_conc_C2': 1, 'weak_subj_C2': 0, 'strong_subj_C2': 1, 'MRCP_concretness_ratings_C2': 393, 'MRCP_Imagability_ratings_C2': 532, 'hyperbolic_terms_C2': 0, 'attitude_markers_C2': 0, 'kill_verbs_C2': 0, 'bias_lexicon_C2': 0, 'text_C3': 'Trump', 'text_low_C3': 'trump', 'pos_C3': 'PROPN', 'lemma_C3': 'Trump', 'lemma_low_C3': 'trump', 'tag_C3': 'NNP', 'dep_C3': 'nsubj', 'shape_C3': 'Xxxxx', 'is_alpha_C3': True, 'is_stop_C3': False, 'has_vec_C3': True, 'glove_vec300_C3': array([ 0.60732174, -0.45728394, -3.5649567 , -2.1744874 ,  1.3643047 ,
#        -1.1683029 , -0.81667846,  2.245509  , -1.7708302 ,  1.2036362 ,
#        -1.0819273 ,  1.8035645 ,  2.191144  , -3.4232817 , -4.5615845 ,
#         0.13325495,  0.7494449 , -1.8905632 , -0.13519168,  1.0753474 ,
#        -1.8177965 , -1.7737341 ,  1.9752417 , -2.5609624 , -2.1561115 ,
#         0.0629099 ,  1.0171343 ,  0.27236593, -0.1670343 , -4.4643564 ,
#         1.98068   , -2.7435334 ,  1.4847885 , -3.2501779 ,  2.5541608 ,
#        -3.290646  ,  1.5346978 , -1.6107153 , -1.024206  ,  3.5252826 ,
#        -1.2259681 ,  1.5499495 ,  1.3005277 , -3.0936418 ,  0.66602933,
#         4.8807645 , -2.886193  ,  1.187335  ,  0.7055118 ,  2.0495782 ,
#         1.6000254 ,  1.9992073 ,  0.00870097, -0.45050347, -3.039001  ,
#         1.313643  , -2.0468855 ,  4.9615507 ,  5.9556313 ,  0.30394483,
#         1.8115586 , -1.0292323 ,  0.6816999 ,  1.2509885 , -0.899361  ,
#         0.2511499 , -3.9400318 ,  3.2095208 ,  1.4688033 , -1.5865185 ,
#        -0.87137914, -1.224659  , -0.23414683, -1.946579  , -1.055157  ,
#         0.59367913,  3.7539284 , -2.1586318 , -1.9011242 , -1.7756962 ,
#         0.64730716,  1.1605623 ,  1.2610135 ,  1.4792057 , -1.3529465 ,
#         1.1468966 ,  1.0767351 , -0.8972961 ,  0.45825535,  1.337317  ,
#         1.7868032 , -0.5349264 ,  2.547089  ,  3.305139  , -0.47338557,
#         1.9667777 ], dtype=float32), 'glove_vec300_norm_C3': 20.631742, 'is_oov_C3': True, 'order_C3': 4, 'is_ne_C3': True, 'ne_label_C3': 'PERSON', 'tfidf_art_C3': 0.08352059251909213, 'liwc2015_C3': [], 'negative_conc_C3': 0, 'positive_conc_C3': 1, 'weak_subj_C3': 0, 'strong_subj_C3': 1, 'MRCP_concretness_ratings_C3': None, 'MRCP_Imagability_ratings_C3': None, 'hyperbolic_terms_C3': 0, 'attitude_markers_C3': 0, 'kill_verbs_C3': 0, 'bias_lexicon_C3': 0, 'text_C4': 'recently', 'text_low_C4': 'recently', 'pos_C4': 'ADV', 'lemma_C4': 'recently', 'lemma_low_C4': 'recently', 'tag_C4': 'RB', 'dep_C4': 'advmod', 'shape_C4': 'xxxx', 'is_alpha_C4': True, 'is_stop_C4': False, 'has_vec_C4': True, 'glove_vec300_C4': array([ 1.263055  , -1.7897688 ,  2.6992624 , -0.9803779 , -0.7569143 ,
#        -3.7781007 ,  1.7289946 ,  0.17907545, -1.9765699 ,  1.0407529 ,
#        -1.3328599 ,  1.6105115 , -1.1332214 ,  0.52900094, -0.78552735,
#        -1.2588551 ,  0.45483226,  0.8148671 , -3.0082004 ,  2.9004798 ,
#        -1.625483  , -5.072552  ,  0.00729746, -0.55940115, -1.5447247 ,
#         5.554523  ,  3.845502  , -0.92855895, -1.1660392 , -4.1529336 ,
#         3.2665775 , -3.6018045 ,  1.4368714 , -1.8641777 ,  2.6838648 ,
#         0.03271806,  1.1711339 , -1.1887933 , -3.0970201 , -1.7917619 ,
#        -1.1196198 , -1.0480204 , -0.29511598,  1.343651  , -1.4754375 ,
#         5.9275527 , -0.9335904 , -1.884697  , -1.0051427 ,  2.1060638 ,
#         1.032903  ,  1.9394591 ,  0.7334273 ,  0.87609327, -2.3847075 ,
#        -0.07630092, -1.5743846 ,  2.5099027 , -0.5933989 , -1.0468186 ,
#        -2.0655546 , -2.3564215 ,  0.7114805 , -1.9602534 ,  2.6071162 ,
#        -0.2794789 , -1.0627644 , -2.902858  ,  7.1759644 ,  0.29806817,
#        -1.1789532 , -0.19579391, -1.456621  , -1.6958094 , -1.8421783 ,
#        -2.1855383 ,  5.814557  ,  3.937067  ,  0.11497439, -0.22077134,
#        -3.5991602 , -4.539239  ,  2.6846323 ,  2.7430851 , -1.2213697 ,
#        -1.7091018 ,  5.356979  ,  3.7128675 , -3.53374   ,  1.3308955 ,
#         2.285049  ,  1.3908658 , -0.41040048,  5.6230364 ,  2.2361832 ,
#         0.63165396], dtype=float32), 'glove_vec300_norm_C4': 24.164957, 'is_oov_C4': True, 'order_C4': 5, 'is_ne_C4': False, 'ne_label_C4': None, 'tfidf_art_C4': 0.20215574753344304, 'liwc2015_C4': [], 'negative_conc_C4': 0, 'positive_conc_C4': 0, 'weak_subj_C4': 0, 'strong_subj_C4': 0, 'MRCP_concretness_ratings_C4': None, 'MRCP_Imagability_ratings_C4': None, 'hyperbolic_terms_C4': 0, 'attitude_markers_C4': 0, 'kill_verbs_C4': 0, 'bias_lexicon_C4': 0, 'window_text': [None, 'we', 'have', 'beautiful', 'law', 'trump', 'recently', 'said', 'in'], 'window_lemma': [None, '-pron-', 'have', 'beautiful', 'law', 'trump', 'recently', 'say', 'in'], 'assertive_verbs': 0, 'factive_verbs': 0, 'report_verbs': 0, 'hedges': 0, 'boosters': 0, 'implicative_verbs': 0, 'assertive_verbs_C1': 0, 'factive_verbs_C1': 0, 'report_verbs_C1': 0, 'hedges_C1': 0, 'boosters_C1': 0, 'implicative_verbs_C1': 0, 'assertive_verbs_C2': 0, 'factive_verbs_C2': 0, 'report_verbs_C2': 0, 'hedges_C2': 0, 'boosters_C2': 0, 'implicative_verbs_C2': 0, 'assertive_verbs_C3': 0, 'factive_verbs_C3': 0, 'report_verbs_C3': 0, 'hedges_C3': 0, 'boosters_C3': 0, 'implicative_verbs_C3': 0, 'assertive_verbs_C4': 0, 'factive_verbs_C4': 0, 'report_verbs_C4': 0, 'hedges_C4': 0, 'boosters_C4': 0, 'implicative_verbs_C4': 0}
# {'text': 'Trump', 'text_low': 'trump', 'pos': 'PROPN', 'lemma': 'Trump', 'lemma_low': 'trump', 'tag': 'NNP', 'dep': 'nsubj', 'shape': 'Xxxxx', 'is_alpha': True, 'is_stop': False, 'has_vec': True, 'glove_vec300': array([ 0.60732174, -0.45728394, -3.5649567 , -2.1744874 ,  1.3643047 ,
#        -1.1683029 , -0.81667846,  2.245509  , -1.7708302 ,  1.2036362 ,
#        -1.0819273 ,  1.8035645 ,  2.191144  , -3.4232817 , -4.5615845 ,
#         0.13325495,  0.7494449 , -1.8905632 , -0.13519168,  1.0753474 ,
#        -1.8177965 , -1.7737341 ,  1.9752417 , -2.5609624 , -2.1561115 ,
#         0.0629099 ,  1.0171343 ,  0.27236593, -0.1670343 , -4.4643564 ,
#         1.98068   , -2.7435334 ,  1.4847885 , -3.2501779 ,  2.5541608 ,
#        -3.290646  ,  1.5346978 , -1.6107153 , -1.024206  ,  3.5252826 ,
#        -1.2259681 ,  1.5499495 ,  1.3005277 , -3.0936418 ,  0.66602933,
#         4.8807645 , -2.886193  ,  1.187335  ,  0.7055118 ,  2.0495782 ,
#         1.6000254 ,  1.9992073 ,  0.00870097, -0.45050347, -3.039001  ,
#         1.313643  , -2.0468855 ,  4.9615507 ,  5.9556313 ,  0.30394483,
#         1.8115586 , -1.0292323 ,  0.6816999 ,  1.2509885 , -0.899361  ,
#         0.2511499 , -3.9400318 ,  3.2095208 ,  1.4688033 , -1.5865185 ,
#        -0.87137914, -1.224659  , -0.23414683, -1.946579  , -1.055157  ,
#         0.59367913,  3.7539284 , -2.1586318 , -1.9011242 , -1.7756962 ,
#         0.64730716,  1.1605623 ,  1.2610135 ,  1.4792057 , -1.3529465 ,
#         1.1468966 ,  1.0767351 , -0.8972961 ,  0.45825535,  1.337317  ,
#         1.7868032 , -0.5349264 ,  2.547089  ,  3.305139  , -0.47338557,
#         1.9667777 ], dtype=float32), 'glove_vec300_norm': 20.631742, 'is_oov': True, 'order': 4, 'tfidf_art': 0.08352059251909213, 'label3': 0, 'label4': 0, 'label5': 0, 'is_ne': True, 'ne_label': 'PERSON', 'liwc2015': [], 'negative_conc': 0, 'positive_conc': 1, 'weak_subj': 0, 'strong_subj': 1, 'MRCP_concretness_ratings': None, 'MRCP_Imagability_ratings': None, 'hyperbolic_terms': 0, 'attitude_markers': 0, 'kill_verbs': 0, 'bias_lexicon': 0, 'text_C1': 'beautiful', 'text_low_C1': 'beautiful', 'pos_C1': 'ADJ', 'lemma_C1': 'beautiful', 'lemma_low_C1': 'beautiful', 'tag_C1': 'JJ', 'dep_C1': 'amod', 'shape_C1': 'xxxx', 'is_alpha_C1': True, 'is_stop_C1': False, 'has_vec_C1': True, 'glove_vec300_C1': array([ 1.04209149e+00, -2.17558932e+00,  2.94323444e-01,  3.04307985e+00,
#        -2.62667298e+00,  1.52154946e+00, -1.45757461e+00,  1.15834236e+00,
#         2.75327969e+00,  1.69927657e-01,  2.11420894e+00,  5.67618787e-01,
#        -7.29837000e-01, -3.46303797e+00, -3.71549368e-01,  1.78159881e+00,
#        -4.86358225e-01,  2.41373062e-01, -9.76020098e-01, -1.99699879e+00,
#         7.37772465e-01, -9.60470676e-01, -2.45286560e+00,  3.52509832e+00,
#         2.24856424e+00, -2.05712104e+00, -1.43415308e+00,  3.47142053e+00,
#         5.47310889e-01, -1.61996675e+00, -7.93453574e-01,  7.19007850e-01,
#         2.46076536e+00, -2.49649465e-01, -1.12812662e+00, -5.49496055e-01,
#         3.42656112e+00, -1.56731606e+00, -3.22637939e+00,  7.37800062e-01,
#        -5.59149623e-01,  2.50340414e+00, -2.62753630e+00, -1.61706376e+00,
#         4.66870129e-01, -6.83374584e-01, -2.68598318e+00, -9.84853089e-01,
#        -1.95788419e+00,  9.39807892e-01,  3.87146622e-01,  2.10551596e+00,
#         2.22005844e+00, -2.12531710e+00, -2.21331310e+00, -4.41923022e-01,
#         6.05265617e+00,  1.65894949e+00, -7.25416064e-01, -1.10649514e+00,
#         6.15745783e-03, -1.42015171e+00,  2.45333362e+00, -2.48504519e-01,
#         2.61109161e+00, -2.31210399e+00,  6.75478029e+00, -1.54075718e+00,
#        -3.51919031e+00,  3.17375183e+00, -5.92801094e-01, -4.14915562e+00,
#        -9.52237606e-01,  1.13658404e+00,  2.05301240e-01, -2.24639869e+00,
#         1.61625552e+00, -1.25904191e+00,  8.08365464e-01,  3.82820177e+00,
#         1.18315327e+00, -1.80433226e+00,  2.44297886e+00, -6.95991337e-01,
#        -4.10978913e-01, -2.91799879e+00,  7.19997764e-01,  1.41642523e+00,
#        -6.45504653e-01, -9.00105357e-01, -1.95513892e+00, -3.32588720e+00,
#         9.94870901e-01, -1.62688643e-01,  1.19637445e-01,  4.08287001e+00],
#       dtype=float32), 'glove_vec300_norm_C1': 20.559483, 'is_oov_C1': True, 'order_C1': 2, 'is_ne_C1': False, 'ne_label_C1': None, 'tfidf_art_C1': 0.6027134447479771, 'liwc2015_C1': [21, 30, 31, 60, 61], 'negative_conc_C1': 0, 'positive_conc_C1': 1, 'weak_subj_C1': 0, 'strong_subj_C1': 1, 'MRCP_concretness_ratings_C1': 393, 'MRCP_Imagability_ratings_C1': 532, 'hyperbolic_terms_C1': 0, 'attitude_markers_C1': 0, 'kill_verbs_C1': 0, 'bias_lexicon_C1': 0, 'text_C2': 'law', 'text_low_C2': 'law', 'pos_C2': 'NOUN', 'lemma_C2': 'law', 'lemma_low_C2': 'law', 'tag_C2': 'NN', 'dep_C2': 'dobj', 'shape_C2': 'xxx', 'is_alpha_C2': True, 'is_stop_C2': False, 'has_vec_C2': True, 'glove_vec300_C2': array([ 2.5127182 ,  1.0801048 ,  0.55141866, -1.0467696 ,  1.4058485 ,
#         1.893547  ,  1.4644513 , -0.38699186,  0.5582211 ,  2.2739348 ,
#        -0.6482614 ,  1.1916167 ,  2.6871152 , -1.4116424 , -0.00630745,
#        -2.0520222 ,  0.13316554, -0.9806278 , -0.70416397,  0.5440371 ,
#         2.9542725 ,  1.4204788 ,  2.8996089 ,  0.44668955, -2.963249  ,
#         2.7618935 , -2.9747844 , -0.9640903 ,  3.7109625 , -0.429999  ,
#         0.10766715, -0.324152  , -0.06549639, -2.1600335 ,  0.3804598 ,
#        -1.9936872 ,  0.950349  , -1.4694576 , -4.0618324 , -2.6660106 ,
#         3.5937643 , -0.9165827 , -2.472858  , -1.6270965 , -0.3674165 ,
#        -0.32352   , -1.2343179 , -1.745507  ,  0.08969823,  1.908558  ,
#         0.08551818, -2.0132713 , -3.1785307 , -0.98710597, -3.0032306 ,
#         0.07831207,  2.4955766 ,  3.0445752 , -1.3814574 ,  2.920233  ,
#         0.72864485, -2.2533162 ,  0.13788372,  1.0061135 ,  0.39507318,
#        -1.5263107 ,  1.4342663 , -0.3147173 ,  0.26480955,  4.166658  ,
#        -0.4282336 , -1.5266174 ,  1.7268038 ,  4.1373615 , -3.609137  ,
# ...
#        -0.92807436,  0.41986376,  0.20895159, -3.5284746 ,  4.1553216 ,
#        -0.10229058, -0.42054412, -3.6451204 , -2.1910534 , -1.5603075 ,
#        -1.8391553 ,  1.8770895 , -1.2125645 , -0.83195275,  1.9980006 ,
#        -2.6080709 ,  0.82637537,  3.9294403 , -3.3858943 ,  0.8538753 ,
#         1.2283447 , -1.5260466 , -0.43841088,  4.0647273 , -2.3276825 ,
#         0.535577  ], dtype=float32), 'glove_vec300_norm_C1': 23.672306, 'is_oov_C1': True, 'order_C1': 13, 'is_ne_C1': False, 'ne_label_C1': None, 'tfidf_art_C1': 0.30135672237398853, 'liwc2015_C1': [100, 103], 'negative_conc_C1': 0, 'positive_conc_C1': 0, 'weak_subj_C1': 0, 'strong_subj_C1': 0, 'MRCP_concretness_ratings_C1': 331, 'MRCP_Imagability_ratings_C1': 351, 'hyperbolic_terms_C1': 0, 'attitude_markers_C1': 0, 'kill_verbs_C1': 0, 'bias_lexicon_C1': 0, 'text_C2': 'the', 'text_low_C2': 'the', 'pos_C2': 'DET', 'lemma_C2': 'the', 'lemma_low_C2': 'the', 'tag_C2': 'DT', 'dep_C2': 'det', 'shape_C2': 'xxx', 'is_alpha_C2': True, 'is_stop_C2': True, 'has_vec_C2': True, 'glove_vec300_C2': array([-5.25409794e+00, -4.89750862e-01,  4.22537923e-01, -1.02851880e+00,
#         1.77278519e+00, -9.78205740e-01, -1.22133124e+00, -1.35063934e+00,
#         2.45278955e+00, -9.21110272e-01, -4.41279221e+00,  2.29043126e+00,
#        -1.85853696e+00,  3.09981060e+00, -1.92174864e+00,  1.95247495e+00,
#        -2.64293313e-01, -1.22710133e+00, -2.53580713e+00, -2.15210271e+00,
#         4.65591311e-01,  1.27923024e+00, -1.97517955e+00, -2.01355052e+00,
#        -1.08770180e+00,  4.49661911e-03, -2.16987133e+00,  8.30426335e-01,
#         2.84035802e-02,  8.66622806e-01,  8.67135108e-01,  2.02666736e+00,
#        -4.70295238e+00, -3.44993711e-01,  8.19105744e-01, -1.48658895e+00,
#        -3.72531962e+00, -1.10799074e-01, -2.24842191e-01, -1.82444811e+00,
#         1.95989263e+00, -5.34255564e-01,  8.00660431e-01,  4.25918341e+00,
#         7.82516837e-01, -2.40664983e+00, -6.07852578e-01,  1.85790718e-01,
#        -4.93825793e-01,  1.98519483e-01,  2.93785262e+00, -1.50431171e-01,
#        -1.60526419e+00,  1.09245074e+00,  9.45551217e-01,  1.94304526e+00,
#         4.97116947e+00,  4.17919779e+00, -2.81802583e+00, -2.38081980e+00,
#         2.37379909e+00,  5.22310019e-01,  5.96814513e-01,  1.01918483e+00,
#         2.01096117e-01, -8.22336078e-01,  3.63565922e+00, -3.68057585e+00,
#        -1.34526348e+00,  5.79289436e-01, -2.74809122e+00,  3.48760080e+00,
#        -4.93094981e-01, -2.65587616e+00,  7.86337852e-02,  3.01738411e-01,
#        -7.37121105e-01,  1.83719969e+00, -3.40595913e+00,  7.35422254e-01,
#         1.03088522e+00,  5.57412505e-01,  5.44221449e+00, -1.74364090e+00,
#         2.40537333e+00, -2.65938520e+00, -8.92511606e-01,  2.30077052e+00,
#         4.23015690e+00,  2.27055192e-01, -2.83196068e+00, -1.51023364e+00,
#         9.39514399e-01,  5.63005447e+00,  2.72091079e+00,  1.19185555e+00],
#       dtype=float32), 'glove_vec300_norm_C2': 21.709099, 'is_oov_C2': True, 'order_C2': 14, 'is_ne_C2': False, 'ne_label_C2': None, 'tfidf_art_C2': 0.042508878943923634, 'liwc2015_C2': [1, 10], 'negative_conc_C2': 0, 'positive_conc_C2': 0, 'weak_subj_C2': 0, 'strong_subj_C2': 0, 'MRCP_concretness_ratings_C2': 237, 'MRCP_Imagability_ratings_C2': 209, 'hyperbolic_terms_C2': 0, 'attitude_markers_C2': 0, 'kill_verbs_C2': 0, 'bias_lexicon_C2': 0, 'text_C3': 'beautiful', 'text_low_C3': 'beautiful', 'pos_C3': 'ADJ', 'lemma_C3': 'beautiful', 'lemma_low_C3': 'beautiful', 'tag_C3': 'JJ', 'dep_C3': 'oprd', 'shape_C3': 'xxxx', 'is_alpha_C3': True, 'is_stop_C3': False, 'has_vec_C3': True, 'glove_vec300_C3': array([ 3.6286345 , -3.2528472 , -2.055689  , -1.0111427 ,  1.8296225 ,
#         4.6169786 ,  1.0401318 ,  1.8623377 ,  2.7874587 , -0.7497706 ,
#        -0.16312689,  0.25135118,  2.8778915 , -1.9743049 ,  1.8981558 ,
#        -0.04883525, -0.05835903,  0.8298068 , -2.219631  , -2.6750085 ,
#         0.8254297 , -3.2799323 , -3.56433   , -0.290472  ,  2.706402  ,
#        -1.7849991 ,  1.5153624 ,  1.4325851 ,  0.5199921 , -1.933123  ,
#         0.48734504, -1.3211417 ,  1.2503084 ,  1.1542636 , -0.01960075,
#        -1.9418465 ,  4.0212445 , -1.6852943 , -2.913999  ,  0.05174685,
#        -1.6757128 ,  1.373245  , -1.7117684 , -1.8507925 , -0.60204566,
#         0.4430859 , -0.9994416 , -0.9777164 , -0.9535779 , -2.8807817 ,
#        -1.1593952 ,  3.5669792 , -1.3622887 ,  0.41826522, -1.3039888 ,
#        -1.4233713 ,  4.5558114 ,  0.5060061 , -0.7545784 , -0.6600528 ,
#         0.24803373, -2.0225556 , -0.02094734, -0.0822117 ,  0.11692709,
#        -4.0672297 , -1.9908135 ,  3.2008862 , -0.31470478,  1.7597141 ,
#        -0.2188127 , -1.5157449 ,  1.1283746 ,  2.097743  , -0.4577508 ,
#        -2.867246  , -0.10811839, -2.6271918 , -0.8274614 ,  4.878867  ,
#         5.5572157 , -2.5854058 ,  3.0924869 , -1.0630391 ,  0.12632114,
#         2.624938  ,  1.1060444 ,  0.78893393,  0.44235697, -0.3100279 ,
#         1.5552671 ,  0.88822776, -1.4318109 ,  2.9790206 , -0.7506848 ,
#         4.500677  ], dtype=float32), 'glove_vec300_norm_C3': 20.427483, 'is_oov_C3': True, 'order_C3': 16, 'is_ne_C3': False, 'ne_label_C3': None, 'tfidf_art_C3': 0.6027134447479771, 'liwc2015_C3': [21, 30, 31, 60, 61], 'negative_conc_C3': 0, 'positive_conc_C3': 1, 'weak_subj_C3': 0, 'strong_subj_C3': 1, 'MRCP_concretness_ratings_C3': 393, 'MRCP_Imagability_ratings_C3': 532, 'hyperbolic_terms_C3': 0, 'attitude_markers_C3': 0, 'kill_verbs_C3': 0, 'bias_lexicon_C3': 0, 'text_C4': None, 'text_low_C4': None, 'pos_C4': None, 'lemma_C4': None, 'lemma_low_C4': None, 'tag_C4': None, 'dep_C4': None, 'shape_C4': None, 'is_alpha_C4': None, 'is_stop_C4': None, 'has_vec_C4': None, 'glove_vec300_C4': None, 'glove_vec300_norm_C4': None, 'is_oov_C4': None, 'order_C4': None, 'is_ne_C4': None, 'ne_label_C4': None, 'tfidf_art_C4': None, 'liwc2015_C4': None, 'negative_conc_C4': None, 'positive_conc_C4': None, 'weak_subj_C4': None, 'strong_subj_C4': None, 'MRCP_concretness_ratings_C4': None, 'MRCP_Imagability_ratings_C4': None, 'hyperbolic_terms_C4': None, 'attitude_markers_C4': None, 'kill_verbs_C4': None, 'bias_lexicon_C4': None, 'window_text': ['syntax', 'diction', 'repeating', 'the', 'word', 'beautiful', None, None, None], 'window_lemma': ['syntax', 'diction', 'repeat', 'the', 'word', 'beautiful', None, None, None], 'assertive_verbs': 0, 'factive_verbs': 0, 'report_verbs': 0, 'hedges': 0, 'boosters': 0, 'implicative_verbs': 0, 'assertive_verbs_C1': 0, 'factive_verbs_C1': 0, 'report_verbs_C1': 1, 'hedges_C1': 0, 'boosters_C1': 0, 'implicative_verbs_C1': 0, 'assertive_verbs_C2': 0, 'factive_verbs_C2': 0, 'report_verbs_C2': 0, 'hedges_C2': 0, 'boosters_C2': 0, 'implicative_verbs_C2': 0, 'assertive_verbs_C3': 0, 'factive_verbs_C3': 0, 'report_verbs_C3': 0, 'hedges_C3': 0, 'boosters_C3': 0, 'implicative_verbs_C3': 0, 'assertive_verbs_C4': 0, 'factive_verbs_C4': 0, 'report_verbs_C4': 0, 'hedges_C4': 0, 'boosters_C4': 0, 'implicative_verbs_C4': 0}
# {'text': 'beautiful', 'text_low': 'beautiful', 'pos': 'ADJ', 'lemma': 'beautiful', 'lemma_low': 'beautiful', 'tag': 'JJ', 'dep': 'oprd', 'shape': 'xxxx', 'is_alpha': True, 'is_stop': False, 'has_vec': True, 'glove_vec300': array([ 3.6286345 , -3.2528472 , -2.055689  , -1.0111427 ,  1.8296225 ,
#         4.6169786 ,  1.0401318 ,  1.8623377 ,  2.7874587 , -0.7497706 ,
#        -0.16312689,  0.25135118,  2.8778915 , -1.9743049 ,  1.8981558 ,
#        -0.04883525, -0.05835903,  0.8298068 , -2.219631  , -2.6750085 ,
#         0.8254297 , -3.2799323 , -3.56433   , -0.290472  ,  2.706402  ,
#        -1.7849991 ,  1.5153624 ,  1.4325851 ,  0.5199921 , -1.933123  ,
#         0.48734504, -1.3211417 ,  1.2503084 ,  1.1542636 , -0.01960075,
#        -1.9418465 ,  4.0212445 , -1.6852943 , -2.913999  ,  0.05174685,
#        -1.6757128 ,  1.373245  , -1.7117684 , -1.8507925 , -0.60204566,
#         0.4430859 , -0.9994416 , -0.9777164 , -0.9535779 , -2.8807817 ,
#        -1.1593952 ,  3.5669792 , -1.3622887 ,  0.41826522, -1.3039888 ,
#        -1.4233713 ,  4.5558114 ,  0.5060061 , -0.7545784 , -0.6600528 ,
#         0.24803373, -2.0225556 , -0.02094734, -0.0822117 ,  0.11692709,
#        -4.0672297 , -1.9908135 ,  3.2008862 , -0.31470478,  1.7597141 ,
#        -0.2188127 , -1.5157449 ,  1.1283746 ,  2.097743  , -0.4577508 ,
#        -2.867246  , -0.10811839, -2.6271918 , -0.8274614 ,  4.878867  ,
#         5.5572157 , -2.5854058 ,  3.0924869 , -1.0630391 ,  0.12632114,
#         2.624938  ,  1.1060444 ,  0.78893393,  0.44235697, -0.3100279 ,
#         1.5552671 ,  0.88822776, -1.4318109 ,  2.9790206 , -0.7506848 ,
#         4.500677  ], dtype=float32), 'glove_vec300_norm': 20.427483, 'is_oov': True, 'order': 16, 'tfidf_art': 0.6027134447479771, 'label3': 0, 'label4': 0, 'label5': 0, 'is_ne': False, 'ne_label': None, 'liwc2015': [21, 30, 31, 60, 61], 'negative_conc': 0, 'positive_conc': 1, 'weak_subj': 0, 'strong_subj': 1, 'MRCP_concretness_ratings': 393, 'MRCP_Imagability_ratings': 532, 'hyperbolic_terms': 0, 'attitude_markers': 0, 'kill_verbs': 0, 'bias_lexicon': 0, 'text_C1': 'the', 'text_low_C1': 'the', 'pos_C1': 'DET', 'lemma_C1': 'the', 'lemma_low_C1': 'the', 'tag_C1': 'DT', 'dep_C1': 'det', 'shape_C1': 'xxx', 'is_alpha_C1': True, 'is_stop_C1': True, 'has_vec_C1': True, 'glove_vec300_C1': array([-5.25409794e+00, -4.89750862e-01,  4.22537923e-01, -1.02851880e+00,
#         1.77278519e+00, -9.78205740e-01, -1.22133124e+00, -1.35063934e+00,
#         2.45278955e+00, -9.21110272e-01, -4.41279221e+00,  2.29043126e+00,
#        -1.85853696e+00,  3.09981060e+00, -1.92174864e+00,  1.95247495e+00,
#        -2.64293313e-01, -1.22710133e+00, -2.53580713e+00, -2.15210271e+00,
#         4.65591311e-01,  1.27923024e+00, -1.97517955e+00, -2.01355052e+00,
#        -1.08770180e+00,  4.49661911e-03, -2.16987133e+00,  8.30426335e-01,
#         2.84035802e-02,  8.66622806e-01,  8.67135108e-01,  2.02666736e+00,
#        -4.70295238e+00, -3.44993711e-01,  8.19105744e-01, -1.48658895e+00,
#        -3.72531962e+00, -1.10799074e-01, -2.24842191e-01, -1.82444811e+00,
#         1.95989263e+00, -5.34255564e-01,  8.00660431e-01,  4.25918341e+00,
#         7.82516837e-01, -2.40664983e+00, -6.07852578e-01,  1.85790718e-01,
#        -4.93825793e-01,  1.98519483e-01,  2.93785262e+00, -1.50431171e-01,
#        -1.60526419e+00,  1.09245074e+00,  9.45551217e-01,  1.94304526e+00,
#         4.97116947e+00,  4.17919779e+00, -2.81802583e+00, -2.38081980e+00,
#         2.37379909e+00,  5.22310019e-01,  5.96814513e-01,  1.01918483e+00,
#         2.01096117e-01, -8.22336078e-01,  3.63565922e+00, -3.68057585e+00,
#        -1.34526348e+00,  5.79289436e-01, -2.74809122e+00,  3.48760080e+00,
#        -4.93094981e-01, -2.65587616e+00,  7.86337852e-02,  3.01738411e-01,
#        -7.37121105e-01,  1.83719969e+00, -3.40595913e+00,  7.35422254e-01,
#         1.03088522e+00,  5.57412505e-01,  5.44221449e+00, -1.74364090e+00,
#         2.40537333e+00, -2.65938520e+00, -8.92511606e-01,  2.30077052e+00,
#         4.23015690e+00,  2.27055192e-01, -2.83196068e+00, -1.51023364e+00,
#         9.39514399e-01,  5.63005447e+00,  2.72091079e+00,  1.19185555e+00],
#       dtype=float32), 'glove_vec300_norm_C1': 21.709099, 'is_oov_C1': True, 'order_C1': 14, 'is_ne_C1': False, 'ne_label_C1': None, 'tfidf_art_C1': 0.042508878943923634, 'liwc2015_C1': [1, 10], 'negative_conc_C1': 0, 'positive_conc_C1': 0, 'weak_subj_C1': 0, 'strong_subj_C1': 0, 'MRCP_concretness_ratings_C1': 237, 'MRCP_Imagability_ratings_C1': 209, 'hyperbolic_terms_C1': 0, 'attitude_markers_C1': 0, 'kill_verbs_C1': 0, 'bias_lexicon_C1': 0, 'text_C2': 'word', 'text_low_C2': 'word', 'pos_C2': 'NOUN', 'lemma_C2': 'word', 'lemma_low_C2': 'word', 'tag_C2': 'NN', 'dep_C2': 'dobj', 'shape_C2': 'xxxx', 'is_alpha_C2': True, 'is_stop_C2': False, 'has_vec_C2': True, 'glove_vec300_C2': array([ 3.6629713e-01, -1.6044074e-01, -9.1364527e-01,  1.2391781e+00,
#         7.8434318e-01,  3.3046517e+00,  2.1112063e+00, -5.8893150e-01,
#         1.6030126e+00,  1.1624476e+00, -3.2070601e-01, -1.3571517e+00,
#         4.2527962e+00, -4.5721927e+00,  1.5652833e+00,  1.9408590e+00,
#         4.4368964e-01,  2.9255502e+00, -1.5336769e+00, -9.7931135e-01,
#        -5.1213491e-01,  2.0350919e+00,  5.0668597e-01, -2.2469819e-01,
#        -3.9306507e+00,  1.5655053e+00, -1.5064306e+00,  1.2800046e+00,
#         2.2144990e+00, -3.5668778e+00, -1.0735186e+00, -2.6370686e-01,
#        -7.3409081e-04, -2.6924691e+00, -7.7045631e-01,  3.5493598e+00,
#         2.1140509e+00, -2.4577980e+00, -2.4389443e+00,  3.5241765e-01,
#         2.1894722e+00, -6.2807590e-02, -2.3108430e+00, -1.0157971e+00,
#         1.7610015e+00, -7.6045716e-01,  6.3046998e-01, -8.9320982e-01,
#        -1.3448389e+00,  8.8857520e-01,  1.3134285e+00, -1.8409660e+00,
#         8.0212444e-02, -1.2538047e+00, -1.5957661e+00,  8.4130418e-01,
#         2.0433209e+00,  2.4284477e+00,  6.4032614e-01,  2.1896377e+00,
#         1.5541042e+00, -7.2351426e-02,  8.2371265e-01,  1.0900377e+00,
#         1.7589772e+00, -3.4931308e-01,  7.1247405e-01, -2.5538201e+00,
#        -3.2058892e+00,  9.3468118e-01, -3.6073132e+00, -3.6104085e+00,
#        -4.9680898e-01,  9.3456000e-02, -2.7936132e+00,  3.3328289e-01,
#        -7.2548151e-02, -2.5608263e+00, -1.4323781e+00,  3.2008976e-01,
#         2.8422070e-01, -2.9690700e+00, -1.1099056e+00,  3.1620848e+00,
#        -4.3317187e-01, -2.7996540e+00,  2.0636179e+00,  2.2947032e+00,
#        -1.0228144e+00, -1.3038105e+00, -9.3506640e-01,  1.1806762e+00,
#         1.7866558e-01,  1.0154972e+00,  1.3028306e+00, -4.4507563e-01],
#       dtype=float32), 'glove_vec300_norm_C2': 17.959375, 'is_oov_C2': True, 'order_C2': 15, 'is_ne_C2': False, 'ne_label_C2': None, 'tfidf_art_C2': 0.23249786817416734, 'liwc2015_C2': [], 'negative_conc_C2': 0, 'positive_conc_C2': 0, 'weak_subj_C2': 0, 'strong_subj_C2': 0, 'MRCP_concretness_ratings_C2': None, 'MRCP_Imagability_ratings_C2': None, 'hyperbolic_terms_C2': 0, 'attitude_markers_C2': 0, 'kill_verbs_C2': 0, 'bias_lexicon_C2': 0, 'text_C3': None, 'text_low_C3': None, 'pos_C3': None, 'lemma_C3': None, 'lemma_low_C3': None, 'tag_C3': None, 'dep_C3': None, 'shape_C3': None, 'is_alpha_C3': None, 'is_stop_C3': None, 'has_vec_C3': None, 'glove_vec300_C3': None, 'glove_vec300_norm_C3': None, 'is_oov_C3': None, 'order_C3': None, 'is_ne_C3': None, 'ne_label_C3': None, 'tfidf_art_C3': None, 'liwc2015_C3': None, 'negative_conc_C3': None, 'positive_conc_C3': None, 'weak_subj_C3': None, 'strong_subj_C3': None, 'MRCP_concretness_ratings_C3': None, 'MRCP_Imagability_ratings_C3': None, 'hyperbolic_terms_C3': None, 'attitude_markers_C3': None, 'kill_verbs_C3': None, 'bias_lexicon_C3': None, 'text_C4': None, 'text_low_C4': None, 'pos_C4': None, 'lemma_C4': None, 'lemma_low_C4': None, 'tag_C4': None, 'dep_C4': None, 'shape_C4': None, 'is_alpha_C4': None, 'is_stop_C4': None, 'has_vec_C4': None, 'glove_vec300_C4': None, 'glove_vec300_norm_C4': None, 'is_oov_C4': None, 'order_C4': None, 'is_ne_C4': None, 'ne_label_C4': None, 'tfidf_art_C4': None, 'liwc2015_C4': None, 'negative_conc_C4': None, 'positive_conc_C4': None, 'weak_subj_C4': None, 'strong_subj_C4': None, 'MRCP_concretness_ratings_C4': None, 'MRCP_Imagability_ratings_C4': None, 'hyperbolic_terms_C4': None, 'attitude_markers_C4': None, 'kill_verbs_C4': None, 'bias_lexicon_C4': None, 'window_text': ['diction', 'repeating', 'the', 'word', 'beautiful', None, None, None, None], 'window_lemma': ['diction', 'repeat', 'the', 'word', 'beautiful', None, None, None, None], 'assertive_verbs': 0, 'factive_verbs': 0, 'report_verbs': 0, 'hedges': 0, 'boosters': 0, 'implicative_verbs': 0, 'assertive_verbs_C1': 0, 'factive_verbs_C1': 0, 'report_verbs_C1': 0, 'hedges_C1': 0, 'boosters_C1': 0, 'implicative_verbs_C1': 0, 'assertive_verbs_C2': 0, 'factive_verbs_C2': 0, 'report_verbs_C2': 0, 'hedges_C2': 0, 'boosters_C2': 0, 'implicative_verbs_C2': 0, 'assertive_verbs_C3': 0, 'factive_verbs_C3': 0, 'report_verbs_C3': 0, 'hedges_C3': 0, 'boosters_C3': 0, 'implicative_verbs_C3': 0, 'assertive_verbs_C4': 0, 'factive_verbs_C4': 0, 'report_verbs_C4': 0, 'hedges_C4': 0, 'boosters_C4': 0, 'implicative_verbs_C4': 0}

# %%
dt.columns
# Out:
# Index(['sentence', 'outlet', 'topic', 'type', 'biased_words2', 'spacy_lg',
#        'spacy_lg_dict', 'article'],
#       dtype='object')

# %%
#dt = dt[['sentence','outlet','topic','type','num_sent','article','biased_words','spacy_lg','spacy_lg_dict']]

rows = []
dt.apply(lambda row: len([rows.append([row['sentence'],
                                               row['outlet'],
                                               row['topic'],
                                               row['type'],
                                               row['biased_words2'],
                                               row['spacy_lg'],
                                               row['article'], t]) for t in row.spacy_lg_dict]), axis=1)
dt_ungrouped = pd.DataFrame(rows, columns=['sentence', 'outlet', 'topic', 'type', 'biased_words2', 'spacy_lg', 'article', 'spacy_lg_dict'])

print('The length of the initial datset with sentences is:', len(dt),
      ', the length of the exposed datset with words is:', len(dt_ungrouped))
# Out:
# The length of the initial datset with sentences is: 3673 , the length of the exposed datset with words is: 110269

# %%
dt.head(2)
# Out:
#                                             sentence  ...                                            article
# 0  "Orange Is the New Black" star Yael Stone is r...  ...  "Orange Is the New Black" star Yael Stone is r...
# 1  "We have one beautiful law," Trump recently sa...  ...  "We have one beautiful law," Trump recently sa...
#
# [2 rows x 8 columns]

# %%
dt_ungrouped.head(2)
# Out:
#                                             sentence  ...                                      spacy_lg_dict
# 0  "Orange Is the New Black" star Yael Stone is r...  ...  {'text': 'Orange', 'text_low': 'orange', 'pos'...
# 1  "Orange Is the New Black" star Yael Stone is r...  ...  {'text': 'Is', 'text_low': 'is', 'pos': 'AUX',...
#
# [2 rows x 8 columns]

# %% [markdown]
# ### 3.2 Create a column for each feature

# %%
features = list(dt_ungrouped['spacy_lg_dict'][0].keys())

for feat in features:
    dt_ungrouped[feat] = dt_ungrouped["spacy_lg_dict"].apply(lambda x: x[feat])

dt_ungrouped.head(2)
# Out:
#                                             sentence  ... implicative_verbs_C4
# 0  "Orange Is the New Black" star Yael Stone is r...  ...                    0
# 1  "Orange Is the New Black" star Yael Stone is r...  ...                    0
#
# [2 rows x 188 columns]

# %% [markdown]
# ### 3.3 Expand categorical features (one-hot encoding)

# %% [markdown]
# Categorical features:
# - liwc2015
# - pos
# - dep
# - ne_label

# %%
dt_ungrouped['liwc2015_C1'] = [[] if x is x==None else x for x in dt_ungrouped['liwc2015_C1']]
dt_ungrouped['liwc2015_C2'] = [[] if x is x==None else x for x in dt_ungrouped['liwc2015_C2']]
dt_ungrouped['liwc2015_C3'] = [[] if x is x==None else x for x in dt_ungrouped['liwc2015_C3']]
dt_ungrouped['liwc2015_C4'] = [[] if x is x==None else x for x in dt_ungrouped['liwc2015_C4']]

# expand liwc to binary features
for i, row in liwc2015_codes.iterrows():
    print(row.code, row.short_description)
    # for token
    dt_ungrouped[row.short_description] = dt_ungrouped.liwc2015.apply(lambda x: 1 if row.code in x else 0)
    # for c1
    c1 = row.short_description + '_C1'
    dt_ungrouped[c1] = dt_ungrouped.liwc2015_C1.apply(lambda x: 1 if row.code in x else 0)
    # for c2
    c2 = row.short_description + '_C2'
    dt_ungrouped[c2] = dt_ungrouped.liwc2015_C2.apply(lambda x: 1 if row.code in x else 0)
    # for c3
    c3 = row.short_description + '_C3'
    dt_ungrouped[c3] = dt_ungrouped.liwc2015_C3.apply(lambda x: 1 if row.code in x else 0)
    # for c4
    c4 = row.short_description + '_C4'
    dt_ungrouped[c4] = dt_ungrouped.liwc2015_C4.apply(lambda x: 1 if row.code in x else 0)
# Out:
# 30 affect
# 31 posemo
# 32 negemo
# 33 anx
# 34 anger
# 35 sad
# 40 social
# 41 family
# 42 friend
# 43 female
# 44 male
# 50 cogproc
# 51 insight
# 52 cause
# 53 discrep
# 54 tentat
# 55 certain
# 56 differ
# 60 percept
# 61 see
# 62 hear
# 63 feel
# 70 bio
# 71 body
# 72 health
# 73 sexual
# 74 ingest
# 80 drives
# 81 affiliation
# 82 achieve
# 83 power
# 84 reward
# 85 risk
# 90 focuspast
# 91 focuspresent
# 92 focusfuture
# 100 relativ
# 101 motion
# 102 space
# 103 time
# 110 work
# 111 leisure
# 112 home
# 113 money
# 114 relig
# 115 death
# 120 informal
# 121 swear
# 122 netspeak
# 123 assent
# 124 nonflu
# 125 filler

# %%
pos_token = pd.get_dummies(dt_ungrouped.pos, prefix='pos')
pos_c1 = pd.get_dummies(dt_ungrouped.pos_C1, prefix='pos')
pos_c2 = pd.get_dummies(dt_ungrouped.pos_C2, prefix='pos')
pos_c3 = pd.get_dummies(dt_ungrouped.pos_C3, prefix='pos')
pos_c4 = pd.get_dummies(dt_ungrouped.pos_C4, prefix='pos')

pos_c1 = pos_c1.add_suffix('_C1')
pos_c2 = pos_c2.add_suffix('_C2')
pos_c3 = pos_c3.add_suffix('_C3')
pos_c4 = pos_c4.add_suffix('_C4')

dt_ungrouped = pd.merge(dt_ungrouped, pos_token, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, pos_c1, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, pos_c2, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, pos_c3, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, pos_c4, left_index=True, right_index=True, how='left')

# %%
dep_token = pd.get_dummies(dt_ungrouped.dep, prefix='dep')
dep_c1 = pd.get_dummies(dt_ungrouped.dep_C1, prefix='dep')
dep_c2 = pd.get_dummies(dt_ungrouped.dep_C2, prefix='dep')
dep_c3 = pd.get_dummies(dt_ungrouped.dep_C3, prefix='dep')
dep_c4 = pd.get_dummies(dt_ungrouped.dep_C4, prefix='dep')
dep_c1 = dep_c1.add_suffix('_C1')
dep_c2 = dep_c2.add_suffix('_C2')
dep_c3 = dep_c3.add_suffix('_C3')
dep_c4 = dep_c4.add_suffix('_C4')

dt_ungrouped = pd.merge(dt_ungrouped, dep_token, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, dep_c1, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, dep_c2, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, dep_c3, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, dep_c4, left_index=True, right_index=True, how='left')

# %%
ne_token = pd.get_dummies(dt_ungrouped.ne_label, prefix='ne')
ne_c1 = pd.get_dummies(dt_ungrouped.ne_label_C1, prefix='ne')
ne_c2 = pd.get_dummies(dt_ungrouped.ne_label_C2, prefix='ne')
ne_c3 = pd.get_dummies(dt_ungrouped.ne_label_C3, prefix='ne')
ne_c4 = pd.get_dummies(dt_ungrouped.ne_label_C4, prefix='ne')
ne_c1 = ne_c1.add_suffix('_C1')
ne_c2 = ne_c2.add_suffix('_C2')
ne_c3 = ne_c3.add_suffix('_C3')
ne_c4 = ne_c4.add_suffix('_C4')

dt_ungrouped = pd.merge(dt_ungrouped, ne_token, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, ne_c1, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, ne_c2, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, ne_c3, left_index=True, right_index=True, how='left')
dt_ungrouped = pd.merge(dt_ungrouped, ne_c4, left_index=True, right_index=True, how='left')

# %% [markdown]
# ### 3.4 Combine context features into a collective feature describing 4 words around the word of interest

# %%
binary_features_for_training = [
 'negative_conc',
 'positive_conc',
 'weak_subj',
 'strong_subj',
 'hyperbolic_terms',
 'attitude_markers',
 'kill_verbs',
 'bias_lexicon',
 'assertive_verbs',
 'factive_verbs',
 'report_verbs',
 'implicative_verbs',
 'hedges',
 'boosters',
 'affect ',
 'posemo ',
 'negemo ',
 'anx ',
 'anger ',
 'sad ',
 'social ',
 'family ',
 'friend ',
 'female ',
 'male ',
 'cogproc ',
 'insight ',
 'cause ',
 'discrep ',
 'tentat ',
 'certain ',
 'differ ',
 'percept ',
 'see ',
 'hear ',
 'feel ',
 'bio ',
 'body ',
 'health ',
 'sexual ',
 'ingest ',
 'drives ',
 'affiliation ',
 'achieve ',
 'power ',
 'reward ',
 'risk ',
 'focuspast ',
 'focuspresent ',
 'focusfuture ',
 'relativ ',
 'motion ',
 'space ',
 'time ',
 'work ',
 'leisure ',
 'home ',
 'money ',
 'relig ',
 'death ',
 'informal ',
 'swear ',
 'netspeak ',
 'assent ',
 'nonflu ',
 'filler ',
 'pos_ADJ',
 'pos_ADP',
 'pos_ADV',
 'pos_AUX',
 'pos_DET',
 'pos_INTJ',
 'pos_NOUN',
 'pos_PRON',
 'pos_PROPN',
 'pos_SCONJ',
 'pos_VERB',
 'pos_X',
 'dep_ROOT',
 'dep_acl',
 'dep_acomp',
 'dep_advcl',
 'dep_advmod',
 'dep_agent',
 'dep_amod',
 'dep_appos',
 'dep_attr',
 'dep_aux',
 'dep_auxpass',
 #'dep_case',
 'dep_cc',
 'dep_ccomp',
 'dep_compound',
 'dep_conj',
 'dep_csubj',
 'dep_dative',
 'dep_dep',
 'dep_det',
 'dep_dobj',
 'dep_expl',
 'dep_intj',
 'dep_mark',
 #'dep_meta',
 'dep_neg',
 'dep_nmod',
 'dep_npadvmod',
 'dep_nsubj',
 'dep_nsubjpass',
 'dep_nummod',
 'dep_oprd',
 'dep_parataxis',
 'dep_pcomp',
 'dep_pobj',
 'dep_poss',
 'dep_preconj',
 'dep_predet',
 'dep_prep',
 'dep_prt',
 'dep_punct',
 'dep_quantmod',
 'dep_relcl',
 'dep_xcomp',
 'ne_CARDINAL',
 'ne_DATE',
 'ne_EVENT',
 'ne_FAC',
 'ne_GPE',
 'ne_LAW',
 'ne_LOC',
 'ne_MONEY',
 'ne_NORP',
 'ne_ORDINAL',
 'ne_ORG',
 'ne_PERCENT',
 'ne_PERSON',
 'ne_PRODUCT',
 'ne_QUANTITY',
 'ne_TIME',
 'ne_WORK_OF_ART']

# 'ne_LANGUAGE' - separately because for some reason ne_LANGUAGE_C1 and ne_LANGUAGE_C2 aren't in the list

# %%
for feat in binary_features_for_training:
  if feat not in dt_ungrouped.columns:
    print(feat)

# %%
for feat in binary_features_for_training:
    new_feat = feat + '_context'
    f1, f2, f3, f4 = feat + '_C1', feat + '_C2', feat + '_C3', feat + '_C4'
    dt_ungrouped[new_feat] = dt_ungrouped.apply(lambda row: 1 if 1 in [row[f1],row[f2],row[f3],row[f4]] else 0,
                                                axis=1)

# 'ne_LANGUAGE' - separately because for some reason ne_LANGUAGE_C1 and ne_LANGUAGE_C2 aren't in the list
new_feat = 'ne_LANGUAGE' + '_context'
f3, f4 = 'ne_LANGUAGE' + '_C3', 'ne_LANGUAGE' + '_C4'
dt_ungrouped[new_feat] = dt_ungrouped.apply(lambda row: 1 if 1 in [row[f3],row[f4]] else 0,
                                            axis=1)

# %% [markdown]
# ### 3.5 Final dataset

# %%
dt_clean = dt_ungrouped[['sentence', # not a feature for training
 'outlet', # not a feature for training
 'topic', # not a feature for training
 'type', # not a feature for training
 #'num_sent', # not a feature for training
 'article', # not a feature for training
 'biased_words2',
 #'biased_words3', # not a feature for training
 #'biased_words4', # not a feature for training
 #'biased_words5', # not a feature for training
 'text', # not a feature for training
 'text_low', # not a feature for training
 'pos', # not a feature for training
 'lemma', # not a feature for training
 'lemma_low', # not a feature for training
 'tag', # not a feature for training
 'dep', # not a feature for training
 'is_stop', # not a feature for training
 'glove_vec300_norm',
 'order', # not a feature for training
 'tfidf_art',
 'label3', # not a feature for training
 'label4', # not a feature for training
 'label5', # not a feature for training
 'is_ne', # not a feature for training
 'ne_label', # not a feature for training
 'negative_conc',
 'positive_conc',
 'weak_subj',
 'strong_subj',
 'MRCP_concretness_ratings',
 'MRCP_Imagability_ratings',
 'hyperbolic_terms',
 'attitude_markers',
 'kill_verbs',
 'bias_lexicon',
 'assertive_verbs',
 'factive_verbs',
 'report_verbs',
 'implicative_verbs',
 'hedges',
 'boosters',
 'affect ',
 'posemo ',
 'negemo ',
 'anx ',
 'anger ',
 'sad ',
 'social ',
 'family ',
 'friend ',
 'female ',
 'male ',
 'cogproc ',
 'insight ',
 'cause ',
 'discrep ',
 'tentat ',
 'certain ',
 'differ ',
 'percept ',
 'see ',
 'hear ',
 'feel ',
 'bio ',
 'body ',
 'health ',
 'sexual ',
 'ingest ',
 'drives ',
 'affiliation ',
 'achieve ',
 'power ',
 'reward ',
 'risk ',
 'focuspast ',
 'focuspresent ',
 'focusfuture ',
 'relativ ',
 'motion ',
 'space ',
 'time ',
 'work ',
 'leisure ',
 'home ',
 'money ',
 'relig ',
 'death ',
 'informal ',
 'swear ',
 'netspeak ',
 'assent ',
 'nonflu ',
 'filler ',
 'pos_ADJ',
 'pos_ADP',
 'pos_ADV',
 'pos_AUX',
 'pos_DET',
 'pos_INTJ',
 'pos_NOUN',
 'pos_PRON',
 'pos_PROPN',
 'pos_SCONJ',
 'pos_VERB',
 'pos_X',
 'dep_ROOT',
 'dep_acl',
 'dep_acomp',
 'dep_advcl',
 'dep_advmod',
 'dep_agent',
 'dep_amod',
 'dep_appos',
 'dep_attr',
 'dep_aux',
 'dep_auxpass',
 #'dep_case',
 'dep_cc',
 'dep_ccomp',
 'dep_compound',
 'dep_conj',
 'dep_csubj',
 'dep_dative',
 'dep_dep',
 'dep_det',
 'dep_dobj',
 'dep_expl',
 'dep_intj',
 'dep_mark',
 #'dep_meta',
 'dep_neg',
 'dep_nmod',
 'dep_npadvmod',
 'dep_nsubj',
 'dep_nsubjpass',
 'dep_nummod',
 'dep_oprd',
 'dep_parataxis',
 'dep_pcomp',
 'dep_pobj',
 'dep_poss',
 'dep_preconj',
 'dep_predet',
 'dep_prep',
 'dep_prt',
 'dep_punct',
 'dep_quantmod',
 'dep_relcl',
 'dep_xcomp',
 'ne_CARDINAL',
 'ne_DATE',
 'ne_EVENT',
 'ne_FAC',
 'ne_GPE',
 'ne_LANGUAGE',
 'ne_LAW',
 'ne_LOC',
 'ne_MONEY',
 'ne_NORP',
 'ne_ORDINAL',
 'ne_ORG',
 'ne_PERCENT',
 'ne_PERSON',
 'ne_PRODUCT',
 'ne_QUANTITY',
 'ne_TIME',
 'ne_WORK_OF_ART',
 'negative_conc_context',
 'positive_conc_context',
 'weak_subj_context',
 'strong_subj_context',
 'hyperbolic_terms_context',
 'attitude_markers_context',
 'kill_verbs_context',
 'bias_lexicon_context',
 'assertive_verbs_context',
 'factive_verbs_context',
 'report_verbs_context',
 'implicative_verbs_context',
 'hedges_context',
 'boosters_context',
 'affect _context',
 'posemo _context',
 'negemo _context',
 'anx _context',
 'anger _context',
 'sad _context',
 'social _context',
 'family _context',
 'friend _context',
 'female _context',
 'male _context',
 'cogproc _context',
 'insight _context',
 'cause _context',
 'discrep _context',
 'tentat _context',
 'certain _context',
 'differ _context',
 'percept _context',
 'see _context',
 'hear _context',
 'feel _context',
 'bio _context',
 'body _context',
 'health _context',
 'sexual _context',
 'ingest _context',
 'drives _context',
 'affiliation _context',
 'achieve _context',
 'power _context',
 'reward _context',
 'risk _context',
 'focuspast _context',
 'focuspresent _context',
 'focusfuture _context',
 'relativ _context',
 'motion _context',
 'space _context',
 'time _context',
 'work _context',
 'leisure _context',
 'home _context',
 'money _context',
 'relig _context',
 'death _context',
 'informal _context',
 'swear _context',
 'netspeak _context',
 'assent _context',
 'nonflu _context',
 'filler _context',
 'pos_ADJ_context',
 'pos_ADP_context',
 'pos_ADV_context',
 'pos_AUX_context',
 'pos_DET_context',
 'pos_INTJ_context',
 'pos_NOUN_context',
 'pos_PRON_context',
 'pos_PROPN_context',
 'pos_SCONJ_context',
 'pos_VERB_context',
 'pos_X_context',
 'dep_ROOT_context',
 'dep_acl_context',
 'dep_acomp_context',
 'dep_advcl_context',
 'dep_advmod_context',
 'dep_agent_context',
 'dep_amod_context',
 'dep_appos_context',
 'dep_attr_context',
 'dep_aux_context',
 'dep_auxpass_context',
 #'dep_case_context',
 'dep_cc_context',
 'dep_ccomp_context',
 'dep_compound_context',
 'dep_conj_context',
 'dep_csubj_context',
 'dep_dative_context',
 'dep_dep_context',
 'dep_det_context',
 'dep_dobj_context',
 'dep_expl_context',
 'dep_intj_context',
 'dep_mark_context',
 #'dep_meta_context',
 'dep_neg_context',
 'dep_nmod_context',
 'dep_npadvmod_context',
 'dep_nsubj_context',
 'dep_nsubjpass_context',
 'dep_nummod_context',
 'dep_oprd_context',
 'dep_parataxis_context',
 'dep_pcomp_context',
 'dep_pobj_context',
 'dep_poss_context',
 'dep_preconj_context',
 'dep_predet_context',
 'dep_prep_context',
 'dep_prt_context',
 'dep_punct_context',
 'dep_quantmod_context',
 'dep_relcl_context',
 'dep_xcomp_context',
 'ne_CARDINAL_context',
 'ne_DATE_context',
 'ne_EVENT_context',
 'ne_FAC_context',
 'ne_GPE_context',
 'ne_LAW_context',
 'ne_LOC_context',
 'ne_MONEY_context',
 'ne_NORP_context',
 'ne_ORDINAL_context',
 'ne_ORG_context',
 'ne_PERCENT_context',
 'ne_PERSON_context',
 'ne_PRODUCT_context',
 'ne_QUANTITY_context',
 'ne_TIME_context',
 'ne_WORK_OF_ART_context',
 'ne_LANGUAGE_context']]

# %%
print('number of observations:', len(dt_clean))
print('number of unique words:', len(set(dt_clean['text_low'])))
print('number of features:', len(list(dt_clean))-23)
print('number of biased words (t=3):', len(dt_clean[dt_clean['label3']==1]))
print('number of biased words (t=4):', len(dt_clean[dt_clean['label4']==1]))
print('number of biased words (t=5):', len(dt_clean[dt_clean['label5']==1]))
# Out:
# number of observations: 110269
# number of unique words: 12523
# number of features: 277
# number of biased words (t=3): 3736
# number of biased words (t=4): 3736
# number of biased words (t=5): 3736

# %%
dt_final = dt_clean[dt_clean['is_stop']==False]
print('number of observations:', len(dt_final))
print('number of unique words:', len(set(dt_final['text_low'])))
print('number of features:', len(list(dt_final))-23)
print('number of biased words (t=3):', len(dt_final[dt_final['label3']==1]))
print('number of biased words (t=4):', len(dt_final[dt_final['label4']==1]))
print('number of biased words (t=5):', len(dt_final[dt_final['label5']==1]))
# Out:
# number of observations: 65745
# number of unique words: 12253
# number of features: 277
# number of biased words (t=3): 3416
# number of biased words (t=4): 3416
# number of biased words (t=5): 3416

# %%
#dt_clean.to_excel('dt_clean.xlsx')
#dt_final.to_excel('data/dt_final_SG1.xlsx')
dt_final.to_excel('data/dt_final_SG2.xlsx')
